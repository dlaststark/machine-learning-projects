# %% [markdown]
# ## Import libraries

# %%
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

import gc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_absolute_percentage_error

from catboost import CatBoostRegressor

np.random.seed(42)

# %% [markdown]
# ## Load source datasets

# %%
train = pd.read_csv("../input/renew-data-preprocess/train.csv")
print(f"train: {train.shape}")
train.head()
# Out:
# train: (909604, 31)
#    active_power_calculated_by_converter  ambient_temperature  generator_speed  \
# 0                              0.408318             0.613994         0.915144
# 1                              0.209554             0.171368         0.732948
# 2                              0.651765             0.259741         0.947977
# 3                              0.030747             0.536150         0.607514
# 4                              0.296757             0.609877         0.826204
#
#    generator_winding_temp_max  grid_power10min_average  nc1_inside_temp  \
# 0                    0.386890                 0.458951         0.497983
# 1                    0.325640                 0.222778         0.510990
# 2                    0.341945                 0.682361         0.007322
# 3                    0.144305                 0.007162         0.554918
# 4                    0.371417                 0.299511         0.510555
#
#    nacelle_temp  reactice_power_calculated_by_converter  wind_speed_raw  \
# 0      0.478286                                0.545956        0.325693
# 1      0.516904                                0.483897        0.241944
# 2      0.071699                                0.651816        0.380506
# 3      0.514037                                0.456620        0.167626
# 4      0.477103                                0.540858        0.288687
#
#    wind_speed_turbulence  ...  power_ratio5  power_ratio6  power_ratio7  \
# 0               0.057063  ...      0.000003      0.002194      0.000009
# 1               0.049192  ...      0.000003      0.002194      0.000009
# 2               0.065268  ...      0.000004      0.002194      0.000009
# 3               0.079784  ...      0.000015      0.002217      0.000026
# 4               0.036295  ...      0.000004      0.002194      0.000009
#
#    nacelle_temp_ratio  nacelle_temp_diff  nacelle_ambient_temp_diff  \
# 0            0.259173           0.367857                   0.180091
# 1            0.283021           0.402985                   0.834179
# 2            0.921857           0.727568                   0.241233
# 3            0.221799           0.307781                   0.325729
# 4            0.240646           0.340027                   0.184544
#
#    nacelle_ambient_temp_ratio  temp_avg  wind_direction_sin  \
# 0                    0.054556  0.595187            0.008963
# 1                    0.526251  0.430147            0.065048
# 2                    0.087251  0.218837            0.998067
# 3                    0.102320  0.418384            0.999429
# 4                    0.055867  0.586000            0.138666
#
#    wind_direction_cos
# 0            0.594250
# 1            0.746616
# 2            0.543929
# 3            0.523896
# 4            0.845604
#
# [5 rows x 31 columns]

# %%
test = pd.read_csv("../input/renew-data-preprocess/test.csv")
print(f"test: {test.shape}")
test.head()
# Out:
# test: (303202, 30)
#    active_power_calculated_by_converter  ambient_temperature  generator_speed  \
# 0                              0.007754             0.815039         0.323988
# 1                              0.236289             0.157517         0.761618
# 2                              0.223915             0.553069         0.748169
# 3                              0.127007             0.505230         0.635260
# 4                              0.587465             0.624684         0.946821
#
#    generator_winding_temp_max  grid_power10min_average  nc1_inside_temp  \
# 0                    0.304395                 0.042004         0.904835
# 1                    0.251035                 0.246267         0.391749
# 2                    0.334485                 0.196577         0.678749
# 3                    0.288893                 0.089358         0.440234
# 4                    0.399539                 0.557928         0.498909
#
#    nacelle_temp  reactice_power_calculated_by_converter  wind_speed_raw  \
# 0      0.906080                                0.380883        0.081212
# 1      0.248036                                0.492167        0.264465
# 2      0.608271                                0.485162        0.265764
# 3      0.467395                                0.484001        0.185554
# 4      0.458517                                0.603270        0.366207
#
#    wind_speed_turbulence  ...  power_ratio5  power_ratio6  power_ratio7  \
# 0               0.082900  ...  7.690738e-07      0.002193      0.000007
# 1               0.057075  ...  3.517404e-06      0.002194      0.000009
# 2               0.053854  ...  4.165736e-06      0.002195      0.000009
# 3               0.047078  ...  5.132108e-06      0.002196      0.000010
# 4               0.058886  ...  3.881753e-06      0.002194      0.000009
#
#    nacelle_temp_ratio  nacelle_temp_diff  nacelle_ambient_temp_diff  \
# 0            0.195332           0.215033                   0.353636
# 1            0.137712           0.217567                   0.569225
# 2            0.170673           0.203557                   0.401875
# 3            0.333348           0.469495                   0.319278
# 4            0.236208           0.334229                   0.144386
#
#    nacelle_ambient_temp_ratio  temp_avg  wind_direction_sin  \
# 0                    0.095282  0.812131            0.700179
# 1                    0.347376  0.274635            0.916672
# 2                    0.125650  0.621230            0.149295
# 3                    0.102320  0.471071            0.481230
# 4                    0.044196  0.603445            0.005272
#
#    wind_direction_cos
# 0            0.041821
# 1            0.776383
# 2            0.143622
# 3            0.000352
# 4            0.427585
#
# [5 rows x 30 columns]

# %%
features = test.columns.tolist()

# %%
cat_cols = ['turbine_id']
train[cat_cols] = train[cat_cols].astype(int)
test[cat_cols] = test[cat_cols].astype(int)
cat_cols_indices = [train.columns.get_loc(col) for col in cat_cols]
print(cat_cols_indices)
# Out:
# [10]

# %% [markdown]
# ## CatBoost

# %%
splits = 10
skf = StratifiedKFold(n_splits=splits, shuffle=True, random_state=42)

cb_oof_preds = np.zeros((train.shape[0],))
cb_model_preds = 0
fet_imp = 0

for fold, (train_idx, valid_idx) in enumerate(skf.split(train, train['turbine_id'])):
    X_train, X_valid = train.loc[train_idx][features], train.loc[valid_idx][features]
    y_train, y_valid = train.loc[train_idx]['Target'], train.loc[valid_idx]['Target']
    
    model = CatBoostRegressor(
        objective='RMSE',
        eval_metric='MAPE',
        num_boost_round=5000,
        learning_rate=0.25,
        reg_lambda=0.005,
        use_best_model=True,
        bootstrap_type='Bernoulli',
        subsample=0.87,
        max_depth=10, 
        grow_policy='Lossguide',
        task_type='GPU',
        min_data_in_leaf=1, 
        max_leaves=252,
        verbose=0,
        random_state=42
    )
    
    model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], 
              cat_features=cat_cols_indices, 
              early_stopping_rounds=100, verbose=500)
    
    cb_model_preds += model.predict(test[features]) / splits
    cb_oof_preds[valid_idx] = model.predict(X_valid)
    fet_imp += model.feature_importances_ / splits
    
    print(f"\nFold-{fold+1} | MAPE: {mean_absolute_percentage_error(y_valid, cb_oof_preds[valid_idx])}\n")
    
    del X_train, X_valid
    del y_train, y_valid
    gc.collect()

model_mape = mean_absolute_percentage_error(train['Target'], cb_oof_preds)
print(f"All Folds | MAPE: {model_mape}")
# Out:
# 0:	learn: 0.0343064	test: 0.0343757	best: 0.0343757 (0)	total: 153ms	remaining: 12m 46s
# 500:	learn: 0.0122289	test: 0.0156472	best: 0.0156472 (500)	total: 1m 13s	remaining: 11m 4s
# 1000:	learn: 0.0097593	test: 0.0152595	best: 0.0152595 (1000)	total: 2m 24s	remaining: 9m 38s
# 1500:	learn: 0.0080297	test: 0.0151117	best: 0.0151117 (1500)	total: 3m 35s	remaining: 8m 21s
# 2000:	learn: 0.0067030	test: 0.0150220	best: 0.0150220 (2000)	total: 4m 45s	remaining: 7m 8s
# 2500:	learn: 0.0056500	test: 0.0149727	best: 0.0149726 (2499)	total: 5m 55s	remaining: 5m 55s
# 3000:	learn: 0.0047902	test: 0.0149300	best: 0.0149293 (2994)	total: 7m 6s	remaining: 4m 43s
# 3500:	learn: 0.0040879	test: 0.0149056	best: 0.0149053 (3489)	total: 8m 16s	remaining: 3m 32s
# 4000:	learn: 0.0035070	test: 0.0148813	best: 0.0148812 (3993)	total: 9m 27s	remaining: 2m 21s
# 4500:	learn: 0.0030249	test: 0.0148698	best: 0.0148677 (4469)	total: 10m 37s	remaining: 1m 10s
# 4999:	learn: 0.0026210	test: 0.0148552	best: 0.0148551 (4997)	total: 11m 47s	remaining: 0us
# bestTest = 0.01485513613
# bestIteration = 4997
# Shrink model to first 4998 iterations.
#
# Fold-1 | MAPE: 0.01485514372380922
#
# 0:	learn: 0.0343210	test: 0.0343652	best: 0.0343652 (0)	total: 417ms	remaining: 34m 44s
# 500:	learn: 0.0122208	test: 0.0157037	best: 0.0157037 (500)	total: 1m 12s	remaining: 10m 52s
# 1000:	learn: 0.0097225	test: 0.0153043	best: 0.0153021 (994)	total: 2m 23s	remaining: 9m 31s
# 1500:	learn: 0.0080146	test: 0.0151614	best: 0.0151612 (1497)	total: 3m 34s	remaining: 8m 19s
# 2000:	learn: 0.0066915	test: 0.0150873	best: 0.0150873 (2000)	total: 4m 44s	remaining: 7m 6s
# 2500:	learn: 0.0056312	test: 0.0150369	best: 0.0150368 (2490)	total: 5m 55s	remaining: 5m 54s
# 3000:	learn: 0.0047772	test: 0.0150005	best: 0.0150004 (2999)	total: 7m 5s	remaining: 4m 43s
# 3500:	learn: 0.0040744	test: 0.0149782	best: 0.0149780 (3498)	total: 8m 16s	remaining: 3m 32s
# 4000:	learn: 0.0034957	test: 0.0149620	best: 0.0149620 (4000)	total: 9m 26s	remaining: 2m 21s
# 4500:	learn: 0.0030086	test: 0.0149456	best: 0.0149456 (4500)	total: 10m 37s	remaining: 1m 10s
# 4999:	learn: 0.0026014	test: 0.0149348	best: 0.0149343 (4981)	total: 11m 47s	remaining: 0us
# bestTest = 0.01493429979
# bestIteration = 4981
# Shrink model to first 4982 iterations.
#
# Fold-2 | MAPE: 0.014934298419648169
#
# 0:	learn: 0.0343249	test: 0.0343043	best: 0.0343043 (0)	total: 150ms	remaining: 12m 31s
# 500:	learn: 0.0122770	test: 0.0157293	best: 0.0157293 (500)	total: 1m 12s	remaining: 10m 48s
# 1000:	learn: 0.0097906	test: 0.0153097	best: 0.0153097 (1000)	total: 2m 23s	remaining: 9m 32s
# 1500:	learn: 0.0080646	test: 0.0151419	best: 0.0151414 (1457)	total: 3m 33s	remaining: 8m 17s
# 2000:	learn: 0.0067378	test: 0.0150518	best: 0.0150503 (1982)	total: 4m 43s	remaining: 7m 5s
# 2500:	learn: 0.0056867	test: 0.0150078	best: 0.0150073 (2492)	total: 5m 55s	remaining: 5m 55s
# 3000:	learn: 0.0048340	test: 0.0149728	best: 0.0149726 (2995)	total: 7m 6s	remaining: 4m 43s
# 3500:	learn: 0.0041343	test: 0.0149509	best: 0.0149508 (3495)	total: 8m 17s	remaining: 3m 32s
# 4000:	learn: 0.0035628	test: 0.0149268	best: 0.0149268 (4000)	total: 9m 27s	remaining: 2m 21s
# 4500:	learn: 0.0030810	test: 0.0149127	best: 0.0149118 (4474)	total: 10m 38s	remaining: 1m 10s
# 4999:	learn: 0.0026802	test: 0.0149004	best: 0.0149003 (4998)	total: 11m 48s	remaining: 0us
# bestTest = 0.01490033761
# bestIteration = 4998
# Shrink model to first 4999 iterations.
#
# Fold-3 | MAPE: 0.014900328438775975
#
# 0:	learn: 0.0342805	test: 0.0345285	best: 0.0345285 (0)	total: 150ms	remaining: 12m 31s
# 500:	learn: 0.0122487	test: 0.0158284	best: 0.0158284 (500)	total: 1m 11s	remaining: 10m 44s
# 1000:	learn: 0.0097685	test: 0.0154231	best: 0.0154219 (998)	total: 2m 22s	remaining: 9m 30s
# 1500:	learn: 0.0080199	test: 0.0152450	best: 0.0152450 (1500)	total: 3m 34s	remaining: 8m 19s
# 2000:	learn: 0.0066970	test: 0.0151586	best: 0.0151586 (2000)	total: 4m 44s	remaining: 7m 6s
# 2500:	learn: 0.0056487	test: 0.0151072	best: 0.0151068 (2495)	total: 5m 55s	remaining: 5m 54s
# bestTest = 0.01506889505
# bestIteration = 2874
# Shrink model to first 2875 iterations.
#
# Fold-4 | MAPE: 0.015068889555975271
#
# 0:	learn: 0.0342930	test: 0.0342997	best: 0.0342997 (0)	total: 151ms	remaining: 12m 36s
# 500:	learn: 0.0121781	test: 0.0156989	best: 0.0156989 (500)	total: 1m 13s	remaining: 10m 56s
# 1000:	learn: 0.0097080	test: 0.0153022	best: 0.0153014 (999)	total: 2m 23s	remaining: 9m 33s
# 1500:	learn: 0.0079756	test: 0.0151442	best: 0.0151441 (1499)	total: 3m 34s	remaining: 8m 20s
# 2000:	learn: 0.0066376	test: 0.0150693	best: 0.0150692 (1993)	total: 4m 45s	remaining: 7m 7s
# 2500:	learn: 0.0055765	test: 0.0150194	best: 0.0150187 (2491)	total: 5m 55s	remaining: 5m 54s
# 3000:	learn: 0.0047152	test: 0.0149962	best: 0.0149958 (2993)	total: 7m 5s	remaining: 4m 43s
# 3500:	learn: 0.0040097	test: 0.0149700	best: 0.0149698 (3495)	total: 8m 16s	remaining: 3m 32s
# 4000:	learn: 0.0034213	test: 0.0149486	best: 0.0149478 (3985)	total: 9m 27s	remaining: 2m 21s
# bestTest = 0.01494017964
# bestIteration = 4219
# Shrink model to first 4220 iterations.
#
# Fold-5 | MAPE: 0.014940179318982503
#
# 0:	learn: 0.0343005	test: 0.0342886	best: 0.0342886 (0)	total: 147ms	remaining: 12m 16s
# 500:	learn: 0.0121872	test: 0.0157306	best: 0.0157306 (500)	total: 1m 11s	remaining: 10m 42s
# 1000:	learn: 0.0097090	test: 0.0153488	best: 0.0153488 (1000)	total: 2m 22s	remaining: 9m 29s
# 1500:	learn: 0.0079890	test: 0.0152237	best: 0.0152231 (1498)	total: 3m 33s	remaining: 8m 17s
# 2000:	learn: 0.0066601	test: 0.0151521	best: 0.0151518 (1999)	total: 4m 44s	remaining: 7m 6s
# 2500:	learn: 0.0056075	test: 0.0151070	best: 0.0151070 (2500)	total: 5m 54s	remaining: 5m 53s
# 3000:	learn: 0.0047485	test: 0.0150750	best: 0.0150742 (2990)	total: 7m 3s	remaining: 4m 42s
# 3500:	learn: 0.0040418	test: 0.0150454	best: 0.0150449 (3493)	total: 8m 13s	remaining: 3m 31s
# 4000:	learn: 0.0034581	test: 0.0150229	best: 0.0150229 (3999)	total: 9m 23s	remaining: 2m 20s
# 4500:	learn: 0.0029772	test: 0.0150091	best: 0.0150087 (4484)	total: 10m 34s	remaining: 1m 10s
# 4999:	learn: 0.0025718	test: 0.0149933	best: 0.0149932 (4972)	total: 11m 45s	remaining: 0us
# bestTest = 0.01499315596
# bestIteration = 4972
# Shrink model to first 4973 iterations.
#
# Fold-6 | MAPE: 0.014993153339865357
#
# 0:	learn: 0.0343398	test: 0.0342495	best: 0.0342495 (0)	total: 149ms	remaining: 12m 26s
# 500:	learn: 0.0123220	test: 0.0157057	best: 0.0157057 (500)	total: 1m 13s	remaining: 10m 58s
# 1000:	learn: 0.0098621	test: 0.0153181	best: 0.0153181 (1000)	total: 2m 25s	remaining: 9m 41s
# 1500:	learn: 0.0081256	test: 0.0151624	best: 0.0151608 (1467)	total: 3m 37s	remaining: 8m 26s
# 2000:	learn: 0.0067968	test: 0.0150863	best: 0.0150857 (1947)	total: 4m 48s	remaining: 7m 11s
# 2500:	learn: 0.0057445	test: 0.0150400	best: 0.0150400 (2500)	total: 5m 59s	remaining: 5m 59s
# 3000:	learn: 0.0048872	test: 0.0150112	best: 0.0150111 (2999)	total: 7m 12s	remaining: 4m 48s
# 3500:	learn: 0.0041940	test: 0.0149833	best: 0.0149832 (3499)	total: 8m 23s	remaining: 3m 35s
# 4000:	learn: 0.0036124	test: 0.0149656	best: 0.0149651 (3994)	total: 9m 35s	remaining: 2m 23s
# 4500:	learn: 0.0031302	test: 0.0149516	best: 0.0149511 (4488)	total: 10m 47s	remaining: 1m 11s
# bestTest = 0.01494649117
# bestIteration = 4671
# Shrink model to first 4672 iterations.
#
# Fold-7 | MAPE: 0.014946488571538007
#
# 0:	learn: 0.0342882	test: 0.0341866	best: 0.0341866 (0)	total: 149ms	remaining: 12m 22s
# 500:	learn: 0.0122467	test: 0.0157241	best: 0.0157238 (499)	total: 1m 12s	remaining: 10m 49s
# 1000:	learn: 0.0097633	test: 0.0153098	best: 0.0153093 (999)	total: 2m 24s	remaining: 9m 37s
# 1500:	learn: 0.0080315	test: 0.0151528	best: 0.0151528 (1500)	total: 3m 35s	remaining: 8m 23s
# 2000:	learn: 0.0066941	test: 0.0150517	best: 0.0150506 (1994)	total: 4m 49s	remaining: 7m 13s
# 2500:	learn: 0.0056390	test: 0.0150014	best: 0.0150008 (2494)	total: 6m	remaining: 6m
# 3000:	learn: 0.0047767	test: 0.0149717	best: 0.0149716 (2995)	total: 7m 11s	remaining: 4m 47s
# 3500:	learn: 0.0040714	test: 0.0149542	best: 0.0149535 (3471)	total: 8m 23s	remaining: 3m 35s
# 4000:	learn: 0.0034902	test: 0.0149340	best: 0.0149324 (3920)	total: 9m 35s	remaining: 2m 23s
# bestTest = 0.01493238518
# bestIteration = 3920
# Shrink model to first 3921 iterations.
#
# Fold-8 | MAPE: 0.014932382022882084
#
# 0:	learn: 0.0343253	test: 0.0343248	best: 0.0343248 (0)	total: 326ms	remaining: 27m 11s
# 500:	learn: 0.0122324	test: 0.0157232	best: 0.0157215 (496)	total: 1m 13s	remaining: 11m 1s
# 1000:	learn: 0.0097495	test: 0.0153052	best: 0.0153052 (1000)	total: 2m 26s	remaining: 9m 44s
# 1500:	learn: 0.0080115	test: 0.0151469	best: 0.0151465 (1481)	total: 3m 38s	remaining: 8m 28s
# 2000:	learn: 0.0066924	test: 0.0150694	best: 0.0150694 (2000)	total: 4m 50s	remaining: 7m 15s
# 2500:	learn: 0.0056352	test: 0.0150186	best: 0.0150186 (2500)	total: 6m 3s	remaining: 6m 2s
# 3000:	learn: 0.0047813	test: 0.0149855	best: 0.0149855 (3000)	total: 7m 15s	remaining: 4m 50s
# 3500:	learn: 0.0040737	test: 0.0149627	best: 0.0149627 (3499)	total: 8m 27s	remaining: 3m 37s
# 4000:	learn: 0.0034922	test: 0.0149464	best: 0.0149464 (3988)	total: 9m 39s	remaining: 2m 24s
# 4500:	learn: 0.0030078	test: 0.0149280	best: 0.0149280 (4500)	total: 10m 50s	remaining: 1m 12s
# 4999:	learn: 0.0026026	test: 0.0149164	best: 0.0149158 (4973)	total: 12m 2s	remaining: 0us
# bestTest = 0.01491580181
# bestIteration = 4973
# Shrink model to first 4974 iterations.
#
# Fold-9 | MAPE: 0.014915813123965425
#
# 0:	learn: 0.0343231	test: 0.0342067	best: 0.0342067 (0)	total: 150ms	remaining: 12m 29s
# 500:	learn: 0.0122371	test: 0.0156940	best: 0.0156940 (500)	total: 1m 13s	remaining: 10m 57s
# 1000:	learn: 0.0097693	test: 0.0152798	best: 0.0152798 (1000)	total: 2m 25s	remaining: 9m 41s
# 1500:	learn: 0.0080523	test: 0.0151584	best: 0.0151584 (1500)	total: 3m 37s	remaining: 8m 28s
# 2000:	learn: 0.0067295	test: 0.0150926	best: 0.0150918 (1994)	total: 4m 49s	remaining: 7m 13s
# 2500:	learn: 0.0056707	test: 0.0150407	best: 0.0150404 (2494)	total: 6m 1s	remaining: 6m
# 3000:	learn: 0.0048105	test: 0.0150048	best: 0.0150033 (2987)	total: 7m 12s	remaining: 4m 48s
# 3500:	learn: 0.0041097	test: 0.0149787	best: 0.0149785 (3483)	total: 8m 24s	remaining: 3m 36s
# 4000:	learn: 0.0035291	test: 0.0149645	best: 0.0149640 (3995)	total: 9m 37s	remaining: 2m 24s
# 4500:	learn: 0.0030468	test: 0.0149484	best: 0.0149484 (4500)	total: 10m 48s	remaining: 1m 11s
# 4999:	learn: 0.0026467	test: 0.0149318	best: 0.0149317 (4992)	total: 12m	remaining: 0us
# bestTest = 0.01493171819
# bestIteration = 4992
# Shrink model to first 4993 iterations.
#
# Fold-10 | MAPE: 0.014931717648406092
#
# All Folds | MAPE: 0.014941839406822931

# %%
feature_imp = pd.DataFrame(sorted(zip(fet_imp[0:25],train.columns[0:25])), columns=['Value','Feature'])

plt.figure(figsize=(12, 12))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('CatBoost Features Importance', fontweight='bold', pad=15);

# %% [markdown]
# ## Create submission file

# %%
submission = pd.read_csv("../input/mh-renew-data/submission.csv")
submission['Target'] = cb_model_preds
submission.to_csv("./cb_submission.csv", index=False)
submission.head()
# Out:
#       Target
# 0  50.020232
# 1  41.083741
# 2  48.754754
# 3  46.438156
# 4  45.525633

# %%
## Good Day!!
