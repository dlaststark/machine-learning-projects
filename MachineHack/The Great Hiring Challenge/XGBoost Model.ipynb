# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Download Packages

# %%
! pip install optuna
# Out:
# Collecting optuna
#   Downloading https://files.pythonhosted.org/packages/87/10/06b58f4120f26b603d905a594650440ea1fd74476b8b360dbf01e111469b/optuna-2.3.0.tar.gz (258kB)
#      |████████████████████████████████| 266kB 6.5MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.20)
# Collecting cmaes>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/8d/3c/06c76ec8b54b9b1fad7f35e903fd25010fe3e0d41bd94cea5e6f12e0d651/cmaes-0.7.0-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.18.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from optuna) (0.17.0)
# Collecting alembic
#   Downloading https://files.pythonhosted.org/packages/12/aa/c261dfd7f4ba6ce4701846a2689a46e2a172e012171de4378fc2926e3bf0/alembic-1.4.3-py2.py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 25.2MB/s
# Collecting colorlog
#   Downloading https://files.pythonhosted.org/packages/4e/c8/c16d30bbed11a1722060014c246d124582d1f781b26f5859d8dacc3e08e1/colorlog-4.6.2-py2.py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna) (4.41.1)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (20.4)
# Collecting cliff
#   Downloading https://files.pythonhosted.org/packages/8a/61/5b64d73b01c1218f55c894b5ec0fb89b32c6960b7f7b3ad9f5ac0c373b9d/cliff-3.5.0-py3-none-any.whl (81kB)
#      |████████████████████████████████| 81kB 10.3MB/s
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/a6/37/0e706200d22172eb8fa17d68a7ae22dec7631a0a92266634fb518a88a5b2/Mako-1.1.3-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 10.3MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.8.1)
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->optuna) (1.15.0)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fb/48/69046506f6ac61c1eaa9a0d42d22d54673b69e176d30ca98e3f61513e980/pbr-5.5.1-py2.py3-none-any.whl (106kB)
#      |████████████████████████████████| 112kB 37.9MB/s
# Collecting stevedore>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/b8/a1/004f04ba411a8002b02aadb089fd6868116c12ddc9f6d576175e89d07587/stevedore-3.2.2-py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 8.0MB/s
# Collecting cmd2!=0.8.3,>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/27/54/af6e2703f064485d717cb311d3f9440cd302a823ba6d80a020b59eae166d/cmd2-1.4.0-py3-none-any.whl (133kB)
#      |████████████████████████████████| 133kB 42.7MB/s
# Collecting PrettyTable<0.8,>=0.7.2
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Requirement already satisfied: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from stevedore>=2.0.1->cliff->optuna) (2.0.0)
# Collecting pyperclip>=1.6
#   Downloading https://files.pythonhosted.org/packages/6f/4c/0b1d507ad7e8bc31d690d04b4f475e74c2002d060f7994ce8c09612df707/pyperclip-1.8.1.tar.gz
# Collecting colorama>=0.3.7
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (20.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna) (3.4.0)
# Building wheels for collected packages: optuna
#   Building wheel for optuna (PEP 517) ... done
#   Created wheel for optuna: filename=optuna-2.3.0-cp36-none-any.whl size=359761 sha256=0c945d9097fbe75cb7675c63ab33aa7d13bb5f4c9ce2d0f2761aa7667e3ddfde
#   Stored in directory: /root/.cache/pip/wheels/fa/91/19/64b0ec6b964f89c0695a9dc6db6f851d0b54c5381a5c9cadfb
# Successfully built optuna
# Building wheels for collected packages: PrettyTable, pyperclip
#   Building wheel for PrettyTable (setup.py) ... done
#   Created wheel for PrettyTable: filename=prettytable-0.7.2-cp36-none-any.whl size=13700 sha256=a9f58b260895daf250245da7ab51e30cab43ad85b9bfeef0c097ac11c0f5979b
#   Stored in directory: /root/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.1-cp36-none-any.whl size=11119 sha256=0856078727ff245fa9d7dcf499007617839f5dd2ea605eb0cde3ddbd8c43ca0e
#   Stored in directory: /root/.cache/pip/wheels/44/10/3a/c830e9bb3db2c93274ea1f213a41fabde0d8cf3794251fad0c
# Successfully built PrettyTable pyperclip
# Installing collected packages: cmaes, Mako, python-editor, alembic, colorlog, pbr, stevedore, pyperclip, colorama, cmd2, PrettyTable, cliff, optuna
#   Found existing installation: prettytable 1.0.1
#     Uninstalling prettytable-1.0.1:
#       Successfully uninstalled prettytable-1.0.1
# Successfully installed Mako-1.1.3 PrettyTable-0.7.2 alembic-1.4.3 cliff-3.5.0 cmaes-0.7.0 cmd2-1.4.0 colorama-0.4.4 colorlog-4.6.2 optuna-2.3.0 pbr-5.5.1 pyperclip-1.8.1 python-editor-1.0.4 stevedore-3.2.2

# %% [markdown]
# ## Import Packages

# %%
import pickle
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import IsolationForest
from xgboost import XGBRegressor
#import optuna

# %% [markdown]
# ## Load datasets from saved file

# %%
with open('/content/drive/My Drive/Colab Notebooks/The Great Hiring Challenge/TGHC_Dataset_CB.txt', 'rb') as handle: 
    data = handle.read()
        
processed_dataset = pickle.loads(data)
Xtrain, Ytrain = processed_dataset['Xtrain'], processed_dataset['Ytrain']
Xpredict = processed_dataset['Xpredict']

print("------------------------- Training Dataset -------------------------")
print("Xtrain shape: {}".format(Xtrain.shape))
print("Ytrain shape: {}".format(Ytrain.shape))

print("\n------------------------- Prediction Dataset -------------------------")
print("Xpredict shape: {}".format(Xpredict.shape))
# Out:
# ------------------------- Training Dataset -------------------------
# Xtrain shape: (284780, 512)
# Ytrain shape: (284780, 1)
#
# ------------------------- Prediction Dataset -------------------------
# Xpredict shape: (122049, 512)

# %%
'''
pt = PowerTransformer(method='yeo-johnson')
pt.fit(Ytrain)
tmp = pt.transform(Ytrain)
del tmp
'''

Ytrain = pd.DataFrame(Ytrain, columns=['UnitPrice'])
del processed_dataset
gc.collect()
# Out:
# 375

# %% [markdown]
# ## Remove Outliers

# %%
clf = IsolationForest(max_samples = 100, random_state = 42)
clf.fit(Xtrain)
y_noano = clf.predict(Xtrain)
y_noano = pd.DataFrame(y_noano, columns = ['Top'])
y_noano[y_noano['Top'] == 1].index.values

Xtrain = Xtrain.iloc[y_noano[y_noano['Top'] == 1].index.values]
Ytrain = Ytrain.iloc[y_noano[y_noano['Top'] == 1].index.values]
Xtrain.reset_index(drop = True, inplace = True)
print("Number of Outliers:", y_noano[y_noano['Top'] == -1].shape[0])
print("Number of rows without outliers:", Xtrain.shape[0])
# Out:
# Number of Outliers: 43572
# Number of rows without outliers: 241208

# %%
print("------------------------- Training Dataset -------------------------")
print("Xtrain shape: {}".format(Xtrain.shape))
print("Ytrain shape: {}".format(Ytrain.shape))

print("\n------------------------- Prediction Dataset -------------------------")
print("Xpredict shape: {}".format(Xpredict.shape))
# Out:
# ------------------------- Training Dataset -------------------------
# Xtrain shape: (241208, 512)
# Ytrain shape: (241208, 1)
#
# ------------------------- Prediction Dataset -------------------------
# Xpredict shape: (122049, 512)

# %% [markdown]
# ## Split training data into train/test datasets

# %%
Xtrain_new, Xtest, Ytrain_new, Ytest = train_test_split(Xtrain, Ytrain, test_size=0.1, random_state=10)

print("------------------------- Training Dataset -------------------------")
print("Xtrain_new shape: {}".format(Xtrain_new.shape))
print("Ytrain_new shape: {}".format(Ytrain_new.shape))

print("\n------------------------- Test Dataset -------------------------")
print("Xtest shape: {}".format(Xtest.shape))
print("Ytest shape: {}".format(Ytest.shape))
# Out:
# ------------------------- Training Dataset -------------------------
# Xtrain_new shape: (256302, 512)
# Ytrain_new shape: (256302, 1)
#
# ------------------------- Test Dataset -------------------------
# Xtest shape: (28478, 512)
# Ytest shape: (28478, 1)

# %% [markdown]
# ## Hyperparameter search using Optuna

# %%
def objective(trial):
    
    model = XGBRegressor(
        objective='reg:squarederror',
        eval_metric='rmse',
        booster='gbtree',
        sample_type='uniform',
        tree_method='gpu_hist',
        grow_policy='lossguide',
        num_round=8000,
        max_depth=trial.suggest_int("max_depth", 6, 15), 
        max_leaves=trial.suggest_int("max_leaves", 35, 500),
        learning_rate=trial.suggest_loguniform("learning_rate", 1e-2, 1e-1),
        subsample=trial.suggest_uniform("subsample", 0.5, 1.0),
        colsample_bytree=trial.suggest_uniform("colsample_bytree", 0.5, 1.0),
        min_child_weight=trial.suggest_int("min_child_weight", 1, 15),
        reg_lambda=trial.suggest_loguniform("reg_lambda", 1e-4, 1.0),
        verbosity=0
    )

    model.fit(Xtrain_new, Ytrain_new, eval_set=[(Xtest, Ytest)], 
              early_stopping_rounds=100, verbose=False)
    y_pred = model.predict(Xtest, ntree_limit=model.best_ntree_limit)
    rmse = np.sqrt(mean_squared_error(Ytest, y_pred))
    return rmse

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=250)
# Out:
# [I 2020-11-17 13:18:48,258] A new study created in memory with name: no-name-c4de4fbd-36b4-450e-a006-c81af8b49854
# [I 2020-11-17 13:19:00,296] Trial 0 finished with value: 19.59581367423754 and parameters: {'max_depth': 6, 'max_leaves': 348, 'learning_rate': 0.01921075080036617, 'subsample': 0.8170524629179234, 'colsample_bytree': 0.5407562053838675, 'min_child_weight': 12, 'reg_lambda': 0.00040437763567270277}. Best is trial 0 with value: 19.59581367423754.
# [I 2020-11-17 13:19:26,919] Trial 1 finished with value: 19.499448358865557 and parameters: {'max_depth': 13, 'max_leaves': 392, 'learning_rate': 0.011153830475172828, 'subsample': 0.5537354536542545, 'colsample_bytree': 0.5255700772629568, 'min_child_weight': 3, 'reg_lambda': 0.595921248917796}. Best is trial 1 with value: 19.499448358865557.
# [I 2020-11-17 13:19:39,721] Trial 2 finished with value: 17.650722275539895 and parameters: {'max_depth': 8, 'max_leaves': 468, 'learning_rate': 0.044283247287674445, 'subsample': 0.7698627010654018, 'colsample_bytree': 0.8629525681139425, 'min_child_weight': 13, 'reg_lambda': 0.0002940113831116818}. Best is trial 2 with value: 17.650722275539895.
# [I 2020-11-17 13:19:56,032] Trial 3 finished with value: 17.775653150627637 and parameters: {'max_depth': 10, 'max_leaves': 300, 'learning_rate': 0.03491221631138924, 'subsample': 0.6467644238335164, 'colsample_bytree': 0.9604612682680994, 'min_child_weight': 6, 'reg_lambda': 0.0013659746260198816}. Best is trial 2 with value: 17.650722275539895.
# [I 2020-11-17 13:20:21,436] Trial 4 finished with value: 16.156231842985704 and parameters: {'max_depth': 12, 'max_leaves': 451, 'learning_rate': 0.017661597820810716, 'subsample': 0.6940659567577158, 'colsample_bytree': 0.5119104626898099, 'min_child_weight': 2, 'reg_lambda': 0.031899047794665056}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:20:38,688] Trial 5 finished with value: 17.678549788590626 and parameters: {'max_depth': 14, 'max_leaves': 226, 'learning_rate': 0.08898594553966667, 'subsample': 0.6914327286137213, 'colsample_bytree': 0.7869881970367989, 'min_child_weight': 15, 'reg_lambda': 0.011112238962790991}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:20:55,473] Trial 6 finished with value: 21.843552429639946 and parameters: {'max_depth': 12, 'max_leaves': 456, 'learning_rate': 0.08416476116651712, 'subsample': 0.5258705074734777, 'colsample_bytree': 0.7156292681360876, 'min_child_weight': 3, 'reg_lambda': 0.01346359665977274}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:21:22,758] Trial 7 finished with value: 19.090497994006054 and parameters: {'max_depth': 12, 'max_leaves': 334, 'learning_rate': 0.015070380525772567, 'subsample': 0.8385455104963676, 'colsample_bytree': 0.9768048963317044, 'min_child_weight': 8, 'reg_lambda': 0.0002301315705229132}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:21:38,678] Trial 8 finished with value: 19.70781039693183 and parameters: {'max_depth': 13, 'max_leaves': 335, 'learning_rate': 0.09772416449098566, 'subsample': 0.5228469888971035, 'colsample_bytree': 0.7331874072750089, 'min_child_weight': 14, 'reg_lambda': 0.009055888101110495}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:21:59,069] Trial 9 finished with value: 20.001867813993247 and parameters: {'max_depth': 13, 'max_leaves': 240, 'learning_rate': 0.06324588341438497, 'subsample': 0.7269817229143194, 'colsample_bytree': 0.654477461979428, 'min_child_weight': 1, 'reg_lambda': 0.0015392495707290637}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:22:12,169] Trial 10 finished with value: 18.15607686589192 and parameters: {'max_depth': 10, 'max_leaves': 70, 'learning_rate': 0.022565116748937186, 'subsample': 0.9661931240446309, 'colsample_bytree': 0.6217577735795259, 'min_child_weight': 8, 'reg_lambda': 0.4547181144237957}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:22:22,970] Trial 11 finished with value: 18.339282229508676 and parameters: {'max_depth': 7, 'max_leaves': 499, 'learning_rate': 0.041422240001654564, 'subsample': 0.7954406364049714, 'colsample_bytree': 0.8791944827011342, 'min_child_weight': 11, 'reg_lambda': 0.10309098864089747}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:22:34,642] Trial 12 finished with value: 17.613088783115646 and parameters: {'max_depth': 8, 'max_leaves': 496, 'learning_rate': 0.04930109568721103, 'subsample': 0.9221261469043982, 'colsample_bytree': 0.8419088892191104, 'min_child_weight': 11, 'reg_lambda': 0.07439399772077722}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:22:49,200] Trial 13 finished with value: 17.407024067330358 and parameters: {'max_depth': 9, 'max_leaves': 424, 'learning_rate': 0.025615856335918334, 'subsample': 0.9940582810167781, 'colsample_bytree': 0.8404793625705704, 'min_child_weight': 10, 'reg_lambda': 0.08066728334770316}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:23:03,831] Trial 14 finished with value: 17.382166602845125 and parameters: {'max_depth': 9, 'max_leaves': 413, 'learning_rate': 0.02569317185204746, 'subsample': 0.6442249460245204, 'colsample_bytree': 0.9296580107993633, 'min_child_weight': 6, 'reg_lambda': 0.07000626625032594}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:23:23,388] Trial 15 finished with value: 18.628023684974824 and parameters: {'max_depth': 11, 'max_leaves': 151, 'learning_rate': 0.013084617733774345, 'subsample': 0.6305424875086756, 'colsample_bytree': 0.916063063339266, 'min_child_weight': 4, 'reg_lambda': 0.03530378694479211}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:23:52,923] Trial 16 finished with value: 20.814619215963116 and parameters: {'max_depth': 15, 'max_leaves': 411, 'learning_rate': 0.016675068859320335, 'subsample': 0.6081589614584815, 'colsample_bytree': 0.5869582827372483, 'min_child_weight': 1, 'reg_lambda': 0.27075786984269246}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:24:13,434] Trial 17 finished with value: 16.817849961481247 and parameters: {'max_depth': 11, 'max_leaves': 386, 'learning_rate': 0.028065557077714905, 'subsample': 0.6937231474644938, 'colsample_bytree': 0.9971839145114131, 'min_child_weight': 6, 'reg_lambda': 0.02635838790801575}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:24:30,692] Trial 18 finished with value: 16.669275503602385 and parameters: {'max_depth': 11, 'max_leaves': 376, 'learning_rate': 0.03058889168478881, 'subsample': 0.7091225708126087, 'colsample_bytree': 0.5024345789135426, 'min_child_weight': 6, 'reg_lambda': 0.003170692990507469}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:24:54,689] Trial 19 finished with value: 18.73548047287094 and parameters: {'max_depth': 15, 'max_leaves': 294, 'learning_rate': 0.0107306965235989, 'subsample': 0.8810738045424092, 'colsample_bytree': 0.5014138377556733, 'min_child_weight': 4, 'reg_lambda': 0.002546775221627183}. Best is trial 4 with value: 16.156231842985704.
# [I 2020-11-17 13:25:19,602] Trial 20 finished with value: 15.69882993306044 and parameters: {'max_depth': 12, 'max_leaves': 452, 'learning_rate': 0.02011756563511136, 'subsample': 0.5770415236665642, 'colsample_bytree': 0.5767842437504409, 'min_child_weight': 2, 'reg_lambda': 0.004031837469121235}. Best is trial 20 with value: 15.69882993306044.
# [I 2020-11-17 13:25:45,070] Trial 21 finished with value: 23.6829391320316 and parameters: {'max_depth': 12, 'max_leaves': 458, 'learning_rate': 0.02130754616177702, 'subsample': 0.5962585339419284, 'colsample_bytree': 0.5686538913215069, 'min_child_weight': 1, 'reg_lambda': 0.0039736889854957635}. Best is trial 20 with value: 15.69882993306044.
# [I 2020-11-17 13:26:06,671] Trial 22 finished with value: 16.350692882101495 and parameters: {'max_depth': 11, 'max_leaves': 492, 'learning_rate': 0.017075382809873113, 'subsample': 0.7260497374869559, 'colsample_bytree': 0.5003552107506642, 'min_child_weight': 3, 'reg_lambda': 0.0008074930862252159}. Best is trial 20 with value: 15.69882993306044.
# [I 2020-11-17 13:26:34,467] Trial 23 finished with value: 15.423893068969779 and parameters: {'max_depth': 12, 'max_leaves': 469, 'learning_rate': 0.016321760284175757, 'subsample': 0.7468642217427035, 'colsample_bytree': 0.646532903409636, 'min_child_weight': 2, 'reg_lambda': 0.00011180307094313547}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:27:06,260] Trial 24 finished with value: 16.682821541429238 and parameters: {'max_depth': 14, 'max_leaves': 459, 'learning_rate': 0.013314309369180478, 'subsample': 0.5741062841096948, 'colsample_bytree': 0.6692484796803818, 'min_child_weight': 2, 'reg_lambda': 0.00010017461072492794}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:27:35,311] Trial 25 finished with value: 16.796015663627486 and parameters: {'max_depth': 14, 'max_leaves': 439, 'learning_rate': 0.018431793190168858, 'subsample': 0.7600472949482588, 'colsample_bytree': 0.5996780089460909, 'min_child_weight': 4, 'reg_lambda': 0.1819611007180283}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:28:04,132] Trial 26 finished with value: 15.794194444843095 and parameters: {'max_depth': 12, 'max_leaves': 495, 'learning_rate': 0.013682968915520389, 'subsample': 0.6706660758170289, 'colsample_bytree': 0.6708625960877771, 'min_child_weight': 2, 'reg_lambda': 0.00011615751510695906}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:28:34,197] Trial 27 finished with value: 18.749253876545648 and parameters: {'max_depth': 13, 'max_leaves': 491, 'learning_rate': 0.013096860196991241, 'subsample': 0.6761222846292322, 'colsample_bytree': 0.6724148601760739, 'min_child_weight': 5, 'reg_lambda': 0.00010469795652562528}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:28:55,380] Trial 28 finished with value: 17.447730505068236 and parameters: {'max_depth': 10, 'max_leaves': 493, 'learning_rate': 0.01105227764984073, 'subsample': 0.6598484874534787, 'colsample_bytree': 0.7702778002511159, 'min_child_weight': 2, 'reg_lambda': 0.00016166823961389517}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:29:21,249] Trial 29 finished with value: 17.64602039862104 and parameters: {'max_depth': 12, 'max_leaves': 360, 'learning_rate': 0.022111561743320338, 'subsample': 0.8286776977367762, 'colsample_bytree': 0.6288848558839558, 'min_child_weight': 1, 'reg_lambda': 0.0005742467395823645}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:29:39,412] Trial 30 finished with value: 19.57298582171441 and parameters: {'max_depth': 14, 'max_leaves': 132, 'learning_rate': 0.014092966876342332, 'subsample': 0.503765609596943, 'colsample_bytree': 0.7061580063579225, 'min_child_weight': 5, 'reg_lambda': 0.0004662508199242757}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:30:04,776] Trial 31 finished with value: 15.760160480245235 and parameters: {'max_depth': 12, 'max_leaves': 439, 'learning_rate': 0.018942946965262736, 'subsample': 0.7503630021503116, 'colsample_bytree': 0.5532756090310896, 'min_child_weight': 2, 'reg_lambda': 0.032168522952666964}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:30:31,545] Trial 32 finished with value: 15.513295250790355 and parameters: {'max_depth': 13, 'max_leaves': 408, 'learning_rate': 0.01980797656332959, 'subsample': 0.7896293454609075, 'colsample_bytree': 0.545868109169292, 'min_child_weight': 2, 'reg_lambda': 0.005777623253361122}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:30:57,545] Trial 33 finished with value: 16.49985289565004 and parameters: {'max_depth': 13, 'max_leaves': 401, 'learning_rate': 0.02086807358986264, 'subsample': 0.7888958449113799, 'colsample_bytree': 0.5507443709256402, 'min_child_weight': 3, 'reg_lambda': 0.005545073142496561}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:31:24,922] Trial 34 finished with value: 17.430038415501688 and parameters: {'max_depth': 13, 'max_leaves': 427, 'learning_rate': 0.015821718411663854, 'subsample': 0.8448298558830954, 'colsample_bytree': 0.5418117514995542, 'min_child_weight': 3, 'reg_lambda': 0.017982913919657232}. Best is trial 23 with value: 15.423893068969779.
# [I 2020-11-17 13:31:47,474] Trial 35 finished with value: 15.327295109580884 and parameters: {'max_depth': 11, 'max_leaves': 362, 'learning_rate': 0.01861023215185093, 'subsample': 0.8808721437746521, 'colsample_bytree': 0.573792853614022, 'min_child_weight': 2, 'reg_lambda': 0.006096456677581042}. Best is trial 35 with value: 15.327295109580884.
# [I 2020-11-17 13:32:09,044] Trial 36 finished with value: 15.539734912021606 and parameters: {'max_depth': 10, 'max_leaves': 360, 'learning_rate': 0.03298135576345411, 'subsample': 0.8970837368789589, 'colsample_bytree': 0.6049401089286349, 'min_child_weight': 1, 'reg_lambda': 0.006685633029031294}. Best is trial 35 with value: 15.327295109580884.
# [I 2020-11-17 13:32:26,722] Trial 37 finished with value: 16.54909827989438 and parameters: {'max_depth': 9, 'max_leaves': 307, 'learning_rate': 0.0335157786206251, 'subsample': 0.890075267733948, 'colsample_bytree': 0.6142459921877553, 'min_child_weight': 1, 'reg_lambda': 0.007938272713180308}. Best is trial 35 with value: 15.327295109580884.
# [I 2020-11-17 13:32:42,190] Trial 38 finished with value: 15.133106069817813 and parameters: {'max_depth': 10, 'max_leaves': 353, 'learning_rate': 0.03968104696821331, 'subsample': 0.9325758682022874, 'colsample_bytree': 0.5246015384688512, 'min_child_weight': 4, 'reg_lambda': 0.0017404796755527295}. Best is trial 38 with value: 15.133106069817813.
# [I 2020-11-17 13:32:57,716] Trial 39 finished with value: 13.574834037829886 and parameters: {'max_depth': 11, 'max_leaves': 274, 'learning_rate': 0.06050544506396006, 'subsample': 0.9470337320989934, 'colsample_bytree': 0.5253002609186971, 'min_child_weight': 5, 'reg_lambda': 0.0013714495833565834}. Best is trial 39 with value: 13.574834037829886.
# [I 2020-11-17 13:33:11,871] Trial 40 finished with value: 13.22139236241017 and parameters: {'max_depth': 10, 'max_leaves': 263, 'learning_rate': 0.060444438364619005, 'subsample': 0.9688610488360454, 'colsample_bytree': 0.5273910635582753, 'min_child_weight': 5, 'reg_lambda': 0.0018239514616038236}. Best is trial 40 with value: 13.22139236241017.
# [I 2020-11-17 13:33:25,194] Trial 41 finished with value: 18.35448093403853 and parameters: {'max_depth': 10, 'max_leaves': 255, 'learning_rate': 0.06870816059306462, 'subsample': 0.9512895980919519, 'colsample_bytree': 0.525117712678105, 'min_child_weight': 7, 'reg_lambda': 0.0011495900806561296}. Best is trial 40 with value: 13.22139236241017.
# [I 2020-11-17 13:33:40,663] Trial 42 finished with value: 13.103141690639724 and parameters: {'max_depth': 11, 'max_leaves': 204, 'learning_rate': 0.05544310233480594, 'subsample': 0.9982058529504503, 'colsample_bytree': 0.5186693672692485, 'min_child_weight': 5, 'reg_lambda': 0.0017021628303087526}. Best is trial 42 with value: 13.103141690639724.
# [I 2020-11-17 13:33:53,543] Trial 43 finished with value: 12.654816919173445 and parameters: {'max_depth': 9, 'max_leaves': 198, 'learning_rate': 0.05686033655419917, 'subsample': 0.99447857294909, 'colsample_bytree': 0.5304522419959621, 'min_child_weight': 5, 'reg_lambda': 0.0017862129704298096}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:34:04,802] Trial 44 finished with value: 16.05615062775076 and parameters: {'max_depth': 8, 'max_leaves': 196, 'learning_rate': 0.05437340074327726, 'subsample': 0.9973730316473859, 'colsample_bytree': 0.5221071306190657, 'min_child_weight': 7, 'reg_lambda': 0.0021138690169525843}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:34:18,305] Trial 45 finished with value: 12.896387988063521 and parameters: {'max_depth': 9, 'max_leaves': 211, 'learning_rate': 0.03962337937118788, 'subsample': 0.9684779476331611, 'colsample_bytree': 0.5231007348390136, 'min_child_weight': 5, 'reg_lambda': 0.0009439861461719651}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:34:28,832] Trial 46 finished with value: 14.923256640586061 and parameters: {'max_depth': 7, 'max_leaves': 207, 'learning_rate': 0.07052613569067534, 'subsample': 0.9691778691517282, 'colsample_bytree': 0.502130743806898, 'min_child_weight': 5, 'reg_lambda': 0.0009540379627015343}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:34:41,378] Trial 47 finished with value: 14.96764774249769 and parameters: {'max_depth': 9, 'max_leaves': 170, 'learning_rate': 0.05431700312989395, 'subsample': 0.9750423258898563, 'colsample_bytree': 0.5655550120919196, 'min_child_weight': 7, 'reg_lambda': 0.0006813565683781391}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:34:52,189] Trial 48 finished with value: 17.34212102268526 and parameters: {'max_depth': 8, 'max_leaves': 277, 'learning_rate': 0.08079778967775031, 'subsample': 0.9958686096152534, 'colsample_bytree': 0.5384219614509965, 'min_child_weight': 9, 'reg_lambda': 0.0014036202634707517}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:35:05,548] Trial 49 finished with value: 13.110003701520958 and parameters: {'max_depth': 9, 'max_leaves': 240, 'learning_rate': 0.046394525365816876, 'subsample': 0.9281942715511645, 'colsample_bytree': 0.5921547980249979, 'min_child_weight': 5, 'reg_lambda': 0.0002063867927451418}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:35:18,289] Trial 50 finished with value: 15.029391378024384 and parameters: {'max_depth': 9, 'max_leaves': 99, 'learning_rate': 0.04631723340248628, 'subsample': 0.9135118988841139, 'colsample_bytree': 0.596078152242286, 'min_child_weight': 6, 'reg_lambda': 0.00037200462670325954}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:35:31,007] Trial 51 finished with value: 16.571801443937204 and parameters: {'max_depth': 9, 'max_leaves': 237, 'learning_rate': 0.05827758925386761, 'subsample': 0.9468010466395038, 'colsample_bytree': 0.5192602222962848, 'min_child_weight': 5, 'reg_lambda': 0.00022481773752042642}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:35:43,233] Trial 52 finished with value: 15.016052971142676 and parameters: {'max_depth': 8, 'max_leaves': 210, 'learning_rate': 0.03702700314540975, 'subsample': 0.9776384041235786, 'colsample_bytree': 0.5359269826346209, 'min_child_weight': 5, 'reg_lambda': 0.00028095426812675776}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:35:53,720] Trial 53 finished with value: 16.29591777952989 and parameters: {'max_depth': 7, 'max_leaves': 181, 'learning_rate': 0.04934379077444226, 'subsample': 0.9519978003400131, 'colsample_bytree': 0.5114719128802352, 'min_child_weight': 7, 'reg_lambda': 0.003127611970451455}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:36:08,002] Trial 54 finished with value: 16.667079102212956 and parameters: {'max_depth': 10, 'max_leaves': 267, 'learning_rate': 0.06463872378446804, 'subsample': 0.9322963639070037, 'colsample_bytree': 0.5599305683707646, 'min_child_weight': 4, 'reg_lambda': 0.0019383246474991853}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:36:19,932] Trial 55 finished with value: 14.7021507405748 and parameters: {'max_depth': 9, 'max_leaves': 227, 'learning_rate': 0.07889577449584001, 'subsample': 0.9974374268454316, 'colsample_bytree': 0.5784810026187057, 'min_child_weight': 8, 'reg_lambda': 0.00046141160580654436}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:36:36,234] Trial 56 finished with value: 15.549829485243006 and parameters: {'max_depth': 11, 'max_leaves': 322, 'learning_rate': 0.04339804424645358, 'subsample': 0.9822586862653093, 'colsample_bytree': 0.5008046836523968, 'min_child_weight': 6, 'reg_lambda': 0.0011183194789867428}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:36:49,160] Trial 57 finished with value: 14.528895654378346 and parameters: {'max_depth': 9, 'max_leaves': 256, 'learning_rate': 0.04956832680191811, 'subsample': 0.8544453439144175, 'colsample_bytree': 0.5312698674404168, 'min_child_weight': 5, 'reg_lambda': 0.0007326514624823988}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:37:03,800] Trial 58 finished with value: 15.259812509122556 and parameters: {'max_depth': 11, 'max_leaves': 145, 'learning_rate': 0.05966289279845214, 'subsample': 0.915285870893715, 'colsample_bytree': 0.5822616788644535, 'min_child_weight': 6, 'reg_lambda': 0.0024416215560112255}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:37:19,748] Trial 59 finished with value: 14.612097353507917 and parameters: {'max_depth': 10, 'max_leaves': 218, 'learning_rate': 0.03854985572916934, 'subsample': 0.9567370915849451, 'colsample_bytree': 0.6378332698365572, 'min_child_weight': 4, 'reg_lambda': 0.004168908649853386}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:37:34,209] Trial 60 finished with value: 15.169778870783407 and parameters: {'max_depth': 10, 'max_leaves': 283, 'learning_rate': 0.0737429770946477, 'subsample': 0.8656396856618935, 'colsample_bytree': 0.5021395865025204, 'min_child_weight': 3, 'reg_lambda': 0.0015474109730405292}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:37:47,078] Trial 61 finished with value: 16.132021203534144 and parameters: {'max_depth': 9, 'max_leaves': 252, 'learning_rate': 0.051450493460183586, 'subsample': 0.935353745342477, 'colsample_bytree': 0.5327536496816172, 'min_child_weight': 5, 'reg_lambda': 0.0006009729747333913}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:37:58,747] Trial 62 finished with value: 15.232783831036432 and parameters: {'max_depth': 8, 'max_leaves': 189, 'learning_rate': 0.04652496531916404, 'subsample': 0.9021931388971622, 'colsample_bytree': 0.5227979239978187, 'min_child_weight': 5, 'reg_lambda': 0.0003511593975969113}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:38:11,093] Trial 63 finished with value: 15.455989253132714 and parameters: {'max_depth': 9, 'max_leaves': 248, 'learning_rate': 0.06327071693514966, 'subsample': 0.8637585666184036, 'colsample_bytree': 0.5630386483946976, 'min_child_weight': 6, 'reg_lambda': 0.0009338934230930602}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:38:24,718] Trial 64 finished with value: 16.092949952170606 and parameters: {'max_depth': 10, 'max_leaves': 226, 'learning_rate': 0.09425467586435818, 'subsample': 0.9650626177894861, 'colsample_bytree': 0.551279828198018, 'min_child_weight': 4, 'reg_lambda': 0.00019099858673173636}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:38:38,015] Trial 65 finished with value: 13.241419475333938 and parameters: {'max_depth': 9, 'max_leaves': 167, 'learning_rate': 0.04251462915078321, 'subsample': 0.9812743024598852, 'colsample_bytree': 0.5118676167746498, 'min_child_weight': 5, 'reg_lambda': 0.0006806488521765036}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:38:49,563] Trial 66 finished with value: 16.22113160216678 and parameters: {'max_depth': 8, 'max_leaves': 164, 'learning_rate': 0.04237888498524405, 'subsample': 0.984415024770679, 'colsample_bytree': 0.5141877957955665, 'min_child_weight': 7, 'reg_lambda': 0.0012111145230484857}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:39:04,645] Trial 67 finished with value: 15.91298965228586 and parameters: {'max_depth': 11, 'max_leaves': 128, 'learning_rate': 0.056470556259872816, 'subsample': 0.9394771115670001, 'colsample_bytree': 0.5910898112249618, 'min_child_weight': 4, 'reg_lambda': 0.002867256202196629}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:39:18,912] Trial 68 finished with value: 16.07629158555923 and parameters: {'max_depth': 10, 'max_leaves': 200, 'learning_rate': 0.045409924832809305, 'subsample': 0.9992896249132467, 'colsample_bytree': 0.5107997390373413, 'min_child_weight': 6, 'reg_lambda': 0.0005251310229012139}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:39:31,074] Trial 69 finished with value: 14.069572337696009 and parameters: {'max_depth': 7, 'max_leaves': 180, 'learning_rate': 0.029483377691998464, 'subsample': 0.9598621084023398, 'colsample_bytree': 0.8112008150727077, 'min_child_weight': 3, 'reg_lambda': 0.00028719830342213725}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:39:44,965] Trial 70 finished with value: 15.043758733966138 and parameters: {'max_depth': 9, 'max_leaves': 302, 'learning_rate': 0.03546242912418916, 'subsample': 0.9207107750886063, 'colsample_bytree': 0.6137515310402277, 'min_child_weight': 5, 'reg_lambda': 0.0008516152817940177}. Best is trial 43 with value: 12.654816919173445.
# [I 2020-11-17 13:39:55,552] Trial 71 finished with value: 12.646635606535908 and parameters: {'max_depth': 6, 'max_leaves': 177, 'learning_rate': 0.03012475081627718, 'subsample': 0.984717363484451, 'colsample_bytree': 0.8314489030925821, 'min_child_weight': 4, 'reg_lambda': 0.0003245588739058725}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:40:06,111] Trial 72 finished with value: 14.544279373403525 and parameters: {'max_depth': 6, 'max_leaves': 235, 'learning_rate': 0.02665858814619238, 'subsample': 0.9853272839417683, 'colsample_bytree': 0.8058578749548879, 'min_child_weight': 4, 'reg_lambda': 0.00017592908051713288}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:40:16,474] Trial 73 finished with value: 12.875160364222003 and parameters: {'max_depth': 6, 'max_leaves': 159, 'learning_rate': 0.05240555211937368, 'subsample': 0.9994561306820654, 'colsample_bytree': 0.8847755310379443, 'min_child_weight': 5, 'reg_lambda': 0.0016090247348136643}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:40:26,599] Trial 74 finished with value: 14.144886944318428 and parameters: {'max_depth': 6, 'max_leaves': 107, 'learning_rate': 0.053412969828653276, 'subsample': 0.9698184609284821, 'colsample_bytree': 0.8971236238327488, 'min_child_weight': 6, 'reg_lambda': 0.0003612647010967323}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:40:37,139] Trial 75 finished with value: 13.258625029999951 and parameters: {'max_depth': 6, 'max_leaves': 156, 'learning_rate': 0.04162007615157287, 'subsample': 0.9984477813110256, 'colsample_bytree': 0.9398950987996982, 'min_child_weight': 4, 'reg_lambda': 0.00013204744208342094}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:40:49,150] Trial 76 finished with value: 13.607260789578536 and parameters: {'max_depth': 7, 'max_leaves': 141, 'learning_rate': 0.039757709406326495, 'subsample': 0.9879461997334135, 'colsample_bytree': 0.8661040621222913, 'min_child_weight': 3, 'reg_lambda': 0.0021360347341348516}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:41:01,653] Trial 77 finished with value: 13.228245879072967 and parameters: {'max_depth': 8, 'max_leaves': 180, 'learning_rate': 0.047360926476808514, 'subsample': 0.9648112574874197, 'colsample_bytree': 0.851085208043986, 'min_child_weight': 5, 'reg_lambda': 0.0007167123452038571}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:41:12,317] Trial 78 finished with value: 14.388458915359545 and parameters: {'max_depth': 6, 'max_leaves': 217, 'learning_rate': 0.024151444796836927, 'subsample': 0.9685734159064536, 'colsample_bytree': 0.8316589976418015, 'min_child_weight': 4, 'reg_lambda': 0.011151803712085864}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:41:24,329] Trial 79 finished with value: 12.702057326649767 and parameters: {'max_depth': 8, 'max_leaves': 184, 'learning_rate': 0.0664950541465275, 'subsample': 0.9999865554415734, 'colsample_bytree': 0.8922712474879944, 'min_child_weight': 6, 'reg_lambda': 0.00436548498991619}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:41:35,071] Trial 80 finished with value: 15.476445301149633 and parameters: {'max_depth': 7, 'max_leaves': 194, 'learning_rate': 0.06718383494079325, 'subsample': 0.998195002249064, 'colsample_bytree': 0.9132733051767815, 'min_child_weight': 7, 'reg_lambda': 0.9497360885090783}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:41:47,434] Trial 81 finished with value: 14.219873650486505 and parameters: {'max_depth': 8, 'max_leaves': 179, 'learning_rate': 0.047514005046177456, 'subsample': 0.9547176817280169, 'colsample_bytree': 0.8816116810799169, 'min_child_weight': 6, 'reg_lambda': 0.0017777413064852927}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:42:00,279] Trial 82 finished with value: 12.854878644314427 and parameters: {'max_depth': 8, 'max_leaves': 120, 'learning_rate': 0.051788566380461254, 'subsample': 0.9995571340213142, 'colsample_bytree': 0.8586841025267837, 'min_child_weight': 5, 'reg_lambda': 0.004501173079165926}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:42:11,349] Trial 83 finished with value: 14.488975470049235 and parameters: {'max_depth': 7, 'max_leaves': 115, 'learning_rate': 0.056763036329407865, 'subsample': 0.9886649938225319, 'colsample_bytree': 0.9578813054324757, 'min_child_weight': 6, 'reg_lambda': 0.004364952534353619}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:42:21,331] Trial 84 finished with value: 14.184540910210378 and parameters: {'max_depth': 6, 'max_leaves': 157, 'learning_rate': 0.0730520694058376, 'subsample': 0.9309226234816713, 'colsample_bytree': 0.8933992694421021, 'min_child_weight': 5, 'reg_lambda': 0.003517259374244601}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:42:33,662] Trial 85 finished with value: 14.218400317700391 and parameters: {'max_depth': 8, 'max_leaves': 96, 'learning_rate': 0.05153514695999933, 'subsample': 0.977159244413971, 'colsample_bytree': 0.7464345657573308, 'min_child_weight': 4, 'reg_lambda': 0.004993289504010688}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:42:46,181] Trial 86 finished with value: 16.676820078945244 and parameters: {'max_depth': 10, 'max_leaves': 63, 'learning_rate': 0.06140603759047822, 'subsample': 0.999552986428431, 'colsample_bytree': 0.8626549258057526, 'min_child_weight': 8, 'reg_lambda': 0.0025408147631225857}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:42:59,387] Trial 87 finished with value: 14.086498939346576 and parameters: {'max_depth': 9, 'max_leaves': 208, 'learning_rate': 0.06426707704308202, 'subsample': 0.9472049321743345, 'colsample_bytree': 0.8330005838009701, 'min_child_weight': 6, 'reg_lambda': 0.007437763167914516}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:43:12,538] Trial 88 finished with value: 13.119548112587175 and parameters: {'max_depth': 8, 'max_leaves': 80, 'learning_rate': 0.031238331741489735, 'subsample': 0.9725271885852912, 'colsample_bytree': 0.9214539958895409, 'min_child_weight': 5, 'reg_lambda': 0.001027808434574777}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:43:24,086] Trial 89 finished with value: 13.23007566902412 and parameters: {'max_depth': 8, 'max_leaves': 44, 'learning_rate': 0.030621714483832316, 'subsample': 0.9902316889468509, 'colsample_bytree': 0.9292239910248347, 'min_child_weight': 4, 'reg_lambda': 0.0010376758092540584}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:43:36,360] Trial 90 finished with value: 13.765290828584746 and parameters: {'max_depth': 7, 'max_leaves': 83, 'learning_rate': 0.03291334599071404, 'subsample': 0.9770432364164482, 'colsample_bytree': 0.895520036729437, 'min_child_weight': 3, 'reg_lambda': 0.0033717978947993225}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:43:48,968] Trial 91 finished with value: 13.278981550923557 and parameters: {'max_depth': 8, 'max_leaves': 127, 'learning_rate': 0.05307128963432485, 'subsample': 0.9585856764038327, 'colsample_bytree': 0.915234819561431, 'min_child_weight': 5, 'reg_lambda': 0.0016701436318785892}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:44:03,450] Trial 92 finished with value: 13.890253115749564 and parameters: {'max_depth': 9, 'max_leaves': 138, 'learning_rate': 0.035127529562427554, 'subsample': 0.9413362299999881, 'colsample_bytree': 0.8833510071725186, 'min_child_weight': 5, 'reg_lambda': 0.009690887325110017}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:44:19,295] Trial 93 finished with value: 14.181751825353157 and parameters: {'max_depth': 9, 'max_leaves': 202, 'learning_rate': 0.02793825123124654, 'subsample': 0.9993147979607657, 'colsample_bytree': 0.8699018820769447, 'min_child_weight': 4, 'reg_lambda': 0.0013247797832650868}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:44:31,407] Trial 94 finished with value: 14.15916985393507 and parameters: {'max_depth': 8, 'max_leaves': 116, 'learning_rate': 0.0572440068265684, 'subsample': 0.973492770389468, 'colsample_bytree': 0.8509800689717326, 'min_child_weight': 6, 'reg_lambda': 0.0022494020997546106}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:44:43,540] Trial 95 finished with value: 15.26815200392032 and parameters: {'max_depth': 8, 'max_leaves': 219, 'learning_rate': 0.03782592014235896, 'subsample': 0.8077634077896043, 'colsample_bytree': 0.7080718920388553, 'min_child_weight': 5, 'reg_lambda': 0.00023410664373124912}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:44:59,676] Trial 96 finished with value: 17.654646267666926 and parameters: {'max_depth': 11, 'max_leaves': 190, 'learning_rate': 0.05107564454378699, 'subsample': 0.9626300804731838, 'colsample_bytree': 0.9767461690629319, 'min_child_weight': 15, 'reg_lambda': 0.00266306746785979}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:45:10,390] Trial 97 finished with value: 15.513067668771763 and parameters: {'max_depth': 7, 'max_leaves': 66, 'learning_rate': 0.07610553847747191, 'subsample': 0.9281718813796147, 'colsample_bytree': 0.9026428839643106, 'min_child_weight': 6, 'reg_lambda': 0.013744431410801016}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:45:25,729] Trial 98 finished with value: 15.991761530525816 and parameters: {'max_depth': 10, 'max_leaves': 264, 'learning_rate': 0.04395070385003437, 'subsample': 0.9096934729584176, 'colsample_bytree': 0.8169568197875828, 'min_child_weight': 7, 'reg_lambda': 0.0017597585555529278}. Best is trial 71 with value: 12.646635606535908.
# [I 2020-11-17 13:45:39,124] Trial 99 finished with value: 11.646402058460788 and parameters: {'max_depth': 9, 'max_leaves': 242, 'learning_rate': 0.06694921652295704, 'subsample': 0.9881858040427779, 'colsample_bytree': 0.7823109089478195, 'min_child_weight': 5, 'reg_lambda': 0.0004414605964471387}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:45:52,509] Trial 100 finished with value: 12.88125377992984 and parameters: {'max_depth': 9, 'max_leaves': 244, 'learning_rate': 0.06713102623495623, 'subsample': 0.9926861701557073, 'colsample_bytree': 0.7859930334469967, 'min_child_weight': 5, 'reg_lambda': 0.0005036760799958219}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:46:05,518] Trial 101 finished with value: 13.460408927623954 and parameters: {'max_depth': 9, 'max_leaves': 242, 'learning_rate': 0.08927669539006122, 'subsample': 0.9848463636381307, 'colsample_bytree': 0.7910066426800108, 'min_child_weight': 5, 'reg_lambda': 0.0004195351437384375}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:46:19,111] Trial 102 finished with value: 14.778656397298656 and parameters: {'max_depth': 9, 'max_leaves': 229, 'learning_rate': 0.06803648378096057, 'subsample': 0.9895047142507901, 'colsample_bytree': 0.7603546860284133, 'min_child_weight': 4, 'reg_lambda': 0.0005184042633946881}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:46:32,109] Trial 103 finished with value: 13.986978585894546 and parameters: {'max_depth': 9, 'max_leaves': 241, 'learning_rate': 0.0849089899345354, 'subsample': 0.9989867040166944, 'colsample_bytree': 0.7896113921111066, 'min_child_weight': 5, 'reg_lambda': 0.0002402568561676171}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:46:43,234] Trial 104 finished with value: 16.85551424229526 and parameters: {'max_depth': 8, 'max_leaves': 170, 'learning_rate': 0.06497687131194779, 'subsample': 0.9803538922189861, 'colsample_bytree': 0.7697850297226683, 'min_child_weight': 13, 'reg_lambda': 0.0008658371840890775}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:46:56,287] Trial 105 finished with value: 15.38449411389135 and parameters: {'max_depth': 9, 'max_leaves': 149, 'learning_rate': 0.07112283218136685, 'subsample': 0.9474842480605167, 'colsample_bytree': 0.728536833383891, 'min_child_weight': 4, 'reg_lambda': 0.0003077903743562923}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:47:08,599] Trial 106 finished with value: 12.207634190795243 and parameters: {'max_depth': 8, 'max_leaves': 212, 'learning_rate': 0.05461718173846922, 'subsample': 0.9731806824646878, 'colsample_bytree': 0.8003448070932677, 'min_child_weight': 5, 'reg_lambda': 0.00014968405380934576}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:47:18,607] Trial 107 finished with value: 14.471119985500657 and parameters: {'max_depth': 6, 'max_leaves': 220, 'learning_rate': 0.055843156046554224, 'subsample': 0.9997784108838449, 'colsample_bytree': 0.7996089977918202, 'min_child_weight': 6, 'reg_lambda': 0.0001481637876806931}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:47:32,334] Trial 108 finished with value: 14.052281578176139 and parameters: {'max_depth': 9, 'max_leaves': 209, 'learning_rate': 0.05992510159029508, 'subsample': 0.9590752246373698, 'colsample_bytree': 0.8264468769924572, 'min_child_weight': 5, 'reg_lambda': 0.000199414709819808}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:47:46,077] Trial 109 finished with value: 12.70913305598725 and parameters: {'max_depth': 9, 'max_leaves': 289, 'learning_rate': 0.06272669790565184, 'subsample': 0.9886372390772982, 'colsample_bytree': 0.7698796904227886, 'min_child_weight': 4, 'reg_lambda': 0.00040542072786509304}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:47:58,777] Trial 110 finished with value: 12.72584020709002 and parameters: {'max_depth': 8, 'max_leaves': 291, 'learning_rate': 0.06669675265342623, 'subsample': 0.9909601435908509, 'colsample_bytree': 0.7784828214818137, 'min_child_weight': 3, 'reg_lambda': 0.0004396281094241019}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:48:11,402] Trial 111 finished with value: 13.26319144347797 and parameters: {'max_depth': 8, 'max_leaves': 287, 'learning_rate': 0.06696567652626091, 'subsample': 0.9928913428333495, 'colsample_bytree': 0.7678913885418998, 'min_child_weight': 3, 'reg_lambda': 0.0006342269575591726}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:48:22,458] Trial 112 finished with value: 14.129153583083687 and parameters: {'max_depth': 7, 'max_leaves': 312, 'learning_rate': 0.07567594426302358, 'subsample': 0.9873972871115416, 'colsample_bytree': 0.7838189632460112, 'min_child_weight': 4, 'reg_lambda': 0.00042254235742304405}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:48:35,330] Trial 113 finished with value: 15.113858198936164 and parameters: {'max_depth': 8, 'max_leaves': 271, 'learning_rate': 0.05874218554779577, 'subsample': 0.9751326707010397, 'colsample_bytree': 0.7843812193466461, 'min_child_weight': 3, 'reg_lambda': 0.0003260222904767312}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:48:48,109] Trial 114 finished with value: 14.601657607307956 and parameters: {'max_depth': 8, 'max_leaves': 186, 'learning_rate': 0.06227477014921806, 'subsample': 0.9642745536267753, 'colsample_bytree': 0.8199103270727551, 'min_child_weight': 3, 'reg_lambda': 0.0005073535171148763}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:49:01,776] Trial 115 finished with value: 15.201299075392484 and parameters: {'max_depth': 9, 'max_leaves': 334, 'learning_rate': 0.07020003385642443, 'subsample': 0.9907626606006591, 'colsample_bytree': 0.8031812162173356, 'min_child_weight': 4, 'reg_lambda': 0.0007417644857564585}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:49:12,468] Trial 116 finished with value: 13.729876162604533 and parameters: {'max_depth': 7, 'max_leaves': 198, 'learning_rate': 0.08242326167644602, 'subsample': 0.980510428516344, 'colsample_bytree': 0.7547224464077384, 'min_child_weight': 5, 'reg_lambda': 0.0002675971588933242}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:49:28,163] Trial 117 finished with value: 13.524736572985114 and parameters: {'max_depth': 10, 'max_leaves': 159, 'learning_rate': 0.05484834466472737, 'subsample': 0.9982396094366485, 'colsample_bytree': 0.8471534420162219, 'min_child_weight': 4, 'reg_lambda': 0.00040924526191659136}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:49:40,669] Trial 118 finished with value: 15.774837088934996 and parameters: {'max_depth': 9, 'max_leaves': 288, 'learning_rate': 0.06492743357059146, 'subsample': 0.9436313971383139, 'colsample_bytree': 0.7410784246742084, 'min_child_weight': 9, 'reg_lambda': 0.0005685037112008291}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:49:52,190] Trial 119 finished with value: 14.265937509018183 and parameters: {'max_depth': 8, 'max_leaves': 248, 'learning_rate': 0.07799588357134646, 'subsample': 0.999993037641999, 'colsample_bytree': 0.778952208314482, 'min_child_weight': 6, 'reg_lambda': 0.0012102352678928533}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:50:02,364] Trial 120 finished with value: 13.78625461237177 and parameters: {'max_depth': 6, 'max_leaves': 173, 'learning_rate': 0.04947608461992446, 'subsample': 0.9527300882306696, 'colsample_bytree': 0.8371792881354587, 'min_child_weight': 5, 'reg_lambda': 0.001394425502475494}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:50:16,236] Trial 121 finished with value: 12.914658426542472 and parameters: {'max_depth': 9, 'max_leaves': 234, 'learning_rate': 0.051632482325625534, 'subsample': 0.9697291582530142, 'colsample_bytree': 0.7766650497945095, 'min_child_weight': 5, 'reg_lambda': 0.0003373478755027294}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:50:30,219] Trial 122 finished with value: 13.715802815073033 and parameters: {'max_depth': 9, 'max_leaves': 228, 'learning_rate': 0.05271552269844531, 'subsample': 0.9701095380756055, 'colsample_bytree': 0.7599004920598736, 'min_child_weight': 4, 'reg_lambda': 0.0003466711104424117}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:50:43,711] Trial 123 finished with value: 12.740621411854088 and parameters: {'max_depth': 9, 'max_leaves': 320, 'learning_rate': 0.06215164100486865, 'subsample': 0.9854082239988027, 'colsample_bytree': 0.7937187016050089, 'min_child_weight': 5, 'reg_lambda': 0.0004718590215607243}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:50:56,803] Trial 124 finished with value: 15.433180989755517 and parameters: {'max_depth': 9, 'max_leaves': 326, 'learning_rate': 0.06140807408102747, 'subsample': 0.9808517276632339, 'colsample_bytree': 0.7963719343648104, 'min_child_weight': 6, 'reg_lambda': 0.00044348992160281217}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:51:10,586] Trial 125 finished with value: 14.856529662098263 and parameters: {'max_depth': 9, 'max_leaves': 346, 'learning_rate': 0.05907476608797745, 'subsample': 0.9656438616636928, 'colsample_bytree': 0.7779571267990968, 'min_child_weight': 4, 'reg_lambda': 0.00013806026700506217}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:51:23,679] Trial 126 finished with value: 12.613469470850767 and parameters: {'max_depth': 9, 'max_leaves': 294, 'learning_rate': 0.07165591777545245, 'subsample': 0.9888722050742123, 'colsample_bytree': 0.7334100959905278, 'min_child_weight': 5, 'reg_lambda': 0.0002758667667905222}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:51:35,756] Trial 127 finished with value: 12.43774542811958 and parameters: {'max_depth': 8, 'max_leaves': 314, 'learning_rate': 0.0722916136190819, 'subsample': 0.9920108341231462, 'colsample_bytree': 0.812087352036881, 'min_child_weight': 5, 'reg_lambda': 0.0001804771803801299}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:51:48,060] Trial 128 finished with value: 16.01757241272134 and parameters: {'max_depth': 8, 'max_leaves': 313, 'learning_rate': 0.07080827356970112, 'subsample': 0.9899911221013702, 'colsample_bytree': 0.8098905198640609, 'min_child_weight': 4, 'reg_lambda': 0.0002528212909764815}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:52:00,017] Trial 129 finished with value: 12.775160074892797 and parameters: {'max_depth': 8, 'max_leaves': 301, 'learning_rate': 0.0741860926565116, 'subsample': 0.9823262811792385, 'colsample_bytree': 0.8616148409159865, 'min_child_weight': 5, 'reg_lambda': 0.00010792806690759146}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:52:11,369] Trial 130 finished with value: 14.739670403433221 and parameters: {'max_depth': 7, 'max_leaves': 300, 'learning_rate': 0.08813797910374581, 'subsample': 0.9816328223075554, 'colsample_bytree': 0.8580461929342289, 'min_child_weight': 3, 'reg_lambda': 0.0001244117995645587}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:52:23,368] Trial 131 finished with value: 13.078500033571883 and parameters: {'max_depth': 8, 'max_leaves': 295, 'learning_rate': 0.07398740591729841, 'subsample': 0.9901089655110267, 'colsample_bytree': 0.8189000440049804, 'min_child_weight': 5, 'reg_lambda': 0.00019470002916839845}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:52:35,200] Trial 132 finished with value: 13.625881787446126 and parameters: {'max_depth': 8, 'max_leaves': 317, 'learning_rate': 0.06646706353214037, 'subsample': 0.9997143484646146, 'colsample_bytree': 0.8706512211357565, 'min_child_weight': 6, 'reg_lambda': 0.00015422847844265232}. Best is trial 99 with value: 11.646402058460788.
# [I 2020-11-17 13:52:47,137] Trial 133 finished with value: 13.521631536140916 and parameters: {'max_depth': 8, 'max_leaves': 279, 'learning_rate': 0.07932764272575851, 'subsample': 0.9993478721788939, 'colsample_bytree': 0.8265710495636008, 'min_child_weight': 5, 'reg_lambda': 0.00011471709364428022}. Best is trial 99 with value: 11.646402058460788.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-dc92947633ff> in <module>()
#       1 study = optuna.create_study()
# ----> 2 study.optimize(objective, n_trials=250)
#
# /usr/local/lib/python3.6/dist-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     313             callbacks=callbacks,
#     314             gc_after_trial=gc_after_trial,
# --> 315             show_progress_bar=show_progress_bar,
#     316         )
#     317
#
# /usr/local/lib/python3.6/dist-packages/optuna/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      63                 reseed_sampler_rng=False,
#      64                 time_start=None,
# ---> 65                 progress_bar=progress_bar,
#      66             )
#      67         else:
#
# /usr/local/lib/python3.6/dist-packages/optuna/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     154
#     155         try:
# --> 156             trial = _run_trial(study, func, catch)
#     157         except Exception:
#     158             raise
#
# /usr/local/lib/python3.6/dist-packages/optuna/_optimize.py in _run_trial(study, func, catch)
#     187
#     188     try:
# --> 189         value = func(trial)
#     190     except exceptions.TrialPruned as e:
#     191         # Register the last intermediate value if present as the value of the trial.
#
# <ipython-input-14-d90174c23897> in objective(trial)
#      20
#      21     model.fit(Xtrain_new, Ytrain_new, eval_set=[(Xtest, Ytest)],
# ---> 22               early_stopping_rounds=100, verbose=False)
#      23     y_pred = model.predict(Xtest, ntree_limit=model.best_ntree_limit)
#      24     rmse = np.sqrt(mean_squared_error(Ytest, y_pred))
#
# /usr/local/lib/python3.6/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print(" Value: {}".format(trial.value))

print("Params: ")
for key, value in trial.params.items():
    print(" {}: {}".format(key, value))
# Out:
# Number of finished trials: 135
# Best trial:
#  Value: 11.646402058460788
# Params:
#  max_depth: 9
#  max_leaves: 242
#  learning_rate: 0.06694921652295704
#  subsample: 0.9881858040427779
#  colsample_bytree: 0.7823109089478195
#  min_child_weight: 5
#  reg_lambda: 0.0004414605964471387

# %%
del Xtrain_new
del Ytrain_new
del Xtest
del Ytest
gc.collect()
# Out:
# 89

# %% [markdown]
# ## Build and validate the model

# %%
# Set number of K-Folds
FOLD = 5

# Set seeds for model training
np.random.seed(3)
seeds = np.random.randint(0, 100, size=3)

oof_rmse_score = 0
y_pred_final_xgb = 0
counter = 0


for seed in seeds:
    seed_rmse_score = 0
    
    # Define K-fold cross validation test harness
    kfold = KFold(n_splits=FOLD, shuffle=True, random_state=seed)

    for idx, (train, val) in enumerate(kfold.split(Xtrain.values, Ytrain.values)):
        counter += 1

        train_x, train_y = Xtrain.iloc[train], Ytrain.iloc[train]
        val_x, val_y = Xtrain.iloc[val], Ytrain.iloc[val]

        model = XGBRegressor(
            objective='reg:squarederror',
            eval_metric='rmse',
            booster='gbtree',
            sample_type='uniform',
            tree_method='gpu_hist',
            grow_policy='lossguide',
            num_round=8000,
            max_depth=9, 
            max_leaves=242,
            learning_rate=0.067,
            subsample=0.988,
            colsample_bytree=0.7823,
            min_child_weight=5,
            reg_lambda=0.00044,
            verbosity=0
        )

        model.fit(train_x, train_y, eval_set=[(val_x, val_y)], 
                  early_stopping_rounds=100, verbose=1000)

        y_pred = model.predict(val_x, ntree_limit=model.best_ntree_limit)
        y_pred_final_xgb += model.predict(Xpredict, ntree_limit=model.best_ntree_limit)
        score = np.sqrt(mean_squared_error(val_y, y_pred))
        oof_rmse_score += score
        seed_rmse_score += score
        print("Seed-{} | Fold-{} | RMSE Score: {}".format(seed, idx, score))
    
    print("\nSeed: {} | Aggregate Log Loss: {}\n\n".format(seed, (seed_rmse_score / FOLD)))

y_pred_final_xgb /= float(counter)
oof_rmse_score /= float(counter)
print("Aggregate RMSE Score: {}".format(oof_rmse_score))
# Out:
# [0]	validation_0-rmse:15.3559
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:31.7018
# Seed-24 | Fold-0 | RMSE Score: 15.35591769464343
# [0]	validation_0-rmse:17.0291
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:43.4344
# Seed-24 | Fold-1 | RMSE Score: 17.029091600463058
# [0]	validation_0-rmse:177.42
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:175.894
# Seed-24 | Fold-2 | RMSE Score: 175.8906843788416
# [0]	validation_0-rmse:39.5464
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:45.9569
# Seed-24 | Fold-3 | RMSE Score: 39.54642898344322
# [0]	validation_0-rmse:5.94059
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:35.9033
# Seed-24 | Fold-4 | RMSE Score: 5.940591112104452
#
# Seed: 24 | Aggregate Log Loss: 50.75254275389914
#
#
# [0]	validation_0-rmse:181.291
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:179.322
# Seed-3 | Fold-0 | RMSE Score: 179.2955724523432
# [0]	validation_0-rmse:10.0911
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:23.5316
# Seed-3 | Fold-1 | RMSE Score: 9.70215578937114
# [0]	validation_0-rmse:16.3403
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:35.3299
# Seed-3 | Fold-2 | RMSE Score: 16.34029610075621
# [0]	validation_0-rmse:10.126
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:39.4377
# Seed-3 | Fold-3 | RMSE Score: 10.12597524164091
# [0]	validation_0-rmse:16.1412
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:39.0237
# Seed-3 | Fold-4 | RMSE Score: 16.141175549771926
#
# Seed: 3 | Aggregate Log Loss: 46.32103502677668
#
#
# [0]	validation_0-rmse:16.3121
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:72.8362
# Seed-56 | Fold-0 | RMSE Score: 16.312095107186625
# [0]	validation_0-rmse:181.213
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:179.341
# Seed-56 | Fold-1 | RMSE Score: 179.1874581743098
# [0]	validation_0-rmse:7.94667
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:21.432
# Seed-56 | Fold-2 | RMSE Score: 7.9466703984499905
# [0]	validation_0-rmse:9.56823
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:22.7894
# Seed-56 | Fold-3 | RMSE Score: 9.568234851490981
# [0]	validation_0-rmse:17.293
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [99]	validation_0-rmse:46.3256
# Seed-56 | Fold-4 | RMSE Score: 17.29301936464611
#
# Seed: 56 | Aggregate Log Loss: 46.0614955792167
#
#
# Aggregate RMSE Score: 47.711691119964165

# %% [markdown]
# ## Create submission file

# %%
#tmp = np.array([y_pred_final_xgb]).T
#y_pred_final = pt.inverse_transform(tmp)
submit_df = pd.DataFrame(y_pred_final_xgb, columns=['UnitPrice'])
print(submit_df.shape)
submit_df.head()
# Out:
# (122049, 1)
#    UnitPrice
# 0   1.558417
# 1   1.623244
# 2   2.496832
# 3   1.182177
# 4   6.546930

# %%
submit_df.to_csv('/content/drive/My Drive/Colab Notebooks/The Great Hiring Challenge/Experiment-2/Predictions/predictions_v10_XGB.csv', index=False)
