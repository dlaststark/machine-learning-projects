# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb
import xgboost as xgb
import optuna

# %% [markdown]
# ## Read training data

# %%
train_df = pd.read_csv("Dataset/Train.csv", index_col='Day')
train_df.head()
# Out:
#      GrocerySales
# Day
# 1         8418.59
# 2         8447.47
# 3         8336.49
# 4         8579.17
# 5         8524.31

# %% [markdown]
# ## Exploratory Data Analysis

# %%
def test_stationarity(timeseries):
    '''
    Check stationarity of time series data
    '''
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
plt.figure(figsize=(15,8))
plt.grid()
test_stationarity(train_df)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.316546
# p-value                          0.000416
# #Lags Used                       2.000000
# Number of Observations Used    689.000000
# Critical Value (1%)             -3.439877
# Critical Value (5%)             -2.865744
# Critical Value (10%)            -2.569009
# dtype: float64

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Normalize training data

# %%
train = train_df.values
scaler = MinMaxScaler().fit(train)
train = scaler.transform(train)

# %% [markdown]
# #### Prepare dataset for time-series model

# %%
window_size = 90

# %%
def prepare_data(sales_list, item=None):
    
    if item is not None:
        sales_list = sales_list[1:]
        sales_list = np.append(sales_list, item)
        
    df = pd.DataFrame(np.array([sales_list]).T, columns=["Sales"])
    df["cum_mean"] = df['Sales'].expanding().mean()
    df["cum_std"] = df['Sales'].expanding().std()
    df["cum_std"] = df["cum_std"].fillna(0)
    
    for i in range(1, window_size+1):
        if i == window_size:
            df['target'] = df['Sales'].shift(-i)
        else:
            df['sale-lag-'+str(i)] = df['Sales'].shift(-i)
            df['sale-lag-diff-'+str(i)] = df['Sales'] - df['Sales'].shift(-i)
    
        if i < window_size:
            df['mean-lag-'+str(i)] = df['cum_mean'].shift(-i)
            df['std-lag-'+str(i)] = df['cum_std'].shift(-i)
    
    df.dropna(inplace=True)
    df.drop(['cum_mean', 'cum_std'], inplace=True, axis=1)
    
    return sales_list, df

# %%
sales_list = train.ravel()
_, sales_df = prepare_data(sales_list)
sales_df.head()
# Out:
#       Sales  sale-lag-1  sale-lag-diff-1  mean-lag-1  std-lag-1  sale-lag-2  \
# 0  0.654695    0.666138        -0.011444    0.660416   0.008092    0.622162
# 1  0.666138    0.622162         0.043976    0.647665   0.022815    0.718325
# 2  0.622162    0.718325        -0.096162    0.665330   0.039940    0.696586
# 3  0.718325    0.696586         0.021738    0.671581   0.037307    0.735890
# 4  0.696586    0.735890        -0.039304    0.682299   0.042458    0.615672
#
#    sale-lag-diff-2  mean-lag-2  std-lag-2  sale-lag-3  ...  std-lag-87  \
# 0         0.032532    0.647665   0.022815    0.718325  ...    0.159936
# 1        -0.052186    0.665330   0.039940    0.696586  ...    0.159848
# 2        -0.074424    0.671581   0.037307    0.735890  ...    0.160104
# 3        -0.017566    0.682299   0.042458    0.615672  ...    0.160083
# 4         0.080915    0.672781   0.046222    0.613064  ...    0.159457
#
#    sale-lag-88  sale-lag-diff-88  mean-lag-88  std-lag-88  sale-lag-89  \
# ...

# %%
train_y = np.array([sales_df['target'].values]).T
sales_df.drop(['target'], inplace=True, axis=1)
train_x = sales_df.values
print("train_x: {} \ntrain_y: {}".format(train_x.shape, train_y.shape))
# Out:
# train_x: (602, 357)
# train_y: (602, 1)

# %%
Xtrain_full = train_x.copy()
Ytrain_full = train_y.copy()

# %% [markdown]
# #### Create train and test datasets

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(train_x, train_y, test_size=0.05, shuffle=False, random_state=10)
print("Xtrain: {} \nYtrain: {}".format(Xtrain.shape, Ytrain.shape))
print("Xtest: {} \nYtest: {}".format(Xtest.shape, Ytest.shape))
# Out:
# Xtrain: (571, 357)
# Ytrain: (571, 1)
# Xtest: (31, 357)
# Ytest: (31, 1)

# %% [markdown]
# #### Plot train/test dataset division

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(0, len(Ytrain)), Ytrain, 'g', label="train")
plt.plot(np.arange(len(Ytrain), len(Ytrain) + len(Ytest)), Ytest, 'r', label="test")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## LightGBM Model

# %% [markdown]
# #### Time-series Model

# %%
params = {}
params["objective"] = 'regression'
params['metric'] = 'rmse'
params['boosting'] = 'gbdt'
params["max_depth"] = 21
params["num_leaves"] = 131
params["learning_rate"] = 0.077
params["bagging_fraction"] = 0.81
params["feature_fraction"] = 0.70
params["bagging_freq"] = 13
params["bagging_seed"] = 10
params["lambda_l2"] = 0.0008
params["min_data_in_leaf"] = 7
params["verbosity"] = -1
num_rounds = 5000

# %%
lgtrain = lgb.Dataset(Xtrain, label=Ytrain.ravel())
lgtest = lgb.Dataset(Xtest, label=Ytest.ravel())

# %%
model = lgb.train(params, lgtrain, num_rounds, valid_sets=[lgtest], early_stopping_rounds=200, verbose_eval=1000)
# Out:
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [59]	valid_0's rmse: 0.0628966

# %%
y_pred = model.predict(Xtest, num_iteration=model.best_iteration)

# %% [markdown]
# #### Get RMSE value on test dataset predictions

# %%
np.sqrt(mean_squared_error(Ytest, y_pred))
# Out:
# 0.06289663603670036

# %% [markdown]
# #### Plot the predictions on test dataset

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(0, len(Ytrain)), Ytrain, 'g', label="history")
plt.plot(np.arange(len(Ytrain), len(Ytrain) + len(Ytest)), Ytest, marker='.', label="true data")
plt.plot(np.arange(len(Ytrain), len(Ytrain) + len(y_pred)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(Ytest, marker='*', label="true data")
plt.plot(y_pred, marker='o', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Train the model on entire training data

# %%
lgtrain = lgb.Dataset(Xtrain_full, label=Ytrain_full.ravel())
model = lgb.train(params, lgtrain, num_rounds, verbose_eval=1000)

# %% [markdown]
# #### Make predictions for future 90 days

# %%
Ypred_lgb = []

for i in range(90):
    Xpred = sales_df[-1:]
    y_pred = model.predict(Xpred, num_iteration=model.best_iteration)
    Ypred_lgb.append(y_pred)
    
    sales_list, sales_df = prepare_data(sales_list, y_pred)
    sales_df.drop(['target'], inplace=True, axis=1)

# %% [markdown]
# ## Random Forest Model

# %% [markdown]
# #### Time-series Model

# %%
rf = RandomForestRegressor(n_estimators = 200, 
                           max_depth = 56,
                           min_samples_leaf = 9,
                           min_samples_split = 0.1,
                           random_state = 10, 
                           verbose=100)

# %%
rf.fit(Xtrain, Ytrain.ravel())
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# building tree 1 of 200
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# building tree 2 of 200
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# building tree 3 of 200
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# building tree 4 of 200
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# building tree 5 of 200
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s remaining:    0.0s
# building tree 6 of 200
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.4s remaining:    0.0s
# building tree 7 of 200
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.5s remaining:    0.0s
# building tree 8 of 200
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.6s remaining:    0.0s
# building tree 9 of 200
# ...

# %%
y_pred = rf.predict(Xtest)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.0s remaining:    0.0s
# ...

# %% [markdown]
# #### Get RMSE value on test dataset predictions

# %%
np.sqrt(mean_squared_error(Ytest, y_pred))
# Out:
# 0.05540493120781545

# %% [markdown]
# #### Plot the predictions on test dataset

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(0, len(Ytrain)), Ytrain, 'g', label="history")
plt.plot(np.arange(len(Ytrain), len(Ytrain) + len(Ytest)), Ytest, marker='.', label="true data")
plt.plot(np.arange(len(Ytrain), len(Ytrain) + len(y_pred)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(Ytest, marker='*', label="true data")
plt.plot(y_pred, marker='o', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Train the model on entire training data

# %%
rf.fit(Xtrain_full, Ytrain_full.ravel())
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# building tree 1 of 200
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# building tree 2 of 200
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# building tree 3 of 200
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# building tree 4 of 200
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# building tree 5 of 200
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s remaining:    0.0s
# building tree 6 of 200
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.5s remaining:    0.0s
# building tree 7 of 200
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.5s remaining:    0.0s
# building tree 8 of 200
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.6s remaining:    0.0s
# building tree 9 of 200
# ...

# %% [markdown]
# #### Make predictions for future 90 days

# %%
sales_list = train.ravel()
_, sales_df = prepare_data(sales_list)
sales_df.drop(['target'], inplace=True, axis=1)

# %%
Ypred_rf = []

for i in range(90):
    Xpred = sales_df[-1:]
    y_pred = rf.predict(Xpred)
    Ypred_rf.append(y_pred)
    
    sales_list, sales_df = prepare_data(sales_list, y_pred)
    sales_df.drop(['target'], inplace=True, axis=1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.0s remaining:    0.0s
# ...

# %% [markdown]
# ## XGBoost Model

# %% [markdown]
# #### Time-series Model

# %%
model = xgb.XGBRegressor(max_depth=54, 
                         learning_rate=0.055,
                         subsample=0.77,
                         min_child_weight=7,
                         n_estimators=500, 
                         eval_metric='rmse', 
                         verbosity=3)

# %%
model.fit(Xtrain, Ytrain.flatten())
# Out:
# [03:37:39] DEBUG: /workspace/src/gbm/gbtree.cc:146: Using tree method: 2
# [03:37:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [03:37:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=7
# [03:37:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=7
# [03:37:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=7
# [03:37:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=8
# [03:37:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=8
# [03:37:39] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=9
# ...

# %%
y_pred = model.predict(Xtest)

# %% [markdown]
# #### Get RMSE value on test dataset predictions

# %%
np.sqrt(mean_squared_error(Ytest, y_pred))
# Out:
# 0.05912968025558995

# %% [markdown]
# #### Plot the predictions on test dataset

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(0, len(Ytrain)), Ytrain, 'g', label="history")
plt.plot(np.arange(len(Ytrain), len(Ytrain) + len(Ytest)), Ytest, marker='.', label="true data")
plt.plot(np.arange(len(Ytrain), len(Ytrain) + len(y_pred)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(Ytest, marker='*', label="true data")
plt.plot(y_pred, marker='o', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Train the model on entire training data

# %%
model.fit(Xtrain_full, Ytrain_full.flatten())
# Out:
# [03:39:20] DEBUG: /workspace/src/gbm/gbtree.cc:146: Using tree method: 2
# [03:39:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [03:39:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=7
# [03:39:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [03:39:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [03:39:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=7
# [03:39:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=9
# [03:39:20] INFO: /workspace/src/tree/updater_prune.cc:89: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=10
# ...

# %% [markdown]
# #### Make predictions for future 90 days

# %%
sales_list = train.ravel()
_, sales_df = prepare_data(sales_list)
sales_df.drop(['target'], inplace=True, axis=1)

# %%
Ypred_xgb = []

for i in range(90):
    Xpred = sales_df[-1:].values
    y_pred = model.predict(Xpred)
    Ypred_xgb.append(y_pred)
    
    sales_list, sales_df = prepare_data(sales_list, y_pred)
    sales_df.drop(['target'], inplace=True, axis=1)

# %% [markdown]
# ## Final prediction data

# %%
final_pred = (np.array(Ypred_lgb) + np.array(Ypred_rf) + np.array(Ypred_xgb))/3

# %% [markdown]
# #### Plot future predictions

# %%
plt.figure(figsize=(15,8))
plt.plot(np.arange(0, len(Ytrain_full)), Ytrain_full, 'g', label="history")
plt.plot(np.arange(len(Ytrain_full), len(Ytrain_full) + len(final_pred)), final_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Create submission file

# %%
final_pred = np.array(final_pred)
final_pred = scaler.inverse_transform(final_pred)
print(final_pred.shape)
# Out:
# (90, 1)

# %%
submit_df = pd.DataFrame(final_pred, columns=['GrocerySales'])
submit_df['GrocerySales'] = submit_df['GrocerySales'].astype(float).round(2)
submit_df.head()
# Out:
#    GrocerySales
# 0       8958.41
# 1       8946.87
# 2       8929.89
# 3       8936.35
# 4       8921.64

# %%
submit_df.to_excel("predictions_v9.xlsx", index=False)
