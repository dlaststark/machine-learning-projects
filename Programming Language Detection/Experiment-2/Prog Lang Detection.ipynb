# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/Programming Language Detection/Experiment-2'
# Out:
#  Artifacts    'Final Model'   predict.py		  'Saved Files'   utils
#  Dataset.zip   Predictions   'Prog Lang Detection.ipynb'   train.py

# %%
import sys
sys.path.insert(1, '/content/drive/My Drive/Colab Notebooks/Programming Language Detection/Experiment-2')
# %tensorflow_version 2.x

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#      |████████████████████████████████| 71kB 3.2MB/s
# ...
#      |████████████████████████████████| 1.1MB 6.1MB/s
# ...
#      |████████████████████████████████| 890kB 12.9MB/s
# ...
#      |████████████████████████████████| 1.1MB 29.6MB/s
# ...
#      |████████████████████████████████| 3.0MB 44.7MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.3.8-cp36-none-any.whl size=101996 sha256=17b0b74b6fc0544e0e4b9b850a6c59316b6cd07eaadaf07fc161c81df62fce7e
#   Stored in directory: /root/.cache/pip/wheels/27/ec/b3/d12cc8e4daf77846db6543033d3a5642f204c0320b15945647
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=3c436f1da3a722750afca06cb7dfa7d73649664760e8fac182cfc86618cb9fbb
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sentence-transformers sacremoses
# ...

# %%
! unzip '/content/drive/My Drive/Colab Notebooks/Programming Language Detection/Experiment-2/Dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset/Train/Rust/fibonacci-sequence-2.rust
#   inflating: Dataset/Train/Rust/fibonacci-sequence-3.rust
#   inflating: Dataset/Train/Rust/fibonacci-sequence-4.rust
#   inflating: Dataset/Train/Rust/fibonacci-sequence-5.rust
#   inflating: Dataset/Train/Rust/fibonacci-sequence-6.rust
#   inflating: Dataset/Train/Rust/fibonacci-word.rust
#   inflating: Dataset/Train/Rust/file-input-output-1.rust
#   inflating: Dataset/Train/Rust/file-input-output-2.rust
#   inflating: Dataset/Train/Rust/file-modification-time.rust
#   inflating: Dataset/Train/Rust/file-size.rust
#   inflating: Dataset/Train/Rust/filter.rust
#   inflating: Dataset/Train/Rust/find-common-directory-path.rust
#   inflating: Dataset/Train/Rust/find-limit-of-recursion.rust
#   inflating: Dataset/Train/Rust/first-class-functions-use-numbers-analogously.rust
#   inflating: Dataset/Train/Rust/first-class-functions.rust
# ...

# %%
% run '/content/drive/My Drive/Colab Notebooks/Programming Language Detection/Experiment-2/train.py' \
--dataset_path 'Dataset/Train' \
--max_iterations 275 \
--mini_batch_size 256 \
--model_save_path '/content/drive/My Drive/Colab Notebooks/Programming Language Detection/Experiment-2/Final Model'
# Out:
# [2020-11-05 13:03:36.124273]  Starting data preprocessing for training data...
# [2020-11-05 13:03:36.125282]    load_train_data module started...
# [2020-11-05 13:03:39.891867]    load_train_data module completed.
# [2020-11-05 13:03:39.893374]  Data preprocessing for training data completed.
# [2020-11-05 13:03:39.893476]  --------- Training Dataset ---------
# [2020-11-05 13:03:39.893506]      Xtrain shape: (29073, 2047, 1)
# [2020-11-05 13:03:39.893537]      Ytrain shape: (29073, 1)
# [2020-11-05 13:03:39.893561]      Ytrain_oh shape: (29073, 35)
# [2020-11-05 13:03:39.893603]  --------- Test Dataset ---------
# [2020-11-05 13:03:39.893625]      Xtest shape: (3231, 2047, 1)
# [2020-11-05 13:03:39.893665]      Ytest shape: (3231, 1)
# [2020-11-05 13:03:42.357221]  Model Summary...
#
# Model: "Prog_Lang_Detect_Model"
# __________________________________________________________________________________________________
# ...

# %%
% run '/content/drive/My Drive/Colab Notebooks/Programming Language Detection/Experiment-2/predict.py' \
--dataset_path 'Dataset/Test' \
--model_save_path '/content/drive/My Drive/Colab Notebooks/Programming Language Detection/Experiment-2/Final Model' \
--pred_file_name 'model_predictions.csv'
# Out:
# [2020-11-04 14:42:48.172943]  Starting data preprocessing for test data...
# [2020-11-04 14:42:48.173057]    prepare_predict_data module started...
# [2020-11-04 14:42:48.180559]    prepare_predict_data module completed.
# [2020-11-04 14:42:48.180656]    feature_engg module started...
# [2020-11-04 14:42:48.205325]      TF-IDF Vectorization started...
# [2020-11-04 14:42:48.652580]      TF-IDF Vectorization completed.
# [2020-11-04 14:42:58.564711]      Roberta Base Embedding started...
# ...
# [2020-11-04 14:43:09.209579]      Roberta Base Embedding completed.
# [2020-11-04 14:43:09.209693]      BERT Base Embedding started...
# ...
# [2020-11-04 14:43:09.774846]      BERT Base Embedding completed.
# [2020-11-04 14:43:09.778358]    feature_engg module completed.
# [2020-11-04 14:43:10.123166]  Data preprocessing for test data completed.
# [2020-11-04 14:43:17.608674]  Trained model loaded for making predictions.
# ...
