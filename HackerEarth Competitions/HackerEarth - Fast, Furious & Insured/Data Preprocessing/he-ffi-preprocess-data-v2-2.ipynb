# %% [markdown]
# ## Import libraries

# %%
import gc
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, load_model
from tensorflow_addons.optimizers import AdamW, Lookahead

# %% [markdown]
# ## Helper Functions

# %%
def build_decoder(with_labels=True, img_size=64, ext='jpg'):
    def decode(path, add_noise=True):
        file_bytes = tf.io.read_file(path)

        if ext == 'png':
            img = tf.image.decode_png(file_bytes, channels=3)
        elif ext in ['jpg', 'jpeg']:
            img = tf.image.decode_jpeg(file_bytes, channels=3)
        else:
            raise ValueError("Image extension not supported")

        img = tf.cast(img, tf.float32) / 255.0
        img = tf.image.resize(img, (img_size, img_size), method="bicubic")
        
        if add_noise:
            noise = np.random.normal(loc=0.1, scale=0.2, size=img.shape)
            img = tf.clip_by_value(tf.add(img, noise), 0, 1)

        return img
    
    def decode_with_labels(src_img_path, tgt_img_path):
        return decode(src_img_path), decode(tgt_img_path, add_noise=False)
    
    return decode_with_labels if with_labels else decode

# %%
def build_dataset(paths, labels=None, 
                  bsize=32, decode_fn=None, 
                  repeat=True, shuffle=256):
    
    AUTO = tf.data.experimental.AUTOTUNE
    slices = paths if labels is None else (paths, labels)
    
    dset = tf.data.Dataset.from_tensor_slices(slices)
    dset = dset.map(decode_fn, num_parallel_calls=AUTO)
    dset = dset.repeat() if repeat else dset
    dset = dset.shuffle(shuffle) if shuffle else dset
    dset = dset.batch(bsize).prefetch(AUTO)
    return dset

# %% [markdown]
# ## Load autoencoder model

# %%
autoencoder = load_model('../input/he-ffi-dae-model-v2/DAE_model.h5')
feature_model = Model(inputs=autoencoder.input,
                      outputs=autoencoder.get_layer('Embedding').output)
feature_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 192, 192, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 96, 96, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 96, 96, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 96, 96, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 12, 12, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 1536)              7079424
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1536)              6144
# _________________________________________________________________
# Embedding (Activation)       (None, 1536)              0
# =================================================================
# Total params: 7,180,224
# Trainable params: 7,176,448
# Non-trainable params: 3,776
# _________________________________________________________________

# %% [markdown]
# ## Prepare data

# %%
with open("../input/he-ffi-preprocess-data/HE_FFI_Dataset.txt", 'rb') as handle: 
    data = handle.read()

processed_data = pickle.loads(data)
train_df = processed_data['train_df']
test_df = processed_data['test_df']

del processed_data
gc.collect()

train_df.shape, test_df.shape
# Out:
# ((1382, 157), (600, 156))

# %%
train_df['id'] = train_df['Image_path']
test_df['id'] = test_df['Image_path']
train_df.set_index("id", inplace=True)
test_df.set_index("id", inplace=True)
train_df.head()
# Out:
#                                                     Insurance_company  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...                6.0
# ../input/he-fast-furious-insured/dataset/trainI...                6.0
# ../input/he-fast-furious-insured/dataset/trainI...                0.0
# ../input/he-fast-furious-insured/dataset/trainI...                0.0
# ../input/he-fast-furious-insured/dataset/trainI...                2.0
#
#                                                     Min_coverage  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...      0.411534
# ../input/he-fast-furious-insured/dataset/trainI...      1.464186
# ../input/he-fast-furious-insured/dataset/trainI...      1.212751
# ../input/he-fast-furious-insured/dataset/trainI...     -0.369558
# ../input/he-fast-furious-insured/dataset/trainI...     -0.989697
#
#                                                     Max_coverage  Condition  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...      1.895378        0.0
# ../input/he-fast-furious-insured/dataset/trainI...      1.104747        1.0
# ../input/he-fast-furious-insured/dataset/trainI...      2.225731        0.0
# ../input/he-fast-furious-insured/dataset/trainI...     -0.425228        1.0
# ../input/he-fast-furious-insured/dataset/trainI...     -1.029375        1.0
#
#                                                     Parent_company  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             1.0
# ../input/he-fast-furious-insured/dataset/trainI...             1.0
# ../input/he-fast-furious-insured/dataset/trainI...             0.0
# ../input/he-fast-furious-insured/dataset/trainI...             0.0
# ../input/he-fast-furious-insured/dataset/trainI...             0.0
#
#                                                     Child_company  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...            4.0
# ../input/he-fast-furious-insured/dataset/trainI...            4.0
# ../input/he-fast-furious-insured/dataset/trainI...            5.0
# ../input/he-fast-furious-insured/dataset/trainI...            5.0
# ../input/he-fast-furious-insured/dataset/trainI...            2.0
#
#                                                     expiry_dt_year  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...          2026.0
# ../input/he-fast-furious-insured/dataset/trainI...          2025.0
# ../input/he-fast-furious-insured/dataset/trainI...          2022.0
# ../input/he-fast-furious-insured/dataset/trainI...          2022.0
# ../input/he-fast-furious-insured/dataset/trainI...          2026.0
#
#                                                     expiry_dt_quarter  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...                4.0
# ../input/he-fast-furious-insured/dataset/trainI...                3.0
# ../input/he-fast-furious-insured/dataset/trainI...                3.0
# ../input/he-fast-furious-insured/dataset/trainI...                3.0
# ../input/he-fast-furious-insured/dataset/trainI...                2.0
#
#                                                     expiry_dt_month  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             12.0
# ../input/he-fast-furious-insured/dataset/trainI...              7.0
# ../input/he-fast-furious-insured/dataset/trainI...              8.0
# ../input/he-fast-furious-insured/dataset/trainI...              8.0
# ../input/he-fast-furious-insured/dataset/trainI...              5.0
#
#                                                     expiry_dt_week  ...  \
# id                                                                  ...
# ../input/he-fast-furious-insured/dataset/trainI...        1.318946  ...
# ../input/he-fast-furious-insured/dataset/trainI...        0.040157  ...
# ../input/he-fast-furious-insured/dataset/trainI...        0.216204  ...
# ../input/he-fast-furious-insured/dataset/trainI...        0.177827  ...
# ../input/he-fast-furious-insured/dataset/trainI...       -0.461215  ...
#
#                                                     clusters__6  clusters__7  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            1
#
#                                                     clusters__8  clusters__9  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
# ../input/he-fast-furious-insured/dataset/trainI...            0            0
#
#                                                     clusters__10  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
#
#                                                     clusters__11  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
#
#                                                     clusters__12  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
#
#                                                     clusters__13  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             1
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             1
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
#
#                                                     clusters__14  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
# ../input/he-fast-furious-insured/dataset/trainI...             0
#
#                                                                                            Image_path
# id
# ../input/he-fast-furious-insured/dataset/trainI...  ../input/he-fast-furious-insured/dataset/train...
# ../input/he-fast-furious-insured/dataset/trainI...  ../input/he-fast-furious-insured/dataset/train...
# ../input/he-fast-furious-insured/dataset/trainI...  ../input/he-fast-furious-insured/dataset/train...
# ../input/he-fast-furious-insured/dataset/trainI...  ../input/he-fast-furious-insured/dataset/train...
# ../input/he-fast-furious-insured/dataset/trainI...  ../input/he-fast-furious-insured/dataset/train...
#
# [5 rows x 157 columns]

# %%
train_paths = train_df['Image_path']
test_paths = test_df['Image_path']
len(train_paths), len(test_paths)
# Out:
# (1382, 600)

# %%
img_size = 192
mini_batch_size = 128

decoder = build_decoder(with_labels=True, img_size=img_size)

dtrain = build_dataset(
    train_paths, train_paths, 
    bsize=mini_batch_size, repeat=False, 
    shuffle=False, decode_fn=decoder
)

dtest = build_dataset(
    test_paths, test_paths, 
    bsize=mini_batch_size, repeat=False, 
    shuffle=False, decode_fn=decoder
)

# %%
Xtrain_embed = feature_model.predict(dtrain, verbose=1)
Xtest_embed = feature_model.predict(dtest, verbose=1)
col_list = ['dae_'+str(i) for i in range(Xtrain_embed.shape[1])]
Xtrain_embed_df = pd.DataFrame(Xtrain_embed, columns=col_list, index=train_df.index)
Xtest_embed_df = pd.DataFrame(Xtest_embed, columns=col_list, index=test_df.index)

train_df = pd.merge(train_df, Xtrain_embed_df, on='id', sort=False)
test_df = pd.merge(test_df, Xtest_embed_df, on='id', sort=False)

print("\n\ntrain_df: {} \ntest_df: {}".format(train_df.shape, test_df.shape))

del Xtrain_embed
del Xtest_embed
del Xtrain_embed_df
del Xtest_embed_df
gc.collect()
# Out:
# 11/11 [==============================] - 13s 1s/step
# 5/5 [==============================] - 5s 933ms/step
#
#
# train_df: (1382, 1693)
# test_df: (600, 1692)
# 104

# %%
train_df.head()
# Out:
#                                                     Insurance_company  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...                6.0
# ../input/he-fast-furious-insured/dataset/trainI...                6.0
# ../input/he-fast-furious-insured/dataset/trainI...                0.0
# ../input/he-fast-furious-insured/dataset/trainI...                0.0
# ../input/he-fast-furious-insured/dataset/trainI...                2.0
#
#                                                     Min_coverage  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...      0.411534
# ../input/he-fast-furious-insured/dataset/trainI...      1.464186
# ../input/he-fast-furious-insured/dataset/trainI...      1.212751
# ../input/he-fast-furious-insured/dataset/trainI...     -0.369558
# ../input/he-fast-furious-insured/dataset/trainI...     -0.989697
#
#                                                     Max_coverage  Condition  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...      1.895378        0.0
# ../input/he-fast-furious-insured/dataset/trainI...      1.104747        1.0
# ../input/he-fast-furious-insured/dataset/trainI...      2.225731        0.0
# ../input/he-fast-furious-insured/dataset/trainI...     -0.425228        1.0
# ../input/he-fast-furious-insured/dataset/trainI...     -1.029375        1.0
#
#                                                     Parent_company  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             1.0
# ../input/he-fast-furious-insured/dataset/trainI...             1.0
# ../input/he-fast-furious-insured/dataset/trainI...             0.0
# ../input/he-fast-furious-insured/dataset/trainI...             0.0
# ../input/he-fast-furious-insured/dataset/trainI...             0.0
#
#                                                     Child_company  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...            4.0
# ../input/he-fast-furious-insured/dataset/trainI...            4.0
# ../input/he-fast-furious-insured/dataset/trainI...            5.0
# ../input/he-fast-furious-insured/dataset/trainI...            5.0
# ../input/he-fast-furious-insured/dataset/trainI...            2.0
#
#                                                     expiry_dt_year  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...          2026.0
# ../input/he-fast-furious-insured/dataset/trainI...          2025.0
# ../input/he-fast-furious-insured/dataset/trainI...          2022.0
# ../input/he-fast-furious-insured/dataset/trainI...          2022.0
# ../input/he-fast-furious-insured/dataset/trainI...          2026.0
#
#                                                     expiry_dt_quarter  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...                4.0
# ../input/he-fast-furious-insured/dataset/trainI...                3.0
# ../input/he-fast-furious-insured/dataset/trainI...                3.0
# ../input/he-fast-furious-insured/dataset/trainI...                3.0
# ../input/he-fast-furious-insured/dataset/trainI...                2.0
#
#                                                     expiry_dt_month  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...             12.0
# ../input/he-fast-furious-insured/dataset/trainI...              7.0
# ../input/he-fast-furious-insured/dataset/trainI...              8.0
# ../input/he-fast-furious-insured/dataset/trainI...              8.0
# ../input/he-fast-furious-insured/dataset/trainI...              5.0
#
#                                                     expiry_dt_week  ...  \
# id                                                                  ...
# ../input/he-fast-furious-insured/dataset/trainI...        1.318946  ...
# ../input/he-fast-furious-insured/dataset/trainI...        0.040157  ...
# ../input/he-fast-furious-insured/dataset/trainI...        0.216204  ...
# ../input/he-fast-furious-insured/dataset/trainI...        0.177827  ...
# ../input/he-fast-furious-insured/dataset/trainI...       -0.461215  ...
#
#                                                     dae_1526  dae_1527  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...  0.570730 -0.195283
# ../input/he-fast-furious-insured/dataset/trainI... -0.272337 -0.200668
# ../input/he-fast-furious-insured/dataset/trainI... -0.220627 -0.111004
# ../input/he-fast-furious-insured/dataset/trainI...  0.866317  0.072017
# ../input/he-fast-furious-insured/dataset/trainI...  0.795036  0.658731
#
#                                                     dae_1528  dae_1529  \
# id
# ../input/he-fast-furious-insured/dataset/trainI... -0.235323 -0.257360
# ../input/he-fast-furious-insured/dataset/trainI... -0.094072 -0.003438
# ../input/he-fast-furious-insured/dataset/trainI... -0.243602 -0.234025
# ../input/he-fast-furious-insured/dataset/trainI...  2.382662  0.254028
# ../input/he-fast-furious-insured/dataset/trainI... -0.042184  0.145100
#
#                                                     dae_1530  dae_1531  \
# id
# ../input/he-fast-furious-insured/dataset/trainI... -0.130368 -0.206337
# ../input/he-fast-furious-insured/dataset/trainI...  0.469453  0.462481
# ../input/he-fast-furious-insured/dataset/trainI... -0.264965 -0.200110
# ../input/he-fast-furious-insured/dataset/trainI... -0.239630 -0.098770
# ../input/he-fast-furious-insured/dataset/trainI... -0.127701  0.464389
#
#                                                     dae_1532  dae_1533  \
# id
# ../input/he-fast-furious-insured/dataset/trainI...  0.267727  1.835724
# ../input/he-fast-furious-insured/dataset/trainI...  0.410512  1.625738
# ../input/he-fast-furious-insured/dataset/trainI... -0.041671 -0.246042
# ../input/he-fast-furious-insured/dataset/trainI... -0.152048 -0.151377
# ../input/he-fast-furious-insured/dataset/trainI...  1.263631  0.584261
#
#                                                     dae_1534  dae_1535
# id
# ../input/he-fast-furious-insured/dataset/trainI...  0.177982 -0.183419
# ../input/he-fast-furious-insured/dataset/trainI... -0.273421 -0.055653
# ../input/he-fast-furious-insured/dataset/trainI...  0.097152 -0.108427
# ../input/he-fast-furious-insured/dataset/trainI... -0.246364  4.634300
# ../input/he-fast-furious-insured/dataset/trainI... -0.194823  0.220396
#
# [5 rows x 1693 columns]

# %%
test_df.head()
# Out:
#                                                     Insurance_company  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...                3.0
# ../input/he-fast-furious-insured/dataset/testIm...                7.0
# ../input/he-fast-furious-insured/dataset/testIm...                2.0
# ../input/he-fast-furious-insured/dataset/testIm...                4.0
# ../input/he-fast-furious-insured/dataset/testIm...                4.0
#
#                                                     Min_coverage  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...     -1.873053
# ../input/he-fast-furious-insured/dataset/testIm...     -0.895780
# ../input/he-fast-furious-insured/dataset/testIm...      0.605955
# ../input/he-fast-furious-insured/dataset/testIm...      0.848075
# ../input/he-fast-furious-insured/dataset/testIm...      0.334851
#
#                                                     Max_coverage  Condition  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...     -1.895259        1.0
# ../input/he-fast-furious-insured/dataset/testIm...     -0.933910        1.0
# ../input/he-fast-furious-insured/dataset/testIm...      0.468203        1.0
# ../input/he-fast-furious-insured/dataset/testIm...      0.667419        1.0
# ../input/he-fast-furious-insured/dataset/testIm...      0.230353        1.0
#
#                                                     Parent_company  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...             1.0
# ../input/he-fast-furious-insured/dataset/testIm...             2.0
# ../input/he-fast-furious-insured/dataset/testIm...             0.0
# ../input/he-fast-furious-insured/dataset/testIm...             1.0
# ../input/he-fast-furious-insured/dataset/testIm...             1.0
#
#                                                     Child_company  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...            5.0
# ../input/he-fast-furious-insured/dataset/testIm...            5.0
# ../input/he-fast-furious-insured/dataset/testIm...            2.0
# ../input/he-fast-furious-insured/dataset/testIm...            1.0
# ../input/he-fast-furious-insured/dataset/testIm...            1.0
#
#                                                     expiry_dt_year  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...          2025.0
# ../input/he-fast-furious-insured/dataset/testIm...          2028.0
# ../input/he-fast-furious-insured/dataset/testIm...          2023.0
# ../input/he-fast-furious-insured/dataset/testIm...          2028.0
# ../input/he-fast-furious-insured/dataset/testIm...          2022.0
#
#                                                     expiry_dt_quarter  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...                2.0
# ../input/he-fast-furious-insured/dataset/testIm...                3.0
# ../input/he-fast-furious-insured/dataset/testIm...                4.0
# ../input/he-fast-furious-insured/dataset/testIm...                1.0
# ../input/he-fast-furious-insured/dataset/testIm...                1.0
#
#                                                     expiry_dt_month  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...              4.0
# ../input/he-fast-furious-insured/dataset/testIm...              8.0
# ../input/he-fast-furious-insured/dataset/testIm...             11.0
# ../input/he-fast-furious-insured/dataset/testIm...              2.0
# ../input/he-fast-furious-insured/dataset/testIm...              1.0
#
#                                                     expiry_dt_week  ...  \
# id                                                                  ...
# ../input/he-fast-furious-insured/dataset/testIm...       -0.615025  ...
# ../input/he-fast-furious-insured/dataset/testIm...        0.307111  ...
# ../input/he-fast-furious-insured/dataset/testIm...        1.194628  ...
# ../input/he-fast-furious-insured/dataset/testIm...       -1.340200  ...
# ../input/he-fast-furious-insured/dataset/testIm...       -5.199338  ...
#
#                                                     dae_1526  dae_1527  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...  0.630905  0.380645
# ../input/he-fast-furious-insured/dataset/testIm... -0.083731 -0.042264
# ../input/he-fast-furious-insured/dataset/testIm...  0.370341  0.344271
# ../input/he-fast-furious-insured/dataset/testIm... -0.230202 -0.274917
# ../input/he-fast-furious-insured/dataset/testIm...  0.245114  0.047936
#
#                                                     dae_1528  dae_1529  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...  0.058258  0.423731
# ../input/he-fast-furious-insured/dataset/testIm...  0.051222 -0.037250
# ../input/he-fast-furious-insured/dataset/testIm...  0.143334 -0.271525
# ../input/he-fast-furious-insured/dataset/testIm... -0.167255 -0.260308
# ../input/he-fast-furious-insured/dataset/testIm... -0.265861  0.043784
#
#                                                     dae_1530  dae_1531  \
# id
# ../input/he-fast-furious-insured/dataset/testIm... -0.181567  0.551998
# ../input/he-fast-furious-insured/dataset/testIm... -0.154595 -0.271914
# ../input/he-fast-furious-insured/dataset/testIm... -0.009960  0.384522
# ../input/he-fast-furious-insured/dataset/testIm... -0.113609 -0.098236
# ../input/he-fast-furious-insured/dataset/testIm...  0.046780  0.123816
#
#                                                     dae_1532  dae_1533  \
# id
# ../input/he-fast-furious-insured/dataset/testIm...  1.217214  0.069390
# ../input/he-fast-furious-insured/dataset/testIm...  0.259340  0.214751
# ../input/he-fast-furious-insured/dataset/testIm...  0.139219  0.286501
# ../input/he-fast-furious-insured/dataset/testIm... -0.235533  0.004004
# ../input/he-fast-furious-insured/dataset/testIm...  1.676999  0.702943
#
#                                                     dae_1534  dae_1535
# id
# ../input/he-fast-furious-insured/dataset/testIm...  0.164178  0.533777
# ../input/he-fast-furious-insured/dataset/testIm... -0.057445 -0.278002
# ../input/he-fast-furious-insured/dataset/testIm... -0.011328  0.095330
# ../input/he-fast-furious-insured/dataset/testIm... -0.210981 -0.212444
# ../input/he-fast-furious-insured/dataset/testIm... -0.194432 -0.108078
#
# [5 rows x 1692 columns]

# %% [markdown]
# ## Save the processed datasets

# %%
data_dict = {}
data_dict['train_df'] = train_df
data_dict['test_df'] = test_df

file = open("./HE_FFI_Dataset.txt", 'wb')
pickle.dump(data_dict, file)
file.close()
