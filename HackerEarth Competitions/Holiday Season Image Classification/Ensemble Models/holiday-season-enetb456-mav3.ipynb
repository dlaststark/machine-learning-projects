# %% [markdown]
# ## Import Packages

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
from tensorflow_addons.metrics import F1Score
from tensorflow.keras.models import Model, load_model
from tensorflow_addons.optimizers import AdamW, Lookahead
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import BatchNormalization, Input
from tensorflow.keras.layers import ZeroPadding2D, MaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D, Add
from tensorflow.keras.layers import GlobalMaxPooling2D, Reshape
from tensorflow.keras.layers import Activation, Conv2D, Average
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Read true labels + Basic EDA

# %%
class_map = {
    'Airplane': 0,
    'Candle': 1,
    'Christmas_Tree': 2,
    'Jacket': 3,
    'Miscellaneous': 4,
    'Snowman': 5
}

# %%
train_df = pd.read_csv("../input/hackereath-holiday-season-deep-learning-contest/dataset/train.csv")
train_df['Class_enc'] = train_df['Class'].map(class_map)
train_df['Class_enc'] = train_df['Class_enc'].astype('str')
train_df.head()
# Out:
#            Image          Class Class_enc
# 0  image3476.jpg  Miscellaneous         4
# 1  image5198.jpg         Candle         1
# 2  image4183.jpg        Snowman         5
# 3  image1806.jpg  Miscellaneous         4
# 4  image7831.jpg  Miscellaneous         4

# %%
test_dir = "../input/hackereath-holiday-season-deep-learning-contest/dataset/test"
test_files = []

for file in tqdm(os.listdir(test_dir)):
    test_files.append(file)

test_df = pd.DataFrame(test_files, columns=['Image'])
test_df['Class'] = '0'
test_df.head()
# Out:
# 100%|██████████| 3489/3489 [00:00<00:00, 961051.20it/s]
#            Image Class
# 0  image7761.jpg     0
# 1  image3202.jpg     0
# 2   image688.jpg     0
# 3   image233.jpg     0
# 4  image4332.jpg     0

# %% [markdown]
# ## Calculate class-weights

# %%
temp_df = train_df.groupby(['Class_enc']).size().reset_index().rename(columns={0:'count'})
total_count = np.sum(temp_df['count'].values)
temp_df['class%'] = (temp_df['count'] / total_count) * 100
lowest_pct = min(temp_df['class%'])
temp_df['class_weight'] = lowest_pct / temp_df['class%']
class_weight = temp_df[['Class_enc', 'class_weight']].to_dict()['class_weight']
class_weight
# Out:
# {0: 0.6747663551401869,
#  1: 0.6087689713322091,
#  2: 0.23456790123456786,
#  3: 0.5640625,
#  4: 0.12888254194930382,
#  5: 1.0}

# %% [markdown]
# ## Model Hyperparameters

# %%
dataset_dir = "../input/hackereath-holiday-season-deep-learning-contest/dataset/"
mini_batch_size = 64
image_dim = (400, 400, 3)
test_steps = int(np.ceil(test_df.shape[0] / float(mini_batch_size)))

# %% [markdown]
# ## Configure image generators

# %%
def train_generator(df, mode='train'):

    while True:
        if mode=='train':
            train_datagen = ImageDataGenerator(rotation_range = 30,
                                               zoom_range = 0.2,
                                               horizontal_flip = True,
                                               fill_mode = 'nearest',
                                               height_shift_range = 0.1,
                                               width_shift_range = 0.1)
            
            batches = train_datagen.flow_from_dataframe(df,
                                                        directory = os.path.join(dataset_dir,"train"),
                                                        x_col = "Image", 
                                                        y_col = "Class_enc",
                                                        target_size = (image_dim[0], image_dim[1]),
                                                        batch_size = mini_batch_size,
                                                        class_mode = "categorical",
                                                        interpolation="bicubic")
        else:
            train_datagen = ImageDataGenerator()
            
            batches = train_datagen.flow_from_dataframe(df,
                                                        directory = os.path.join(dataset_dir,"train"),
                                                        x_col = "Image", 
                                                        y_col = "Class_enc",
                                                        shuffle=False,
                                                        target_size = (image_dim[0], image_dim[1]),
                                                        batch_size = mini_batch_size,
                                                        class_mode = "categorical",
                                                        interpolation="bicubic")
        
        idx0 = 0
        for batch in batches:
            idx1 = idx0 + batch[0].shape[0]

            yield [batch[0], batch[0], batch[0]], batch[1]

            idx0 = idx1
            if idx1 >= df.shape[0]:
                break

# %%
def test_generator():

    while True:
        test_datagen = ImageDataGenerator()

        batches = test_datagen.flow_from_dataframe(test_df,
                                                   directory = os.path.join(dataset_dir,"test"),
                                                   x_col = "Image",
                                                   y_col = "Class",
                                                   shuffle=False,
                                                   target_size = (image_dim[0], image_dim[1]),
                                                   batch_size = mini_batch_size,
                                                   class_mode = "categorical",
                                                   interpolation="bicubic")

        idx0 = 0
        for batch in batches:
            idx1 = idx0 + batch[0].shape[0]

            yield [batch[0], batch[0], batch[0]], batch[1]

            idx0 = idx1
            if idx1 >= test_df.shape[0]:
                break

# %% [markdown]
# ## Build and validate the model

# %%
def head(x1, x2, x3):
    
    x = Concatenate()([x1, x2, x3])
    
    x = Dense(units=2048, kernel_regularizer=l2(0.0001), 
              kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.5)(x)
    
    x = Dense(units=512, kernel_regularizer=l2(0.0001), 
              kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.5)(x)
    
    x = Dense(units=512, kernel_regularizer=l2(0.0001), 
              kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.5)(x)
    
    x = Dense(units=128, kernel_regularizer=l2(0.0001), 
              kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(rate=0.5)(x)
    
    x = Dense(units=6, activation='softmax', 
              kernel_initializer='he_uniform')(x)

    return x

# %%
# Define K-fold cross validation test harness
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
y_pred_final = np.zeros((test_df.shape[0], 6))
final_oof_score = 0
counter = 0

# Load the pre-trained models
base_model1 = load_model('../input/holiday-season-enetb4-mav34/hackerearth_holiday_season_model.h5')
base_model2 = load_model('../input/holiday-season-enetb5-mav4/hackerearth_holiday_season_model.h5')
base_model3 = load_model('../input/holiday-season-enetb6-mav4/hackerearth_holiday_season_model.h5')

# Freeze weights for base models
base_model1.trainable = False
base_model2.trainable = False
base_model3.trainable = False

# Update layer names for base models
for layer in tqdm(base_model1.layers):
    layer._name = 'm1_' + layer.name

for layer in tqdm(base_model2.layers):
    layer._name = 'm2_' + layer.name

for layer in tqdm(base_model3.layers):
    layer._name = 'm3_' + layer.name
# Out:
# 100%|██████████| 530/530 [00:00<00:00, 29662.69it/s]
# 100%|██████████| 632/632 [00:00<00:00, 20623.98it/s]
# 100%|██████████| 722/722 [00:00<00:00, 29704.24it/s]

# %%
for train, val in kfold.split(train_df.loc[:, train_df.columns!='Class_enc'], train_df['Class_enc']):
    counter += 1
    
    # Prepare data for model training
    train_ds, val_ds = train_df.iloc[train], train_df.iloc[val]
    steps_per_epoch = int(np.ceil(train_ds.shape[0] / float(mini_batch_size)))
    validation_steps = int(np.ceil(val_ds.shape[0] / float(mini_batch_size)))
    
    # Build the model
    model = Model(inputs=[base_model1.input, base_model2.input, base_model3.input], 
                  outputs=head(base_model1.get_layer('m1_activation_11').output, 
                               base_model2.get_layer('m2_activation_11').output,
                               base_model3.get_layer('m3_activation_11').output),
                  name='HackerEarth_Holiday_Season_Model')

    # Compile the final model
    model.compile(loss='categorical_crossentropy', 
                  metrics=[F1Score(num_classes=6, average='weighted'), 
                           'categorical_accuracy'],
                  optimizer=Lookahead(AdamW(lr=1e-4, 
                                            weight_decay=1e-5, 
                                            clipvalue=700), 
                                      sync_period=10))

    # Load best weights from pre-trained model
    model.load_weights('../input/holiday-season-enetb456-mav2/hackerearth_holiday_season_model.h5')

    # Compile the final model
    model.compile(loss='categorical_crossentropy', 
                  metrics=[F1Score(num_classes=6, average='weighted'), 
                           'categorical_accuracy'],
                  optimizer=Lookahead(AdamW(lr=1e-4, 
                                            weight_decay=1e-5, 
                                            clipvalue=700), 
                                      sync_period=10))
    
    # Configure model callbacks
    early = EarlyStopping(monitor="val_loss", mode="min", patience=5, 
                          restore_best_weights=True, verbose=1)

    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.2, 
                                  min_lr=1e-6, patience=3, 
                                  verbose=1, mode='min')

    chk_point = ModelCheckpoint('hackerearth_holiday_season_model.h5', 
                                monitor='val_loss', verbose=1, 
                                save_weights_only=True, 
                                save_best_only=True, mode='min')
    
    # Fit the model
    history = model.fit(
        train_generator(train_ds), 
        steps_per_epoch=steps_per_epoch,
        class_weight=class_weight, 
        epochs=15, 
        verbose=1,
        callbacks=[reduce_lr, early, chk_point], 
        validation_data=train_generator(val_ds, 'valid'),
        validation_steps=validation_steps
    )
    
    # Load best model
    model = Model(inputs=[base_model1.input, base_model2.input, base_model3.input], 
                  outputs=head(base_model1.get_layer('m1_activation_11').output, 
                               base_model2.get_layer('m2_activation_11').output,
                               base_model3.get_layer('m3_activation_11').output),
                  name='HackerEarth_Holiday_Season_Model')

    model.compile(loss='categorical_crossentropy', 
                  metrics=[F1Score(num_classes=6, average='weighted'), 
                           'categorical_accuracy'],
                  optimizer=Lookahead(AdamW(lr=1e-4, 
                                            weight_decay=1e-5, 
                                            clipvalue=700), 
                                      sync_period=10))

    model.load_weights('./hackerearth_holiday_season_model.h5')
    
    # Make predictions and capture metrics
    y_true = val_ds['Class_enc'].values
    y_pred = model.predict(train_generator(val_ds, 'valid'), steps=validation_steps, verbose=0)
    y_pred = np.argmax(y_pred, axis=1)
    y_pred_final += model.predict(test_generator(), steps=test_steps, verbose=0)
    score = f1_score(y_true.astype(int), y_pred, average='weighted')
    final_oof_score += score
    print("\nFold-{} | F1-Score: {}\n".format(counter, score))

y_pred_final = y_pred_final / float(counter)
final_oof_score /= float(counter)
print("\n\nAggregate F1-Score: {}".format(final_oof_score))
# Out:
# Found 5175 validated image filenames belonging to 6 classes.
# Epoch 1/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1263 - f1_score: 0.9630 - categorical_accuracy: 0.9629Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1261 - f1_score: 0.9632 - categorical_accuracy: 0.9631Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00001: val_loss improved from inf to 0.19371, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 391s 5s/step - loss: 0.1261 - f1_score: 0.9632 - categorical_accuracy: 0.9631 - val_loss: 0.1937 - val_f1_score: 0.9760 - val_categorical_accuracy: 0.9760
# Epoch 2/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1235 - f1_score: 0.9604 - categorical_accuracy: 0.9604Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1235 - f1_score: 0.9606 - categorical_accuracy: 0.9606Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00002: val_loss improved from 0.19371 to 0.18545, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 365s 5s/step - loss: 0.1235 - f1_score: 0.9606 - categorical_accuracy: 0.9606 - val_loss: 0.1854 - val_f1_score: 0.9753 - val_categorical_accuracy: 0.9753
# Epoch 3/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1218 - f1_score: 0.9622 - categorical_accuracy: 0.9621Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1218 - f1_score: 0.9618 - categorical_accuracy: 0.9617Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00003: val_loss improved from 0.18545 to 0.18132, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 369s 5s/step - loss: 0.1218 - f1_score: 0.9618 - categorical_accuracy: 0.9617 - val_loss: 0.1813 - val_f1_score: 0.9738 - val_categorical_accuracy: 0.9737
# Epoch 4/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1266 - f1_score: 0.9595 - categorical_accuracy: 0.9594Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1264 - f1_score: 0.9594 - categorical_accuracy: 0.9592Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00004: val_loss did not improve from 0.18132
# 81/81 [==============================] - 367s 5s/step - loss: 0.1264 - f1_score: 0.9594 - categorical_accuracy: 0.9592 - val_loss: 0.1823 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 5/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1202 - f1_score: 0.9609 - categorical_accuracy: 0.9607Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1201 - f1_score: 0.9610 - categorical_accuracy: 0.9608Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00005: val_loss improved from 0.18132 to 0.17975, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 375s 5s/step - loss: 0.1201 - f1_score: 0.9610 - categorical_accuracy: 0.9608 - val_loss: 0.1798 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 6/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1202 - f1_score: 0.9595 - categorical_accuracy: 0.9594Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1200 - f1_score: 0.9595 - categorical_accuracy: 0.9594Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00006: val_loss did not improve from 0.17975
# 81/81 [==============================] - 368s 5s/step - loss: 0.1200 - f1_score: 0.9595 - categorical_accuracy: 0.9594 - val_loss: 0.1826 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 7/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1199 - f1_score: 0.9560 - categorical_accuracy: 0.9559Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1199 - f1_score: 0.9563 - categorical_accuracy: 0.9561Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00007: val_loss improved from 0.17975 to 0.17554, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 379s 5s/step - loss: 0.1199 - f1_score: 0.9563 - categorical_accuracy: 0.9561 - val_loss: 0.1755 - val_f1_score: 0.9753 - val_categorical_accuracy: 0.9753
# Epoch 8/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1186 - f1_score: 0.9620 - categorical_accuracy: 0.9619Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1187 - f1_score: 0.9617 - categorical_accuracy: 0.9615Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00008: val_loss improved from 0.17554 to 0.17551, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 380s 5s/step - loss: 0.1187 - f1_score: 0.9617 - categorical_accuracy: 0.9615 - val_loss: 0.1755 - val_f1_score: 0.9769 - val_categorical_accuracy: 0.9768
# Epoch 9/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1219 - f1_score: 0.9582 - categorical_accuracy: 0.9580Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1217 - f1_score: 0.9579 - categorical_accuracy: 0.9577Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00009: val_loss improved from 0.17551 to 0.17544, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 384s 5s/step - loss: 0.1217 - f1_score: 0.9579 - categorical_accuracy: 0.9577 - val_loss: 0.1754 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 10/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1150 - f1_score: 0.9650 - categorical_accuracy: 0.9648Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1151 - f1_score: 0.9646 - categorical_accuracy: 0.9644Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00010: val_loss improved from 0.17544 to 0.17354, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 382s 5s/step - loss: 0.1151 - f1_score: 0.9646 - categorical_accuracy: 0.9644 - val_loss: 0.1735 - val_f1_score: 0.9745 - val_categorical_accuracy: 0.9745
# Epoch 11/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1205 - f1_score: 0.9572 - categorical_accuracy: 0.9570Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1204 - f1_score: 0.9568 - categorical_accuracy: 0.9567Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00011: val_loss did not improve from 0.17354
# 81/81 [==============================] - 379s 5s/step - loss: 0.1204 - f1_score: 0.9568 - categorical_accuracy: 0.9567 - val_loss: 0.1744 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 12/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1151 - f1_score: 0.9611 - categorical_accuracy: 0.9609Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1150 - f1_score: 0.9611 - categorical_accuracy: 0.9610Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00012: val_loss did not improve from 0.17354
# 81/81 [==============================] - 379s 5s/step - loss: 0.1150 - f1_score: 0.9611 - categorical_accuracy: 0.9610 - val_loss: 0.1755 - val_f1_score: 0.9777 - val_categorical_accuracy: 0.9776
# Epoch 13/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1135 - f1_score: 0.9613 - categorical_accuracy: 0.9611Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1134 - f1_score: 0.9615 - categorical_accuracy: 0.9614Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00013: val_loss did not improve from 0.17354
# 81/81 [==============================] - 378s 5s/step - loss: 0.1134 - f1_score: 0.9615 - categorical_accuracy: 0.9614 - val_loss: 0.1754 - val_f1_score: 0.9738 - val_categorical_accuracy: 0.9737
# Epoch 14/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1173 - f1_score: 0.9588 - categorical_accuracy: 0.9586Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1171 - f1_score: 0.9591 - categorical_accuracy: 0.9588Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00014: val_loss did not improve from 0.17354
# 81/81 [==============================] - 380s 5s/step - loss: 0.1171 - f1_score: 0.9591 - categorical_accuracy: 0.9588 - val_loss: 0.1759 - val_f1_score: 0.9746 - val_categorical_accuracy: 0.9745
# Epoch 15/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1152 - f1_score: 0.9572 - categorical_accuracy: 0.9570Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1151 - f1_score: 0.9572 - categorical_accuracy: 0.9571Found 1294 validated image filenames belonging to 6 classes.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00015: val_loss did not improve from 0.17354
# 81/81 [==============================] - 377s 5s/step - loss: 0.1151 - f1_score: 0.9572 - categorical_accuracy: 0.9571 - val_loss: 0.1757 - val_f1_score: 0.9746 - val_categorical_accuracy: 0.9745
# Epoch 00015: early stopping
# Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
# Found 3489 validated image filenames belonging to 1 classes.
# Found 3489 validated image filenames belonging to 1 classes.
#
# Fold-1 | F1-Score: 0.9745338978760074
#
# Found 5175 validated image filenames belonging to 6 classes.
# Epoch 1/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1260 - f1_score: 0.9655 - categorical_accuracy: 0.9654Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1261 - f1_score: 0.9649 - categorical_accuracy: 0.9648Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00001: val_loss improved from inf to 0.14332, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 387s 5s/step - loss: 0.1261 - f1_score: 0.9649 - categorical_accuracy: 0.9648 - val_loss: 0.1433 - val_f1_score: 0.9846 - val_categorical_accuracy: 0.9845
# Epoch 2/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1307 - f1_score: 0.9586 - categorical_accuracy: 0.9584Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1304 - f1_score: 0.9591 - categorical_accuracy: 0.9588Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00002: val_loss did not improve from 0.14332
# 81/81 [==============================] - 367s 5s/step - loss: 0.1304 - f1_score: 0.9591 - categorical_accuracy: 0.9588 - val_loss: 0.1437 - val_f1_score: 0.9846 - val_categorical_accuracy: 0.9845
# Epoch 3/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1226 - f1_score: 0.9597 - categorical_accuracy: 0.9596Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1225 - f1_score: 0.9595 - categorical_accuracy: 0.9594Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00003: val_loss did not improve from 0.14332
# 81/81 [==============================] - 378s 5s/step - loss: 0.1225 - f1_score: 0.9595 - categorical_accuracy: 0.9594 - val_loss: 0.1451 - val_f1_score: 0.9839 - val_categorical_accuracy: 0.9838
# Epoch 4/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1243 - f1_score: 0.9568 - categorical_accuracy: 0.9566Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1243 - f1_score: 0.9567 - categorical_accuracy: 0.9565Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00004: val_loss did not improve from 0.14332
# 81/81 [==============================] - 374s 5s/step - loss: 0.1243 - f1_score: 0.9567 - categorical_accuracy: 0.9565 - val_loss: 0.1460 - val_f1_score: 0.9831 - val_categorical_accuracy: 0.9830
# Epoch 5/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1269 - f1_score: 0.9595 - categorical_accuracy: 0.9594Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1266 - f1_score: 0.9597 - categorical_accuracy: 0.9596Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00005: val_loss did not improve from 0.14332
# 81/81 [==============================] - 377s 5s/step - loss: 0.1266 - f1_score: 0.9597 - categorical_accuracy: 0.9596 - val_loss: 0.1454 - val_f1_score: 0.9831 - val_categorical_accuracy: 0.9830
# Epoch 6/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1225 - f1_score: 0.9614 - categorical_accuracy: 0.9613Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1224 - f1_score: 0.9609 - categorical_accuracy: 0.9608Found 1294 validated image filenames belonging to 6 classes.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.14332
# 81/81 [==============================] - 401s 5s/step - loss: 0.1224 - f1_score: 0.9609 - categorical_accuracy: 0.9608 - val_loss: 0.1452 - val_f1_score: 0.9831 - val_categorical_accuracy: 0.9830
# Epoch 00006: early stopping
# Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
# Found 3489 validated image filenames belonging to 1 classes.
# Found 3489 validated image filenames belonging to 1 classes.
#
# Fold-2 | F1-Score: 0.9845797522202041
#
# Found 5175 validated image filenames belonging to 6 classes.
# Epoch 1/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1308 - f1_score: 0.9561 - categorical_accuracy: 0.9561Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1306 - f1_score: 0.9562 - categorical_accuracy: 0.9561Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00001: val_loss improved from inf to 0.16409, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 422s 5s/step - loss: 0.1306 - f1_score: 0.9562 - categorical_accuracy: 0.9561 - val_loss: 0.1641 - val_f1_score: 0.9768 - val_categorical_accuracy: 0.9768
# Epoch 2/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1251 - f1_score: 0.9590 - categorical_accuracy: 0.9588Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1250 - f1_score: 0.9586 - categorical_accuracy: 0.9585Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00002: val_loss improved from 0.16409 to 0.16221, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 403s 5s/step - loss: 0.1250 - f1_score: 0.9586 - categorical_accuracy: 0.9585 - val_loss: 0.1622 - val_f1_score: 0.9738 - val_categorical_accuracy: 0.9737
# Epoch 3/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1257 - f1_score: 0.9570 - categorical_accuracy: 0.9568Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1256 - f1_score: 0.9571 - categorical_accuracy: 0.9569Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00003: val_loss did not improve from 0.16221
# 81/81 [==============================] - 381s 5s/step - loss: 0.1256 - f1_score: 0.9571 - categorical_accuracy: 0.9569 - val_loss: 0.1624 - val_f1_score: 0.9769 - val_categorical_accuracy: 0.9768
# Epoch 4/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1209 - f1_score: 0.9605 - categorical_accuracy: 0.9604Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1208 - f1_score: 0.9604 - categorical_accuracy: 0.9602Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00004: val_loss improved from 0.16221 to 0.15941, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 384s 5s/step - loss: 0.1208 - f1_score: 0.9604 - categorical_accuracy: 0.9602 - val_loss: 0.1594 - val_f1_score: 0.9746 - val_categorical_accuracy: 0.9745
# Epoch 5/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1230 - f1_score: 0.9537 - categorical_accuracy: 0.9535Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1229 - f1_score: 0.9538 - categorical_accuracy: 0.9536Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00005: val_loss improved from 0.15941 to 0.15723, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 385s 5s/step - loss: 0.1229 - f1_score: 0.9538 - categorical_accuracy: 0.9536 - val_loss: 0.1572 - val_f1_score: 0.9753 - val_categorical_accuracy: 0.9753
# Epoch 6/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1215 - f1_score: 0.9568 - categorical_accuracy: 0.9566Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1214 - f1_score: 0.9569 - categorical_accuracy: 0.9567Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00006: val_loss did not improve from 0.15723
# 81/81 [==============================] - 382s 5s/step - loss: 0.1214 - f1_score: 0.9569 - categorical_accuracy: 0.9567 - val_loss: 0.1573 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 7/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1206 - f1_score: 0.9593 - categorical_accuracy: 0.9592Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1205 - f1_score: 0.9594 - categorical_accuracy: 0.9592Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00007: val_loss improved from 0.15723 to 0.15422, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 387s 5s/step - loss: 0.1205 - f1_score: 0.9594 - categorical_accuracy: 0.9592 - val_loss: 0.1542 - val_f1_score: 0.9753 - val_categorical_accuracy: 0.9753
# Epoch 8/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1177 - f1_score: 0.9593 - categorical_accuracy: 0.9592Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1175 - f1_score: 0.9595 - categorical_accuracy: 0.9594Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00008: val_loss improved from 0.15422 to 0.15322, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 386s 5s/step - loss: 0.1175 - f1_score: 0.9595 - categorical_accuracy: 0.9594 - val_loss: 0.1532 - val_f1_score: 0.9746 - val_categorical_accuracy: 0.9745
# Epoch 9/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1211 - f1_score: 0.9577 - categorical_accuracy: 0.9574Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1209 - f1_score: 0.9577 - categorical_accuracy: 0.9575Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00009: val_loss did not improve from 0.15322
# 81/81 [==============================] - 384s 5s/step - loss: 0.1209 - f1_score: 0.9577 - categorical_accuracy: 0.9575 - val_loss: 0.1539 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 10/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1197 - f1_score: 0.9596 - categorical_accuracy: 0.9594Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1194 - f1_score: 0.9596 - categorical_accuracy: 0.9594Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00010: val_loss did not improve from 0.15322
# 81/81 [==============================] - 384s 5s/step - loss: 0.1194 - f1_score: 0.9596 - categorical_accuracy: 0.9594 - val_loss: 0.1546 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 11/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1174 - f1_score: 0.9562 - categorical_accuracy: 0.9561Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1175 - f1_score: 0.9560 - categorical_accuracy: 0.9559Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00011: val_loss did not improve from 0.15322
# 81/81 [==============================] - 381s 5s/step - loss: 0.1175 - f1_score: 0.9560 - categorical_accuracy: 0.9559 - val_loss: 0.1540 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 12/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1172 - f1_score: 0.9611 - categorical_accuracy: 0.9609Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1172 - f1_score: 0.9609 - categorical_accuracy: 0.9608Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00012: val_loss did not improve from 0.15322
# 81/81 [==============================] - 379s 5s/step - loss: 0.1172 - f1_score: 0.9609 - categorical_accuracy: 0.9608 - val_loss: 0.1536 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 13/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1185 - f1_score: 0.9574 - categorical_accuracy: 0.9572Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1183 - f1_score: 0.9575 - categorical_accuracy: 0.9573Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00013: val_loss improved from 0.15322 to 0.15274, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 384s 5s/step - loss: 0.1183 - f1_score: 0.9575 - categorical_accuracy: 0.9573 - val_loss: 0.1527 - val_f1_score: 0.9769 - val_categorical_accuracy: 0.9768
# Epoch 14/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1186 - f1_score: 0.9577 - categorical_accuracy: 0.9576Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1188 - f1_score: 0.9576 - categorical_accuracy: 0.9575Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00014: val_loss improved from 0.15274 to 0.15274, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 385s 5s/step - loss: 0.1188 - f1_score: 0.9576 - categorical_accuracy: 0.9575 - val_loss: 0.1527 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Epoch 15/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1167 - f1_score: 0.9618 - categorical_accuracy: 0.9617Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1166 - f1_score: 0.9620 - categorical_accuracy: 0.9619Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00015: val_loss improved from 0.15274 to 0.15259, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 388s 5s/step - loss: 0.1166 - f1_score: 0.9620 - categorical_accuracy: 0.9619 - val_loss: 0.1526 - val_f1_score: 0.9761 - val_categorical_accuracy: 0.9760
# Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
# Found 3489 validated image filenames belonging to 1 classes.
# Found 3489 validated image filenames belonging to 1 classes.
#
# Fold-3 | F1-Score: 0.9760966601886671
#
# Found 5175 validated image filenames belonging to 6 classes.
# Epoch 1/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1253 - f1_score: 0.9625 - categorical_accuracy: 0.9623Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1255 - f1_score: 0.9619 - categorical_accuracy: 0.9617Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00001: val_loss improved from inf to 0.15602, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 400s 5s/step - loss: 0.1255 - f1_score: 0.9619 - categorical_accuracy: 0.9617 - val_loss: 0.1560 - val_f1_score: 0.9853 - val_categorical_accuracy: 0.9853
# Epoch 2/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1285 - f1_score: 0.9560 - categorical_accuracy: 0.9559Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1284 - f1_score: 0.9559 - categorical_accuracy: 0.9557Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00002: val_loss improved from 0.15602 to 0.15503, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 386s 5s/step - loss: 0.1284 - f1_score: 0.9559 - categorical_accuracy: 0.9557 - val_loss: 0.1550 - val_f1_score: 0.9830 - val_categorical_accuracy: 0.9830
# Epoch 3/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1322 - f1_score: 0.9515 - categorical_accuracy: 0.9514Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1320 - f1_score: 0.9519 - categorical_accuracy: 0.9517Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00003: val_loss improved from 0.15503 to 0.15399, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 383s 5s/step - loss: 0.1320 - f1_score: 0.9519 - categorical_accuracy: 0.9517 - val_loss: 0.1540 - val_f1_score: 0.9845 - val_categorical_accuracy: 0.9845
# Epoch 4/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1210 - f1_score: 0.9569 - categorical_accuracy: 0.9568Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1210 - f1_score: 0.9570 - categorical_accuracy: 0.9569Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00004: val_loss improved from 0.15399 to 0.15230, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 381s 5s/step - loss: 0.1210 - f1_score: 0.9570 - categorical_accuracy: 0.9569 - val_loss: 0.1523 - val_f1_score: 0.9830 - val_categorical_accuracy: 0.9830
# Epoch 5/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1269 - f1_score: 0.9553 - categorical_accuracy: 0.9551Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1266 - f1_score: 0.9556 - categorical_accuracy: 0.9554Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00005: val_loss did not improve from 0.15230
# 81/81 [==============================] - 380s 5s/step - loss: 0.1266 - f1_score: 0.9556 - categorical_accuracy: 0.9554 - val_loss: 0.1525 - val_f1_score: 0.9823 - val_categorical_accuracy: 0.9822
# Epoch 6/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1246 - f1_score: 0.9549 - categorical_accuracy: 0.9547Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1243 - f1_score: 0.9553 - categorical_accuracy: 0.9552Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00006: val_loss improved from 0.15230 to 0.15182, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 382s 5s/step - loss: 0.1243 - f1_score: 0.9553 - categorical_accuracy: 0.9552 - val_loss: 0.1518 - val_f1_score: 0.9815 - val_categorical_accuracy: 0.9815
# Epoch 7/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1247 - f1_score: 0.9545 - categorical_accuracy: 0.9543Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1249 - f1_score: 0.9544 - categorical_accuracy: 0.9542Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00007: val_loss improved from 0.15182 to 0.15036, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 381s 5s/step - loss: 0.1249 - f1_score: 0.9544 - categorical_accuracy: 0.9542 - val_loss: 0.1504 - val_f1_score: 0.9830 - val_categorical_accuracy: 0.9830
# Epoch 8/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1222 - f1_score: 0.9516 - categorical_accuracy: 0.9514Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1222 - f1_score: 0.9515 - categorical_accuracy: 0.9513Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00008: val_loss improved from 0.15036 to 0.15031, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 384s 5s/step - loss: 0.1222 - f1_score: 0.9515 - categorical_accuracy: 0.9513 - val_loss: 0.1503 - val_f1_score: 0.9838 - val_categorical_accuracy: 0.9838
# Epoch 9/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1210 - f1_score: 0.9568 - categorical_accuracy: 0.9566Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1214 - f1_score: 0.9563 - categorical_accuracy: 0.9561Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00009: val_loss improved from 0.15031 to 0.14983, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 382s 5s/step - loss: 0.1214 - f1_score: 0.9563 - categorical_accuracy: 0.9561 - val_loss: 0.1498 - val_f1_score: 0.9846 - val_categorical_accuracy: 0.9845
# Epoch 10/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1194 - f1_score: 0.9523 - categorical_accuracy: 0.9521Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1193 - f1_score: 0.9526 - categorical_accuracy: 0.9525Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00010: val_loss improved from 0.14983 to 0.14927, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 379s 5s/step - loss: 0.1193 - f1_score: 0.9526 - categorical_accuracy: 0.9525 - val_loss: 0.1493 - val_f1_score: 0.9823 - val_categorical_accuracy: 0.9822
# Epoch 11/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1244 - f1_score: 0.9506 - categorical_accuracy: 0.9504Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1241 - f1_score: 0.9511 - categorical_accuracy: 0.9509Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00011: val_loss did not improve from 0.14927
# 81/81 [==============================] - 362s 4s/step - loss: 0.1241 - f1_score: 0.9511 - categorical_accuracy: 0.9509 - val_loss: 0.1514 - val_f1_score: 0.9815 - val_categorical_accuracy: 0.9815
# Epoch 12/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1174 - f1_score: 0.9562 - categorical_accuracy: 0.9561Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1175 - f1_score: 0.9559 - categorical_accuracy: 0.9557Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00012: val_loss did not improve from 0.14927
# 81/81 [==============================] - 361s 4s/step - loss: 0.1175 - f1_score: 0.9559 - categorical_accuracy: 0.9557 - val_loss: 0.1497 - val_f1_score: 0.9815 - val_categorical_accuracy: 0.9815
# Epoch 13/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1198 - f1_score: 0.9568 - categorical_accuracy: 0.9566Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1195 - f1_score: 0.9572 - categorical_accuracy: 0.9571Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00013: val_loss did not improve from 0.14927
# 81/81 [==============================] - 359s 4s/step - loss: 0.1195 - f1_score: 0.9572 - categorical_accuracy: 0.9571 - val_loss: 0.1494 - val_f1_score: 0.9830 - val_categorical_accuracy: 0.9830
# Epoch 14/15
# 80/81 [============================>.] - ETA: 3s - loss: 0.1188 - f1_score: 0.9601 - categorical_accuracy: 0.9600Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1189 - f1_score: 0.9600 - categorical_accuracy: 0.9598Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00014: val_loss improved from 0.14927 to 0.14835, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 360s 4s/step - loss: 0.1189 - f1_score: 0.9600 - categorical_accuracy: 0.9598 - val_loss: 0.1484 - val_f1_score: 0.9823 - val_categorical_accuracy: 0.9822
# Epoch 15/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1194 - f1_score: 0.9554 - categorical_accuracy: 0.9553Found 5175 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1192 - f1_score: 0.9551 - categorical_accuracy: 0.9550Found 1294 validated image filenames belonging to 6 classes.
#
# Epoch 00015: val_loss improved from 0.14835 to 0.14800, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 376s 5s/step - loss: 0.1192 - f1_score: 0.9551 - categorical_accuracy: 0.9550 - val_loss: 0.1480 - val_f1_score: 0.9830 - val_categorical_accuracy: 0.9830
# Found 1294 validated image filenames belonging to 6 classes.
# Found 1294 validated image filenames belonging to 6 classes.
# Found 3489 validated image filenames belonging to 1 classes.
# Found 3489 validated image filenames belonging to 1 classes.
#
# Fold-4 | F1-Score: 0.9830253202954291
#
# Found 5176 validated image filenames belonging to 6 classes.
# Epoch 1/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1293 - f1_score: 0.9659 - categorical_accuracy: 0.9658Found 5176 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1292 - f1_score: 0.9659 - categorical_accuracy: 0.9658Found 1293 validated image filenames belonging to 6 classes.
# Found 1293 validated image filenames belonging to 6 classes.
#
# Epoch 00001: val_loss improved from inf to 0.13928, saving model to hackerearth_holiday_season_model.h5
# 81/81 [==============================] - 391s 5s/step - loss: 0.1292 - f1_score: 0.9659 - categorical_accuracy: 0.9658 - val_loss: 0.1393 - val_f1_score: 0.9792 - val_categorical_accuracy: 0.9791
# Epoch 2/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1282 - f1_score: 0.9560 - categorical_accuracy: 0.9559Found 5176 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1279 - f1_score: 0.9561 - categorical_accuracy: 0.9560Found 1293 validated image filenames belonging to 6 classes.
#
# Epoch 00002: val_loss did not improve from 0.13928
# 81/81 [==============================] - 372s 5s/step - loss: 0.1279 - f1_score: 0.9561 - categorical_accuracy: 0.9560 - val_loss: 0.1406 - val_f1_score: 0.9800 - val_categorical_accuracy: 0.9799
# Epoch 3/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1232 - f1_score: 0.9623 - categorical_accuracy: 0.9621Found 5176 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1235 - f1_score: 0.9617 - categorical_accuracy: 0.9616Found 1293 validated image filenames belonging to 6 classes.
#
# Epoch 00003: val_loss did not improve from 0.13928
# 81/81 [==============================] - 372s 5s/step - loss: 0.1235 - f1_score: 0.9617 - categorical_accuracy: 0.9616 - val_loss: 0.1407 - val_f1_score: 0.9784 - val_categorical_accuracy: 0.9783
# Epoch 4/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1239 - f1_score: 0.9582 - categorical_accuracy: 0.9580Found 5176 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1241 - f1_score: 0.9580 - categorical_accuracy: 0.9579Found 1293 validated image filenames belonging to 6 classes.
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00004: val_loss did not improve from 0.13928
# 81/81 [==============================] - 384s 5s/step - loss: 0.1241 - f1_score: 0.9580 - categorical_accuracy: 0.9579 - val_loss: 0.1404 - val_f1_score: 0.9792 - val_categorical_accuracy: 0.9791
# Epoch 5/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1312 - f1_score: 0.9594 - categorical_accuracy: 0.9592Found 5176 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1310 - f1_score: 0.9588 - categorical_accuracy: 0.9587Found 1293 validated image filenames belonging to 6 classes.
#
# Epoch 00005: val_loss did not improve from 0.13928
# 81/81 [==============================] - 379s 5s/step - loss: 0.1310 - f1_score: 0.9588 - categorical_accuracy: 0.9587 - val_loss: 0.1406 - val_f1_score: 0.9792 - val_categorical_accuracy: 0.9791
# Epoch 6/15
# 80/81 [============================>.] - ETA: 4s - loss: 0.1256 - f1_score: 0.9533 - categorical_accuracy: 0.9531Found 5176 validated image filenames belonging to 6 classes.
# 81/81 [==============================] - ETA: 0s - loss: 0.1253 - f1_score: 0.9537 - categorical_accuracy: 0.9534Found 1293 validated image filenames belonging to 6 classes.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.13928
# 81/81 [==============================] - 377s 5s/step - loss: 0.1253 - f1_score: 0.9537 - categorical_accuracy: 0.9534 - val_loss: 0.1407 - val_f1_score: 0.9808 - val_categorical_accuracy: 0.9807
# Epoch 00006: early stopping
# Found 1293 validated image filenames belonging to 6 classes.
# Found 1293 validated image filenames belonging to 6 classes.
# Found 3489 validated image filenames belonging to 1 classes.
# Found 3489 validated image filenames belonging to 1 classes.
#
# Fold-5 | F1-Score: 0.979169916024426
#
#
#
# Aggregate F1-Score: 0.9794811093209466

# %% [markdown]
# ## Create submission file

# %%
rev_class_map = {
    0: 'Airplane',
    1: 'Candle',
    2: 'Christmas_Tree',
    3: 'Jacket',
    4: 'Miscellaneous',
    5: 'Snowman'
}

# %%
test_df['Class'] = np.argmax(y_pred_final, axis=1)
test_df['Class'] = test_df['Class'].map(rev_class_map)
test_df.head()
# Out:
#            Image           Class
# 0  image7761.jpg   Miscellaneous
# 1  image3202.jpg   Miscellaneous
# 2   image688.jpg         Snowman
# 3   image233.jpg          Candle
# 4  image4332.jpg  Christmas_Tree

# %%
test_df.to_csv("/kaggle/working/submission.csv", index=False)
