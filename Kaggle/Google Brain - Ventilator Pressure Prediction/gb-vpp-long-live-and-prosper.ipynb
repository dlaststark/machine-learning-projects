# %% [markdown]
# ## Import libraries

# %%
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Bidirectional, LSTM
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Concatenate, Add, GRU

np.random.seed(42)
tf.random.set_seed(42)
# Out:
# 2021-10-13 10:05:51.696396: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-10-13 10:05:51.696515: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Load source datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_in__mean'] = df.groupby(['breath_id'])['u_in'].transform('mean')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"})\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df


print("Train data...\n")
train = add_features(train_df)

print("\nTest data...\n")
test = add_features(test_df)

del train_df
del test_df
gc.collect()
# Out:
# Train data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
#
# Test data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
# 0

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)

train.drop(['pressure','id', 'breath_id','one','count',
            'breath_id_lag','breath_id_lag2','breath_id_lagsame',
            'breath_id_lag2same'], axis=1, inplace=True)

test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                  'breath_id_lag2','breath_id_lagsame',
                  'breath_id_lag2same'], axis=1)

print(f"train: {train.shape} \ntest: {test.shape}")
# Out:
# train: (6036000, 64)
# test: (4024000, 64)

# %%
scaler = RobustScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 64)
# test: (50300, 80, 64)
# targets: (75450, 80)

# %%
pressure = targets.squeeze().reshape(-1,1).astype('float32')

P_MIN = np.min(pressure)
P_MAX = np.max(pressure)
P_STEP = (pressure[1] - pressure[0])[0]
print('Min pressure: {}'.format(P_MIN))
print('Max pressure: {}'.format(P_MAX))
print('Pressure step: {}'.format(P_STEP))
print('Unique values:  {}'.format(np.unique(pressure).shape[0]))

del pressure
gc.collect()
# Out:
# Min pressure: -1.8957443237304688
# Max pressure: 64.82099151611328
# Pressure step: 0.07030248641967773
# Unique values:  950
# 63

# %% [markdown]
# ## Hardware config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    
except ValueError:
    strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 512
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# 2021-10-13 10:08:43.292665: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-13 10:08:43.295855: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-10-13 10:08:43.295895: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-13 10:08:43.295926: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (33046e0bc736): /proc/driver/nvidia/version does not exist
# 2021-10-13 10:08:43.298923: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-13 10:08:43.300553: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-13 10:08:43.306371: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-13 10:08:43.329424: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2021-10-13 10:08:43.329476: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2021-10-13 10:08:43.355216: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2021-10-13 10:08:43.355280: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2021-10-13 10:08:43.356860: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30019
# Running on TPU: grpc://10.0.0.2:8470
# Batch Size: 512

# %% [markdown]
# ## Keras DNN Model

# %%
def dnn_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=256, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=128, return_sequences=True))(x3)
    
    z2 = Bidirectional(GRU(units=256, return_sequences=True))(x2)
    z3 = Bidirectional(GRU(units=128, return_sequences=True))(Add()([x3, z2]))
    z4 = Bidirectional(GRU(units=64, return_sequences=True))(Add()([x4, z3]))
    
    x = Concatenate(axis=2)([x4, z2, z3, z4])
    
    x1 = Dense(units=128, activation='selu')(x)
    x2 = Dense(units=128, activation='relu')(x)
    x3 = Dense(units=128, activation='elu')(x)
    x4 = Dense(units=128, activation='swish')(x)
    
    x = Concatenate(axis=2)([x1, x2, x3, x4])
    
    x_output = Dense(units=1)(x)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
model = dnn_model()
model.summary()
# Out:
# Model: "DNN_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 64)]     0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 80, 1536)     5117952     input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 1024)     8392704     bidirectional[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 512)      2623488     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 512)      1969152     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 80, 512)      0           bidirectional_2[0][0]
#                                                                  bidirectional_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 256)      656384      bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 80, 256)      493056      add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 80, 256)      0           bidirectional_3[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 80, 128)      123648      add_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 80, 1152)     0           bidirectional_3[0][0]
#                                                                  bidirectional_4[0][0]
#                                                                  bidirectional_5[0][0]
#                                                                  bidirectional_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 80, 128)      147584      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80, 128)      147584      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80, 128)      147584      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 80, 128)      147584      concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 80, 512)      0           dense[0][0]
#                                                                  dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 80, 1)        513         concatenate_1[0][0]
# ==================================================================================================
# Total params: 19,967,233
# Trainable params: 19,967,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(
    model, 
    to_file='Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)

# %%
with tpu_strategy.scope():
    
    VERBOSE = 1
    test_preds = []
    kf = KFold(n_splits=7, shuffle=True, random_state=2021)
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        
        model = dnn_model()
        model.compile(optimizer="adam", loss="mae")

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.85, 
                               patience=10, verbose=VERBOSE)
        
        save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
        chk_point = ModelCheckpoint(f'./Bidirect_LSTM_model_2021_{fold+1}C.h5', options=save_locally, 
                                    monitor='val_loss', verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_loss", patience=50, 
                           verbose=VERBOSE, mode="min", 
                           restore_best_weights=True)
        
        model.fit(X_train, y_train, 
                  validation_data=(X_valid, y_valid), 
                  epochs=300,
                  verbose=VERBOSE,
                  batch_size=BATCH_SIZE, 
                  callbacks=[lr, chk_point, es])
        
        load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
        model = load_model(f'./Bidirect_LSTM_model_2021_{fold+1}C.h5', options=load_locally)
        
        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
        score = mean_absolute_error(y_true, y_pred)
        print(f"Fold-{fold+1} | OOF Score: {score}")
        
        test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
# Out:
# 2021-10-13 10:09:17.740321: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1324462080 exceeds 10% of free system memory.
# Epoch 1/300
# 127/127 [==============================] - 70s 287ms/step - loss: 3.1105 - val_loss: 0.7587
#
# Epoch 00001: val_loss improved from inf to 0.75866, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 2/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.7037 - val_loss: 0.5266
#
# Epoch 00002: val_loss improved from 0.75866 to 0.52658, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 3/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.5154 - val_loss: 0.4809
#
# Epoch 00003: val_loss improved from 0.52658 to 0.48090, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 4/300
# 127/127 [==============================] - 16s 127ms/step - loss: 0.4987 - val_loss: 0.4391
#
# Epoch 00004: val_loss improved from 0.48090 to 0.43912, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 5/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.4362 - val_loss: 0.4445
#
# Epoch 00005: val_loss did not improve from 0.43912
# Epoch 6/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.4109 - val_loss: 0.3827
#
# Epoch 00006: val_loss improved from 0.43912 to 0.38268, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 7/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3774 - val_loss: 0.3861
#
# Epoch 00007: val_loss did not improve from 0.38268
# Epoch 8/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3750 - val_loss: 0.3597
#
# Epoch 00008: val_loss improved from 0.38268 to 0.35968, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 9/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3495 - val_loss: 0.3366
#
# Epoch 00009: val_loss improved from 0.35968 to 0.33658, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 10/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3472 - val_loss: 0.3261
#
# Epoch 00010: val_loss improved from 0.33658 to 0.32612, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 11/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3204 - val_loss: 0.3196
#
# Epoch 00011: val_loss improved from 0.32612 to 0.31964, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 12/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3124 - val_loss: 0.3173
#
# Epoch 00012: val_loss improved from 0.31964 to 0.31728, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 13/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3063 - val_loss: 0.2992
#
# Epoch 00013: val_loss improved from 0.31728 to 0.29917, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 14/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3055 - val_loss: 0.2849
#
# Epoch 00014: val_loss improved from 0.29917 to 0.28494, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 15/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2892 - val_loss: 0.3253
#
# Epoch 00015: val_loss did not improve from 0.28494
# Epoch 16/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3062 - val_loss: 0.3326
#
# Epoch 00016: val_loss did not improve from 0.28494
# Epoch 17/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2925 - val_loss: 0.2793
#
# Epoch 00017: val_loss improved from 0.28494 to 0.27926, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 18/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2883 - val_loss: 0.3374
#
# Epoch 00018: val_loss did not improve from 0.27926
# Epoch 19/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2835 - val_loss: 0.3019
#
# Epoch 00019: val_loss did not improve from 0.27926
# Epoch 20/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2770 - val_loss: 0.3170
#
# Epoch 00020: val_loss did not improve from 0.27926
# Epoch 21/300
# 127/127 [==============================] - 16s 122ms/step - loss: 0.2811 - val_loss: 0.2733
#
# Epoch 00021: val_loss improved from 0.27926 to 0.27329, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 22/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2783 - val_loss: 0.2688
#
# Epoch 00022: val_loss improved from 0.27329 to 0.26879, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 23/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2615 - val_loss: 0.2832
#
# Epoch 00023: val_loss did not improve from 0.26879
# Epoch 24/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2553 - val_loss: 0.2639
#
# Epoch 00024: val_loss improved from 0.26879 to 0.26385, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 25/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2629 - val_loss: 0.2569
#
# Epoch 00025: val_loss improved from 0.26385 to 0.25694, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 26/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2522 - val_loss: 0.2818
#
# Epoch 00026: val_loss did not improve from 0.25694
# Epoch 27/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2569 - val_loss: 0.2652
#
# Epoch 00027: val_loss did not improve from 0.25694
# Epoch 28/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2444 - val_loss: 0.2747
#
# Epoch 00028: val_loss did not improve from 0.25694
# Epoch 29/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2572 - val_loss: 0.2459
#
# Epoch 00029: val_loss improved from 0.25694 to 0.24593, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 30/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2406 - val_loss: 0.2570
#
# Epoch 00030: val_loss did not improve from 0.24593
# Epoch 31/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2436 - val_loss: 0.2594
#
# Epoch 00031: val_loss did not improve from 0.24593
# Epoch 32/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2551 - val_loss: 0.2646
#
# Epoch 00032: val_loss did not improve from 0.24593
# Epoch 33/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2485 - val_loss: 0.2523
#
# Epoch 00033: val_loss did not improve from 0.24593
# Epoch 34/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2358 - val_loss: 0.2737
#
# Epoch 00034: val_loss did not improve from 0.24593
# Epoch 35/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2528 - val_loss: 0.2350
#
# Epoch 00035: val_loss improved from 0.24593 to 0.23497, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 36/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2383 - val_loss: 0.2354
#
# Epoch 00036: val_loss did not improve from 0.23497
# Epoch 37/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2213 - val_loss: 0.2253
#
# Epoch 00037: val_loss improved from 0.23497 to 0.22534, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 38/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2120 - val_loss: 0.2472
#
# Epoch 00038: val_loss did not improve from 0.22534
# Epoch 39/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2243 - val_loss: 0.2409
#
# Epoch 00039: val_loss did not improve from 0.22534
# Epoch 40/300
# 127/127 [==============================] - 16s 122ms/step - loss: 0.2232 - val_loss: 0.2727
#
# Epoch 00040: val_loss did not improve from 0.22534
# Epoch 41/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2270 - val_loss: 0.2432
#
# Epoch 00041: val_loss did not improve from 0.22534
# Epoch 42/300
# 127/127 [==============================] - 16s 122ms/step - loss: 0.2230 - val_loss: 0.2263
#
# Epoch 00042: val_loss did not improve from 0.22534
# Epoch 43/300
# 127/127 [==============================] - 16s 122ms/step - loss: 0.2127 - val_loss: 0.2721
#
# Epoch 00043: val_loss did not improve from 0.22534
# Epoch 44/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2254 - val_loss: 0.2250
#
# Epoch 00044: val_loss improved from 0.22534 to 0.22497, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 45/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2044 - val_loss: 0.2246
#
# Epoch 00045: val_loss improved from 0.22497 to 0.22459, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 46/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2038 - val_loss: 0.2441
#
# Epoch 00046: val_loss did not improve from 0.22459
# Epoch 47/300
# 127/127 [==============================] - 16s 122ms/step - loss: 0.2158 - val_loss: 0.2333
#
# Epoch 00047: val_loss did not improve from 0.22459
# Epoch 48/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.2028 - val_loss: 0.2154
#
# Epoch 00048: val_loss improved from 0.22459 to 0.21539, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 49/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2091 - val_loss: 0.2227
#
# Epoch 00049: val_loss did not improve from 0.21539
# Epoch 50/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2066 - val_loss: 0.2197
#
# Epoch 00050: val_loss did not improve from 0.21539
# Epoch 51/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1956 - val_loss: 0.2094
#
# Epoch 00051: val_loss improved from 0.21539 to 0.20944, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 52/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2008 - val_loss: 0.2133
#
# Epoch 00052: val_loss did not improve from 0.20944
# Epoch 53/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1985 - val_loss: 0.2226
#
# Epoch 00053: val_loss did not improve from 0.20944
# Epoch 54/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1974 - val_loss: 0.2265
#
# Epoch 00054: val_loss did not improve from 0.20944
# Epoch 55/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2104 - val_loss: 0.2030
#
# Epoch 00055: val_loss improved from 0.20944 to 0.20303, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 56/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1876 - val_loss: 0.2194
#
# Epoch 00056: val_loss did not improve from 0.20303
# Epoch 57/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1892 - val_loss: 0.2098
#
# Epoch 00057: val_loss did not improve from 0.20303
# Epoch 58/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1948 - val_loss: 0.2206
#
# Epoch 00058: val_loss did not improve from 0.20303
# Epoch 59/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1947 - val_loss: 0.2169
#
# Epoch 00059: val_loss did not improve from 0.20303
# Epoch 60/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1785 - val_loss: 0.2005
#
# Epoch 00060: val_loss improved from 0.20303 to 0.20053, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 61/300
# 127/127 [==============================] - 17s 130ms/step - loss: 0.1742 - val_loss: 0.1938
#
# Epoch 00061: val_loss improved from 0.20053 to 0.19381, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 62/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1711 - val_loss: 0.2003
#
# Epoch 00062: val_loss did not improve from 0.19381
# Epoch 63/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1733 - val_loss: 0.1937
#
# Epoch 00063: val_loss improved from 0.19381 to 0.19371, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 64/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1742 - val_loss: 0.2030
#
# Epoch 00064: val_loss did not improve from 0.19371
# Epoch 65/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1795 - val_loss: 0.2408
#
# Epoch 00065: val_loss did not improve from 0.19371
# Epoch 66/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2033 - val_loss: 0.2393
#
# Epoch 00066: val_loss did not improve from 0.19371
# Epoch 67/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2084 - val_loss: 0.2411
#
# Epoch 00067: val_loss did not improve from 0.19371
# Epoch 68/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2058 - val_loss: 0.2077
#
# Epoch 00068: val_loss did not improve from 0.19371
# Epoch 69/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1810 - val_loss: 0.2048
#
# Epoch 00069: val_loss did not improve from 0.19371
# Epoch 70/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1827 - val_loss: 0.2016
#
# Epoch 00070: val_loss did not improve from 0.19371
# Epoch 71/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1721 - val_loss: 0.1846
#
# Epoch 00071: val_loss improved from 0.19371 to 0.18464, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 72/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2127 - val_loss: 0.2293
#
# Epoch 00072: val_loss did not improve from 0.18464
# Epoch 73/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1973 - val_loss: 0.2058
#
# Epoch 00073: val_loss did not improve from 0.18464
# Epoch 74/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1771 - val_loss: 0.1968
#
# Epoch 00074: val_loss did not improve from 0.18464
# Epoch 75/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1696 - val_loss: 0.1924
#
# Epoch 00075: val_loss did not improve from 0.18464
# Epoch 76/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1653 - val_loss: 0.1885
#
# Epoch 00076: val_loss did not improve from 0.18464
# Epoch 77/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1786 - val_loss: 0.2208
#
# Epoch 00077: val_loss did not improve from 0.18464
# Epoch 78/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1870 - val_loss: 0.1918
#
# Epoch 00078: val_loss did not improve from 0.18464
# Epoch 79/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1651 - val_loss: 0.2026
#
# Epoch 00079: val_loss did not improve from 0.18464
# Epoch 80/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1683 - val_loss: 0.1961
#
# Epoch 00080: val_loss did not improve from 0.18464
# Epoch 81/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1649 - val_loss: 0.2207
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 0.0008500000403728336.
#
# Epoch 00081: val_loss did not improve from 0.18464
# Epoch 82/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1747 - val_loss: 0.1803
#
# Epoch 00082: val_loss improved from 0.18464 to 0.18031, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 83/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1541 - val_loss: 0.1817
#
# Epoch 00083: val_loss did not improve from 0.18031
# Epoch 84/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1483 - val_loss: 0.1802
#
# Epoch 00084: val_loss improved from 0.18031 to 0.18016, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 85/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1470 - val_loss: 0.1787
#
# Epoch 00085: val_loss improved from 0.18016 to 0.17871, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 86/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1757 - val_loss: 0.2084
#
# Epoch 00086: val_loss did not improve from 0.17871
# Epoch 87/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1689 - val_loss: 0.1918
#
# Epoch 00087: val_loss did not improve from 0.17871
# Epoch 88/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1747 - val_loss: 0.2095
#
# Epoch 00088: val_loss did not improve from 0.17871
# Epoch 89/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1669 - val_loss: 0.1844
#
# Epoch 00089: val_loss did not improve from 0.17871
# Epoch 90/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1510 - val_loss: 0.1823
#
# Epoch 00090: val_loss did not improve from 0.17871
# Epoch 91/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1451 - val_loss: 0.1776
#
# Epoch 00091: val_loss improved from 0.17871 to 0.17756, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 92/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1414 - val_loss: 0.1792
#
# Epoch 00092: val_loss did not improve from 0.17756
# Epoch 93/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1397 - val_loss: 0.1726
#
# Epoch 00093: val_loss improved from 0.17756 to 0.17257, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 94/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1387 - val_loss: 0.1773
#
# Epoch 00094: val_loss did not improve from 0.17257
# Epoch 95/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1380 - val_loss: 0.1741
#
# Epoch 00095: val_loss did not improve from 0.17257
# Epoch 96/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1382 - val_loss: 0.1754
#
# Epoch 00096: val_loss did not improve from 0.17257
# Epoch 97/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1398 - val_loss: 0.1770
#
# Epoch 00097: val_loss did not improve from 0.17257
# Epoch 98/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1352 - val_loss: 0.1723
#
# Epoch 00098: val_loss improved from 0.17257 to 0.17227, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 99/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1330 - val_loss: 0.1802
#
# Epoch 00099: val_loss did not improve from 0.17227
# Epoch 100/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1391 - val_loss: 0.1712
#
# Epoch 00100: val_loss improved from 0.17227 to 0.17125, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 101/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1328 - val_loss: 0.1742
#
# Epoch 00101: val_loss did not improve from 0.17125
# Epoch 102/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1365 - val_loss: 0.1990
#
# Epoch 00102: val_loss did not improve from 0.17125
# Epoch 103/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1518 - val_loss: 0.1768
#
# Epoch 00103: val_loss did not improve from 0.17125
# Epoch 104/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1343 - val_loss: 0.1760
#
# Epoch 00104: val_loss did not improve from 0.17125
# Epoch 105/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1330 - val_loss: 0.1712
#
# Epoch 00105: val_loss improved from 0.17125 to 0.17119, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 106/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1293 - val_loss: 0.1812
#
# Epoch 00106: val_loss did not improve from 0.17119
# Epoch 107/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1350 - val_loss: 0.1772
#
# Epoch 00107: val_loss did not improve from 0.17119
# Epoch 108/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1309 - val_loss: 0.1689
#
# Epoch 00108: val_loss improved from 0.17119 to 0.16893, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 109/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1274 - val_loss: 0.1833
#
# Epoch 00109: val_loss did not improve from 0.16893
# Epoch 110/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1368 - val_loss: 0.1758
#
# Epoch 00110: val_loss did not improve from 0.16893
# Epoch 111/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1298 - val_loss: 0.1712
#
# Epoch 00111: val_loss did not improve from 0.16893
# Epoch 112/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1240 - val_loss: 0.1758
#
# Epoch 00112: val_loss did not improve from 0.16893
# Epoch 113/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1281 - val_loss: 0.1734
#
# Epoch 00113: val_loss did not improve from 0.16893
# Epoch 114/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1260 - val_loss: 0.1756
#
# Epoch 00114: val_loss did not improve from 0.16893
# Epoch 115/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1237 - val_loss: 0.1729
#
# Epoch 00115: val_loss did not improve from 0.16893
# Epoch 116/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1258 - val_loss: 0.1772
#
# Epoch 00116: val_loss did not improve from 0.16893
# Epoch 117/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1257 - val_loss: 0.1700
#
# Epoch 00117: val_loss did not improve from 0.16893
# Epoch 118/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1181 - val_loss: 0.1787
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 0.0007225000590551645.
#
# Epoch 00118: val_loss did not improve from 0.16893
# Epoch 119/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1186 - val_loss: 0.1660
#
# Epoch 00119: val_loss improved from 0.16893 to 0.16597, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 120/300
# 127/127 [==============================] - 16s 128ms/step - loss: 0.1111 - val_loss: 0.1714
#
# Epoch 00120: val_loss did not improve from 0.16597
# Epoch 121/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1098 - val_loss: 0.1685
#
# Epoch 00121: val_loss did not improve from 0.16597
# Epoch 122/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1097 - val_loss: 0.1668
#
# Epoch 00122: val_loss did not improve from 0.16597
# Epoch 123/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1108 - val_loss: 0.1777
#
# Epoch 00123: val_loss did not improve from 0.16597
# Epoch 124/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1179 - val_loss: 0.1701
#
# Epoch 00124: val_loss did not improve from 0.16597
# Epoch 125/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1097 - val_loss: 0.1678
#
# Epoch 00125: val_loss did not improve from 0.16597
# Epoch 126/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1082 - val_loss: 0.1668
#
# Epoch 00126: val_loss did not improve from 0.16597
# Epoch 127/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1071 - val_loss: 0.1673
#
# Epoch 00127: val_loss did not improve from 0.16597
# Epoch 128/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1056 - val_loss: 0.1699
#
# Epoch 00128: val_loss did not improve from 0.16597
# Epoch 129/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1074 - val_loss: 0.1688
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 0.0006141250254586339.
#
# Epoch 00129: val_loss did not improve from 0.16597
# Epoch 130/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1013 - val_loss: 0.1639
#
# Epoch 00130: val_loss improved from 0.16597 to 0.16386, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 131/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0987 - val_loss: 0.1630
#
# Epoch 00131: val_loss improved from 0.16386 to 0.16300, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 132/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0965 - val_loss: 0.1626
#
# Epoch 00132: val_loss improved from 0.16300 to 0.16263, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 133/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0947 - val_loss: 0.1631
#
# Epoch 00133: val_loss did not improve from 0.16263
# Epoch 134/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0940 - val_loss: 0.1671
#
# Epoch 00134: val_loss did not improve from 0.16263
# Epoch 135/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0966 - val_loss: 0.1660
#
# Epoch 00135: val_loss did not improve from 0.16263
# Epoch 136/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0950 - val_loss: 0.1651
#
# Epoch 00136: val_loss did not improve from 0.16263
# Epoch 137/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0934 - val_loss: 0.1640
#
# Epoch 00137: val_loss did not improve from 0.16263
# Epoch 138/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0928 - val_loss: 0.1663
#
# Epoch 00138: val_loss did not improve from 0.16263
# Epoch 139/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0911 - val_loss: 0.1662
#
# Epoch 00139: val_loss did not improve from 0.16263
# Epoch 140/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0927 - val_loss: 0.1640
#
# Epoch 00140: val_loss did not improve from 0.16263
# Epoch 141/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0903 - val_loss: 0.1648
#
# Epoch 00141: val_loss did not improve from 0.16263
# Epoch 142/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0902 - val_loss: 0.1636
#
# Epoch 00142: ReduceLROnPlateau reducing learning rate to 0.0005220062914304435.
#
# Epoch 00142: val_loss did not improve from 0.16263
# Epoch 143/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0855 - val_loss: 0.1629
#
# Epoch 00143: val_loss did not improve from 0.16263
# Epoch 144/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0831 - val_loss: 0.1635
#
# Epoch 00144: val_loss did not improve from 0.16263
# Epoch 145/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0832 - val_loss: 0.1641
#
# Epoch 00145: val_loss did not improve from 0.16263
# Epoch 146/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0824 - val_loss: 0.1640
#
# Epoch 00146: val_loss did not improve from 0.16263
# Epoch 147/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0832 - val_loss: 0.1650
#
# Epoch 00147: val_loss did not improve from 0.16263
# Epoch 148/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0812 - val_loss: 0.1656
#
# Epoch 00148: val_loss did not improve from 0.16263
# Epoch 149/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0827 - val_loss: 0.1638
#
# Epoch 00149: val_loss did not improve from 0.16263
# Epoch 150/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0822 - val_loss: 0.1654
#
# Epoch 00150: val_loss did not improve from 0.16263
# Epoch 151/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0826 - val_loss: 0.1704
#
# Epoch 00151: val_loss did not improve from 0.16263
# Epoch 152/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0841 - val_loss: 0.1638
#
# Epoch 00152: ReduceLROnPlateau reducing learning rate to 0.00044370535761117935.
#
# Epoch 00152: val_loss did not improve from 0.16263
# Epoch 153/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0787 - val_loss: 0.1626
#
# Epoch 00153: val_loss improved from 0.16263 to 0.16256, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 154/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0748 - val_loss: 0.1627
#
# Epoch 00154: val_loss did not improve from 0.16256
# Epoch 155/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0738 - val_loss: 0.1623
#
# Epoch 00155: val_loss improved from 0.16256 to 0.16232, saving model to ./Bidirect_LSTM_model_2021_1C.h5
# Epoch 156/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0733 - val_loss: 0.1631
#
# Epoch 00156: val_loss did not improve from 0.16232
# Epoch 157/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0735 - val_loss: 0.1643
#
# Epoch 00157: val_loss did not improve from 0.16232
# Epoch 158/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0751 - val_loss: 0.1640
#
# Epoch 00158: val_loss did not improve from 0.16232
# Epoch 159/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0722 - val_loss: 0.1650
#
# Epoch 00159: val_loss did not improve from 0.16232
# Epoch 160/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0726 - val_loss: 0.1632
#
# Epoch 00160: val_loss did not improve from 0.16232
# Epoch 161/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0730 - val_loss: 0.1640
#
# Epoch 00161: val_loss did not improve from 0.16232
# Epoch 162/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0726 - val_loss: 0.1631
#
# Epoch 00162: val_loss did not improve from 0.16232
# Epoch 163/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0714 - val_loss: 0.1633
#
# Epoch 00163: val_loss did not improve from 0.16232
# Epoch 164/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0702 - val_loss: 0.1638
#
# Epoch 00164: val_loss did not improve from 0.16232
# Epoch 165/300
# 127/127 [==============================] - 16s 128ms/step - loss: 0.0696 - val_loss: 0.1639
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 0.00037714955396950245.
#
# Epoch 00165: val_loss did not improve from 0.16232
# Epoch 166/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0677 - val_loss: 0.1631
#
# Epoch 00166: val_loss did not improve from 0.16232
# Epoch 167/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0666 - val_loss: 0.1628
#
# Epoch 00167: val_loss did not improve from 0.16232
# Epoch 168/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0649 - val_loss: 0.1631
#
# Epoch 00168: val_loss did not improve from 0.16232
# Epoch 169/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0643 - val_loss: 0.1628
#
# Epoch 00169: val_loss did not improve from 0.16232
# Epoch 170/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0640 - val_loss: 0.1631
#
# Epoch 00170: val_loss did not improve from 0.16232
# Epoch 171/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0640 - val_loss: 0.1625
#
# Epoch 00171: val_loss did not improve from 0.16232
# Epoch 172/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0633 - val_loss: 0.1634
#
# Epoch 00172: val_loss did not improve from 0.16232
# Epoch 173/300
# 127/127 [==============================] - 16s 129ms/step - loss: 0.0638 - val_loss: 0.1638
#
# Epoch 00173: val_loss did not improve from 0.16232
# Epoch 174/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0626 - val_loss: 0.1640
#
# Epoch 00174: val_loss did not improve from 0.16232
# Epoch 175/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0627 - val_loss: 0.1639
#
# Epoch 00175: ReduceLROnPlateau reducing learning rate to 0.0003205771208740771.
#
# Epoch 00175: val_loss did not improve from 0.16232
# Epoch 176/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0614 - val_loss: 0.1631
#
# Epoch 00176: val_loss did not improve from 0.16232
# Epoch 177/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0597 - val_loss: 0.1640
#
# Epoch 00177: val_loss did not improve from 0.16232
# Epoch 178/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0586 - val_loss: 0.1632
#
# Epoch 00178: val_loss did not improve from 0.16232
# Epoch 179/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0581 - val_loss: 0.1642
#
# Epoch 00179: val_loss did not improve from 0.16232
# Epoch 180/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0581 - val_loss: 0.1640
#
# Epoch 00180: val_loss did not improve from 0.16232
# Epoch 181/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0582 - val_loss: 0.1639
#
# Epoch 00181: val_loss did not improve from 0.16232
# Epoch 182/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0578 - val_loss: 0.1636
#
# Epoch 00182: val_loss did not improve from 0.16232
# Epoch 183/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0579 - val_loss: 0.1636
#
# Epoch 00183: val_loss did not improve from 0.16232
# Epoch 184/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0565 - val_loss: 0.1640
#
# Epoch 00184: val_loss did not improve from 0.16232
# Epoch 185/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0564 - val_loss: 0.1639
#
# Epoch 00185: ReduceLROnPlateau reducing learning rate to 0.0002724905527429655.
#
# Epoch 00185: val_loss did not improve from 0.16232
# Epoch 186/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0547 - val_loss: 0.1632
#
# Epoch 00186: val_loss did not improve from 0.16232
# Epoch 187/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0533 - val_loss: 0.1636
#
# Epoch 00187: val_loss did not improve from 0.16232
# Epoch 188/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0532 - val_loss: 0.1632
#
# Epoch 00188: val_loss did not improve from 0.16232
# Epoch 189/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0531 - val_loss: 0.1637
#
# Epoch 00189: val_loss did not improve from 0.16232
# Epoch 190/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0535 - val_loss: 0.1634
#
# Epoch 00190: val_loss did not improve from 0.16232
# Epoch 191/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0530 - val_loss: 0.1644
#
# Epoch 00191: val_loss did not improve from 0.16232
# Epoch 192/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0523 - val_loss: 0.1640
#
# Epoch 00192: val_loss did not improve from 0.16232
# Epoch 193/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0521 - val_loss: 0.1641
#
# Epoch 00193: val_loss did not improve from 0.16232
# Epoch 194/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0527 - val_loss: 0.1633
#
# Epoch 00194: val_loss did not improve from 0.16232
# Epoch 195/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0516 - val_loss: 0.1635
#
# Epoch 00195: ReduceLROnPlateau reducing learning rate to 0.00023161696735769509.
#
# Epoch 00195: val_loss did not improve from 0.16232
# Epoch 196/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0504 - val_loss: 0.1639
#
# Epoch 00196: val_loss did not improve from 0.16232
# Epoch 197/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0492 - val_loss: 0.1642
#
# Epoch 00197: val_loss did not improve from 0.16232
# Epoch 198/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0486 - val_loss: 0.1637
#
# Epoch 00198: val_loss did not improve from 0.16232
# Epoch 199/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0490 - val_loss: 0.1641
#
# Epoch 00199: val_loss did not improve from 0.16232
# Epoch 200/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0488 - val_loss: 0.1637
#
# Epoch 00200: val_loss did not improve from 0.16232
# Epoch 201/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0478 - val_loss: 0.1637
#
# Epoch 00201: val_loss did not improve from 0.16232
# Epoch 202/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0476 - val_loss: 0.1640
#
# Epoch 00202: val_loss did not improve from 0.16232
# Epoch 203/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0475 - val_loss: 0.1643
#
# Epoch 00203: val_loss did not improve from 0.16232
# Epoch 204/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0486 - val_loss: 0.1642
#
# Epoch 00204: val_loss did not improve from 0.16232
# Epoch 205/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0475 - val_loss: 0.1642
#
# Epoch 00205: ReduceLROnPlateau reducing learning rate to 0.00019687442472786642.
#
# Epoch 00205: val_loss did not improve from 0.16232
# Restoring model weights from the end of the best epoch.
# Epoch 00205: early stopping
# Fold-1 | OOF Score: 0.16232432919053058
# 2021-10-13 11:05:15.698695: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1030144000 exceeds 10% of free system memory.
# 2021-10-13 11:05:40.834768: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1324462080 exceeds 10% of free system memory.
# Epoch 1/300
# 127/127 [==============================] - 71s 296ms/step - loss: 3.3524 - val_loss: 0.7091
#
# Epoch 00001: val_loss improved from inf to 0.70911, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 2/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.6872 - val_loss: 0.5263
#
# Epoch 00002: val_loss improved from 0.70911 to 0.52626, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 3/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.5154 - val_loss: 0.5203
#
# Epoch 00003: val_loss improved from 0.52626 to 0.52032, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 4/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.4761 - val_loss: 0.4540
#
# Epoch 00004: val_loss improved from 0.52032 to 0.45399, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 5/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.4628 - val_loss: 0.4504
#
# Epoch 00005: val_loss improved from 0.45399 to 0.45042, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 6/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.4121 - val_loss: 0.4205
#
# Epoch 00006: val_loss improved from 0.45042 to 0.42046, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 7/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.4004 - val_loss: 0.3671
#
# Epoch 00007: val_loss improved from 0.42046 to 0.36714, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 8/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3598 - val_loss: 0.3509
#
# Epoch 00008: val_loss improved from 0.36714 to 0.35089, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 9/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3563 - val_loss: 0.3391
#
# Epoch 00009: val_loss improved from 0.35089 to 0.33913, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 10/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3472 - val_loss: 0.3722
#
# Epoch 00010: val_loss did not improve from 0.33913
# Epoch 11/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3297 - val_loss: 0.3457
#
# Epoch 00011: val_loss did not improve from 0.33913
# Epoch 12/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3231 - val_loss: 0.3317
#
# Epoch 00012: val_loss improved from 0.33913 to 0.33175, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 13/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.3094 - val_loss: 0.3023
#
# Epoch 00013: val_loss improved from 0.33175 to 0.30225, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 14/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2996 - val_loss: 0.2952
#
# Epoch 00014: val_loss improved from 0.30225 to 0.29518, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 15/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2871 - val_loss: 0.2816
#
# Epoch 00015: val_loss improved from 0.29518 to 0.28158, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 16/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.2829 - val_loss: 0.2886
#
# Epoch 00016: val_loss did not improve from 0.28158
# Epoch 17/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2717 - val_loss: 0.2662
#
# Epoch 00017: val_loss improved from 0.28158 to 0.26617, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 18/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2638 - val_loss: 0.2684
#
# Epoch 00018: val_loss did not improve from 0.26617
# Epoch 19/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2641 - val_loss: 0.2708
#
# Epoch 00019: val_loss did not improve from 0.26617
# Epoch 20/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2631 - val_loss: 0.2705
#
# Epoch 00020: val_loss did not improve from 0.26617
# Epoch 21/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2518 - val_loss: 0.2751
#
# Epoch 00021: val_loss did not improve from 0.26617
# Epoch 22/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2514 - val_loss: 0.2515
#
# Epoch 00022: val_loss improved from 0.26617 to 0.25155, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 23/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2473 - val_loss: 0.2530
#
# Epoch 00023: val_loss did not improve from 0.25155
# Epoch 24/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2411 - val_loss: 0.2549
#
# Epoch 00024: val_loss did not improve from 0.25155
# Epoch 25/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.2378 - val_loss: 0.2645
#
# Epoch 00025: val_loss did not improve from 0.25155
# Epoch 26/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2421 - val_loss: 0.2458
#
# Epoch 00026: val_loss improved from 0.25155 to 0.24583, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 27/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.2369 - val_loss: 0.2334
#
# Epoch 00027: val_loss improved from 0.24583 to 0.23336, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 28/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2298 - val_loss: 0.2521
#
# Epoch 00028: val_loss did not improve from 0.23336
# Epoch 29/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2342 - val_loss: 0.2726
#
# Epoch 00029: val_loss did not improve from 0.23336
# Epoch 30/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2472 - val_loss: 0.2493
#
# Epoch 00030: val_loss did not improve from 0.23336
# Epoch 31/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2264 - val_loss: 0.2513
#
# Epoch 00031: val_loss did not improve from 0.23336
# Epoch 32/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2229 - val_loss: 0.2422
#
# Epoch 00032: val_loss did not improve from 0.23336
# Epoch 33/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.2239 - val_loss: 0.2390
#
# Epoch 00033: val_loss did not improve from 0.23336
# Epoch 34/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2204 - val_loss: 0.2287
#
# Epoch 00034: val_loss improved from 0.23336 to 0.22868, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 35/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2152 - val_loss: 0.2403
#
# Epoch 00035: val_loss did not improve from 0.22868
# Epoch 36/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2136 - val_loss: 0.2386
#
# Epoch 00036: val_loss did not improve from 0.22868
# Epoch 37/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2147 - val_loss: 0.2254
#
# Epoch 00037: val_loss improved from 0.22868 to 0.22541, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 38/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2224 - val_loss: 0.2633
#
# Epoch 00038: val_loss did not improve from 0.22541
# Epoch 39/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2226 - val_loss: 0.2228
#
# Epoch 00039: val_loss improved from 0.22541 to 0.22276, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 40/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2195 - val_loss: 0.2268
#
# Epoch 00040: val_loss did not improve from 0.22276
# Epoch 41/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2210 - val_loss: 0.2310
#
# Epoch 00041: val_loss did not improve from 0.22276
# Epoch 42/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2135 - val_loss: 0.2963
#
# Epoch 00042: val_loss did not improve from 0.22276
# Epoch 43/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2331 - val_loss: 0.2155
#
# Epoch 00043: val_loss improved from 0.22276 to 0.21551, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 44/300
# 127/127 [==============================] - 16s 128ms/step - loss: 0.2012 - val_loss: 0.2090
#
# Epoch 00044: val_loss improved from 0.21551 to 0.20899, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 45/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1932 - val_loss: 0.2055
#
# Epoch 00045: val_loss improved from 0.20899 to 0.20551, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 46/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1947 - val_loss: 0.2013
#
# Epoch 00046: val_loss improved from 0.20551 to 0.20126, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 47/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1857 - val_loss: 0.2268
#
# Epoch 00047: val_loss did not improve from 0.20126
# Epoch 48/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2105 - val_loss: 0.2468
#
# Epoch 00048: val_loss did not improve from 0.20126
# Epoch 49/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.2091 - val_loss: 0.2169
#
# Epoch 00049: val_loss did not improve from 0.20126
# Epoch 50/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1993 - val_loss: 0.2122
#
# Epoch 00050: val_loss did not improve from 0.20126
# Epoch 51/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1890 - val_loss: 0.2133
#
# Epoch 00051: val_loss did not improve from 0.20126
# Epoch 52/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1892 - val_loss: 0.2328
#
# Epoch 00052: val_loss did not improve from 0.20126
# Epoch 53/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1972 - val_loss: 0.1971
#
# Epoch 00053: val_loss improved from 0.20126 to 0.19709, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 54/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1871 - val_loss: 0.2098
#
# Epoch 00054: val_loss did not improve from 0.19709
# Epoch 55/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1867 - val_loss: 0.2319
#
# Epoch 00055: val_loss did not improve from 0.19709
# Epoch 56/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1872 - val_loss: 0.2033
#
# Epoch 00056: val_loss did not improve from 0.19709
# Epoch 57/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1816 - val_loss: 0.2100
#
# Epoch 00057: val_loss did not improve from 0.19709
# Epoch 58/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1904 - val_loss: 0.2123
#
# Epoch 00058: val_loss did not improve from 0.19709
# Epoch 59/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1973 - val_loss: 0.2002
#
# Epoch 00059: val_loss did not improve from 0.19709
# Epoch 60/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1825 - val_loss: 0.2077
#
# Epoch 00060: val_loss did not improve from 0.19709
# Epoch 61/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1779 - val_loss: 0.2066
#
# Epoch 00061: val_loss did not improve from 0.19709
# Epoch 62/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1797 - val_loss: 0.2002
#
# Epoch 00062: val_loss did not improve from 0.19709
# Epoch 63/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1777 - val_loss: 0.1978
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.0008500000403728336.
#
# Epoch 00063: val_loss did not improve from 0.19709
# Epoch 64/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1715 - val_loss: 0.1907
#
# Epoch 00064: val_loss improved from 0.19709 to 0.19072, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 65/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1647 - val_loss: 0.1964
#
# Epoch 00065: val_loss did not improve from 0.19072
# Epoch 66/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1789 - val_loss: 0.1858
#
# Epoch 00066: val_loss improved from 0.19072 to 0.18581, saving model to ./Bidirect_LSTM_model_2021_2C.h5
# Epoch 67/300
# ...
# Epoch 125/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1041 - val_loss: 0.1659
#
# Epoch 00125: val_loss did not improve from 0.16371
# Epoch 126/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1013 - val_loss: 0.1710
#
# Epoch 00126: val_loss did not improve from 0.16371
# Epoch 127/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1018 - val_loss: 0.1669
#
# Epoch 00127: val_loss did not improve from 0.16371
# Epoch 128/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0991 - val_loss: 0.1657
#
# Epoch 00128: val_loss did not improve from 0.16371
# Epoch 129/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.1000 - val_loss: 0.1694
#
# Epoch 00129: val_loss did not improve from 0.16371
# Epoch 130/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0995 - val_loss: 0.1698
#
# Epoch 00130: val_loss did not improve from 0.16371
# Epoch 131/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1051 - val_loss: 0.1675
#
# Epoch 00131: val_loss did not improve from 0.16371
# Epoch 132/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.1038 - val_loss: 0.1683
#
# Epoch 00132: val_loss did not improve from 0.16371
# Epoch 133/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0980 - val_loss: 0.1644
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 0.0006141250254586339.
#
# Epoch 00133: val_loss did not improve from 0.16371
# Epoch 134/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0912 - val_loss: 0.1639
#
# Epoch 00134: val_loss did not improve from 0.16371
# Epoch 135/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0885 - val_loss: 0.1636
#
# Epoch 00135: val_loss improved from 0.16371 to 0.16356, saving model to ./Bidirect_LSTM_model_2021_7C.h5
# Epoch 136/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0871 - val_loss: 0.1638
#
# Epoch 00136: val_loss did not improve from 0.16356
# Epoch 137/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0885 - val_loss: 0.1663
#
# Epoch 00137: val_loss did not improve from 0.16356
# Epoch 138/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0872 - val_loss: 0.1635
#
# Epoch 00138: val_loss improved from 0.16356 to 0.16352, saving model to ./Bidirect_LSTM_model_2021_7C.h5
# Epoch 139/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0877 - val_loss: 0.1672
#
# Epoch 00139: val_loss did not improve from 0.16352
# Epoch 140/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0936 - val_loss: 0.1683
#
# Epoch 00140: val_loss did not improve from 0.16352
# Epoch 141/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0892 - val_loss: 0.1646
#
# Epoch 00141: val_loss did not improve from 0.16352
# Epoch 142/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0854 - val_loss: 0.1678
#
# Epoch 00142: val_loss did not improve from 0.16352
# Epoch 143/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0856 - val_loss: 0.1634
#
# Epoch 00143: val_loss improved from 0.16352 to 0.16342, saving model to ./Bidirect_LSTM_model_2021_7C.h5
# Epoch 144/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0830 - val_loss: 0.1638
#
# Epoch 00144: val_loss did not improve from 0.16342
# Epoch 145/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0826 - val_loss: 0.1653
#
# Epoch 00145: val_loss did not improve from 0.16342
# Epoch 146/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0864 - val_loss: 0.1691
#
# Epoch 00146: val_loss did not improve from 0.16342
# Epoch 147/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0829 - val_loss: 0.1642
#
# Epoch 00147: val_loss did not improve from 0.16342
# Epoch 148/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0808 - val_loss: 0.1638
#
# Epoch 00148: val_loss did not improve from 0.16342
# Epoch 149/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0798 - val_loss: 0.1675
#
# Epoch 00149: val_loss did not improve from 0.16342
# Epoch 150/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0813 - val_loss: 0.1657
#
# Epoch 00150: val_loss did not improve from 0.16342
# Epoch 151/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0805 - val_loss: 0.1638
#
# Epoch 00151: val_loss did not improve from 0.16342
# Epoch 152/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0785 - val_loss: 0.1678
#
# Epoch 00152: val_loss did not improve from 0.16342
# Epoch 153/300
# 127/127 [==============================] - 17s 130ms/step - loss: 0.0790 - val_loss: 0.1656
#
# Epoch 00153: ReduceLROnPlateau reducing learning rate to 0.0005220062914304435.
#
# Epoch 00153: val_loss did not improve from 0.16342
# Epoch 154/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0758 - val_loss: 0.1631
#
# Epoch 00154: val_loss improved from 0.16342 to 0.16308, saving model to ./Bidirect_LSTM_model_2021_7C.h5
# Epoch 155/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0724 - val_loss: 0.1624
#
# Epoch 00155: val_loss improved from 0.16308 to 0.16236, saving model to ./Bidirect_LSTM_model_2021_7C.h5
# Epoch 156/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0709 - val_loss: 0.1639
#
# Epoch 00156: val_loss did not improve from 0.16236
# Epoch 157/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0708 - val_loss: 0.1627
#
# Epoch 00157: val_loss did not improve from 0.16236
# Epoch 158/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0700 - val_loss: 0.1629
#
# Epoch 00158: val_loss did not improve from 0.16236
# Epoch 159/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0715 - val_loss: 0.1628
#
# Epoch 00159: val_loss did not improve from 0.16236
# Epoch 160/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0711 - val_loss: 0.1624
#
# Epoch 00160: val_loss did not improve from 0.16236
# Epoch 161/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0697 - val_loss: 0.1628
#
# Epoch 00161: val_loss did not improve from 0.16236
# Epoch 162/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0687 - val_loss: 0.1631
#
# Epoch 00162: val_loss did not improve from 0.16236
# Epoch 163/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0688 - val_loss: 0.1628
#
# Epoch 00163: val_loss did not improve from 0.16236
# Epoch 164/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0675 - val_loss: 0.1642
#
# Epoch 00164: val_loss did not improve from 0.16236
# Epoch 165/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0680 - val_loss: 0.1631
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 0.00044370535761117935.
#
# Epoch 00165: val_loss did not improve from 0.16236
# Epoch 166/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0650 - val_loss: 0.1636
#
# Epoch 00166: val_loss did not improve from 0.16236
# Epoch 167/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0629 - val_loss: 0.1625
#
# Epoch 00167: val_loss did not improve from 0.16236
# Epoch 168/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0617 - val_loss: 0.1614
#
# Epoch 00168: val_loss improved from 0.16236 to 0.16144, saving model to ./Bidirect_LSTM_model_2021_7C.h5
# Epoch 169/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0623 - val_loss: 0.1628
#
# Epoch 00169: val_loss did not improve from 0.16144
# Epoch 170/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0627 - val_loss: 0.1634
#
# Epoch 00170: val_loss did not improve from 0.16144
# Epoch 171/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0613 - val_loss: 0.1623
#
# Epoch 00171: val_loss did not improve from 0.16144
# Epoch 172/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0606 - val_loss: 0.1636
#
# Epoch 00172: val_loss did not improve from 0.16144
# Epoch 173/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0601 - val_loss: 0.1626
#
# Epoch 00173: val_loss did not improve from 0.16144
# Epoch 174/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0604 - val_loss: 0.1627
#
# Epoch 00174: val_loss did not improve from 0.16144
# Epoch 175/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0594 - val_loss: 0.1645
#
# Epoch 00175: val_loss did not improve from 0.16144
# Epoch 176/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0604 - val_loss: 0.1625
#
# Epoch 00176: val_loss did not improve from 0.16144
# Epoch 177/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0582 - val_loss: 0.1635
#
# Epoch 00177: val_loss did not improve from 0.16144
# Epoch 178/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0589 - val_loss: 0.1630
#
# Epoch 00178: ReduceLROnPlateau reducing learning rate to 0.00037714955396950245.
#
# Epoch 00178: val_loss did not improve from 0.16144
# Epoch 179/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0564 - val_loss: 0.1621
#
# Epoch 00179: val_loss did not improve from 0.16144
# Epoch 180/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0539 - val_loss: 0.1630
#
# Epoch 00180: val_loss did not improve from 0.16144
# Epoch 181/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0544 - val_loss: 0.1629
#
# Epoch 00181: val_loss did not improve from 0.16144
# Epoch 182/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0535 - val_loss: 0.1620
#
# Epoch 00182: val_loss did not improve from 0.16144
# Epoch 183/300
# 127/127 [==============================] - 16s 125ms/step - loss: 0.0537 - val_loss: 0.1626
#
# Epoch 00183: val_loss did not improve from 0.16144
# Epoch 184/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0527 - val_loss: 0.1626
#
# Epoch 00184: val_loss did not improve from 0.16144
# Epoch 185/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0532 - val_loss: 0.1631
#
# Epoch 00185: val_loss did not improve from 0.16144
# Epoch 186/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0528 - val_loss: 0.1621
#
# Epoch 00186: val_loss did not improve from 0.16144
# Epoch 187/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0527 - val_loss: 0.1636
#
# Epoch 00187: val_loss did not improve from 0.16144
# Epoch 188/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0527 - val_loss: 0.1622
#
# Epoch 00188: ReduceLROnPlateau reducing learning rate to 0.0003205771208740771.
#
# Epoch 00188: val_loss did not improve from 0.16144
# Epoch 189/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0500 - val_loss: 0.1617
#
# Epoch 00189: val_loss did not improve from 0.16144
# Epoch 190/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0482 - val_loss: 0.1619
#
# Epoch 00190: val_loss did not improve from 0.16144
# Epoch 191/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0484 - val_loss: 0.1620
#
# Epoch 00191: val_loss did not improve from 0.16144
# Epoch 192/300
# 127/127 [==============================] - 16s 126ms/step - loss: 0.0476 - val_loss: 0.1624
#
# Epoch 00192: val_loss did not improve from 0.16144
# Epoch 193/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0480 - val_loss: 0.1625
#
# Epoch 00193: val_loss did not improve from 0.16144
# Epoch 194/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0476 - val_loss: 0.1626
#
# Epoch 00194: val_loss did not improve from 0.16144
# Epoch 195/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0472 - val_loss: 0.1635
#
# Epoch 00195: val_loss did not improve from 0.16144
# Epoch 196/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0475 - val_loss: 0.1622
#
# Epoch 00196: val_loss did not improve from 0.16144
# Epoch 197/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0478 - val_loss: 0.1625
#
# Epoch 00197: val_loss did not improve from 0.16144
# Epoch 198/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0466 - val_loss: 0.1625
#
# Epoch 00198: ReduceLROnPlateau reducing learning rate to 0.0002724905527429655.
#
# Epoch 00198: val_loss did not improve from 0.16144
# Epoch 199/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0451 - val_loss: 0.1623
#
# Epoch 00199: val_loss did not improve from 0.16144
# Epoch 200/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0438 - val_loss: 0.1622
#
# Epoch 00200: val_loss did not improve from 0.16144
# Epoch 201/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0430 - val_loss: 0.1632
#
# Epoch 00201: val_loss did not improve from 0.16144
# Epoch 202/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0429 - val_loss: 0.1629
#
# Epoch 00202: val_loss did not improve from 0.16144
# Epoch 203/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0434 - val_loss: 0.1623
#
# Epoch 00203: val_loss did not improve from 0.16144
# Epoch 204/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0429 - val_loss: 0.1621
#
# Epoch 00204: val_loss did not improve from 0.16144
# Epoch 205/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0428 - val_loss: 0.1625
#
# Epoch 00205: val_loss did not improve from 0.16144
# Epoch 206/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0428 - val_loss: 0.1631
#
# Epoch 00206: val_loss did not improve from 0.16144
# Epoch 207/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0425 - val_loss: 0.1628
#
# Epoch 00207: val_loss did not improve from 0.16144
# Epoch 208/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0428 - val_loss: 0.1632
#
# Epoch 00208: ReduceLROnPlateau reducing learning rate to 0.00023161696735769509.
#
# Epoch 00208: val_loss did not improve from 0.16144
# Epoch 209/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0410 - val_loss: 0.1622
#
# Epoch 00209: val_loss did not improve from 0.16144
# Epoch 210/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0392 - val_loss: 0.1623
#
# Epoch 00210: val_loss did not improve from 0.16144
# Epoch 211/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0391 - val_loss: 0.1624
#
# Epoch 00211: val_loss did not improve from 0.16144
# Epoch 212/300
# 127/127 [==============================] - 17s 130ms/step - loss: 0.0392 - val_loss: 0.1625
#
# Epoch 00212: val_loss did not improve from 0.16144
# Epoch 213/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0389 - val_loss: 0.1627
#
# Epoch 00213: val_loss did not improve from 0.16144
# Epoch 214/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0392 - val_loss: 0.1624
#
# Epoch 00214: val_loss did not improve from 0.16144
# Epoch 215/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0390 - val_loss: 0.1626
#
# Epoch 00215: val_loss did not improve from 0.16144
# Epoch 216/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0390 - val_loss: 0.1627
#
# Epoch 00216: val_loss did not improve from 0.16144
# Epoch 217/300
# 127/127 [==============================] - 16s 124ms/step - loss: 0.0386 - val_loss: 0.1628
#
# Epoch 00217: val_loss did not improve from 0.16144
# Epoch 218/300
# 127/127 [==============================] - 16s 123ms/step - loss: 0.0385 - val_loss: 0.1633
#
# Epoch 00218: ReduceLROnPlateau reducing learning rate to 0.00019687442472786642.
#
# Epoch 00218: val_loss did not improve from 0.16144
# Restoring model weights from the end of the best epoch.
# Epoch 00218: early stopping
# Fold-7 | OOF Score: 0.16143533777398575

# %% [markdown]
# ## Create submission file

# %%
submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
submission["pressure"] = sum(test_preds)/5
submission.to_csv('mean_submission.csv', index=False)

# %%
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission["pressure"] = np.round((submission.pressure - P_MIN)/P_STEP) * P_STEP + P_MIN
submission["pressure"] = np.clip(submission.pressure, P_MIN, P_MAX)
submission.to_csv('median_submission.csv', index=False)
