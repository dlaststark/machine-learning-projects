# %% [markdown]
# ## Import libraries

# %%
import gc
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import log_loss
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ## Prepare data for model training

# %%
with open("../input/tps-may-data-preprocess/TPS_May_Dataset_w_Quantile.txt", 'rb') as handle: 
    data = handle.read()

processed_data = pickle.loads(data)
train_df = processed_data['train_df']
test_df = processed_data['test_df']

del processed_data
gc.collect()
# Out:
# 0

# %%
cat_cols = ['feature_0','feature_2','feature_5','feature_9','feature_10','feature_11',
            'feature_12','feature_13','feature_17','feature_18','feature_22',
            'feature_29','feature_36','feature_37','feature_44']

train_df[cat_cols] = train_df[cat_cols].astype(int)
test_df[cat_cols] = test_df[cat_cols].astype(int)
cat_cols_indices = [train_df.columns.get_loc(col) for col in cat_cols]
print(cat_cols_indices)
# Out:
# [0, 2, 5, 9, 10, 11, 12, 13, 17, 18, 22, 29, 36, 37, 44]

# %%
Xtrain = train_df.loc[:, train_df.columns != 'target'].copy()
Ytrain = train_df['target'].copy()
Ytrain_oh = pd.get_dummies(train_df['target']).copy()
Xtest = test_df.copy()

print("Xtrain: {} \nYtrain: {} \nYtrain_oh: {} \nXtest: {}".format(Xtrain.shape, Ytrain.shape, 
                                                                   Ytrain_oh.shape, Xtest.shape))

del train_df
del test_df
gc.collect()
# Out:
# Xtrain: (99918, 951)
# Ytrain: (99918,)
# Ytrain_oh: (99918, 4)
# Xtest: (50000, 951)
# 20

# %% [markdown]
# ## Build and validate the model

# %%
FOLD = 10
NUM_SEED = 3

# Prediction Clipping Thresholds
p_min = 0.025
p_max = 1 - p_min

np.random.seed(3)
seeds = np.random.randint(0, 100, size=NUM_SEED)

oof_score = 0
y_pred_meta_cb = np.zeros((Ytrain.shape[0], 4))
y_pred_final_cb = np.zeros((Xtest.shape[0], 4))
counter = 0


for sidx, seed in enumerate(seeds):
    seed_score = 0
    
    kfold = StratifiedKFold(n_splits=FOLD, shuffle=True, random_state=seed)

    for idx, (train, val) in enumerate(kfold.split(Xtrain.values, Ytrain.values)):
        counter += 1

        train_x, train_y, train_y_oh = Xtrain.iloc[train], Ytrain.iloc[train], Ytrain_oh.iloc[train]
        val_x, val_y, val_y_oh = Xtrain.iloc[val], Ytrain.iloc[val], Ytrain_oh.iloc[val]

        model = CatBoostClassifier(
            objective='MultiClass',
            eval_metric='MultiClass',
            num_boost_round=5000,
            max_ctr_complexity=15,
            od_wait=1000, 
            od_type='Iter',
            use_best_model=True,
            bootstrap_type='Poisson',
            learning_rate=0.01465,
            reg_lambda=0.01864,
            subsample=0.68135,
            max_depth=7, 
            min_data_in_leaf=1,
            task_type='GPU',
            verbose=0
        )

        model.fit(train_x, train_y, eval_set=[(val_x, val_y)], 
                  cat_features=cat_cols_indices,
                  early_stopping_rounds=200, verbose=200)

        y_pred = model.predict_proba(val_x)
        y_pred = np.clip(y_pred, p_min, p_max)
        y_pred_meta_cb[val] += y_pred
        y_pred_final_cb += model.predict_proba(Xtest)
        
        score = log_loss(val_y_oh, y_pred)
        oof_score += score
        seed_score += score
        print("Seed-{} | Fold-{} | OOF Score: {}".format(seed, idx, score))
    
    print("\nSeed: {} | Aggregate OOF Score: {}\n\n".format(seed, (seed_score / FOLD)))


y_pred_meta_cb = y_pred_meta_cb / float(NUM_SEED)
y_pred_final_cb = y_pred_final_cb / float(counter)
oof_score /= float(counter)
print("Aggregate OOF Score: {}".format(oof_score))
# Out:
# 0:	learn: 1.3775604	test: 1.3775908	best: 1.3775908 (0)	total: 26.6ms	remaining: 2m 13s
# 200:	learn: 1.0961572	test: 1.1044545	best: 1.1044545 (200)	total: 4.35s	remaining: 1m 43s
# 400:	learn: 1.0810302	test: 1.0977857	best: 1.0977857 (400)	total: 8.5s	remaining: 1m 37s
# 600:	learn: 1.0706818	test: 1.0951148	best: 1.0951062 (599)	total: 12.5s	remaining: 1m 31s
# 800:	learn: 1.0619227	test: 1.0937810	best: 1.0937810 (800)	total: 16.3s	remaining: 1m 25s
# 1000:	learn: 1.0535459	test: 1.0928160	best: 1.0928086 (993)	total: 20.4s	remaining: 1m 21s
# 1200:	learn: 1.0459816	test: 1.0922123	best: 1.0922123 (1200)	total: 24.3s	remaining: 1m 16s
# 1400:	learn: 1.0388891	test: 1.0919790	best: 1.0919015 (1332)	total: 28.2s	remaining: 1m 12s
# 1600:	learn: 1.0320414	test: 1.0918029	best: 1.0917856 (1594)	total: 32.3s	remaining: 1m 8s
# 1800:	learn: 1.0254236	test: 1.0915740	best: 1.0915352 (1772)	total: 36.1s	remaining: 1m 4s
# bestTest = 1.09153524
# bestIteration = 1772
# Shrink model to first 1773 iterations.
# Seed-24 | Fold-0 | OOF Score: 1.0915352231264621
# 0:	learn: 1.3775583	test: 1.3775772	best: 1.3775772 (0)	total: 22ms	remaining: 1m 50s
# 200:	learn: 1.0964163	test: 1.1036560	best: 1.1036560 (200)	total: 4.24s	remaining: 1m 41s
# 400:	learn: 1.0814223	test: 1.0967757	best: 1.0967757 (400)	total: 8.73s	remaining: 1m 40s
# 600:	learn: 1.0709957	test: 1.0938766	best: 1.0938766 (600)	total: 12.7s	remaining: 1m 32s
# 800:	learn: 1.0621787	test: 1.0919602	best: 1.0919602 (800)	total: 16.6s	remaining: 1m 27s
# 1000:	learn: 1.0540701	test: 1.0909826	best: 1.0909693 (995)	total: 20.8s	remaining: 1m 23s
# 1200:	learn: 1.0462196	test: 1.0902995	best: 1.0902995 (1200)	total: 24.7s	remaining: 1m 18s
# 1400:	learn: 1.0390040	test: 1.0897803	best: 1.0897803 (1400)	total: 29.1s	remaining: 1m 14s
# 1600:	learn: 1.0322352	test: 1.0894857	best: 1.0894672 (1558)	total: 33.3s	remaining: 1m 10s
# 1800:	learn: 1.0256643	test: 1.0893590	best: 1.0893549 (1785)	total: 37.1s	remaining: 1m 5s
# 2000:	learn: 1.0191122	test: 1.0892507	best: 1.0891946 (1949)	total: 41.2s	remaining: 1m 1s
# bestTest = 1.089194598
# bestIteration = 1949
# Shrink model to first 1950 iterations.
# Seed-24 | Fold-1 | OOF Score: 1.0891946265662658
# 0:	learn: 1.3775704	test: 1.3775315	best: 1.3775315 (0)	total: 21.8ms	remaining: 1m 48s
# 200:	learn: 1.0958779	test: 1.1056542	best: 1.1056542 (200)	total: 4.62s	remaining: 1m 50s
# 400:	learn: 1.0806895	test: 1.1003135	best: 1.1003135 (400)	total: 8.68s	remaining: 1m 39s
# 600:	learn: 1.0705240	test: 1.0982055	best: 1.0981966 (598)	total: 13.3s	remaining: 1m 37s
# 800:	learn: 1.0618798	test: 1.0971540	best: 1.0971540 (800)	total: 17.7s	remaining: 1m 33s
# 1000:	learn: 1.0537164	test: 1.0965619	best: 1.0965619 (1000)	total: 21.6s	remaining: 1m 26s
# 1200:	learn: 1.0463088	test: 1.0960227	best: 1.0960227 (1200)	total: 25.8s	remaining: 1m 21s
# 1400:	learn: 1.0392754	test: 1.0958725	best: 1.0958552 (1388)	total: 29.7s	remaining: 1m 16s
# 1600:	learn: 1.0324798	test: 1.0960713	best: 1.0958518 (1403)	total: 33.6s	remaining: 1m 11s
# bestTest = 1.095851779
# bestIteration = 1403
# Shrink model to first 1404 iterations.
# Seed-24 | Fold-2 | OOF Score: 1.0958518444562115
# 0:	learn: 1.3775571	test: 1.3775834	best: 1.3775834 (0)	total: 21.3ms	remaining: 1m 46s
# 200:	learn: 1.0963746	test: 1.1036193	best: 1.1036193 (200)	total: 4.31s	remaining: 1m 42s
# 400:	learn: 1.0812628	test: 1.0971004	best: 1.0971004 (400)	total: 8.86s	remaining: 1m 41s
# 600:	learn: 1.0710756	test: 1.0946036	best: 1.0946036 (600)	total: 12.8s	remaining: 1m 33s
# 800:	learn: 1.0622850	test: 1.0928295	best: 1.0928295 (800)	total: 17.5s	remaining: 1m 31s
# 1000:	learn: 1.0540993	test: 1.0917643	best: 1.0917643 (1000)	total: 21.8s	remaining: 1m 26s
# 1200:	learn: 1.0461548	test: 1.0910343	best: 1.0910224 (1191)	total: 25.8s	remaining: 1m 21s
# 1400:	learn: 1.0391244	test: 1.0904095	best: 1.0904006 (1398)	total: 29.8s	remaining: 1m 16s
# 1600:	learn: 1.0322532	test: 1.0901488	best: 1.0901418 (1596)	total: 33.8s	remaining: 1m 11s
# 1800:	learn: 1.0255729	test: 1.0899548	best: 1.0899537 (1798)	total: 37.7s	remaining: 1m 6s
# 2000:	learn: 1.0192164	test: 1.0897820	best: 1.0897729 (1997)	total: 42s	remaining: 1m 2s
# 2200:	learn: 1.0129652	test: 1.0899029	best: 1.0897591 (2048)	total: 45.8s	remaining: 58.3s
# bestTest = 1.089759112
# bestIteration = 2048
# Shrink model to first 2049 iterations.
# Seed-24 | Fold-3 | OOF Score: 1.0897607468755544
# 0:	learn: 1.3775673	test: 1.3775961	best: 1.3775961 (0)	total: 22.1ms	remaining: 1m 50s
# 200:	learn: 1.0960055	test: 1.1047773	best: 1.1047773 (200)	total: 4.18s	remaining: 1m 39s
# 400:	learn: 1.0806455	test: 1.0986096	best: 1.0986096 (400)	total: 8.23s	remaining: 1m 34s
# 600:	learn: 1.0702437	test: 1.0962301	best: 1.0962279 (597)	total: 12.5s	remaining: 1m 31s
# 800:	learn: 1.0614509	test: 1.0946891	best: 1.0946889 (796)	total: 16.4s	remaining: 1m 25s
# 1000:	learn: 1.0530990	test: 1.0935773	best: 1.0935770 (999)	total: 20.2s	remaining: 1m 20s
# 1200:	learn: 1.0453826	test: 1.0931969	best: 1.0931969 (1200)	total: 24.5s	remaining: 1m 17s
# 1400:	learn: 1.0383249	test: 1.0928796	best: 1.0928796 (1400)	total: 28.3s	remaining: 1m 12s
# 1600:	learn: 1.0314791	test: 1.0926842	best: 1.0926790 (1538)	total: 33.5s	remaining: 1m 11s
# 1800:	learn: 1.0251672	test: 1.0924974	best: 1.0924702 (1781)	total: 37.4s	remaining: 1m 6s
# 2000:	learn: 1.0187072	test: 1.0924989	best: 1.0924571 (1910)	total: 41.2s	remaining: 1m 1s
# 2200:	learn: 1.0125869	test: 1.0925812	best: 1.0924425 (2074)	total: 45.5s	remaining: 57.8s
# bestTest = 1.092442509
# bestIteration = 2074
# Shrink model to first 2075 iterations.
# Seed-24 | Fold-4 | OOF Score: 1.092442561368222
# 0:	learn: 1.3775593	test: 1.3775802	best: 1.3775802 (0)	total: 22.2ms	remaining: 1m 50s
# 200:	learn: 1.0959612	test: 1.1052516	best: 1.1052516 (200)	total: 4.65s	remaining: 1m 51s
# 400:	learn: 1.0811235	test: 1.0991686	best: 1.0991686 (400)	total: 8.73s	remaining: 1m 40s
# 600:	learn: 1.0705465	test: 1.0965122	best: 1.0965122 (600)	total: 13.4s	remaining: 1m 38s
# 800:	learn: 1.0616794	test: 1.0952599	best: 1.0952540 (799)	total: 17.7s	remaining: 1m 32s
# 1000:	learn: 1.0531849	test: 1.0944801	best: 1.0944801 (1000)	total: 21.5s	remaining: 1m 25s
# 1200:	learn: 1.0454940	test: 1.0940557	best: 1.0940445 (1197)	total: 25.8s	remaining: 1m 21s
# 1400:	learn: 1.0385555	test: 1.0938422	best: 1.0938277 (1367)	total: 29.8s	remaining: 1m 16s
# 1600:	learn: 1.0317105	test: 1.0937197	best: 1.0937169 (1551)	total: 33.7s	remaining: 1m 11s
# 1800:	learn: 1.0250544	test: 1.0937201	best: 1.0936766 (1662)	total: 37.9s	remaining: 1m 7s
# 2000:	learn: 1.0184131	test: 1.0937121	best: 1.0936522 (1910)	total: 41.7s	remaining: 1m 2s
# bestTest = 1.093652168
# bestIteration = 1910
# Shrink model to first 1911 iterations.
# Seed-24 | Fold-5 | OOF Score: 1.0936524167956965
# 0:	learn: 1.3775491	test: 1.3775305	best: 1.3775305 (0)	total: 23ms	remaining: 1m 55s
# 200:	learn: 1.0961773	test: 1.1047631	best: 1.1047631 (200)	total: 4.24s	remaining: 1m 41s
# 400:	learn: 1.0810933	test: 1.0984627	best: 1.0984627 (400)	total: 8.62s	remaining: 1m 38s
# 600:	learn: 1.0708829	test: 1.0958672	best: 1.0958672 (600)	total: 12.7s	remaining: 1m 32s
# 800:	learn: 1.0618687	test: 1.0941091	best: 1.0941091 (800)	total: 16.6s	remaining: 1m 26s
# 1000:	learn: 1.0536538	test: 1.0927518	best: 1.0927518 (1000)	total: 20.8s	remaining: 1m 23s
# 1200:	learn: 1.0458237	test: 1.0920560	best: 1.0920560 (1200)	total: 24.7s	remaining: 1m 18s
# 1400:	learn: 1.0385718	test: 1.0914819	best: 1.0914819 (1400)	total: 28.5s	remaining: 1m 13s
# 1600:	learn: 1.0313826	test: 1.0909767	best: 1.0909678 (1599)	total: 33.3s	remaining: 1m 10s
# 1800:	learn: 1.0247873	test: 1.0907149	best: 1.0906973 (1790)	total: 37s	remaining: 1m 5s
# 2000:	learn: 1.0184371	test: 1.0905289	best: 1.0905157 (1989)	total: 41s	remaining: 1m 1s
# 2200:	learn: 1.0123331	test: 1.0905601	best: 1.0904676 (2153)	total: 45.2s	remaining: 57.5s
# bestTest = 1.090467589
# bestIteration = 2153
# Shrink model to first 2154 iterations.
# Seed-24 | Fold-6 | OOF Score: 1.0904617308055966
# 0:	learn: 1.3775577	test: 1.3775603	best: 1.3775603 (0)	total: 22.6ms	remaining: 1m 52s
# 200:	learn: 1.0956119	test: 1.1060871	best: 1.1060871 (200)	total: 4.25s	remaining: 1m 41s
# 400:	learn: 1.0804561	test: 1.1002365	best: 1.1002365 (400)	total: 8.37s	remaining: 1m 36s
# 600:	learn: 1.0700804	test: 1.0979908	best: 1.0979908 (600)	total: 13.3s	remaining: 1m 37s
# 800:	learn: 1.0612458	test: 1.0965556	best: 1.0965556 (800)	total: 17.2s	remaining: 1m 30s
# 1000:	learn: 1.0532389	test: 1.0956087	best: 1.0956087 (1000)	total: 21.4s	remaining: 1m 25s
# 1200:	learn: 1.0457373	test: 1.0949581	best: 1.0949495 (1193)	total: 25.3s	remaining: 1m 19s
# 1400:	learn: 1.0383035	test: 1.0947751	best: 1.0947456 (1333)	total: 29.2s	remaining: 1m 14s
# 1600:	learn: 1.0313727	test: 1.0944050	best: 1.0944017 (1599)	total: 33.4s	remaining: 1m 10s
# 1800:	learn: 1.0249155	test: 1.0942092	best: 1.0941644 (1769)	total: 37.2s	remaining: 1m 6s
# 2000:	learn: 1.0185108	test: 1.0940142	best: 1.0939939 (1965)	total: 41.1s	remaining: 1m 1s
# 2200:	learn: 1.0121310	test: 1.0938644	best: 1.0938264 (2155)	total: 45.3s	remaining: 57.6s
# bestTest = 1.093826428
# bestIteration = 2155
# Shrink model to first 2156 iterations.
# Seed-24 | Fold-7 | OOF Score: 1.0938274427744967
# 0:	learn: 1.3775669	test: 1.3775403	best: 1.3775403 (0)	total: 21.6ms	remaining: 1m 48s
# 200:	learn: 1.0961405	test: 1.1047060	best: 1.1047060 (200)	total: 4.17s	remaining: 1m 39s
# 400:	learn: 1.0810990	test: 1.0985249	best: 1.0985249 (400)	total: 8.24s	remaining: 1m 34s
# 600:	learn: 1.0711483	test: 1.0956259	best: 1.0956259 (600)	total: 12.5s	remaining: 1m 31s
# 800:	learn: 1.0626440	test: 1.0938888	best: 1.0938888 (800)	total: 16.4s	remaining: 1m 25s
# 1000:	learn: 1.0540444	test: 1.0924115	best: 1.0924003 (998)	total: 20.2s	remaining: 1m 20s
# 1200:	learn: 1.0464290	test: 1.0914435	best: 1.0914426 (1196)	total: 24.4s	remaining: 1m 17s
# 1400:	learn: 1.0391180	test: 1.0909288	best: 1.0909131 (1383)	total: 28.9s	remaining: 1m 14s
# 1600:	learn: 1.0322790	test: 1.0905225	best: 1.0905225 (1600)	total: 33.2s	remaining: 1m 10s
# 1800:	learn: 1.0256931	test: 1.0902678	best: 1.0902678 (1800)	total: 37.1s	remaining: 1m 5s
# 2000:	learn: 1.0195198	test: 1.0900513	best: 1.0900294 (1989)	total: 40.9s	remaining: 1m 1s
# 2200:	learn: 1.0130176	test: 1.0899053	best: 1.0898702 (2158)	total: 45.1s	remaining: 57.3s
# 2400:	learn: 1.0071343	test: 1.0898221	best: 1.0897900 (2331)	total: 48.8s	remaining: 52.9s
# 2600:	learn: 1.0011348	test: 1.0898369	best: 1.0897734 (2489)	total: 52.6s	remaining: 48.5s
# bestTest = 1.089773374
# bestIteration = 2489
# Shrink model to first 2490 iterations.
# Seed-24 | Fold-8 | OOF Score: 1.0897734789367983
# 0:	learn: 1.3775489	test: 1.3776059	best: 1.3776059 (0)	total: 23.3ms	remaining: 1m 56s
# 200:	learn: 1.0959589	test: 1.1052502	best: 1.1052502 (200)	total: 4.2s	remaining: 1m 40s
# 400:	learn: 1.0806044	test: 1.0991270	best: 1.0991270 (400)	total: 8.78s	remaining: 1m 40s
# 600:	learn: 1.0703102	test: 1.0969228	best: 1.0969228 (600)	total: 12.8s	remaining: 1m 33s
# 800:	learn: 1.0615808	test: 1.0955444	best: 1.0955444 (800)	total: 16.9s	remaining: 1m 28s
# 1000:	learn: 1.0532048	test: 1.0946664	best: 1.0946633 (999)	total: 20.7s	remaining: 1m 22s
# 1200:	learn: 1.0455551	test: 1.0942782	best: 1.0942568 (1196)	total: 24.5s	remaining: 1m 17s
# 1400:	learn: 1.0386144	test: 1.0939619	best: 1.0939334 (1376)	total: 28.6s	remaining: 1m 13s
# 1600:	learn: 1.0316589	test: 1.0938741	best: 1.0938413 (1553)	total: 33s	remaining: 1m 10s
# 1800:	learn: 1.0251769	test: 1.0938226	best: 1.0938226 (1800)	total: 37s	remaining: 1m 5s
# 2000:	learn: 1.0187221	test: 1.0937900	best: 1.0937120 (1870)	total: 41.1s	remaining: 1m 1s
# bestTest = 1.093711977
# bestIteration = 1870
# Shrink model to first 1871 iterations.
# Seed-24 | Fold-9 | OOF Score: 1.0937126189446338
#
# Seed: 24 | Aggregate OOF Score: 1.0920212690649937
#
#
# 0:	learn: 1.3775616	test: 1.3775475	best: 1.3775475 (0)	total: 23.3ms	remaining: 1m 56s
# 200:	learn: 1.0962939	test: 1.1036818	best: 1.1036818 (200)	total: 4.54s	remaining: 1m 48s
# 400:	learn: 1.0812413	test: 1.0972982	best: 1.0972982 (400)	total: 8.57s	remaining: 1m 38s
# 600:	learn: 1.0711949	test: 1.0945079	best: 1.0945079 (600)	total: 12.4s	remaining: 1m 30s
# 800:	learn: 1.0626701	test: 1.0928708	best: 1.0928708 (800)	total: 17.1s	remaining: 1m 29s
# 1000:	learn: 1.0546105	test: 1.0917483	best: 1.0917483 (1000)	total: 20.9s	remaining: 1m 23s
# 1200:	learn: 1.0469069	test: 1.0911318	best: 1.0911097 (1187)	total: 25.1s	remaining: 1m 19s
# 1400:	learn: 1.0398294	test: 1.0906591	best: 1.0906591 (1400)	total: 28.9s	remaining: 1m 14s
# 1600:	learn: 1.0331404	test: 1.0905187	best: 1.0905187 (1600)	total: 32.8s	remaining: 1m 9s
# 1800:	learn: 1.0268684	test: 1.0903714	best: 1.0903672 (1798)	total: 37s	remaining: 1m 5s
# 2000:	learn: 1.0206668	test: 1.0903635	best: 1.0903472 (1846)	total: 40.8s	remaining: 1m 1s
# 2200:	learn: 1.0142658	test: 1.0901846	best: 1.0901846 (2200)	total: 44.6s	remaining: 56.8s
# 2400:	learn: 1.0082265	test: 1.0903205	best: 1.0901681 (2226)	total: 49.5s	remaining: 53.6s
# bestTest = 1.090168131
# bestIteration = 2226
# Shrink model to first 2227 iterations.
# Seed-3 | Fold-0 | OOF Score: 1.090168933651377
# 0:	learn: 1.3775552	test: 1.3775647	best: 1.3775647 (0)	total: 22.3ms	remaining: 1m 51s
# 200:	learn: 1.0959919	test: 1.1047999	best: 1.1047999 (200)	total: 4.57s	remaining: 1m 49s
# 400:	learn: 1.0813379	test: 1.0982952	best: 1.0982952 (400)	total: 8.65s	remaining: 1m 39s
# 600:	learn: 1.0711534	test: 1.0953750	best: 1.0953750 (600)	total: 12.8s	remaining: 1m 33s
# 800:	learn: 1.0624309	test: 1.0936416	best: 1.0936416 (800)	total: 16.9s	remaining: 1m 28s
# 1000:	learn: 1.0541319	test: 1.0926807	best: 1.0926807 (1000)	total: 20.9s	remaining: 1m 23s
# 1200:	learn: 1.0467003	test: 1.0918615	best: 1.0918615 (1200)	total: 24.9s	remaining: 1m 18s
# 1400:	learn: 1.0395077	test: 1.0914974	best: 1.0914974 (1400)	total: 29.4s	remaining: 1m 15s
# 1600:	learn: 1.0327943	test: 1.0911846	best: 1.0911846 (1600)	total: 33.2s	remaining: 1m 10s
# 1800:	learn: 1.0259980	test: 1.0910081	best: 1.0909832 (1772)	total: 37.5s	remaining: 1m 6s
# 2000:	learn: 1.0194891	test: 1.0909560	best: 1.0909175 (1963)	total: 41.3s	remaining: 1m 1s
# 2200:	learn: 1.0133346	test: 1.0908008	best: 1.0907981 (2195)	total: 45.1s	remaining: 57.4s
# 2400:	learn: 1.0070581	test: 1.0906374	best: 1.0906066 (2319)	total: 49.2s	remaining: 53.3s
# bestTest = 1.090606567
# bestIteration = 2319
# Shrink model to first 2320 iterations.
# Seed-3 | Fold-1 | OOF Score: 1.0905980209788517
# 0:	learn: 1.3775596	test: 1.3775830	best: 1.3775830 (0)	total: 22.2ms	remaining: 1m 50s
# 200:	learn: 1.0957830	test: 1.1060017	best: 1.1060017 (200)	total: 5.33s	remaining: 2m 7s
# 400:	learn: 1.0807449	test: 1.1002470	best: 1.1002470 (400)	total: 9.38s	remaining: 1m 47s
# 600:	learn: 1.0705115	test: 1.0977676	best: 1.0977676 (600)	total: 13.7s	remaining: 1m 40s
# 800:	learn: 1.0616009	test: 1.0962622	best: 1.0962622 (800)	total: 17.6s	remaining: 1m 32s
# 1000:	learn: 1.0533856	test: 1.0954335	best: 1.0954335 (1000)	total: 21.3s	remaining: 1m 25s
# 1200:	learn: 1.0460437	test: 1.0948397	best: 1.0948347 (1186)	total: 25.5s	remaining: 1m 20s
# 1400:	learn: 1.0388688	test: 1.0944341	best: 1.0944294 (1397)	total: 29.4s	remaining: 1m 15s
# 1600:	learn: 1.0320809	test: 1.0941327	best: 1.0941132 (1596)	total: 33.3s	remaining: 1m 10s
# 1800:	learn: 1.0255221	test: 1.0940504	best: 1.0940388 (1700)	total: 37.4s	remaining: 1m 6s
# bestTest = 1.094038805
# bestIteration = 1700
# Shrink model to first 1701 iterations.
# Seed-3 | Fold-2 | OOF Score: 1.094038905500574
# 0:	learn: 1.3775500	test: 1.3775852	best: 1.3775852 (0)	total: 21.8ms	remaining: 1m 48s
# 200:	learn: 1.0957331	test: 1.1055847	best: 1.1055847 (200)	total: 4.14s	remaining: 1m 38s
# 400:	learn: 1.0809258	test: 1.0996876	best: 1.0996811 (399)	total: 8.13s	remaining: 1m 33s
# 600:	learn: 1.0703612	test: 1.0972623	best: 1.0972623 (600)	total: 12.4s	remaining: 1m 30s
# 800:	learn: 1.0616906	test: 1.0958431	best: 1.0958390 (799)	total: 16.2s	remaining: 1m 24s
# 1000:	learn: 1.0533744	test: 1.0948170	best: 1.0948170 (1000)	total: 20s	remaining: 1m 20s
# 1200:	learn: 1.0454626	test: 1.0941451	best: 1.0941385 (1196)	total: 24.3s	remaining: 1m 16s
# 1400:	learn: 1.0385849	test: 1.0939197	best: 1.0939072 (1350)	total: 28.7s	remaining: 1m 13s
# 1600:	learn: 1.0314295	test: 1.0936139	best: 1.0936139 (1600)	total: 32.9s	remaining: 1m 9s
# 1800:	learn: 1.0248787	test: 1.0935403	best: 1.0934062 (1721)	total: 36.7s	remaining: 1m 5s
# 2000:	learn: 1.0186080	test: 1.0933563	best: 1.0932865 (1959)	total: 40.5s	remaining: 1m
# bestTest = 1.093286543
# bestIteration = 1959
# Shrink model to first 1960 iterations.
# Seed-3 | Fold-3 | OOF Score: 1.093286568318564
# 0:	learn: 1.3775605	test: 1.3775730	best: 1.3775730 (0)	total: 22.1ms	remaining: 1m 50s
# 200:	learn: 1.0961605	test: 1.1033870	best: 1.1033870 (200)	total: 4.23s	remaining: 1m 41s
# 400:	learn: 1.0809905	test: 1.0973643	best: 1.0973643 (400)	total: 8.68s	remaining: 1m 39s
# 600:	learn: 1.0706645	test: 1.0950692	best: 1.0950692 (600)	total: 13.6s	remaining: 1m 39s
# 800:	learn: 1.0618634	test: 1.0937616	best: 1.0937602 (799)	total: 17.9s	remaining: 1m 33s
# 1000:	learn: 1.0535636	test: 1.0929208	best: 1.0929208 (1000)	total: 21.7s	remaining: 1m 26s
# 1200:	learn: 1.0460743	test: 1.0926090	best: 1.0925920 (1155)	total: 25.4s	remaining: 1m 20s
# 1400:	learn: 1.0386580	test: 1.0923921	best: 1.0923845 (1393)	total: 29.5s	remaining: 1m 15s
# 1600:	learn: 1.0317462	test: 1.0921554	best: 1.0921554 (1600)	total: 33.3s	remaining: 1m 10s
# 1800:	learn: 1.0253941	test: 1.0922196	best: 1.0921554 (1600)	total: 37.1s	remaining: 1m 5s
# bestTest = 1.092155365
# bestIteration = 1600
# Shrink model to first 1601 iterations.
# Seed-3 | Fold-4 | OOF Score: 1.092155362240893
# 0:	learn: 1.3775565	test: 1.3775803	best: 1.3775803 (0)	total: 20.3ms	remaining: 1m 41s
# 200:	learn: 1.0960466	test: 1.1053666	best: 1.1053666 (200)	total: 5.02s	remaining: 1m 59s
# 400:	learn: 1.0810539	test: 1.0993051	best: 1.0993051 (400)	total: 9.56s	remaining: 1m 49s
# 600:	learn: 1.0707080	test: 1.0970437	best: 1.0970437 (600)	total: 13.4s	remaining: 1m 38s
# 800:	learn: 1.0621859	test: 1.0958618	best: 1.0958560 (799)	total: 17.3s	remaining: 1m 30s
# 1000:	learn: 1.0537562	test: 1.0951866	best: 1.0951825 (996)	total: 21.6s	remaining: 1m 26s
# 1200:	learn: 1.0462724	test: 1.0946885	best: 1.0946837 (1191)	total: 25.5s	remaining: 1m 20s
# 1400:	learn: 1.0392207	test: 1.0945499	best: 1.0944660 (1354)	total: 29.8s	remaining: 1m 16s
# 1600:	learn: 1.0322869	test: 1.0944159	best: 1.0944007 (1597)	total: 34.3s	remaining: 1m 12s
# 1800:	learn: 1.0257241	test: 1.0944191	best: 1.0943699 (1677)	total: 38.1s	remaining: 1m 7s
# 2000:	learn: 1.0192676	test: 1.0944572	best: 1.0943467 (1895)	total: 42.4s	remaining: 1m 3s
# bestTest = 1.094346669
# bestIteration = 1895
# Shrink model to first 1896 iterations.
# Seed-3 | Fold-5 | OOF Score: 1.0943476781599348
# 0:	learn: 1.3775584	test: 1.3775638	best: 1.3775638 (0)	total: 23.1ms	remaining: 1m 55s
# 200:	learn: 1.0959830	test: 1.1039672	best: 1.1039672 (200)	total: 4.53s	remaining: 1m 48s
# 400:	learn: 1.0808421	test: 1.0974112	best: 1.0974112 (400)	total: 8.51s	remaining: 1m 37s
# 600:	learn: 1.0705196	test: 1.0947112	best: 1.0947112 (600)	total: 12.9s	remaining: 1m 34s
# 800:	learn: 1.0617482	test: 1.0932252	best: 1.0932240 (799)	total: 16.7s	remaining: 1m 27s
# 1000:	learn: 1.0534184	test: 1.0922178	best: 1.0922178 (1000)	total: 21.3s	remaining: 1m 24s
# 1200:	learn: 1.0456102	test: 1.0918212	best: 1.0917921 (1194)	total: 25.4s	remaining: 1m 20s
# 1400:	learn: 1.0383107	test: 1.0914067	best: 1.0913842 (1370)	total: 29.3s	remaining: 1m 15s
# 1600:	learn: 1.0313830	test: 1.0912489	best: 1.0912085 (1573)	total: 33.1s	remaining: 1m 10s
# 1800:	learn: 1.0247517	test: 1.0912242	best: 1.0911509 (1661)	total: 37.2s	remaining: 1m 6s
# bestTest = 1.09115085
# bestIteration = 1661
# Shrink model to first 1662 iterations.
# Seed-3 | Fold-6 | OOF Score: 1.0911508199851039
# 0:	learn: 1.3775581	test: 1.3775473	best: 1.3775473 (0)	total: 21.2ms	remaining: 1m 45s
# 200:	learn: 1.0959602	test: 1.1046599	best: 1.1046599 (200)	total: 4.63s	remaining: 1m 50s
# 400:	learn: 1.0807240	test: 1.0983554	best: 1.0983554 (400)	total: 9.67s	remaining: 1m 50s
# 600:	learn: 1.0702630	test: 1.0955644	best: 1.0955644 (600)	total: 14.1s	remaining: 1m 43s
# 800:	learn: 1.0614471	test: 1.0939808	best: 1.0939808 (800)	total: 18s	remaining: 1m 34s
# 1000:	learn: 1.0530782	test: 1.0930532	best: 1.0930532 (1000)	total: 21.9s	remaining: 1m 27s
# 1200:	learn: 1.0454799	test: 1.0925838	best: 1.0925786 (1195)	total: 26.1s	remaining: 1m 22s
# 1400:	learn: 1.0381342	test: 1.0921776	best: 1.0921776 (1400)	total: 29.9s	remaining: 1m 16s
# 1600:	learn: 1.0311828	test: 1.0919508	best: 1.0919406 (1579)	total: 33.8s	remaining: 1m 11s
# 1800:	learn: 1.0245532	test: 1.0919548	best: 1.0919211 (1630)	total: 38.2s	remaining: 1m 7s
# 2000:	learn: 1.0183264	test: 1.0918130	best: 1.0918130 (2000)	total: 42.8s	remaining: 1m 4s
# 2200:	learn: 1.0120066	test: 1.0917339	best: 1.0916909 (2150)	total: 47s	remaining: 59.8s
# bestTest = 1.091690931
# bestIteration = 2150
# Shrink model to first 2151 iterations.
# Seed-3 | Fold-7 | OOF Score: 1.0916909977522251
# 0:	learn: 1.3775589	test: 1.3775725	best: 1.3775725 (0)	total: 22.6ms	remaining: 1m 52s
# 200:	learn: 1.0960615	test: 1.1057012	best: 1.1057012 (200)	total: 4.69s	remaining: 1m 52s
# 400:	learn: 1.0810921	test: 1.0994170	best: 1.0994170 (400)	total: 8.83s	remaining: 1m 41s
# 600:	learn: 1.0706167	test: 1.0968064	best: 1.0968064 (600)	total: 12.9s	remaining: 1m 34s
# 800:	learn: 1.0619371	test: 1.0953331	best: 1.0953331 (800)	total: 17.3s	remaining: 1m 30s
# 1000:	learn: 1.0536520	test: 1.0943534	best: 1.0943512 (999)	total: 21.8s	remaining: 1m 27s
# 1200:	learn: 1.0459716	test: 1.0936367	best: 1.0936156 (1196)	total: 26s	remaining: 1m 22s
# 1400:	learn: 1.0389584	test: 1.0930625	best: 1.0930583 (1398)	total: 29.9s	remaining: 1m 16s
# 1600:	learn: 1.0319198	test: 1.0929176	best: 1.0929035 (1576)	total: 33.9s	remaining: 1m 11s
# 1800:	learn: 1.0254337	test: 1.0926435	best: 1.0926435 (1800)	total: 38.1s	remaining: 1m 7s
# 2000:	learn: 1.0190938	test: 1.0925095	best: 1.0924418 (1967)	total: 41.9s	remaining: 1m 2s
# bestTest = 1.092441791
# bestIteration = 1967
# Shrink model to first 1968 iterations.
# Seed-3 | Fold-8 | OOF Score: 1.0924419396007443
# 0:	learn: 1.3775522	test: 1.3775686	best: 1.3775686 (0)	total: 22ms	remaining: 1m 50s
# 200:	learn: 1.0959302	test: 1.1057589	best: 1.1057589 (200)	total: 4.8s	remaining: 1m 54s
# 400:	learn: 1.0810137	test: 1.0997399	best: 1.0997399 (400)	total: 9.2s	remaining: 1m 45s
# 600:	learn: 1.0706646	test: 1.0972660	best: 1.0972660 (600)	total: 13.1s	remaining: 1m 36s
# 800:	learn: 1.0619219	test: 1.0958862	best: 1.0958862 (800)	total: 17s	remaining: 1m 28s
# 1000:	learn: 1.0534870	test: 1.0949764	best: 1.0949764 (1000)	total: 21.1s	remaining: 1m 24s
# 1200:	learn: 1.0459768	test: 1.0942582	best: 1.0942159 (1187)	total: 24.9s	remaining: 1m 18s
# 1400:	learn: 1.0388684	test: 1.0938775	best: 1.0938730 (1396)	total: 28.9s	remaining: 1m 14s
# 1600:	learn: 1.0319372	test: 1.0937843	best: 1.0937584 (1567)	total: 32.9s	remaining: 1m 9s
# 1800:	learn: 1.0254171	test: 1.0936046	best: 1.0935736 (1769)	total: 36.7s	remaining: 1m 5s
# 2000:	learn: 1.0189497	test: 1.0934116	best: 1.0934012 (1997)	total: 42s	remaining: 1m 2s
# 2200:	learn: 1.0128814	test: 1.0934220	best: 1.0933621 (2084)	total: 45.9s	remaining: 58.4s
# bestTest = 1.093362053
# bestIteration = 2084
# Shrink model to first 2085 iterations.
# Seed-3 | Fold-9 | OOF Score: 1.0933626975352262
#
# Seed: 3 | Aggregate OOF Score: 1.0923241923723495
#
#
# 0:	learn: 1.3775617	test: 1.3775890	best: 1.3775890 (0)	total: 22.6ms	remaining: 1m 52s
# 200:	learn: 1.0959391	test: 1.1035252	best: 1.1035252 (200)	total: 4.34s	remaining: 1m 43s
# 400:	learn: 1.0809113	test: 1.0973920	best: 1.0973920 (400)	total: 8.76s	remaining: 1m 40s
# 600:	learn: 1.0705324	test: 1.0948826	best: 1.0948826 (600)	total: 12.9s	remaining: 1m 34s
# 800:	learn: 1.0616630	test: 1.0933764	best: 1.0933764 (800)	total: 16.9s	remaining: 1m 28s
# 1000:	learn: 1.0530105	test: 1.0924979	best: 1.0924979 (1000)	total: 21.8s	remaining: 1m 26s
# 1200:	learn: 1.0451713	test: 1.0918993	best: 1.0918934 (1199)	total: 25.6s	remaining: 1m 20s
# 1400:	learn: 1.0380754	test: 1.0917694	best: 1.0917601 (1359)	total: 29.4s	remaining: 1m 15s
# 1600:	learn: 1.0311547	test: 1.0915101	best: 1.0915101 (1600)	total: 33.5s	remaining: 1m 11s
# 1800:	learn: 1.0244365	test: 1.0912708	best: 1.0912608 (1771)	total: 37.3s	remaining: 1m 6s
# 2000:	learn: 1.0179709	test: 1.0911025	best: 1.0910922 (1993)	total: 41.3s	remaining: 1m 1s
# 2200:	learn: 1.0116207	test: 1.0912820	best: 1.0910307 (2037)	total: 45.2s	remaining: 57.5s
# bestTest = 1.091030735
# bestIteration = 2037
# Shrink model to first 2038 iterations.
# Seed-56 | Fold-0 | OOF Score: 1.0910310929970959
# 0:	learn: 1.3775559	test: 1.3775580	best: 1.3775580 (0)	total: 42.1ms	remaining: 3m 30s
# 200:	learn: 1.0957929	test: 1.1059937	best: 1.1059937 (200)	total: 5.23s	remaining: 2m 4s
# 400:	learn: 1.0806545	test: 1.0997317	best: 1.0997317 (400)	total: 9.24s	remaining: 1m 45s
# 600:	learn: 1.0703055	test: 1.0970940	best: 1.0970940 (600)	total: 13.5s	remaining: 1m 38s
# 800:	learn: 1.0616031	test: 1.0956156	best: 1.0956156 (800)	total: 17.3s	remaining: 1m 30s
# 1000:	learn: 1.0533154	test: 1.0947157	best: 1.0947157 (1000)	total: 21.3s	remaining: 1m 25s
# 1200:	learn: 1.0455132	test: 1.0940383	best: 1.0940383 (1200)	total: 25.3s	remaining: 1m 20s
# 1400:	learn: 1.0384937	test: 1.0934951	best: 1.0934951 (1400)	total: 29.1s	remaining: 1m 14s
# 1600:	learn: 1.0318580	test: 1.0932594	best: 1.0932158 (1579)	total: 33.2s	remaining: 1m 10s
# 1800:	learn: 1.0251617	test: 1.0931041	best: 1.0930786 (1793)	total: 37.7s	remaining: 1m 6s
# 2000:	learn: 1.0187529	test: 1.0929417	best: 1.0929393 (1999)	total: 41.5s	remaining: 1m 2s
# 2200:	learn: 1.0122005	test: 1.0931300	best: 1.0929304 (2018)	total: 45.6s	remaining: 58s
# bestTest = 1.092930399
# bestIteration = 2018
# Shrink model to first 2019 iterations.
# Seed-56 | Fold-1 | OOF Score: 1.0929310862181987
# 0:	learn: 1.3775571	test: 1.3775591	best: 1.3775591 (0)	total: 21.7ms	remaining: 1m 48s
# 200:	learn: 1.0957085	test: 1.1047278	best: 1.1047278 (200)	total: 4.17s	remaining: 1m 39s
# 400:	learn: 1.0806459	test: 1.0988376	best: 1.0988376 (400)	total: 8.59s	remaining: 1m 38s
# 600:	learn: 1.0703557	test: 1.0964724	best: 1.0964724 (600)	total: 12.6s	remaining: 1m 31s
# 800:	learn: 1.0612926	test: 1.0951041	best: 1.0951041 (800)	total: 17.5s	remaining: 1m 31s
# 1000:	learn: 1.0532967	test: 1.0945190	best: 1.0945190 (1000)	total: 21.2s	remaining: 1m 24s
# 1200:	learn: 1.0455460	test: 1.0940579	best: 1.0940579 (1200)	total: 25.1s	remaining: 1m 19s
# 1400:	learn: 1.0382517	test: 1.0936867	best: 1.0936837 (1399)	total: 29.3s	remaining: 1m 15s
# 1600:	learn: 1.0313478	test: 1.0935235	best: 1.0935235 (1600)	total: 33.2s	remaining: 1m 10s
# 1800:	learn: 1.0248717	test: 1.0933463	best: 1.0933463 (1800)	total: 37s	remaining: 1m 5s
# 2000:	learn: 1.0184924	test: 1.0934071	best: 1.0933288 (1812)	total: 41.3s	remaining: 1m 1s
# bestTest = 1.093328765
# bestIteration = 1812
# Shrink model to first 1813 iterations.
# Seed-56 | Fold-2 | OOF Score: 1.0933290427354254
# 0:	learn: 1.3775597	test: 1.3775705	best: 1.3775705 (0)	total: 22.2ms	remaining: 1m 50s
# 200:	learn: 1.0958874	test: 1.1047860	best: 1.1047860 (200)	total: 5.48s	remaining: 2m 10s
# 400:	learn: 1.0809558	test: 1.0988845	best: 1.0988845 (400)	total: 9.54s	remaining: 1m 49s
# 600:	learn: 1.0706634	test: 1.0964172	best: 1.0964172 (600)	total: 13.4s	remaining: 1m 38s
# 800:	learn: 1.0619755	test: 1.0952272	best: 1.0952261 (799)	total: 17.7s	remaining: 1m 32s
# 1000:	learn: 1.0536947	test: 1.0942119	best: 1.0942119 (1000)	total: 21.6s	remaining: 1m 26s
# 1200:	learn: 1.0462659	test: 1.0936818	best: 1.0936762 (1195)	total: 25.7s	remaining: 1m 21s
# 1400:	learn: 1.0391701	test: 1.0934180	best: 1.0934076 (1350)	total: 29.6s	remaining: 1m 15s
# 1600:	learn: 1.0324035	test: 1.0931963	best: 1.0931927 (1521)	total: 33.4s	remaining: 1m 11s
# 1800:	learn: 1.0260527	test: 1.0930451	best: 1.0930206 (1700)	total: 38.2s	remaining: 1m 7s
# bestTest = 1.093020608
# bestIteration = 1700
# Shrink model to first 1701 iterations.
# Seed-56 | Fold-3 | OOF Score: 1.09302089345756
# 0:	learn: 1.3775603	test: 1.3775607	best: 1.3775607 (0)	total: 21.6ms	remaining: 1m 47s
# 200:	learn: 1.0961556	test: 1.1029278	best: 1.1029278 (200)	total: 4.66s	remaining: 1m 51s
# 400:	learn: 1.0813927	test: 1.0956566	best: 1.0956566 (400)	total: 8.62s	remaining: 1m 38s
# 600:	learn: 1.0709819	test: 1.0924344	best: 1.0924344 (600)	total: 12.5s	remaining: 1m 31s
# 800:	learn: 1.0620448	test: 1.0907483	best: 1.0907483 (800)	total: 16.6s	remaining: 1m 27s
# 1000:	learn: 1.0536326	test: 1.0895052	best: 1.0895052 (1000)	total: 20.5s	remaining: 1m 21s
# 1200:	learn: 1.0458316	test: 1.0887972	best: 1.0887972 (1200)	total: 25.4s	remaining: 1m 20s
# 1400:	learn: 1.0386088	test: 1.0882713	best: 1.0882713 (1400)	total: 29.1s	remaining: 1m 14s
# 1600:	learn: 1.0317312	test: 1.0879836	best: 1.0879600 (1576)	total: 32.9s	remaining: 1m 9s
# 1800:	learn: 1.0249883	test: 1.0876939	best: 1.0876939 (1800)	total: 37.1s	remaining: 1m 5s
# 2000:	learn: 1.0185402	test: 1.0876101	best: 1.0875749 (1961)	total: 40.9s	remaining: 1m 1s
# 2200:	learn: 1.0122741	test: 1.0873963	best: 1.0873960 (2197)	total: 44.7s	remaining: 56.8s
# 2400:	learn: 1.0060803	test: 1.0874211	best: 1.0873255 (2277)	total: 48.8s	remaining: 52.9s
# bestTest = 1.087325524
# bestIteration = 2277
# Shrink model to first 2278 iterations.
# Seed-56 | Fold-4 | OOF Score: 1.0873256401230664
# 0:	learn: 1.3775617	test: 1.3775853	best: 1.3775853 (0)	total: 42.9ms	remaining: 3m 34s
# 200:	learn: 1.0962917	test: 1.1030705	best: 1.1030705 (200)	total: 4.91s	remaining: 1m 57s
# 400:	learn: 1.0814897	test: 1.0961754	best: 1.0961754 (400)	total: 8.91s	remaining: 1m 42s
# 600:	learn: 1.0711726	test: 1.0929492	best: 1.0929492 (600)	total: 13.4s	remaining: 1m 37s
# 800:	learn: 1.0625445	test: 1.0910426	best: 1.0910426 (800)	total: 17.4s	remaining: 1m 31s
# 1000:	learn: 1.0542836	test: 1.0899346	best: 1.0899346 (1000)	total: 21.3s	remaining: 1m 25s
# 1200:	learn: 1.0466567	test: 1.0891796	best: 1.0891739 (1197)	total: 25.5s	remaining: 1m 20s
# 1400:	learn: 1.0394405	test: 1.0888355	best: 1.0888312 (1391)	total: 29.4s	remaining: 1m 15s
# 1600:	learn: 1.0328789	test: 1.0885282	best: 1.0885018 (1588)	total: 33.9s	remaining: 1m 11s
# 1800:	learn: 1.0262789	test: 1.0883398	best: 1.0883175 (1759)	total: 38.1s	remaining: 1m 7s
# 2000:	learn: 1.0198428	test: 1.0881387	best: 1.0881382 (1993)	total: 41.9s	remaining: 1m 2s
# 2200:	learn: 1.0133777	test: 1.0880854	best: 1.0880729 (2109)	total: 46s	remaining: 58.6s
# 2400:	learn: 1.0073018	test: 1.0881891	best: 1.0880686 (2292)	total: 49.9s	remaining: 54s
# bestTest = 1.088068599
# bestIteration = 2292
# Shrink model to first 2293 iterations.
# Seed-56 | Fold-5 | OOF Score: 1.088068667494891
# 0:	learn: 1.3775697	test: 1.3775995	best: 1.3775995 (0)	total: 22.2ms	remaining: 1m 51s
# 200:	learn: 1.0960748	test: 1.1055446	best: 1.1055446 (200)	total: 4.24s	remaining: 1m 41s
# 400:	learn: 1.0810053	test: 1.0995044	best: 1.0995044 (400)	total: 8.35s	remaining: 1m 35s
# 600:	learn: 1.0705022	test: 1.0970165	best: 1.0970165 (600)	total: 13.3s	remaining: 1m 37s
# 800:	learn: 1.0618181	test: 1.0955891	best: 1.0955891 (800)	total: 17.1s	remaining: 1m 29s
# 1000:	learn: 1.0537586	test: 1.0944827	best: 1.0944827 (1000)	total: 21.2s	remaining: 1m 24s
# 1200:	learn: 1.0461502	test: 1.0936825	best: 1.0936755 (1197)	total: 25.3s	remaining: 1m 19s
# 1400:	learn: 1.0389901	test: 1.0933441	best: 1.0933084 (1390)	total: 29.1s	remaining: 1m 14s
# 1600:	learn: 1.0322976	test: 1.0930856	best: 1.0930249 (1553)	total: 33.4s	remaining: 1m 10s
# 1800:	learn: 1.0257925	test: 1.0930506	best: 1.0929961 (1737)	total: 37.2s	remaining: 1m 6s
# 2000:	learn: 1.0193434	test: 1.0928993	best: 1.0928514 (1936)	total: 41.2s	remaining: 1m 1s
# 2200:	learn: 1.0132899	test: 1.0927408	best: 1.0926664 (2155)	total: 46.1s	remaining: 58.6s
# 2400:	learn: 1.0071310	test: 1.0925796	best: 1.0925765 (2390)	total: 50s	remaining: 54.1s
# 2600:	learn: 1.0009935	test: 1.0926239	best: 1.0925505 (2416)	total: 54.1s	remaining: 49.9s
# bestTest = 1.092550505
# bestIteration = 2416
# Shrink model to first 2417 iterations.
# Seed-56 | Fold-6 | OOF Score: 1.0925520673337286
# 0:	learn: 1.3775632	test: 1.3775574	best: 1.3775574 (0)	total: 22.3ms	remaining: 1m 51s
# 200:	learn: 1.0959396	test: 1.1061135	best: 1.1061135 (200)	total: 4.22s	remaining: 1m 40s
# 400:	learn: 1.0809651	test: 1.0998478	best: 1.0998478 (400)	total: 8.57s	remaining: 1m 38s
# 600:	learn: 1.0704460	test: 1.0972404	best: 1.0972346 (597)	total: 12.5s	remaining: 1m 31s
# 800:	learn: 1.0616351	test: 1.0957112	best: 1.0957112 (800)	total: 17.6s	remaining: 1m 32s
# 1000:	learn: 1.0532898	test: 1.0944715	best: 1.0944715 (1000)	total: 21.5s	remaining: 1m 25s
# 1200:	learn: 1.0457866	test: 1.0936429	best: 1.0936320 (1195)	total: 25.5s	remaining: 1m 20s
# 1400:	learn: 1.0387910	test: 1.0930070	best: 1.0929842 (1390)	total: 29.5s	remaining: 1m 15s
# 1600:	learn: 1.0320770	test: 1.0926311	best: 1.0926311 (1598)	total: 33.4s	remaining: 1m 10s
# 1800:	learn: 1.0253836	test: 1.0924441	best: 1.0924410 (1799)	total: 37.2s	remaining: 1m 5s
# 2000:	learn: 1.0190901	test: 1.0923179	best: 1.0922748 (1937)	total: 41.2s	remaining: 1m 1s
# 2200:	learn: 1.0128296	test: 1.0921000	best: 1.0920879 (2183)	total: 45.1s	remaining: 57.3s
# 2400:	learn: 1.0069627	test: 1.0921013	best: 1.0920191 (2230)	total: 49.7s	remaining: 53.8s
# bestTest = 1.092019123
# bestIteration = 2230
# Shrink model to first 2231 iterations.
# Seed-56 | Fold-7 | OOF Score: 1.0920197129087232
# 0:	learn: 1.3775616	test: 1.3775675	best: 1.3775675 (0)	total: 23ms	remaining: 1m 55s
# 200:	learn: 1.0962572	test: 1.1041733	best: 1.1041733 (200)	total: 4.27s	remaining: 1m 41s
# 400:	learn: 1.0812188	test: 1.0981075	best: 1.0981075 (400)	total: 8.64s	remaining: 1m 39s
# 600:	learn: 1.0707802	test: 1.0955689	best: 1.0955689 (600)	total: 12.5s	remaining: 1m 31s
# 800:	learn: 1.0620720	test: 1.0942598	best: 1.0942598 (800)	total: 16.8s	remaining: 1m 27s
# 1000:	learn: 1.0536706	test: 1.0934291	best: 1.0934291 (1000)	total: 20.6s	remaining: 1m 22s
# 1200:	learn: 1.0456552	test: 1.0928755	best: 1.0928735 (1199)	total: 24.4s	remaining: 1m 17s
# 1400:	learn: 1.0383671	test: 1.0925062	best: 1.0925061 (1394)	total: 29.2s	remaining: 1m 14s
# 1600:	learn: 1.0314536	test: 1.0923022	best: 1.0923022 (1600)	total: 33.2s	remaining: 1m 10s
# 1800:	learn: 1.0248670	test: 1.0922369	best: 1.0921523 (1672)	total: 37s	remaining: 1m 5s
# bestTest = 1.092152273
# bestIteration = 1672
# Shrink model to first 1673 iterations.
# Seed-56 | Fold-8 | OOF Score: 1.0921511481284056
# 0:	learn: 1.3775533	test: 1.3775601	best: 1.3775601 (0)	total: 21.4ms	remaining: 1m 46s
# 200:	learn: 1.0956840	test: 1.1061851	best: 1.1061851 (200)	total: 4.28s	remaining: 1m 42s
# 400:	learn: 1.0810200	test: 1.1008750	best: 1.1008750 (400)	total: 8.58s	remaining: 1m 38s
# 600:	learn: 1.0705130	test: 1.0986497	best: 1.0986497 (600)	total: 12.5s	remaining: 1m 31s
# 800:	learn: 1.0617802	test: 1.0974271	best: 1.0974150 (798)	total: 17.4s	remaining: 1m 31s
# 1000:	learn: 1.0534313	test: 1.0965170	best: 1.0965170 (1000)	total: 21.4s	remaining: 1m 25s
# 1200:	learn: 1.0456736	test: 1.0959829	best: 1.0959829 (1200)	total: 25.2s	remaining: 1m 19s
# 1400:	learn: 1.0384651	test: 1.0955441	best: 1.0955441 (1400)	total: 29.3s	remaining: 1m 15s
# 1600:	learn: 1.0316932	test: 1.0953924	best: 1.0953714 (1596)	total: 33.2s	remaining: 1m 10s
# 1800:	learn: 1.0251218	test: 1.0952015	best: 1.0951677 (1760)	total: 37.1s	remaining: 1m 5s
# 2000:	learn: 1.0188456	test: 1.0952043	best: 1.0951626 (1868)	total: 41.3s	remaining: 1m 1s
# 2200:	learn: 1.0125983	test: 1.0952559	best: 1.0950936 (2062)	total: 45.1s	remaining: 57.4s
# bestTest = 1.095093592
# bestIteration = 2062
# Shrink model to first 2063 iterations.
# Seed-56 | Fold-9 | OOF Score: 1.0950946262557075
#
# Seed: 56 | Aggregate OOF Score: 1.0917523977652803
#
#
# Aggregate OOF Score: 1.0920326197342076

# %%
np.savez_compressed('./CB_Meta_Features.npz',
                    y_pred_meta_cb=y_pred_meta_cb, 
                    oof_score=oof_score,
                    y_pred_final_cb=y_pred_final_cb)

# %% [markdown]
# ## Create submission file

# %%
y_pred_final_cb = np.clip(y_pred_final_cb, p_min, p_max)

test_df = pd.read_csv("../input/tabular-playground-series-may-2021/test.csv")
submit_df = pd.DataFrame()
submit_df['id'] = test_df['id']
submit_df['Class_1'] = y_pred_final_cb[:,0]
submit_df['Class_2'] = y_pred_final_cb[:,1]
submit_df['Class_3'] = y_pred_final_cb[:,2]
submit_df['Class_4'] = y_pred_final_cb[:,3]
submit_df.head()
# Out:
#        id   Class_1   Class_2   Class_3   Class_4
# 0  100000  0.086533  0.619636  0.168853  0.124979
# 1  100001  0.085723  0.690545  0.152098  0.071634
# 2  100002  0.082942  0.632967  0.182377  0.101714
# 3  100003  0.084424  0.539033  0.272080  0.104462
# 4  100004  0.073206  0.607155  0.199197  0.120442

# %%
submit_df.to_csv("./CB_submission.csv", index=False)
