# %% [markdown]
# ## Import libraries

# %%
! pip install -U lightautoml
# Out:
# Collecting lightautoml
#   Downloading LightAutoML-0.2.14-py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 404 kB/s
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Collecting importlib-metadata<2.0,>=1.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting poetry-core<2.0.0,>=1.0.0
#   Downloading poetry_core-1.0.3-py2.py3-none-any.whl (424 kB)
#      |████████████████████████████████| 424 kB 3.3 MB/s
# Requirement already satisfied: cmaes in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.19.5)
# Requirement already satisfied: pywavelets in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.1.1)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.7.0)
# Collecting autowoe>=1.2
#   Downloading AutoWoE-1.2.5-py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 8.3 MB/s
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.18.1)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1.48)
# Requirement already satisfied: transformers>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.5.4)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.0.1)
# Requirement already satisfied: albumentations>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from lightautoml) (5.3.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.2.4)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Collecting log-calls
#   Downloading log_calls-0.3.2.tar.gz (232 kB)
#      |████████████████████████████████| 232 kB 8.3 MB/s
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.7.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.1)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.25.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.11.3)
# Collecting json2html
#   Downloading json2html-1.3.0.tar.gz (7.0 kB)
# Requirement already satisfied: pandas>=1 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.2.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.59.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.1)
# Collecting lightgbm<3.0,>=2.3
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 8.3 MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.24.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.5)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (4.5.1.48)
# Requirement already satisfied: imgaug>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (0.4.0)
# Collecting sphinx
#   Downloading Sphinx-4.0.1-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 31.7 MB/s
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (3.4.1)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (6.2.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (2021.1)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (0.2.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (7.2.0)
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.7.1)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (2.9.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<2.0,>=1.0->lightautoml) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1->lightautoml) (2.8.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2021.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx->lightautoml) (4.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->lightautoml) (2.1.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.6)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2021.3.17)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (20.9)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.45)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.10.2)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (0.8.4)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (4.14.3)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.7/site-packages (from gensim->lightautoml) (5.0.0)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.1.1)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (0.2.1)
# Requirement already satisfied: convertdate>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.3.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.7/site-packages (from convertdate>=2.3.0->holidays->lightautoml) (0.5.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->lightautoml) (1.1.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.4.3)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.5.8)
# Requirement already satisfied: cliff in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (3.7.0)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (5.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.7/site-packages (from sqlalchemy>=1.1.0->optuna->lightautoml) (1.0.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.1.4)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.0.4)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (5.5.1)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (1.5.0)
# Requirement already satisfied: pyperclip>=1.6 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (1.8.2)
# Requirement already satisfied: attrs>=16.3.0 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (20.3.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.2.5)
# Requirement already satisfied: colorama>=0.3.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.4.4)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly->catboost->lightautoml) (1.3.3)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.10.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.13.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.10.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2020.12.5)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers>=4->lightautoml) (7.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (49.6.0.post20210108)
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-1.0.3-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 3.7 MB/s
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.8.1)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.0)
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.4-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 5.3 MB/s
# Requirement already satisfied: docutils<0.18,>=0.14 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (0.17.1)
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.1 MB/s
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 51.4 MB/s
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.4 MB/s
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.4 MB/s
# Building wheels for collected packages: efficientnet-pytorch, json2html, log-calls
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=ead24fa66cc1af3d83503ada583063282e5ffd4bfb3145b4add743144b9f459c
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7595 sha256=441f096715cd1e715d013444b3b0fe4061854e449b8d6b513f6624b5fc678be5
#   Stored in directory: /root/.cache/pip/wheels/e5/99/37/e1839a5ad733e0d6abb7e0419fd913e8926ddf96408239ce01
# done
#   Created wheel for log-calls: filename=log_calls-0.3.2-py3-none-any.whl size=51828 sha256=1abd4c889cbbc4472f5ed55372deb67e349e6bc1fdba58fe4f12c543b7b20607
#   Stored in directory: /root/.cache/pip/wheels/4c/4b/a5/a5643cfdcff002bbaf88cff0e52326db94182507613b53e971
# Successfully built efficientnet-pytorch json2html log-calls
# Installing collected packages: importlib-metadata, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, imagesize, alabaster, sphinx, lightgbm, poetry-core, log-calls, json2html, efficientnet-pytorch, autowoe, lightautoml
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.2.0
#     Uninstalling lightgbm-3.2.0:
#       Successfully uninstalled lightgbm-3.2.0
# Successfully installed alabaster-0.7.12 autowoe-1.2.5 efficientnet-pytorch-0.7.1 imagesize-1.2.0 importlib-metadata-1.7.0 json2html-1.3.0 lightautoml-0.2.14 lightgbm-2.3.1 log-calls-0.3.2 poetry-core-1.0.3 snowballstemmer-2.1.0 sphinx-4.0.1 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-1.0.3 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.4

# %%
import gc
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold

from lightautoml.tasks import Task
from lightautoml.automl.presets.tabular_presets import TabularUtilizedAutoML
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## Prepare data for model training

# %%
with open("../input/tps-may-data-preprocess-v3/TPS_May_Dataset_w_Org.txt", 'rb') as handle: 
    data = handle.read()

processed_data = pickle.loads(data)
train_df = processed_data['train_df']
test_df = processed_data['test_df']

train_df = train_df.add_suffix('_fet')
test_df = test_df.add_suffix('_fet')

Ytrain_oh = pd.get_dummies(train_df['target_fet']).values

del processed_data
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Build and validate the model

# %%
FOLD = 5
N_THREADS = 4
TIMEOUT = 60 * 60 * 4

model = TabularUtilizedAutoML(
    task = Task('multiclass',), 
    timeout = TIMEOUT,
    cpu_limit = N_THREADS, 
    general_params = {'use_algos': [['linear_l2', 'cb_tuned', 'lgb_tuned'], ['cb', 'lgb']]},
    reader_params = {'n_jobs': N_THREADS, 'cv': FOLD},
)

y_pred_meta_lama = model.fit_predict(train_df, roles={'target':'target_fet'})
print("\n\ny_pred_meta_lama: {}".format(y_pred_meta_lama.shape))
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 42}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'cb_tuned', 'lgb_tuned'], ['cb', 'lgb']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 14399.994770050049 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (99918, 1075)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 14182.517150878906 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1036727399922448
# Linear model: C = 5e-05 score = -1.097461149517038
# Linear model: C = 0.0001 score = -1.096189835971539
# Linear model: C = 0.0005 score = -1.0961874878284537
# Linear model: C = 0.001 score = -1.0971964043956564
# Linear model: C = 0.005 score = -1.0971906793156894
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1037369968922879
# Linear model: C = 5e-05 score = -1.0974695691033554
# Linear model: C = 0.0001 score = -1.0962471794568187
# Linear model: C = 0.0005 score = -1.0964939611284636
# Linear model: C = 0.001 score = -1.0964973858289953
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.104112075322611
# Linear model: C = 5e-05 score = -1.097314329513664
# Linear model: C = 0.0001 score = -1.0957661478424532
# Linear model: C = 0.0005 score = -1.095208941280299
# Linear model: C = 0.001 score = -1.0961696333516602
# Linear model: C = 0.005 score = -1.1003696965747136
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.10391443679833
# Linear model: C = 5e-05 score = -1.0979654545263922
# Linear model: C = 0.0001 score = -1.096839960679238
# Linear model: C = 0.0005 score = -1.0968275557597025
# Linear model: C = 0.001 score = -1.0976425425856462
# Linear model: C = 0.005 score = -1.0976510359634182
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1037967283464567
# Linear model: C = 5e-05 score = -1.0981935688619267
# Linear model: C = 0.0001 score = -1.0973186241741062
# Linear model: C = 0.0005 score = -1.0982012131412138
# Linear model: C = 0.001 score = -1.0994788341279003
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 13914.876282691956
# Optuna may run 2295.998507897477 secs
# Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09921
# [200]	valid's multi_logloss: 1.09831
# [300]	valid's multi_logloss: 1.10105
# Early stopping, best iteration is:
# [168]	valid's multi_logloss: 1.09778
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10002
# Early stopping, best iteration is:
# [89]	valid's multi_logloss: 1.09964
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10037
# Early stopping, best iteration is:
# [84]	valid's multi_logloss: 1.09951
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.1009
# Early stopping, best iteration is:
# [88]	valid's multi_logloss: 1.10029
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.1014
# Early stopping, best iteration is:
# [80]	valid's multi_logloss: 1.10113
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10068
# Early stopping, best iteration is:
# [84]	valid's multi_logloss: 1.10034
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 5414.380414867401 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686060	test: 1.3685955	best: 1.3685955 (0)	total: 372ms	remaining: 18m 36s
# 100:	learn: 1.1110024	test: 1.1115308	best: 1.1115308 (100)	total: 22.6s	remaining: 10m 49s
# 200:	learn: 1.1021519	test: 1.1039819	best: 1.1039819 (200)	total: 46.2s	remaining: 10m 43s
# 300:	learn: 1.0976303	test: 1.1006860	best: 1.1006860 (300)	total: 1m 9s	remaining: 10m 20s
# 400:	learn: 1.0937915	test: 1.0982156	best: 1.0982156 (400)	total: 1m 31s	remaining: 9m 50s
# 500:	learn: 1.0900513	test: 1.0960929	best: 1.0960929 (500)	total: 1m 53s	remaining: 9m 23s
# 600:	learn: 1.0869268	test: 1.0947900	best: 1.0947900 (600)	total: 2m 14s	remaining: 8m 57s
# 700:	learn: 1.0841900	test: 1.0938894	best: 1.0938894 (700)	total: 2m 35s	remaining: 8m 29s
# 800:	learn: 1.0818915	test: 1.0933458	best: 1.0933458 (800)	total: 2m 56s	remaining: 8m 4s
# 900:	learn: 1.0796251	test: 1.0929268	best: 1.0929152 (897)	total: 3m 17s	remaining: 7m 39s
# 1000:	learn: 1.0774542	test: 1.0925930	best: 1.0925818 (998)	total: 3m 38s	remaining: 7m 16s
# 1100:	learn: 1.0754460	test: 1.0924027	best: 1.0924027 (1100)	total: 3m 59s	remaining: 6m 53s
# 1200:	learn: 1.0735167	test: 1.0923258	best: 1.0922856 (1188)	total: 4m 20s	remaining: 6m 29s
# 1300:	learn: 1.0715970	test: 1.0921622	best: 1.0921584 (1299)	total: 4m 41s	remaining: 6m 7s
# 1400:	learn: 1.0697957	test: 1.0921058	best: 1.0921045 (1380)	total: 5m 1s	remaining: 5m 44s
# 1500:	learn: 1.0679357	test: 1.0920424	best: 1.0920310 (1496)	total: 5m 22s	remaining: 5m 22s
# 1600:	learn: 1.0662054	test: 1.0919100	best: 1.0918947 (1594)	total: 5m 43s	remaining: 5m
# 1700:	learn: 1.0644598	test: 1.0917831	best: 1.0917787 (1696)	total: 6m 5s	remaining: 4m 39s
# 1800:	learn: 1.0627374	test: 1.0917379	best: 1.0917236 (1799)	total: 6m 25s	remaining: 4m 16s
# 1900:	learn: 1.0610575	test: 1.0917089	best: 1.0916932 (1844)	total: 6m 46s	remaining: 3m 55s
# 2000:	learn: 1.0594069	test: 1.0917257	best: 1.0916864 (1924)	total: 7m 6s	remaining: 3m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09168639
# bestIteration = 1924
#
# Shrink model to first 1925 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686060	test: 1.3685955	best: 1.3685955 (0)	total: 209ms	remaining: 10m 26s
# 100:	learn: 1.1110024	test: 1.1115308	best: 1.1115308 (100)	total: 22s	remaining: 10m 32s
# 200:	learn: 1.1021519	test: 1.1039819	best: 1.1039819 (200)	total: 45.8s	remaining: 10m 37s
# 300:	learn: 1.0976303	test: 1.1006860	best: 1.1006860 (300)	total: 1m 9s	remaining: 10m 20s
# 400:	learn: 1.0937915	test: 1.0982156	best: 1.0982156 (400)	total: 1m 31s	remaining: 9m 54s
# 500:	learn: 1.0900513	test: 1.0960929	best: 1.0960929 (500)	total: 1m 53s	remaining: 9m 26s
# 600:	learn: 1.0869268	test: 1.0947900	best: 1.0947900 (600)	total: 2m 17s	remaining: 9m 8s
# 700:	learn: 1.0841900	test: 1.0938894	best: 1.0938894 (700)	total: 2m 38s	remaining: 8m 40s
# 800:	learn: 1.0818915	test: 1.0933458	best: 1.0933458 (800)	total: 2m 59s	remaining: 8m 12s
# 900:	learn: 1.0796251	test: 1.0929268	best: 1.0929152 (897)	total: 3m 20s	remaining: 7m 47s
# 1000:	learn: 1.0774542	test: 1.0925930	best: 1.0925818 (998)	total: 3m 41s	remaining: 7m 22s
# 1100:	learn: 1.0754460	test: 1.0924027	best: 1.0924027 (1100)	total: 4m 2s	remaining: 6m 58s
# 1200:	learn: 1.0735167	test: 1.0923258	best: 1.0922856 (1188)	total: 4m 23s	remaining: 6m 34s
# 1300:	learn: 1.0715970	test: 1.0921622	best: 1.0921584 (1299)	total: 4m 44s	remaining: 6m 11s
# 1400:	learn: 1.0697957	test: 1.0921058	best: 1.0921045 (1380)	total: 5m 5s	remaining: 5m 48s
# 1500:	learn: 1.0679357	test: 1.0920424	best: 1.0920310 (1496)	total: 5m 26s	remaining: 5m 26s
# 1600:	learn: 1.0662054	test: 1.0919100	best: 1.0918947 (1594)	total: 5m 47s	remaining: 5m 3s
# 1700:	learn: 1.0644598	test: 1.0917831	best: 1.0917787 (1696)	total: 6m 9s	remaining: 4m 41s
# 1800:	learn: 1.0627374	test: 1.0917379	best: 1.0917236 (1799)	total: 6m 29s	remaining: 4m 19s
# 1900:	learn: 1.0610575	test: 1.0917089	best: 1.0916932 (1844)	total: 6m 50s	remaining: 3m 57s
# 2000:	learn: 1.0594069	test: 1.0917257	best: 1.0916864 (1924)	total: 7m 11s	remaining: 3m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09168639
# bestIteration = 1924
#
# Shrink model to first 1925 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686014	test: 1.3685967	best: 1.3685967 (0)	total: 233ms	remaining: 11m 39s
# 100:	learn: 1.1110569	test: 1.1122769	best: 1.1122769 (100)	total: 22.1s	remaining: 10m 33s
# 200:	learn: 1.1021676	test: 1.1045923	best: 1.1045923 (200)	total: 45.7s	remaining: 10m 36s
# 300:	learn: 1.0976449	test: 1.1012967	best: 1.1012967 (300)	total: 1m 9s	remaining: 10m 18s
# 400:	learn: 1.0939293	test: 1.0988493	best: 1.0988493 (400)	total: 1m 31s	remaining: 9m 50s
# 500:	learn: 1.0899534	test: 1.0966161	best: 1.0966161 (500)	total: 1m 52s	remaining: 9m 22s
# 600:	learn: 1.0868116	test: 1.0954737	best: 1.0954737 (600)	total: 2m 13s	remaining: 8m 53s
# 700:	learn: 1.0841336	test: 1.0946278	best: 1.0946278 (700)	total: 2m 34s	remaining: 8m 27s
# 800:	learn: 1.0817078	test: 1.0941350	best: 1.0941347 (799)	total: 2m 56s	remaining: 8m 4s
# 900:	learn: 1.0794111	test: 1.0938047	best: 1.0938032 (898)	total: 3m 16s	remaining: 7m 38s
# 1000:	learn: 1.0773031	test: 1.0934926	best: 1.0934913 (999)	total: 3m 37s	remaining: 7m 14s
# 1100:	learn: 1.0752948	test: 1.0933270	best: 1.0933244 (1077)	total: 3m 58s	remaining: 6m 51s
# 1200:	learn: 1.0732721	test: 1.0931630	best: 1.0931630 (1200)	total: 4m 19s	remaining: 6m 28s
# 1300:	learn: 1.0714116	test: 1.0929942	best: 1.0929734 (1291)	total: 4m 40s	remaining: 6m 6s
# 1400:	learn: 1.0695114	test: 1.0928657	best: 1.0928425 (1378)	total: 5m 2s	remaining: 5m 45s
# 1500:	learn: 1.0676383	test: 1.0927863	best: 1.0927602 (1467)	total: 5m 23s	remaining: 5m 23s
# 1600:	learn: 1.0658832	test: 1.0927574	best: 1.0927525 (1561)	total: 5m 44s	remaining: 5m 1s
# 1700:	learn: 1.0641354	test: 1.0927184	best: 1.0927029 (1663)	total: 6m 5s	remaining: 4m 38s
# 1800:	learn: 1.0625285	test: 1.0926961	best: 1.0926842 (1753)	total: 6m 25s	remaining: 4m 16s
# 1900:	learn: 1.0607786	test: 1.0926080	best: 1.0925956 (1896)	total: 6m 46s	remaining: 3m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092595641
# bestIteration = 1896
#
# Shrink model to first 1897 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686061	test: 1.3686437	best: 1.3686437 (0)	total: 229ms	remaining: 11m 26s
# 100:	learn: 1.1110346	test: 1.1123149	best: 1.1123149 (100)	total: 21.9s	remaining: 10m 30s
# 200:	learn: 1.1020971	test: 1.1049608	best: 1.1049608 (200)	total: 46.2s	remaining: 10m 43s
# 300:	learn: 1.0977422	test: 1.1016651	best: 1.1016651 (300)	total: 1m 8s	remaining: 10m 14s
# 400:	learn: 1.0940613	test: 1.0992862	best: 1.0992862 (400)	total: 1m 31s	remaining: 9m 52s
# 500:	learn: 1.0901686	test: 1.0972390	best: 1.0972390 (500)	total: 1m 53s	remaining: 9m 23s
# 600:	learn: 1.0869704	test: 1.0960594	best: 1.0960594 (600)	total: 2m 14s	remaining: 8m 56s
# 700:	learn: 1.0842944	test: 1.0952551	best: 1.0952551 (700)	total: 2m 35s	remaining: 8m 29s
# 800:	learn: 1.0818423	test: 1.0946877	best: 1.0946877 (800)	total: 2m 56s	remaining: 8m 5s
# 900:	learn: 1.0795707	test: 1.0943136	best: 1.0943119 (898)	total: 3m 17s	remaining: 7m 39s
# 1000:	learn: 1.0774716	test: 1.0940083	best: 1.0939924 (996)	total: 3m 38s	remaining: 7m 16s
# 1100:	learn: 1.0753667	test: 1.0938244	best: 1.0938202 (1098)	total: 4m	remaining: 6m 54s
# 1200:	learn: 1.0734363	test: 1.0936799	best: 1.0936796 (1197)	total: 4m 20s	remaining: 6m 30s
# 1300:	learn: 1.0715858	test: 1.0935474	best: 1.0935399 (1294)	total: 4m 41s	remaining: 6m 7s
# 1400:	learn: 1.0697533	test: 1.0934809	best: 1.0934809 (1400)	total: 5m 2s	remaining: 5m 44s
# 1500:	learn: 1.0679028	test: 1.0933244	best: 1.0933150 (1479)	total: 5m 23s	remaining: 5m 23s
# 1600:	learn: 1.0661412	test: 1.0933129	best: 1.0932656 (1590)	total: 5m 44s	remaining: 5m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093265627
# bestIteration = 1590
#
# Shrink model to first 1591 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685860	test: 1.3686019	best: 1.3686019 (0)	total: 236ms	remaining: 11m 46s
# 100:	learn: 1.1108286	test: 1.1117808	best: 1.1117808 (100)	total: 21.5s	remaining: 10m 15s
# 200:	learn: 1.1021488	test: 1.1047960	best: 1.1047960 (200)	total: 45.1s	remaining: 10m 27s
# 300:	learn: 1.0974105	test: 1.1016129	best: 1.1016129 (300)	total: 1m 7s	remaining: 10m 3s
# 400:	learn: 1.0936451	test: 1.0994569	best: 1.0994569 (400)	total: 1m 28s	remaining: 9m 33s
# 500:	learn: 1.0898019	test: 1.0975570	best: 1.0975570 (500)	total: 1m 49s	remaining: 9m 7s
# 600:	learn: 1.0866134	test: 1.0963476	best: 1.0963476 (600)	total: 2m 11s	remaining: 8m 43s
# 700:	learn: 1.0838426	test: 1.0955149	best: 1.0954985 (697)	total: 2m 31s	remaining: 8m 18s
# 800:	learn: 1.0813918	test: 1.0950293	best: 1.0950235 (798)	total: 2m 52s	remaining: 7m 54s
# 900:	learn: 1.0792288	test: 1.0946481	best: 1.0946419 (899)	total: 3m 13s	remaining: 7m 29s
# 1000:	learn: 1.0771397	test: 1.0944174	best: 1.0944174 (1000)	total: 3m 33s	remaining: 7m 6s
# 1100:	learn: 1.0750550	test: 1.0942164	best: 1.0942157 (1099)	total: 3m 53s	remaining: 6m 43s
# 1200:	learn: 1.0731529	test: 1.0941715	best: 1.0941715 (1200)	total: 4m 14s	remaining: 6m 21s
# 1300:	learn: 1.0711911	test: 1.0940902	best: 1.0940902 (1300)	total: 4m 35s	remaining: 5m 59s
# 1400:	learn: 1.0693440	test: 1.0940651	best: 1.0940600 (1393)	total: 4m 55s	remaining: 5m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.094059989
# bestIteration = 1393
#
# Shrink model to first 1394 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686001	test: 1.3686001	best: 1.3686001 (0)	total: 206ms	remaining: 10m 16s
# 100:	learn: 1.1109293	test: 1.1121284	best: 1.1121284 (100)	total: 23s	remaining: 11m
# 200:	learn: 1.1019202	test: 1.1049134	best: 1.1049134 (200)	total: 46.4s	remaining: 10m 45s
# 300:	learn: 1.0973272	test: 1.1017961	best: 1.1017961 (300)	total: 1m 8s	remaining: 10m 16s
# 400:	learn: 1.0935929	test: 1.0995783	best: 1.0995783 (400)	total: 1m 30s	remaining: 9m 49s
# 500:	learn: 1.0897930	test: 1.0977407	best: 1.0977407 (500)	total: 1m 52s	remaining: 9m 19s
# 600:	learn: 1.0867190	test: 1.0964882	best: 1.0964882 (600)	total: 2m 12s	remaining: 8m 50s
# 700:	learn: 1.0840864	test: 1.0956724	best: 1.0956724 (700)	total: 2m 34s	remaining: 8m 25s
# 800:	learn: 1.0816771	test: 1.0951600	best: 1.0951600 (800)	total: 2m 55s	remaining: 8m
# 900:	learn: 1.0794403	test: 1.0947672	best: 1.0947672 (900)	total: 3m 15s	remaining: 7m 36s
# 1000:	learn: 1.0772981	test: 1.0945385	best: 1.0945302 (991)	total: 3m 36s	remaining: 7m 13s
# 1100:	learn: 1.0752302	test: 1.0942813	best: 1.0942746 (1099)	total: 3m 57s	remaining: 6m 50s
# 1200:	learn: 1.0732871	test: 1.0940934	best: 1.0940867 (1197)	total: 4m 18s	remaining: 6m 27s
# 1300:	learn: 1.0714347	test: 1.0940319	best: 1.0939924 (1269)	total: 4m 39s	remaining: 6m 5s
# 1400:	learn: 1.0695714	test: 1.0939633	best: 1.0939522 (1390)	total: 5m	remaining: 5m 42s
# 1500:	learn: 1.0677452	test: 1.0938983	best: 1.0938982 (1498)	total: 5m 21s	remaining: 5m 21s
# 1600:	learn: 1.0659668	test: 1.0939149	best: 1.0938690 (1536)	total: 5m 43s	remaining: 4m 59s
# 1700:	learn: 1.0641870	test: 1.0938396	best: 1.0938272 (1652)	total: 6m 4s	remaining: 4m 38s
# 1800:	learn: 1.0624435	test: 1.0937710	best: 1.0937615 (1796)	total: 6m 25s	remaining: 4m 16s
# 1900:	learn: 1.0606291	test: 1.0937791	best: 1.0937436 (1806)	total: 6m 46s	remaining: 3m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093743634
# bestIteration = 1806
#
# Shrink model to first 1807 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Time left 9856.357777357101
# Layer 1 training completed.
#
#
# Layer 2 ...
# Train process start. Time left 9855.559343099594 secs
# Start fitting Lvl_1_Pipe_0_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09371
# [200]	valid's multi_logloss: 1.09452
# [300]	valid's multi_logloss: 1.09544
# Early stopping, best iteration is:
# [103]	valid's multi_logloss: 1.09361
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09306
# [200]	valid's multi_logloss: 1.09378
# [300]	valid's multi_logloss: 1.09493
# Early stopping, best iteration is:
# [128]	valid's multi_logloss: 1.09282
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09424
# [200]	valid's multi_logloss: 1.09541
# [300]	valid's multi_logloss: 1.09686
# Early stopping, best iteration is:
# [110]	valid's multi_logloss: 1.09418
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09479
# [200]	valid's multi_logloss: 1.09547
# [300]	valid's multi_logloss: 1.09684
# Early stopping, best iteration is:
# [122]	valid's multi_logloss: 1.0947
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.0945
# [200]	valid's multi_logloss: 1.0954
# [300]	valid's multi_logloss: 1.09627
# Early stopping, best iteration is:
# [102]	valid's multi_logloss: 1.09448
# Lvl_1_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_0_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3675387	test: 1.3675528	best: 1.3675528 (0)	total: 308ms	remaining: 15m 22s
# 100:	learn: 1.0950017	test: 1.0961275	best: 1.0961275 (100)	total: 25.3s	remaining: 12m 7s
# 200:	learn: 1.0897533	test: 1.0929489	best: 1.0929468 (199)	total: 51s	remaining: 11m 49s
# 300:	learn: 1.0868524	test: 1.0927000	best: 1.0926541 (277)	total: 1m 15s	remaining: 11m 15s
# 400:	learn: 1.0835225	test: 1.0927102	best: 1.0926284 (336)	total: 1m 39s	remaining: 10m 47s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092628405
# bestIteration = 336
#
# Shrink model to first 337 iterations.
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3675401	test: 1.3675001	best: 1.3675001 (0)	total: 370ms	remaining: 18m 29s
# 100:	learn: 1.0951267	test: 1.0962059	best: 1.0962059 (100)	total: 25.4s	remaining: 12m 7s
# 200:	learn: 1.0899132	test: 1.0931855	best: 1.0931855 (200)	total: 49.6s	remaining: 11m 30s
# 300:	learn: 1.0869384	test: 1.0929967	best: 1.0929637 (293)	total: 1m 14s	remaining: 11m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092963709
# bestIteration = 293
#
# Shrink model to first 294 iterations.
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3676514	test: 1.3676977	best: 1.3676977 (0)	total: 284ms	remaining: 14m 10s
# 100:	learn: 1.0949343	test: 1.0964001	best: 1.0964001 (100)	total: 25.5s	remaining: 12m 12s
# 200:	learn: 1.0895593	test: 1.0934788	best: 1.0934788 (200)	total: 50.2s	remaining: 11m 38s
# 300:	learn: 1.0868616	test: 1.0932564	best: 1.0932520 (296)	total: 1m 14s	remaining: 11m 7s
# 400:	learn: 1.0836028	test: 1.0931896	best: 1.0931030 (358)	total: 1m 38s	remaining: 10m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093103012
# bestIteration = 358
#
# Shrink model to first 359 iterations.
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3676508	test: 1.3676655	best: 1.3676655 (0)	total: 324ms	remaining: 16m 10s
# 100:	learn: 1.0943578	test: 1.0965137	best: 1.0965137 (100)	total: 26.2s	remaining: 12m 31s
# 200:	learn: 1.0891434	test: 1.0941755	best: 1.0941664 (198)	total: 51.4s	remaining: 11m 55s
# 300:	learn: 1.0861566	test: 1.0940044	best: 1.0939450 (277)	total: 1m 16s	remaining: 11m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093944956
# bestIteration = 277
#
# Shrink model to first 278 iterations.
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3675426	test: 1.3676221	best: 1.3676221 (0)	total: 343ms	remaining: 17m 9s
# 100:	learn: 1.0945868	test: 1.0970830	best: 1.0970830 (100)	total: 25.6s	remaining: 12m 15s
# 200:	learn: 1.0891895	test: 1.0945792	best: 1.0945759 (198)	total: 51.3s	remaining: 11m 54s
# 300:	learn: 1.0864048	test: 1.0943850	best: 1.0943702 (287)	total: 1m 16s	remaining: 11m 27s
# 400:	learn: 1.0831878	test: 1.0943858	best: 1.0943340 (344)	total: 1m 41s	remaining: 10m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.094334028
# bestIteration = 344
#
# Shrink model to first 345 iterations.
# Lvl_1_Pipe_0_Mod_1_CatBoost fitting and predicting completed
# Time left 8500.606190681458
# Blending: Optimization starts with equal weights and score -1.0932468186619737
# Blending, iter 0: score = -1.0931997612834863, weights = [0.33410165 0.6658984 ]
# Blending, iter 1: score = -1.0931997612834863, weights = [0.33410165 0.6658984 ]
# No score update. Terminated
#
# Automl preset training completed in 5900.47 seconds.
# Current random state: {'reader_params': {'random_state': 43}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 43}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'cb_tuned', 'lgb_tuned'], ['cb', 'lgb']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 8499.486624002457 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (99918, 1075)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 8304.290271520615 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1036285410916284
# Linear model: C = 5e-05 score = -1.0977646804812125
# Linear model: C = 0.0001 score = -1.0966383516042828
# Linear model: C = 0.0005 score = -1.096988053663557
# Linear model: C = 0.001 score = -1.0980375208642135
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.103302620160427
# Linear model: C = 5e-05 score = -1.0963353463019834
# Linear model: C = 0.0001 score = -1.0947450285142153
# Linear model: C = 0.0005 score = -1.0939699853095617
# Linear model: C = 0.001 score = -1.0945654234478326
# Linear model: C = 0.005 score = -1.0945563009485983
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1030504616399448
# Linear model: C = 5e-05 score = -1.0965162769833907
# Linear model: C = 0.0001 score = -1.0953088610271235
# Linear model: C = 0.0005 score = -1.095617439356253
# Linear model: C = 0.001 score = -1.096700830892134
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1044867243091128
# Linear model: C = 5e-05 score = -1.0985702769758583
# Linear model: C = 0.0001 score = -1.097349366102587
# Linear model: C = 0.0005 score = -1.0972521932263313
# Linear model: C = 0.001 score = -1.0972520819608975
# Linear model: C = 0.005 score = -1.097251596050906
# Linear model: C = 0.01 score = -1.1028102779871785
# Linear model: C = 0.05 score = -1.102810854129991
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1048691037410148
# Linear model: C = 5e-05 score = -1.0992657077446395
# Linear model: C = 0.0001 score = -1.0983478419774646
# Linear model: C = 0.0005 score = -1.0989639515766825
# Linear model: C = 0.001 score = -1.0989702157696726
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 8043.989032030106
# Start fitting Selector_LightGBM ...
#
# ===== Start working with fold 0 for Selector_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09859
# [200]	valid's multi_logloss: 1.09595
# [300]	valid's multi_logloss: 1.09599
# [400]	valid's multi_logloss: 1.09645
# Early stopping, best iteration is:
# [260]	valid's multi_logloss: 1.09582
# Selector_LightGBM fitting and predicting completed
# Optuna may run 1 secs
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09939
# [200]	valid's multi_logloss: 1.09888
# [300]	valid's multi_logloss: 1.10108
# Early stopping, best iteration is:
# [162]	valid's multi_logloss: 1.09846
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09957
# Early stopping, best iteration is:
# [85]	valid's multi_logloss: 1.09899
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09928
# Early stopping, best iteration is:
# [99]	valid's multi_logloss: 1.09921
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09923
# Early stopping, best iteration is:
# [81]	valid's multi_logloss: 1.09889
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09961
# Early stopping, best iteration is:
# [90]	valid's multi_logloss: 1.09937
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10327
# Early stopping, best iteration is:
# [67]	valid's multi_logloss: 1.10261
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 2691.088336241245 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686276	test: 1.3686254	best: 1.3686254 (0)	total: 133ms	remaining: 6m 38s
# 100:	learn: 1.1111761	test: 1.1118104	best: 1.1118104 (100)	total: 20.9s	remaining: 9m 58s
# 200:	learn: 1.1022886	test: 1.1044144	best: 1.1044144 (200)	total: 44.1s	remaining: 10m 13s
# 300:	learn: 1.0975438	test: 1.1011084	best: 1.1011084 (300)	total: 1m 5s	remaining: 9m 47s
# 400:	learn: 1.0936582	test: 1.0986746	best: 1.0986746 (400)	total: 1m 26s	remaining: 9m 21s
# 500:	learn: 1.0897285	test: 1.0967645	best: 1.0967645 (500)	total: 1m 47s	remaining: 8m 57s
# 600:	learn: 1.0864039	test: 1.0955526	best: 1.0955526 (600)	total: 2m 8s	remaining: 8m 34s
# 700:	learn: 1.0837892	test: 1.0948393	best: 1.0948393 (700)	total: 2m 28s	remaining: 8m 7s
# 800:	learn: 1.0814205	test: 1.0943351	best: 1.0943274 (797)	total: 2m 48s	remaining: 7m 43s
# 900:	learn: 1.0790564	test: 1.0939618	best: 1.0939618 (900)	total: 3m 9s	remaining: 7m 21s
# 1000:	learn: 1.0770597	test: 1.0936342	best: 1.0936342 (1000)	total: 3m 29s	remaining: 6m 57s
# 1100:	learn: 1.0751216	test: 1.0934469	best: 1.0934311 (1089)	total: 3m 49s	remaining: 6m 35s
# 1200:	learn: 1.0732104	test: 1.0933175	best: 1.0933080 (1198)	total: 4m 10s	remaining: 6m 14s
# 1300:	learn: 1.0713061	test: 1.0932897	best: 1.0932493 (1286)	total: 4m 30s	remaining: 5m 53s
# 1400:	learn: 1.0694236	test: 1.0932385	best: 1.0931924 (1373)	total: 4m 50s	remaining: 5m 31s
# 1500:	learn: 1.0676396	test: 1.0931814	best: 1.0931742 (1423)	total: 5m 10s	remaining: 5m 10s
# 1600:	learn: 1.0658488	test: 1.0931530	best: 1.0931349 (1585)	total: 5m 30s	remaining: 4m 48s
# 1700:	learn: 1.0640613	test: 1.0930751	best: 1.0930711 (1690)	total: 5m 51s	remaining: 4m 28s
# 1800:	learn: 1.0623257	test: 1.0930702	best: 1.0930055 (1732)	total: 6m 11s	remaining: 4m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093005495
# bestIteration = 1732
#
# Shrink model to first 1733 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686276	test: 1.3686254	best: 1.3686254 (0)	total: 128ms	remaining: 6m 24s
# 100:	learn: 1.1111761	test: 1.1118104	best: 1.1118104 (100)	total: 20.6s	remaining: 9m 50s
# 200:	learn: 1.1022886	test: 1.1044144	best: 1.1044144 (200)	total: 43.8s	remaining: 10m 10s
# 300:	learn: 1.0975438	test: 1.1011084	best: 1.1011084 (300)	total: 1m 5s	remaining: 9m 46s
# 400:	learn: 1.0936582	test: 1.0986746	best: 1.0986746 (400)	total: 1m 26s	remaining: 9m 20s
# 500:	learn: 1.0897285	test: 1.0967645	best: 1.0967645 (500)	total: 1m 47s	remaining: 8m 55s
# 600:	learn: 1.0864039	test: 1.0955526	best: 1.0955526 (600)	total: 2m 8s	remaining: 8m 31s
# 700:	learn: 1.0837892	test: 1.0948393	best: 1.0948393 (700)	total: 2m 28s	remaining: 8m 6s
# 800:	learn: 1.0814205	test: 1.0943351	best: 1.0943274 (797)	total: 2m 47s	remaining: 7m 40s
# 900:	learn: 1.0790564	test: 1.0939618	best: 1.0939618 (900)	total: 3m 8s	remaining: 7m 19s
# 1000:	learn: 1.0770597	test: 1.0936342	best: 1.0936342 (1000)	total: 3m 28s	remaining: 6m 56s
# 1100:	learn: 1.0751216	test: 1.0934469	best: 1.0934311 (1089)	total: 3m 48s	remaining: 6m 33s
# 1200:	learn: 1.0732104	test: 1.0933175	best: 1.0933080 (1198)	total: 4m 8s	remaining: 6m 12s
# 1300:	learn: 1.0713061	test: 1.0932897	best: 1.0932493 (1286)	total: 4m 29s	remaining: 5m 51s
# 1400:	learn: 1.0694236	test: 1.0932385	best: 1.0931924 (1373)	total: 4m 49s	remaining: 5m 29s
# 1500:	learn: 1.0676396	test: 1.0931814	best: 1.0931742 (1423)	total: 5m 9s	remaining: 5m 8s
# 1600:	learn: 1.0658488	test: 1.0931530	best: 1.0931349 (1585)	total: 5m 29s	remaining: 4m 47s
# 1700:	learn: 1.0640613	test: 1.0930751	best: 1.0930711 (1690)	total: 5m 49s	remaining: 4m 27s
# 1800:	learn: 1.0623257	test: 1.0930702	best: 1.0930055 (1732)	total: 6m 9s	remaining: 4m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093005495
# bestIteration = 1732
#
# Shrink model to first 1733 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686150	test: 1.3686261	best: 1.3686261 (0)	total: 213ms	remaining: 10m 37s
# 100:	learn: 1.1107599	test: 1.1116006	best: 1.1116006 (100)	total: 21s	remaining: 10m 4s
# 200:	learn: 1.1024050	test: 1.1043452	best: 1.1043452 (200)	total: 44.1s	remaining: 10m 13s
# 300:	learn: 1.0979496	test: 1.1009157	best: 1.1009157 (300)	total: 1m 6s	remaining: 9m 56s
# 400:	learn: 1.0939932	test: 1.0983744	best: 1.0983744 (400)	total: 1m 28s	remaining: 9m 31s
# 500:	learn: 1.0902700	test: 1.0962173	best: 1.0962173 (500)	total: 1m 48s	remaining: 9m 2s
# 600:	learn: 1.0872654	test: 1.0948179	best: 1.0948179 (600)	total: 2m 8s	remaining: 8m 34s
# 700:	learn: 1.0846423	test: 1.0938925	best: 1.0938925 (700)	total: 2m 28s	remaining: 8m 7s
# 800:	learn: 1.0822206	test: 1.0932409	best: 1.0932392 (799)	total: 2m 48s	remaining: 7m 42s
# 900:	learn: 1.0799016	test: 1.0927341	best: 1.0927337 (898)	total: 3m 8s	remaining: 7m 20s
# 1000:	learn: 1.0777596	test: 1.0924002	best: 1.0923999 (999)	total: 3m 29s	remaining: 6m 58s
# 1100:	learn: 1.0757588	test: 1.0921320	best: 1.0921171 (1083)	total: 3m 50s	remaining: 6m 36s
# 1200:	learn: 1.0738015	test: 1.0919702	best: 1.0919702 (1200)	total: 4m 9s	remaining: 6m 14s
# 1300:	learn: 1.0719719	test: 1.0918430	best: 1.0918358 (1296)	total: 4m 30s	remaining: 5m 52s
# 1400:	learn: 1.0701254	test: 1.0917769	best: 1.0917510 (1366)	total: 4m 50s	remaining: 5m 31s
# 1500:	learn: 1.0682176	test: 1.0917590	best: 1.0917108 (1484)	total: 5m 10s	remaining: 5m 10s
# 1600:	learn: 1.0663616	test: 1.0917177	best: 1.0916678 (1553)	total: 5m 31s	remaining: 4m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091667834
# bestIteration = 1553
#
# Shrink model to first 1554 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686263	test: 1.3686275	best: 1.3686275 (0)	total: 127ms	remaining: 6m 21s
# 100:	learn: 1.1112503	test: 1.1113470	best: 1.1113470 (100)	total: 21.1s	remaining: 10m 6s
# 200:	learn: 1.1025721	test: 1.1039105	best: 1.1039105 (200)	total: 44.4s	remaining: 10m 17s
# 300:	learn: 1.0979595	test: 1.1004662	best: 1.1004662 (300)	total: 1m 5s	remaining: 9m 48s
# 400:	learn: 1.0941534	test: 1.0978498	best: 1.0978498 (400)	total: 1m 27s	remaining: 9m 25s
# 500:	learn: 1.0904222	test: 1.0958639	best: 1.0958639 (500)	total: 1m 47s	remaining: 8m 56s
# 600:	learn: 1.0872811	test: 1.0945004	best: 1.0945004 (600)	total: 2m 8s	remaining: 8m 33s
# 700:	learn: 1.0846113	test: 1.0936903	best: 1.0936903 (700)	total: 2m 29s	remaining: 8m 9s
# 800:	learn: 1.0821544	test: 1.0929691	best: 1.0929691 (800)	total: 2m 49s	remaining: 7m 44s
# 900:	learn: 1.0799031	test: 1.0926232	best: 1.0926232 (900)	total: 3m 9s	remaining: 7m 21s
# 1000:	learn: 1.0777710	test: 1.0923144	best: 1.0923074 (992)	total: 3m 30s	remaining: 6m 59s
# 1100:	learn: 1.0757499	test: 1.0921097	best: 1.0921040 (1099)	total: 3m 50s	remaining: 6m 36s
# 1200:	learn: 1.0737166	test: 1.0918925	best: 1.0918917 (1197)	total: 4m 10s	remaining: 6m 15s
# 1300:	learn: 1.0717843	test: 1.0918165	best: 1.0918076 (1297)	total: 4m 31s	remaining: 5m 53s
# 1400:	learn: 1.0699042	test: 1.0916986	best: 1.0916986 (1400)	total: 4m 51s	remaining: 5m 32s
# 1500:	learn: 1.0680726	test: 1.0916413	best: 1.0916249 (1495)	total: 5m 14s	remaining: 5m 13s
# 1600:	learn: 1.0662457	test: 1.0916159	best: 1.0916063 (1597)	total: 5m 34s	remaining: 4m 52s
# 1700:	learn: 1.0644740	test: 1.0915013	best: 1.0914921 (1677)	total: 5m 54s	remaining: 4m 30s
# 1800:	learn: 1.0627229	test: 1.0915452	best: 1.0914869 (1773)	total: 6m 14s	remaining: 4m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091486932
# bestIteration = 1773
#
# Shrink model to first 1774 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686269	test: 1.3686266	best: 1.3686266 (0)	total: 133ms	remaining: 6m 40s
# 100:	learn: 1.1105210	test: 1.1123738	best: 1.1123738 (100)	total: 21.1s	remaining: 10m 5s
# 200:	learn: 1.1017570	test: 1.1052761	best: 1.1052761 (200)	total: 43s	remaining: 9m 58s
# 300:	learn: 1.0972735	test: 1.1022648	best: 1.1022648 (300)	total: 1m 5s	remaining: 9m 51s
# 400:	learn: 1.0935862	test: 1.0999168	best: 1.0999168 (400)	total: 1m 26s	remaining: 9m 22s
# 500:	learn: 1.0898384	test: 1.0979459	best: 1.0979459 (500)	total: 1m 46s	remaining: 8m 53s
# 600:	learn: 1.0867281	test: 1.0968011	best: 1.0968011 (600)	total: 2m 7s	remaining: 8m 27s
# 700:	learn: 1.0840484	test: 1.0960502	best: 1.0960502 (700)	total: 2m 27s	remaining: 8m 3s
# 800:	learn: 1.0816639	test: 1.0954797	best: 1.0954797 (800)	total: 2m 47s	remaining: 7m 39s
# 900:	learn: 1.0795477	test: 1.0950450	best: 1.0950423 (898)	total: 3m 7s	remaining: 7m 17s
# 1000:	learn: 1.0772843	test: 1.0947617	best: 1.0947555 (997)	total: 3m 28s	remaining: 6m 55s
# 1100:	learn: 1.0752094	test: 1.0945197	best: 1.0945197 (1100)	total: 3m 47s	remaining: 6m 32s
# 1200:	learn: 1.0732418	test: 1.0943127	best: 1.0943114 (1191)	total: 4m 7s	remaining: 6m 11s
# 1300:	learn: 1.0713401	test: 1.0941992	best: 1.0941610 (1289)	total: 4m 27s	remaining: 5m 49s
# 1400:	learn: 1.0694822	test: 1.0940463	best: 1.0940463 (1400)	total: 4m 47s	remaining: 5m 28s
# 1500:	learn: 1.0675642	test: 1.0939592	best: 1.0939259 (1468)	total: 5m 7s	remaining: 5m 7s
# 1600:	learn: 1.0657243	test: 1.0938217	best: 1.0938085 (1595)	total: 5m 28s	remaining: 4m 47s
# 1700:	learn: 1.0639014	test: 1.0937777	best: 1.0937777 (1700)	total: 5m 48s	remaining: 4m 26s
# 1800:	learn: 1.0621851	test: 1.0938146	best: 1.0937264 (1753)	total: 6m 8s	remaining: 4m 5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093726421
# bestIteration = 1753
#
# Shrink model to first 1754 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686269	test: 1.3686266	best: 1.3686266 (0)	total: 135ms	remaining: 6m 45s
# 100:	learn: 1.1107955	test: 1.1124672	best: 1.1124672 (100)	total: 21.4s	remaining: 10m 13s
# 200:	learn: 1.1015338	test: 1.1054548	best: 1.1054548 (200)	total: 44.2s	remaining: 10m 15s
# 300:	learn: 1.0971206	test: 1.1027154	best: 1.1027154 (300)	total: 1m 6s	remaining: 9m 52s
# 400:	learn: 1.0933525	test: 1.1007326	best: 1.1007326 (400)	total: 1m 27s	remaining: 9m 23s
# 500:	learn: 1.0893019	test: 1.0988888	best: 1.0988888 (500)	total: 1m 48s	remaining: 8m 59s
# 600:	learn: 1.0860488	test: 1.0977804	best: 1.0977786 (599)	total: 2m 9s	remaining: 8m 35s
# 700:	learn: 1.0833913	test: 1.0971455	best: 1.0971455 (700)	total: 2m 28s	remaining: 8m 8s
# 800:	learn: 1.0808870	test: 1.0966424	best: 1.0966424 (800)	total: 2m 49s	remaining: 7m 45s
# 900:	learn: 1.0786044	test: 1.0963765	best: 1.0963642 (896)	total: 3m 9s	remaining: 7m 21s
# 1000:	learn: 1.0765833	test: 1.0959962	best: 1.0959962 (1000)	total: 3m 29s	remaining: 6m 58s
# 1100:	learn: 1.0745120	test: 1.0958240	best: 1.0958240 (1100)	total: 3m 50s	remaining: 6m 36s
# 1200:	learn: 1.0725371	test: 1.0957313	best: 1.0957185 (1178)	total: 4m 10s	remaining: 6m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.095718461
# bestIteration = 1178
#
# Shrink model to first 1179 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Time left 4072.0356166362762
# Layer 1 training completed.
#
#
# Layer 2 ...
# Train process start. Time left 4070.7618646621704 secs
# Start fitting Lvl_1_Pipe_0_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09871
# [200]	valid's multi_logloss: 1.09551
# [300]	valid's multi_logloss: 1.09525
# [400]	valid's multi_logloss: 1.0956
# Early stopping, best iteration is:
# [262]	valid's multi_logloss: 1.09514
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09812
# [200]	valid's multi_logloss: 1.0947
# [300]	valid's multi_logloss: 1.0941
# [400]	valid's multi_logloss: 1.09442
# Early stopping, best iteration is:
# [267]	valid's multi_logloss: 1.09404
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.0984
# [200]	valid's multi_logloss: 1.0954
# [300]	valid's multi_logloss: 1.09517
# [400]	valid's multi_logloss: 1.09541
# Early stopping, best iteration is:
# [260]	valid's multi_logloss: 1.09501
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09968
# [200]	valid's multi_logloss: 1.09623
# [300]	valid's multi_logloss: 1.09566
# [400]	valid's multi_logloss: 1.09569
# [500]	valid's multi_logloss: 1.09639
# Early stopping, best iteration is:
# [334]	valid's multi_logloss: 1.09541
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10087
# [200]	valid's multi_logloss: 1.09796
# [300]	valid's multi_logloss: 1.09779
# [400]	valid's multi_logloss: 1.09859
# Early stopping, best iteration is:
# [243]	valid's multi_logloss: 1.09753
# Lvl_1_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_0_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686245	test: 1.3686223	best: 1.3686223 (0)	total: 131ms	remaining: 6m 33s
# 100:	learn: 1.1095831	test: 1.1110734	best: 1.1110734 (100)	total: 23.2s	remaining: 11m 4s
# 200:	learn: 1.0989496	test: 1.1033105	best: 1.1033105 (200)	total: 48.8s	remaining: 11m 18s
# 300:	learn: 1.0928157	test: 1.1000819	best: 1.1000819 (300)	total: 1m 12s	remaining: 10m 54s
# 400:	learn: 1.0876184	test: 1.0980530	best: 1.0980530 (400)	total: 1m 36s	remaining: 10m 24s
# 500:	learn: 1.0813945	test: 1.0960765	best: 1.0960765 (500)	total: 2m 1s	remaining: 10m 3s
# 600:	learn: 1.0760747	test: 1.0950306	best: 1.0950306 (600)	total: 2m 24s	remaining: 9m 38s
# 700:	learn: 1.0712035	test: 1.0944090	best: 1.0944090 (700)	total: 2m 48s	remaining: 9m 13s
# 800:	learn: 1.0664974	test: 1.0939602	best: 1.0939602 (800)	total: 3m 12s	remaining: 8m 48s
# 900:	learn: 1.0619047	test: 1.0936794	best: 1.0936794 (900)	total: 3m 36s	remaining: 8m 24s
# 1000:	learn: 1.0573561	test: 1.0934453	best: 1.0934392 (997)	total: 4m	remaining: 8m
# 1100:	learn: 1.0530298	test: 1.0932952	best: 1.0932619 (1079)	total: 4m 24s	remaining: 7m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093261879
# bestIteration = 1079
#
# Shrink model to first 1080 iterations.
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685833	test: 1.3685901	best: 1.3685901 (0)	total: 281ms	remaining: 14m 2s
# 100:	learn: 1.1097753	test: 1.1111073	best: 1.1111073 (100)	total: 23.8s	remaining: 11m 23s
# 200:	learn: 1.0990837	test: 1.1030631	best: 1.1030631 (200)	total: 49.7s	remaining: 11m 31s
# 300:	learn: 1.0931051	test: 1.0997182	best: 1.0997182 (300)	total: 1m 14s	remaining: 11m 6s
# 400:	learn: 1.0876453	test: 1.0973999	best: 1.0973999 (400)	total: 1m 38s	remaining: 10m 37s
# 500:	learn: 1.0816147	test: 1.0953227	best: 1.0953227 (500)	total: 2m 2s	remaining: 10m 12s
# 600:	learn: 1.0762070	test: 1.0941287	best: 1.0941287 (600)	total: 2m 26s	remaining: 9m 45s
# 700:	learn: 1.0712320	test: 1.0932483	best: 1.0932483 (700)	total: 2m 50s	remaining: 9m 18s
# 800:	learn: 1.0665454	test: 1.0926993	best: 1.0926993 (800)	total: 3m 13s	remaining: 8m 51s
# 900:	learn: 1.0621532	test: 1.0922180	best: 1.0922180 (900)	total: 3m 36s	remaining: 8m 24s
# 1000:	learn: 1.0576588	test: 1.0920585	best: 1.0920312 (991)	total: 4m	remaining: 8m
# 1100:	learn: 1.0532413	test: 1.0919745	best: 1.0919097 (1073)	total: 4m 24s	remaining: 7m 36s
# 1200:	learn: 1.0489465	test: 1.0919278	best: 1.0918873 (1193)	total: 4m 48s	remaining: 7m 11s
# 1300:	learn: 1.0448462	test: 1.0919236	best: 1.0918403 (1229)	total: 5m 11s	remaining: 6m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091840347
# bestIteration = 1229
#
# Shrink model to first 1230 iterations.
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686232	test: 1.3686244	best: 1.3686244 (0)	total: 127ms	remaining: 6m 21s
# 100:	learn: 1.1096215	test: 1.1104279	best: 1.1104279 (100)	total: 24.2s	remaining: 11m 33s
# 200:	learn: 1.0989708	test: 1.1026971	best: 1.1026971 (200)	total: 50.8s	remaining: 11m 46s
# 300:	learn: 1.0930527	test: 1.0994330	best: 1.0994330 (300)	total: 1m 14s	remaining: 11m 9s
# 400:	learn: 1.0875516	test: 1.0971022	best: 1.0971022 (400)	total: 1m 39s	remaining: 10m 44s
# 500:	learn: 1.0815259	test: 1.0951169	best: 1.0951169 (500)	total: 2m 3s	remaining: 10m 16s
# 600:	learn: 1.0761572	test: 1.0939081	best: 1.0938970 (599)	total: 2m 27s	remaining: 9m 49s
# 700:	learn: 1.0712186	test: 1.0931806	best: 1.0931806 (700)	total: 2m 51s	remaining: 9m 20s
# 800:	learn: 1.0665391	test: 1.0928525	best: 1.0928321 (786)	total: 3m 15s	remaining: 8m 55s
# 900:	learn: 1.0620012	test: 1.0925655	best: 1.0925608 (897)	total: 3m 39s	remaining: 8m 30s
# 1000:	learn: 1.0576574	test: 1.0925435	best: 1.0924710 (939)	total: 4m 3s	remaining: 8m 5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09247098
# bestIteration = 939
#
# Shrink model to first 940 iterations.
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686237	test: 1.3686235	best: 1.3686235 (0)	total: 128ms	remaining: 6m 22s
# 100:	learn: 1.1085481	test: 1.1112459	best: 1.1112459 (100)	total: 24.3s	remaining: 11m 38s
# 200:	learn: 1.0982561	test: 1.1045149	best: 1.1045149 (200)	total: 50.1s	remaining: 11m 37s
# 300:	learn: 1.0923965	test: 1.1015156	best: 1.1015156 (300)	total: 1m 14s	remaining: 11m 9s
# 400:	learn: 1.0869656	test: 1.0992754	best: 1.0992754 (400)	total: 1m 39s	remaining: 10m 44s
# 500:	learn: 1.0810036	test: 1.0974918	best: 1.0974918 (500)	total: 2m 3s	remaining: 10m 15s
# 600:	learn: 1.0754845	test: 1.0964081	best: 1.0964030 (599)	total: 2m 27s	remaining: 9m 47s
# 700:	learn: 1.0704836	test: 1.0957818	best: 1.0957703 (699)	total: 2m 51s	remaining: 9m 22s
# 800:	learn: 1.0656384	test: 1.0954618	best: 1.0954385 (789)	total: 3m 15s	remaining: 8m 57s
# 900:	learn: 1.0610761	test: 1.0951233	best: 1.0951188 (899)	total: 3m 39s	remaining: 8m 31s
# 1000:	learn: 1.0567213	test: 1.0949014	best: 1.0948920 (996)	total: 4m 2s	remaining: 8m 4s
# 1100:	learn: 1.0523601	test: 1.0946887	best: 1.0946698 (1083)	total: 4m 27s	remaining: 7m 40s
# 1200:	learn: 1.0480151	test: 1.0946468	best: 1.0946416 (1162)	total: 4m 51s	remaining: 7m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.094641605
# bestIteration = 1162
#
# Shrink model to first 1163 iterations.
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686237	test: 1.3686235	best: 1.3686235 (0)	total: 127ms	remaining: 6m 20s
# 100:	learn: 1.1087356	test: 1.1114890	best: 1.1114890 (100)	total: 23.8s	remaining: 11m 23s
# 200:	learn: 1.0978618	test: 1.1045931	best: 1.1045931 (200)	total: 50.1s	remaining: 11m 38s
# 300:	learn: 1.0919704	test: 1.1019434	best: 1.1019434 (300)	total: 1m 15s	remaining: 11m 18s
# 400:	learn: 1.0864385	test: 1.0999662	best: 1.0999662 (400)	total: 1m 40s	remaining: 10m 51s
# 500:	learn: 1.0803737	test: 1.0983306	best: 1.0983306 (500)	total: 2m 4s	remaining: 10m 19s
# 600:	learn: 1.0749565	test: 1.0975119	best: 1.0975119 (600)	total: 2m 28s	remaining: 9m 52s
# 700:	learn: 1.0697924	test: 1.0968870	best: 1.0968870 (700)	total: 2m 52s	remaining: 9m 25s
# 800:	learn: 1.0650549	test: 1.0965736	best: 1.0965644 (798)	total: 3m 17s	remaining: 9m 2s
# 900:	learn: 1.0605755	test: 1.0963964	best: 1.0963755 (897)	total: 3m 40s	remaining: 8m 33s
# 1000:	learn: 1.0561167	test: 1.0963234	best: 1.0962623 (943)	total: 4m 4s	remaining: 8m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.096262266
# bestIteration = 943
#
# Shrink model to first 944 iterations.
# Lvl_1_Pipe_0_Mod_1_CatBoost fitting and predicting completed
# Time left 1497.1208543777466
# Blending: Optimization starts with equal weights and score -1.093726431844408
# Blending, iter 0: score = -1.0935015829113026, weights = [0.2398987 0.7601013]
# Blending, iter 1: score = -1.0935015829113026, weights = [0.2398987 0.7601013]
# No score update. Terminated
#
# Automl preset training completed in 7003.89 seconds.
# Blending: Optimization starts with equal weights and score -1.092642388283573
# Blending, iter 0: score = -1.0926343947926391, weights = [0.55320686 0.44679314]
# Blending, iter 1: score = -1.0926343947926391, weights = [0.55320686 0.44679314]
# No score update. Terminated
#
#
# y_pred_meta_lama: (99918, 4)

# %%
oof_score = log_loss(Ytrain_oh, y_pred_meta_lama.data)
print("Aggregate OOF Score: {}".format(oof_score))
# Out:
# Aggregate OOF Score: 1.0926343947926391

# %%
y_pred_final_lama = model.predict(test_df)

# %%
np.savez_compressed('./LAMA_Meta_Features.npz',
                    y_pred_meta_lama=y_pred_meta_lama.data, 
                    oof_score=oof_score,
                    y_pred_final_lama=y_pred_final_lama.data)

# %% [markdown]
# ## Create submission file

# %%
test_df = pd.read_csv("../input/tabular-playground-series-may-2021/test.csv")
submit_df = pd.DataFrame()
submit_df['id'] = test_df['id']
submit_df['Class_1'] = y_pred_final_lama.data[:,0]
submit_df['Class_2'] = y_pred_final_lama.data[:,1]
submit_df['Class_3'] = y_pred_final_lama.data[:,2]
submit_df['Class_4'] = y_pred_final_lama.data[:,3]
submit_df.head()
# Out:
#        id   Class_1   Class_2   Class_3   Class_4
# 0  100000  0.086900  0.626725  0.176691  0.109684
# 1  100001  0.082608  0.658140  0.158545  0.100708
# 2  100002  0.084615  0.640373  0.172966  0.102046
# 3  100003  0.084839  0.479351  0.341220  0.094590
# 4  100004  0.080192  0.612297  0.195844  0.111666

# %%
submit_df.to_csv("./LAMA_submission.csv", index=False)
