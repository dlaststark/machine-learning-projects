# %% [markdown]
# ## Import libraries

# %%
! pip install -U lightautoml
# Out:
# Collecting lightautoml
#   Downloading LightAutoML-0.2.14-py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 412 kB/s
# Collecting poetry-core<2.0.0,>=1.0.0
#   Downloading poetry_core-1.0.3-py2.py3-none-any.whl (424 kB)
#      |████████████████████████████████| 424 kB 3.1 MB/s
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1.48)
# Requirement already satisfied: pywavelets in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.1.1)
# Requirement already satisfied: albumentations>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.2)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.25.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.5.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.19.5)
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.24.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.11.3)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.0.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.5)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.59.0)
# Requirement already satisfied: transformers>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1)
# Collecting json2html
#   Downloading json2html-1.3.0.tar.gz (7.0 kB)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.1)
# Requirement already satisfied: cmaes in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.2)
# Collecting importlib-metadata<2.0,>=1.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting log-calls
#   Downloading log_calls-0.3.2.tar.gz (232 kB)
#      |████████████████████████████████| 232 kB 3.6 MB/s
# Requirement already satisfied: pandas>=1 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.2.3)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.7.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from lightautoml) (5.3.1)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.18.1)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.2.4)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.7.0)
# Collecting autowoe>=1.2
#   Downloading AutoWoE-1.2.5-py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 3.6 MB/s
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Collecting lightgbm<3.0,>=2.3
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 3.6 MB/s
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: imgaug>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (0.4.0)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (4.5.1.48)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (0.2.4)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (6.2.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (3.4.1)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (2021.1)
# Collecting sphinx
#   Downloading Sphinx-4.0.1-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 4.0 MB/s
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.7.1)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (2.9.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (7.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<2.0,>=1.0->lightautoml) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1->lightautoml) (2.8.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2021.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx->lightautoml) (4.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->lightautoml) (2.1.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (20.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (3.0.12)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.45)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.10.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2.25.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2021.3.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (4.14.3)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (0.8.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.7/site-packages (from gensim->lightautoml) (5.0.0)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.1.1)
# Requirement already satisfied: convertdate>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.3.2)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (0.2.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.7/site-packages (from convertdate>=2.3.0->holidays->lightautoml) (0.5.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->lightautoml) (1.1.1)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (5.0.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.4.3)
# Requirement already satisfied: cliff in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (3.7.0)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.5.8)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.7/site-packages (from sqlalchemy>=1.1.0->optuna->lightautoml) (1.0.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.1.4)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.0.4)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (5.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.0)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (1.5.0)
# Requirement already satisfied: attrs>=16.3.0 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (20.3.0)
# Requirement already satisfied: colorama>=0.3.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.4.4)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (1.8.2)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly->catboost->lightautoml) (1.3.3)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.10.0)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.10.2)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.13.1)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2.10)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers>=4->lightautoml) (7.1.2)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 5.0 MB/s
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-1.0.3-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 2.2 MB/s
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.4-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 2.8 MB/s
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (49.6.0.post20210108)
# Requirement already satisfied: docutils<0.18,>=0.14 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (0.17.1)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 1.6 MB/s
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 3.1 MB/s
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.0 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.0)
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.8.1)
# Building wheels for collected packages: efficientnet-pytorch, json2html, log-calls
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=995d34a0bb8592ae0f6845d0496637c29b0f8006008669190831b37e99dbfeff
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7595 sha256=788fda430f6e73e998056b469b791179c34e3544ee876c9acdf2cc1ff1ab6fa1
#   Stored in directory: /root/.cache/pip/wheels/e5/99/37/e1839a5ad733e0d6abb7e0419fd913e8926ddf96408239ce01
# done
#   Created wheel for log-calls: filename=log_calls-0.3.2-py3-none-any.whl size=51828 sha256=4a82ac8c74a005de85f91a7a3e19fc689c65bc023d7abc5cd79c1c48ea100b82
#   Stored in directory: /root/.cache/pip/wheels/4c/4b/a5/a5643cfdcff002bbaf88cff0e52326db94182507613b53e971
# Successfully built efficientnet-pytorch json2html log-calls
# Installing collected packages: importlib-metadata, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, imagesize, alabaster, sphinx, lightgbm, poetry-core, log-calls, json2html, efficientnet-pytorch, autowoe, lightautoml
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.2.0
#     Uninstalling lightgbm-3.2.0:
#       Successfully uninstalled lightgbm-3.2.0
# Successfully installed alabaster-0.7.12 autowoe-1.2.5 efficientnet-pytorch-0.7.1 imagesize-1.2.0 importlib-metadata-1.7.0 json2html-1.3.0 lightautoml-0.2.14 lightgbm-2.3.1 log-calls-0.3.2 poetry-core-1.0.3 snowballstemmer-2.1.0 sphinx-4.0.1 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-1.0.3 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.4

# %%
import gc
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold

from lightautoml.tasks import Task
from lightautoml.automl.presets.tabular_presets import TabularUtilizedAutoML
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## Prepare data for model training

# %%
with open("../input/tps-may-data-preprocess-v1-1/TPS_May_Dataset.txt", 'rb') as handle: 
    data = handle.read()

processed_data = pickle.loads(data)
train_df = processed_data['train_df']
test_df = processed_data['test_df']

Ytrain_oh = pd.get_dummies(train_df['target']).values

del processed_data
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Build and validate the model

# %%
FOLD = 5
N_THREADS = 4
TIMEOUT = 60 * 60 * 3

model = TabularUtilizedAutoML(
    task = Task('multiclass',), 
    timeout = TIMEOUT,
    cpu_limit = N_THREADS,
    reader_params = {'n_jobs': N_THREADS, 'cv': FOLD},
)

y_pred_meta_lama = model.fit_predict(train_df, roles={'target':'target'})
print("\n\ny_pred_meta_lama: {}".format(y_pred_meta_lama.shape))
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 42}
# Start automl preset with listed constraints:
# - time: 10799.996350765228 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (99918, 952)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 10548.319468259811 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.109103297878853
# Linear model: C = 5e-05 score = -1.1054587205864483
# Linear model: C = 0.0001 score = -1.1045777853563417
# Linear model: C = 0.0005 score = -1.1039695857045015
# Linear model: C = 0.001 score = -1.1039701832288367
# Linear model: C = 0.005 score = -1.1039672080491534
# Linear model: C = 0.01 score = -1.1039695812335568
# Linear model: C = 0.05 score = -1.1040693445882803
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1101535694991307
# Linear model: C = 5e-05 score = -1.1066544672475755
# Linear model: C = 0.0001 score = -1.1059010814729215
# Linear model: C = 0.0005 score = -1.1055695634533624
# Linear model: C = 0.001 score = -1.1055665755214943
# Linear model: C = 0.005 score = -1.105367047791992
# Linear model: C = 0.01 score = -1.10537206398784
# Linear model: C = 0.05 score = -1.10537206398784
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1097078704721839
# Linear model: C = 5e-05 score = -1.1064468269244587
# Linear model: C = 0.0001 score = -1.1057968192410956
# Linear model: C = 0.0005 score = -1.1056160923254619
# Linear model: C = 0.001 score = -1.1056147991404461
# Linear model: C = 0.005 score = -1.1056180201833241
# Linear model: C = 0.01 score = -1.105614364659451
# Linear model: C = 0.05 score = -1.1056207289965487
# Linear model: C = 0.1 score = -1.1057645521873087
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1092388314276864
# Linear model: C = 5e-05 score = -1.1058807700420532
# Linear model: C = 0.0001 score = -1.1052032486003232
# Linear model: C = 0.0005 score = -1.1047737578986458
# Linear model: C = 0.001 score = -1.1047736045098224
# Linear model: C = 0.005 score = -1.1047771221845828
# Linear model: C = 0.01 score = -1.1047749335065307
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1101059418436179
# Linear model: C = 5e-05 score = -1.1064322716790218
# Linear model: C = 0.0001 score = -1.1055704769695425
# Linear model: C = 0.0005 score = -1.1051295776620544
# Linear model: C = 0.001 score = -1.1051263738594537
# Linear model: C = 0.005 score = -1.1051366529776778
# Linear model: C = 0.01 score = -1.1051291519562438
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 10303.058282613754
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09802
# [200]	valid's multi_logloss: 1.09344
# [300]	valid's multi_logloss: 1.0927
# [400]	valid's multi_logloss: 1.09321
# Early stopping, best iteration is:
# [267]	valid's multi_logloss: 1.09256
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09844
# [200]	valid's multi_logloss: 1.09424
# [300]	valid's multi_logloss: 1.09358
# [400]	valid's multi_logloss: 1.0939
# [500]	valid's multi_logloss: 1.09456
# Early stopping, best iteration is:
# [319]	valid's multi_logloss: 1.09343
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09812
# [200]	valid's multi_logloss: 1.09413
# [300]	valid's multi_logloss: 1.09336
# [400]	valid's multi_logloss: 1.09357
# [500]	valid's multi_logloss: 1.09452
# Early stopping, best iteration is:
# [336]	valid's multi_logloss: 1.09318
# Time limit exceeded after calculating fold 2
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 1 secs
# Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.0976
# [200]	valid's multi_logloss: 1.09582
# [300]	valid's multi_logloss: 1.09756
# Early stopping, best iteration is:
# [176]	valid's multi_logloss: 1.09568
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09663
# [200]	valid's multi_logloss: 1.09971
# Early stopping, best iteration is:
# [105]	valid's multi_logloss: 1.09652
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09765
# Early stopping, best iteration is:
# [87]	valid's multi_logloss: 1.09737
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09667
# Early stopping, best iteration is:
# [95]	valid's multi_logloss: 1.09662
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.0983
# Early stopping, best iteration is:
# [82]	valid's multi_logloss: 1.09776
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09764
# [200]	valid's multi_logloss: 1.10097
# Early stopping, best iteration is:
# [105]	valid's multi_logloss: 1.09755
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3683218	test: 1.3683489	best: 1.3683489 (0)	total: 344ms	remaining: 17m 12s
# 100:	learn: 1.1103247	test: 1.1117187	best: 1.1117187 (100)	total: 29.1s	remaining: 13m 53s
# 200:	learn: 1.1013165	test: 1.1055737	best: 1.1055737 (200)	total: 1m 2s	remaining: 14m 26s
# 300:	learn: 1.0958723	test: 1.1024738	best: 1.1024738 (300)	total: 1m 32s	remaining: 13m 53s
# 400:	learn: 1.0905189	test: 1.0997298	best: 1.0997298 (400)	total: 2m 4s	remaining: 13m 27s
# 500:	learn: 1.0841271	test: 1.0969414	best: 1.0969414 (500)	total: 2m 38s	remaining: 13m 11s
# 600:	learn: 1.0788268	test: 1.0951028	best: 1.0951028 (600)	total: 3m 11s	remaining: 12m 43s
# 700:	learn: 1.0742929	test: 1.0941082	best: 1.0941041 (699)	total: 3m 42s	remaining: 12m 10s
# 800:	learn: 1.0702994	test: 1.0934292	best: 1.0934292 (800)	total: 4m 13s	remaining: 11m 36s
# 900:	learn: 1.0665148	test: 1.0927017	best: 1.0926987 (896)	total: 4m 44s	remaining: 11m 3s
# 1000:	learn: 1.0628717	test: 1.0923930	best: 1.0923820 (998)	total: 5m 15s	remaining: 10m 30s
# 1100:	learn: 1.0595011	test: 1.0922306	best: 1.0922218 (1098)	total: 5m 45s	remaining: 9m 56s
# 1200:	learn: 1.0562138	test: 1.0920874	best: 1.0920834 (1199)	total: 6m 15s	remaining: 9m 22s
# 1300:	learn: 1.0530426	test: 1.0919026	best: 1.0919026 (1300)	total: 6m 45s	remaining: 8m 49s
# 1400:	learn: 1.0499198	test: 1.0918175	best: 1.0917777 (1364)	total: 7m 15s	remaining: 8m 17s
# 1500:	learn: 1.0468386	test: 1.0917161	best: 1.0917053 (1498)	total: 7m 44s	remaining: 7m 44s
# 1600:	learn: 1.0438654	test: 1.0917324	best: 1.0916837 (1559)	total: 8m 14s	remaining: 7m 12s
# 1700:	learn: 1.0409222	test: 1.0917769	best: 1.0916782 (1655)	total: 8m 44s	remaining: 6m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091678181
# bestIteration = 1655
#
# Shrink model to first 1656 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3684075	test: 1.3684362	best: 1.3684362 (0)	total: 282ms	remaining: 14m 6s
# 100:	learn: 1.1099957	test: 1.1123460	best: 1.1123460 (100)	total: 29.3s	remaining: 14m 1s
# 200:	learn: 1.1014299	test: 1.1063915	best: 1.1063915 (200)	total: 1m 1s	remaining: 14m 18s
# 300:	learn: 1.0961421	test: 1.1033602	best: 1.1033602 (300)	total: 1m 33s	remaining: 13m 57s
# 400:	learn: 1.0907319	test: 1.1006580	best: 1.1006580 (400)	total: 2m 5s	remaining: 13m 33s
# 500:	learn: 1.0840924	test: 1.0975302	best: 1.0975302 (500)	total: 2m 39s	remaining: 13m 16s
# 600:	learn: 1.0787008	test: 1.0957895	best: 1.0957895 (600)	total: 3m 11s	remaining: 12m 43s
# 700:	learn: 1.0740956	test: 1.0947171	best: 1.0947171 (700)	total: 3m 43s	remaining: 12m 13s
# 800:	learn: 1.0700482	test: 1.0939926	best: 1.0939887 (799)	total: 4m 15s	remaining: 11m 40s
# 900:	learn: 1.0661717	test: 1.0936193	best: 1.0936193 (900)	total: 4m 47s	remaining: 11m 8s
# 1000:	learn: 1.0625551	test: 1.0933774	best: 1.0933774 (1000)	total: 5m 18s	remaining: 10m 35s
# 1100:	learn: 1.0592039	test: 1.0931984	best: 1.0931965 (1099)	total: 5m 48s	remaining: 10m 1s
# 1200:	learn: 1.0558815	test: 1.0931626	best: 1.0931258 (1176)	total: 6m 18s	remaining: 9m 27s
# 1300:	learn: 1.0526812	test: 1.0929526	best: 1.0929438 (1295)	total: 6m 48s	remaining: 8m 53s
# 1400:	learn: 1.0496102	test: 1.0928542	best: 1.0928353 (1373)	total: 7m 17s	remaining: 8m 19s
# 1500:	learn: 1.0466182	test: 1.0927892	best: 1.0927620 (1480)	total: 7m 48s	remaining: 7m 47s
# 1600:	learn: 1.0436648	test: 1.0927093	best: 1.0926576 (1587)	total: 8m 17s	remaining: 7m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092657641
# bestIteration = 1587
#
# Shrink model to first 1588 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3684200	test: 1.3684252	best: 1.3684252 (0)	total: 286ms	remaining: 14m 17s
# 100:	learn: 1.1101393	test: 1.1117243	best: 1.1117243 (100)	total: 29.4s	remaining: 14m 3s
# 200:	learn: 1.1011221	test: 1.1054432	best: 1.1054432 (200)	total: 1m 3s	remaining: 14m 39s
# 300:	learn: 1.0958992	test: 1.1025469	best: 1.1025469 (300)	total: 1m 35s	remaining: 14m 13s
# 400:	learn: 1.0903304	test: 1.0995877	best: 1.0995877 (400)	total: 2m 7s	remaining: 13m 44s
# 500:	learn: 1.0838712	test: 1.0967259	best: 1.0967259 (500)	total: 2m 40s	remaining: 13m 21s
# 600:	learn: 1.0787040	test: 1.0949763	best: 1.0949763 (600)	total: 3m 12s	remaining: 12m 49s
# 700:	learn: 1.0743246	test: 1.0939257	best: 1.0939257 (700)	total: 3m 42s	remaining: 12m 9s
# 800:	learn: 1.0703036	test: 1.0931676	best: 1.0931676 (800)	total: 4m 12s	remaining: 11m 34s
# 900:	learn: 1.0663994	test: 1.0926141	best: 1.0926141 (900)	total: 4m 43s	remaining: 10m 59s
# 1000:	learn: 1.0627029	test: 1.0923074	best: 1.0922746 (997)	total: 5m 13s	remaining: 10m 25s
# 1100:	learn: 1.0592748	test: 1.0920409	best: 1.0920323 (1092)	total: 5m 41s	remaining: 9m 49s
# 1200:	learn: 1.0559616	test: 1.0919371	best: 1.0919269 (1199)	total: 6m 11s	remaining: 9m 15s
# 1300:	learn: 1.0527999	test: 1.0918004	best: 1.0917937 (1277)	total: 6m 41s	remaining: 8m 43s
# 1400:	learn: 1.0497014	test: 1.0917802	best: 1.0916997 (1361)	total: 7m 10s	remaining: 8m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091699689
# bestIteration = 1361
#
# Shrink model to first 1362 iterations.
# Time limit exceeded after calculating fold 2
# Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# Optuna may run 1 secs
# Start fitting Lvl_0_Pipe_1_Mod_3_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3684079	test: 1.3684118	best: 1.3684118 (0)	total: 262ms	remaining: 13m 6s
# 100:	learn: 1.1115094	test: 1.1119702	best: 1.1119702 (100)	total: 27.4s	remaining: 13m 6s
# 200:	learn: 1.1043802	test: 1.1062400	best: 1.1062400 (200)	total: 57.4s	remaining: 13m 19s
# 300:	learn: 1.1003718	test: 1.1032463	best: 1.1032463 (300)	total: 1m 26s	remaining: 12m 52s
# 400:	learn: 1.0964332	test: 1.1004847	best: 1.1004847 (400)	total: 1m 54s	remaining: 12m 22s
# 500:	learn: 1.0921653	test: 1.0977054	best: 1.0977054 (500)	total: 2m 24s	remaining: 12m 1s
# 600:	learn: 1.0889103	test: 1.0958915	best: 1.0958915 (600)	total: 2m 52s	remaining: 11m 30s
# 700:	learn: 1.0863396	test: 1.0946596	best: 1.0946596 (700)	total: 3m 20s	remaining: 10m 58s
# 800:	learn: 1.0841087	test: 1.0937596	best: 1.0937596 (800)	total: 3m 48s	remaining: 10m 27s
# 900:	learn: 1.0821080	test: 1.0930015	best: 1.0930015 (900)	total: 4m 16s	remaining: 9m 57s
# 1000:	learn: 1.0803274	test: 1.0924833	best: 1.0924833 (1000)	total: 4m 43s	remaining: 9m 25s
# 1100:	learn: 1.0786394	test: 1.0920447	best: 1.0920447 (1100)	total: 5m 10s	remaining: 8m 54s
# 1200:	learn: 1.0770856	test: 1.0917996	best: 1.0917996 (1200)	total: 5m 37s	remaining: 8m 26s
# 1300:	learn: 1.0756152	test: 1.0915986	best: 1.0915986 (1300)	total: 6m 4s	remaining: 7m 56s
# 1400:	learn: 1.0742111	test: 1.0913406	best: 1.0913386 (1394)	total: 6m 31s	remaining: 7m 27s
# 1500:	learn: 1.0729677	test: 1.0911715	best: 1.0911704 (1499)	total: 6m 58s	remaining: 6m 57s
# 1600:	learn: 1.0717282	test: 1.0909868	best: 1.0909812 (1594)	total: 7m 24s	remaining: 6m 28s
# 1700:	learn: 1.0705203	test: 1.0909231	best: 1.0909231 (1700)	total: 7m 50s	remaining: 5m 59s
# 1800:	learn: 1.0693413	test: 1.0908096	best: 1.0908078 (1779)	total: 8m 16s	remaining: 5m 30s
# 1900:	learn: 1.0681650	test: 1.0906857	best: 1.0906857 (1900)	total: 8m 43s	remaining: 5m 2s
# 2000:	learn: 1.0669794	test: 1.0906544	best: 1.0906456 (1962)	total: 9m 9s	remaining: 4m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.090645622
# bestIteration = 1962
#
# Shrink model to first 1963 iterations.
# Lvl_0_Pipe_1_Mod_3_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_3_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3684079	test: 1.3684118	best: 1.3684118 (0)	total: 248ms	remaining: 12m 23s
# 100:	learn: 1.1115094	test: 1.1119702	best: 1.1119702 (100)	total: 26.9s	remaining: 12m 52s
# 200:	learn: 1.1043802	test: 1.1062400	best: 1.1062400 (200)	total: 56.5s	remaining: 13m 6s
# 300:	learn: 1.1003718	test: 1.1032463	best: 1.1032463 (300)	total: 1m 25s	remaining: 12m 43s
# 400:	learn: 1.0964332	test: 1.1004847	best: 1.1004847 (400)	total: 1m 54s	remaining: 12m 21s
# 500:	learn: 1.0921653	test: 1.0977054	best: 1.0977054 (500)	total: 2m 24s	remaining: 11m 58s
# 600:	learn: 1.0889103	test: 1.0958915	best: 1.0958915 (600)	total: 2m 52s	remaining: 11m 30s
# 700:	learn: 1.0863396	test: 1.0946596	best: 1.0946596 (700)	total: 3m 20s	remaining: 10m 57s
# 800:	learn: 1.0841087	test: 1.0937596	best: 1.0937596 (800)	total: 3m 48s	remaining: 10m 27s
# 900:	learn: 1.0821080	test: 1.0930015	best: 1.0930015 (900)	total: 4m 16s	remaining: 9m 56s
# 1000:	learn: 1.0803274	test: 1.0924833	best: 1.0924833 (1000)	total: 4m 43s	remaining: 9m 25s
# 1100:	learn: 1.0786394	test: 1.0920447	best: 1.0920447 (1100)	total: 5m 11s	remaining: 8m 56s
# 1200:	learn: 1.0770856	test: 1.0917996	best: 1.0917996 (1200)	total: 5m 39s	remaining: 8m 27s
# 1300:	learn: 1.0756152	test: 1.0915986	best: 1.0915986 (1300)	total: 6m 5s	remaining: 7m 57s
# 1400:	learn: 1.0742111	test: 1.0913406	best: 1.0913386 (1394)	total: 6m 32s	remaining: 7m 28s
# 1500:	learn: 1.0729677	test: 1.0911715	best: 1.0911704 (1499)	total: 6m 59s	remaining: 6m 59s
# 1600:	learn: 1.0717282	test: 1.0909868	best: 1.0909812 (1594)	total: 7m 26s	remaining: 6m 30s
# 1700:	learn: 1.0705203	test: 1.0909231	best: 1.0909231 (1700)	total: 7m 53s	remaining: 6m 1s
# 1800:	learn: 1.0693413	test: 1.0908096	best: 1.0908078 (1779)	total: 8m 19s	remaining: 5m 32s
# 1900:	learn: 1.0681650	test: 1.0906857	best: 1.0906857 (1900)	total: 8m 46s	remaining: 5m 4s
# 2000:	learn: 1.0669794	test: 1.0906544	best: 1.0906456 (1962)	total: 9m 13s	remaining: 4m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.090645622
# bestIteration = 1962
#
# Shrink model to first 1963 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3684337	test: 1.3684610	best: 1.3684610 (0)	total: 264ms	remaining: 13m 10s
# 100:	learn: 1.1115617	test: 1.1128819	best: 1.1128819 (100)	total: 27.7s	remaining: 13m 15s
# 200:	learn: 1.1045515	test: 1.1069728	best: 1.1069728 (200)	total: 57.1s	remaining: 13m 15s
# 300:	learn: 1.1005689	test: 1.1040219	best: 1.1040219 (300)	total: 1m 25s	remaining: 12m 47s
# 400:	learn: 1.0966078	test: 1.1010365	best: 1.1010365 (400)	total: 1m 54s	remaining: 12m 20s
# 500:	learn: 1.0921743	test: 1.0979814	best: 1.0979814 (500)	total: 2m 23s	remaining: 11m 54s
# 600:	learn: 1.0888249	test: 1.0961712	best: 1.0961633 (599)	total: 2m 51s	remaining: 11m 25s
# 700:	learn: 1.0862074	test: 1.0950084	best: 1.0950084 (700)	total: 3m 19s	remaining: 10m 54s
# 800:	learn: 1.0840433	test: 1.0942189	best: 1.0942169 (797)	total: 3m 47s	remaining: 10m 24s
# 900:	learn: 1.0821098	test: 1.0936254	best: 1.0936254 (900)	total: 4m 15s	remaining: 9m 54s
# 1000:	learn: 1.0803427	test: 1.0930629	best: 1.0930629 (1000)	total: 4m 42s	remaining: 9m 25s
# 1100:	learn: 1.0787309	test: 1.0926633	best: 1.0926633 (1100)	total: 5m 10s	remaining: 8m 55s
# 1200:	learn: 1.0772500	test: 1.0923752	best: 1.0923752 (1200)	total: 5m 38s	remaining: 8m 26s
# 1300:	learn: 1.0758566	test: 1.0922985	best: 1.0922919 (1289)	total: 6m 6s	remaining: 7m 58s
# 1400:	learn: 1.0745454	test: 1.0921327	best: 1.0921312 (1388)	total: 6m 33s	remaining: 7m 28s
# 1500:	learn: 1.0733282	test: 1.0920066	best: 1.0920066 (1500)	total: 6m 59s	remaining: 6m 59s
# 1600:	learn: 1.0720939	test: 1.0918818	best: 1.0918790 (1593)	total: 7m 26s	remaining: 6m 29s
# 1700:	learn: 1.0709395	test: 1.0918389	best: 1.0918322 (1696)	total: 7m 53s	remaining: 6m 1s
# 1800:	learn: 1.0698372	test: 1.0917700	best: 1.0917700 (1800)	total: 8m 20s	remaining: 5m 33s
# 1900:	learn: 1.0687568	test: 1.0917728	best: 1.0917401 (1874)	total: 8m 47s	remaining: 5m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091740065
# bestIteration = 1874
#
# Shrink model to first 1875 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3684460	test: 1.3684505	best: 1.3684505 (0)	total: 269ms	remaining: 13m 28s
# 100:	learn: 1.1119747	test: 1.1127030	best: 1.1127030 (100)	total: 26.6s	remaining: 12m 43s
# 200:	learn: 1.1045876	test: 1.1066263	best: 1.1066263 (200)	total: 57.1s	remaining: 13m 15s
# 300:	learn: 1.1006415	test: 1.1034729	best: 1.1034729 (300)	total: 1m 24s	remaining: 12m 39s
# 400:	learn: 1.0968418	test: 1.1006949	best: 1.1006949 (400)	total: 1m 52s	remaining: 12m 11s
# 500:	learn: 1.0925058	test: 1.0976902	best: 1.0976902 (500)	total: 2m 23s	remaining: 11m 54s
# 600:	learn: 1.0891902	test: 1.0958505	best: 1.0958505 (600)	total: 2m 52s	remaining: 11m 27s
# 700:	learn: 1.0865891	test: 1.0946083	best: 1.0946083 (700)	total: 3m 20s	remaining: 10m 58s
# 800:	learn: 1.0843464	test: 1.0936964	best: 1.0936964 (800)	total: 3m 48s	remaining: 10m 27s
# 900:	learn: 1.0824194	test: 1.0930709	best: 1.0930709 (900)	total: 4m 15s	remaining: 9m 55s
# 1000:	learn: 1.0806035	test: 1.0926074	best: 1.0926074 (1000)	total: 4m 43s	remaining: 9m 25s
# 1100:	learn: 1.0790038	test: 1.0922003	best: 1.0922003 (1100)	total: 5m 10s	remaining: 8m 56s
# 1200:	learn: 1.0775391	test: 1.0919249	best: 1.0919249 (1200)	total: 5m 37s	remaining: 8m 24s
# 1300:	learn: 1.0761128	test: 1.0917418	best: 1.0917262 (1290)	total: 6m 3s	remaining: 7m 54s
# 1400:	learn: 1.0747778	test: 1.0916024	best: 1.0916024 (1400)	total: 6m 29s	remaining: 7m 24s
# 1500:	learn: 1.0734372	test: 1.0914847	best: 1.0914847 (1500)	total: 6m 55s	remaining: 6m 54s
# 1600:	learn: 1.0722029	test: 1.0913618	best: 1.0913618 (1600)	total: 7m 21s	remaining: 6m 25s
# 1700:	learn: 1.0709988	test: 1.0912534	best: 1.0912400 (1682)	total: 7m 47s	remaining: 5m 57s
# 1800:	learn: 1.0697739	test: 1.0911573	best: 1.0911573 (1800)	total: 8m 15s	remaining: 5m 29s
# 1900:	learn: 1.0685982	test: 1.0910283	best: 1.0910283 (1900)	total: 8m 40s	remaining: 5m 1s
# 2000:	learn: 1.0674495	test: 1.0909435	best: 1.0909435 (2000)	total: 9m 7s	remaining: 4m 33s
# 2100:	learn: 1.0663580	test: 1.0909076	best: 1.0908997 (2066)	total: 9m 34s	remaining: 4m 5s
# 2200:	learn: 1.0652624	test: 1.0909426	best: 1.0908976 (2130)	total: 10m 1s	remaining: 3m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.090897612
# bestIteration = 2130
#
# Shrink model to first 2131 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685923	test: 1.3686013	best: 1.3686013 (0)	total: 240ms	remaining: 11m 58s
# 100:	learn: 1.1116943	test: 1.1121373	best: 1.1121373 (100)	total: 27.9s	remaining: 13m 21s
# 200:	learn: 1.1045408	test: 1.1063611	best: 1.1063611 (200)	total: 58s	remaining: 13m 27s
# 300:	learn: 1.1002210	test: 1.1033322	best: 1.1033322 (300)	total: 1m 26s	remaining: 12m 54s
# 400:	learn: 1.0962522	test: 1.1007829	best: 1.1007829 (400)	total: 1m 55s	remaining: 12m 29s
# 500:	learn: 1.0919372	test: 1.0981240	best: 1.0981240 (500)	total: 2m 24s	remaining: 12m 3s
# 600:	learn: 1.0886430	test: 1.0964840	best: 1.0964840 (600)	total: 2m 53s	remaining: 11m 33s
# 700:	learn: 1.0860451	test: 1.0954261	best: 1.0954231 (699)	total: 3m 22s	remaining: 11m 2s
# 800:	learn: 1.0838150	test: 1.0947128	best: 1.0947128 (800)	total: 3m 49s	remaining: 10m 30s
# 900:	learn: 1.0818266	test: 1.0941860	best: 1.0941860 (900)	total: 4m 17s	remaining: 10m
# 1000:	learn: 1.0800234	test: 1.0938206	best: 1.0938206 (1000)	total: 4m 45s	remaining: 9m 31s
# 1100:	learn: 1.0783412	test: 1.0935736	best: 1.0935708 (1098)	total: 5m 13s	remaining: 9m
# 1200:	learn: 1.0768606	test: 1.0933534	best: 1.0933522 (1199)	total: 5m 40s	remaining: 8m 30s
# 1300:	learn: 1.0754286	test: 1.0931636	best: 1.0931635 (1291)	total: 6m 8s	remaining: 8m 1s
# 1400:	learn: 1.0740056	test: 1.0931036	best: 1.0930991 (1397)	total: 6m 35s	remaining: 7m 31s
# 1500:	learn: 1.0727239	test: 1.0930004	best: 1.0930004 (1500)	total: 7m 1s	remaining: 7m
# 1600:	learn: 1.0714508	test: 1.0928756	best: 1.0928751 (1599)	total: 7m 27s	remaining: 6m 31s
# 1700:	learn: 1.0702547	test: 1.0928402	best: 1.0928196 (1688)	total: 7m 53s	remaining: 6m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092819615
# bestIteration = 1688
#
# Shrink model to first 1689 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3686009	test: 1.3685991	best: 1.3685991 (0)	total: 292ms	remaining: 14m 36s
# 100:	learn: 1.1116476	test: 1.1130055	best: 1.1130055 (100)	total: 26.6s	remaining: 12m 42s
# 200:	learn: 1.1043692	test: 1.1071036	best: 1.1071036 (200)	total: 56.8s	remaining: 13m 11s
# 300:	learn: 1.1003718	test: 1.1041243	best: 1.1041243 (300)	total: 1m 25s	remaining: 12m 42s
# 400:	learn: 1.0962027	test: 1.1011195	best: 1.1011195 (400)	total: 1m 54s	remaining: 12m 19s
# 500:	learn: 1.0919232	test: 1.0984155	best: 1.0984155 (500)	total: 2m 24s	remaining: 11m 59s
# 600:	learn: 1.0887542	test: 1.0967561	best: 1.0967561 (600)	total: 2m 52s	remaining: 11m 29s
# 700:	learn: 1.0862087	test: 1.0956092	best: 1.0956092 (700)	total: 3m 21s	remaining: 11m
# 800:	learn: 1.0839368	test: 1.0948866	best: 1.0948864 (798)	total: 3m 49s	remaining: 10m 29s
# 900:	learn: 1.0819715	test: 1.0943648	best: 1.0943648 (900)	total: 4m 16s	remaining: 9m 58s
# 1000:	learn: 1.0801656	test: 1.0938926	best: 1.0938925 (998)	total: 4m 45s	remaining: 9m 29s
# 1100:	learn: 1.0785410	test: 1.0935291	best: 1.0935291 (1100)	total: 5m 12s	remaining: 8m 59s
# 1200:	learn: 1.0770347	test: 1.0932823	best: 1.0932643 (1181)	total: 5m 39s	remaining: 8m 29s
# 1300:	learn: 1.0755444	test: 1.0930755	best: 1.0930749 (1299)	total: 6m 6s	remaining: 7m 58s
# 1400:	learn: 1.0741519	test: 1.0930075	best: 1.0930075 (1400)	total: 6m 33s	remaining: 7m 29s
# 1500:	learn: 1.0728532	test: 1.0929188	best: 1.0928915 (1464)	total: 7m	remaining: 6m 59s
# 1600:	learn: 1.0716484	test: 1.0928290	best: 1.0928160 (1590)	total: 7m 27s	remaining: 6m 30s
# 1700:	learn: 1.0704860	test: 1.0926903	best: 1.0926835 (1697)	total: 7m 53s	remaining: 6m 1s
# 1800:	learn: 1.0693291	test: 1.0926492	best: 1.0926332 (1782)	total: 8m 19s	remaining: 5m 32s
# 1900:	learn: 1.0681597	test: 1.0926083	best: 1.0926014 (1841)	total: 8m 45s	remaining: 5m 3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092601448
# bestIteration = 1841
#
# Shrink model to first 1842 iterations.
# Lvl_0_Pipe_1_Mod_3_CatBoost fitting and predicting completed
# Time left 2759.3180816173553
# Time limit exceeded in one of the tasks. AutoML will blend level 1 models.
# Try to set higher time limits or use Profiler to find bottleneck and optimize Pipelines settings
# Blending: Optimization starts with equal weights and score -1.0936596657723716
# Blending, iter 0: score = -1.0916682430556148, weights = [0.         0.18166937 0.         0.06318517 0.7551455 ]
# Blending, iter 1: score = -1.0916622045354971, weights = [0.        0.1987998 0.        0.        0.8012002]
# Blending, iter 2: score = -1.0916622045354971, weights = [0.        0.1987998 0.        0.        0.8012002]
# No score update. Terminated
#
# Automl preset training completed in 8046.98 seconds.
#
#
# y_pred_meta_lama: (99918, 4)

# %%
oof_score = log_loss(Ytrain_oh, y_pred_meta_lama.data)
print("Aggregate OOF Score: {}".format(oof_score))
# Out:
# Aggregate OOF Score: 1.0916622045354971

# %%
y_pred_final_lama = model.predict(test_df)

# %%
np.savez_compressed('./LAMA_Meta_Features.npz',
                    y_pred_meta_lama=y_pred_meta_lama.data, 
                    oof_score=oof_score,
                    y_pred_final_lama=y_pred_final_lama.data)

# %% [markdown]
# ## Create submission file

# %%
test_df = pd.read_csv("../input/tabular-playground-series-may-2021/test.csv")
submit_df = pd.DataFrame()
submit_df['id'] = test_df['id']
submit_df['Class_1'] = y_pred_final_lama.data[:,0]
submit_df['Class_2'] = y_pred_final_lama.data[:,1]
submit_df['Class_3'] = y_pred_final_lama.data[:,2]
submit_df['Class_4'] = y_pred_final_lama.data[:,3]
submit_df.head()
# Out:
#        id   Class_1   Class_2   Class_3   Class_4
# 0  100000  0.090379  0.617119  0.171554  0.120948
# 1  100001  0.080674  0.679363  0.152545  0.087418
# 2  100002  0.084258  0.635151  0.175146  0.105444
# 3  100003  0.084731  0.538044  0.272111  0.105115
# 4  100004  0.075097  0.614920  0.190607  0.119376

# %%
submit_df.to_csv("./LAMA_submission.csv", index=False)
