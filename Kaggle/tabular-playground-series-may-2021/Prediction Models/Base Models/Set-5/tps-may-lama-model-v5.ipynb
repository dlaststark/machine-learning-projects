# %% [markdown]
# ## Import libraries

# %%
! pip install -U lightautoml
# Out:
# Collecting lightautoml
#   Downloading LightAutoML-0.2.14-py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 4.5 MB/s
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1.48)
# Collecting importlib-metadata<2.0,>=1.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: cmaes in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.2)
# Collecting poetry-core<2.0.0,>=1.0.0
#   Downloading poetry_core-1.0.3-py2.py3-none-any.whl (424 kB)
#      |████████████████████████████████| 424 kB 7.5 MB/s
# Requirement already satisfied: transformers>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1)
# Collecting lightgbm<3.0,>=2.3
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 8.3 MB/s
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.2.4)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.18.1)
# Requirement already satisfied: pywavelets in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.1.1)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.7.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from lightautoml) (5.3.1)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.19.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.5)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.0.1)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.25.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.5.4)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.24.1)
# Collecting json2html
#   Downloading json2html-1.3.0.tar.gz (7.0 kB)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.1)
# Collecting log-calls
#   Downloading log_calls-0.3.2.tar.gz (232 kB)
#      |████████████████████████████████| 232 kB 20.4 MB/s
# Requirement already satisfied: pandas>=1 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.2.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.59.0)
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Collecting autowoe>=1.2
#   Downloading AutoWoE-1.2.5-py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 21.7 MB/s
# Requirement already satisfied: albumentations>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.11.3)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.7.0)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (4.5.1.48)
# Requirement already satisfied: imgaug>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (0.4.0)
# Collecting sphinx
#   Downloading Sphinx-4.0.1-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 19.2 MB/s
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (2021.1)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (0.2.4)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (6.2.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (3.4.1)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (2.9.0)
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.7.1)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (7.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<2.0,>=1.0->lightautoml) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1->lightautoml) (2.8.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2021.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (0.10.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx->lightautoml) (4.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->lightautoml) (2.1.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.6)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.10.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2021.3.17)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (20.9)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.45)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2.25.1)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (4.14.3)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (0.8.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.7/site-packages (from gensim->lightautoml) (5.0.0)
# Requirement already satisfied: convertdate>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.3.2)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.1.1)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (0.2.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.7/site-packages (from convertdate>=2.3.0->holidays->lightautoml) (0.5.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->lightautoml) (1.1.1)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.5.8)
# Requirement already satisfied: cliff in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (3.7.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.4.3)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (5.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.7/site-packages (from sqlalchemy>=1.1.0->optuna->lightautoml) (1.0.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.1.4)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.0.4)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (1.5.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (5.5.1)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.2.5)
# Requirement already satisfied: colorama>=0.3.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.4.4)
# Requirement already satisfied: attrs>=16.3.0 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (20.3.0)
# Requirement already satisfied: pyperclip>=1.6 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (1.8.2)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly->catboost->lightautoml) (1.3.3)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.10.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.13.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.10.2)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2.10)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers>=4->lightautoml) (7.1.2)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.0)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.7 MB/s
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.4 MB/s
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.8.1)
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-1.0.3-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 4.0 MB/s
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (49.6.0.post20210108)
# Requirement already satisfied: docutils<0.18,>=0.14 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (0.17.1)
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.4-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 7.1 MB/s
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 60.4 MB/s
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.7 MB/s
# Building wheels for collected packages: efficientnet-pytorch, json2html, log-calls
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=ece8b1408ec9cb270b9ad140b0e91eded2af877ef19a9bfe2d9a272b159d2699
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7595 sha256=a6c416f2070397d8b6e8638beeeb83c1c097c7df45f84b44d0958f58f2811cdb
#   Stored in directory: /root/.cache/pip/wheels/e5/99/37/e1839a5ad733e0d6abb7e0419fd913e8926ddf96408239ce01
# done
#   Created wheel for log-calls: filename=log_calls-0.3.2-py3-none-any.whl size=51828 sha256=72dc32f27cbde0634cfe74b1e930f1d8769bd8f748ce5670e37da18df8053400
#   Stored in directory: /root/.cache/pip/wheels/4c/4b/a5/a5643cfdcff002bbaf88cff0e52326db94182507613b53e971
# Successfully built efficientnet-pytorch json2html log-calls
# Installing collected packages: importlib-metadata, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, imagesize, alabaster, sphinx, lightgbm, poetry-core, log-calls, json2html, efficientnet-pytorch, autowoe, lightautoml
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.2.0
#     Uninstalling lightgbm-3.2.0:
#       Successfully uninstalled lightgbm-3.2.0
# Successfully installed alabaster-0.7.12 autowoe-1.2.5 efficientnet-pytorch-0.7.1 imagesize-1.2.0 importlib-metadata-1.7.0 json2html-1.3.0 lightautoml-0.2.14 lightgbm-2.3.1 log-calls-0.3.2 poetry-core-1.0.3 snowballstemmer-2.1.0 sphinx-4.0.1 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-1.0.3 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.4

# %%
import gc
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold

from lightautoml.tasks import Task
from lightautoml.automl.presets.tabular_presets import TabularUtilizedAutoML
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## Prepare data for model training

# %%
with open("../input/tps-may-data-preprocess-v5/TPS_May_Dataset.txt", 'rb') as handle: 
    data = handle.read()

processed_data = pickle.loads(data)
train_df = processed_data['train_df']
test_df = processed_data['test_df']

Ytrain_oh = pd.get_dummies(train_df['target']).values

del processed_data
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Build and validate the model

# %%
FOLD = 5
N_THREADS = 4
TIMEOUT = 60 * 60 * 3.5

model = TabularUtilizedAutoML(
    task = Task('multiclass',), 
    timeout = TIMEOUT,
    cpu_limit = N_THREADS,
    general_params = {'use_algos': [['linear_l2', 'cb_tuned', 'lgb_tuned'], ['cb', 'lgb']]},
    reader_params = {'n_jobs': N_THREADS, 'cv': FOLD},
)

y_pred_meta_lama = model.fit_predict(train_df, roles={'target':'target'})
print("\n\ny_pred_meta_lama: {}".format(y_pred_meta_lama.shape))
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 42}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'cb_tuned', 'lgb_tuned'], ['cb', 'lgb']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 12599.994782686234 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (99918, 101)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 12555.3079931736 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1109017351324602
# Linear model: C = 5e-05 score = -1.1065233861990242
# Linear model: C = 0.0001 score = -1.105628559517982
# Linear model: C = 0.0005 score = -1.1051174248564986
# Linear model: C = 0.001 score = -1.1051489633431224
# Linear model: C = 0.005 score = -1.1052030294856208
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1113234253181181
# Linear model: C = 5e-05 score = -1.1074530847543615
# Linear model: C = 0.0001 score = -1.1067337716330854
# Linear model: C = 0.0005 score = -1.1061471495180846
# Linear model: C = 0.001 score = -1.1060557068632044
# Linear model: C = 0.005 score = -1.10597391386969
# Linear model: C = 0.01 score = -1.10597391386969
# Linear model: C = 0.05 score = -1.10597391386969
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1111232582927109
# Linear model: C = 5e-05 score = -1.1071636948668904
# Linear model: C = 0.0001 score = -1.1064829366062405
# Linear model: C = 0.0005 score = -1.1062506241157197
# Linear model: C = 0.001 score = -1.106324988003489
# Linear model: C = 0.005 score = -1.1063256952561158
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.111247894830522
# Linear model: C = 5e-05 score = -1.1073589033296156
# Linear model: C = 0.0001 score = -1.1066525040489592
# Linear model: C = 0.0005 score = -1.1062314177036094
# Linear model: C = 0.001 score = -1.1062180089776368
# Linear model: C = 0.005 score = -1.1062099294551397
# Linear model: C = 0.01 score = -1.1062099294551397
# Linear model: C = 0.05 score = -1.1062099294551397
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1109820404419257
# Linear model: C = 5e-05 score = -1.106964904960555
# Linear model: C = 0.0001 score = -1.1062653772553446
# Linear model: C = 0.0005 score = -1.1059906632863967
# Linear model: C = 0.001 score = -1.1060631422980594
# Linear model: C = 0.005 score = -1.1061346248595354
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 12525.636429309845
# Optuna may run 2075.0147613581858 secs
# Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09925
# [200]	valid's multi_logloss: 1.09704
# [300]	valid's multi_logloss: 1.0989
# Early stopping, best iteration is:
# [196]	valid's multi_logloss: 1.09702
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09914
# [200]	valid's multi_logloss: 1.0969
# [300]	valid's multi_logloss: 1.09801
# Early stopping, best iteration is:
# [194]	valid's multi_logloss: 1.09682
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10007
# [200]	valid's multi_logloss: 1.09624
# [300]	valid's multi_logloss: 1.09555
# [400]	valid's multi_logloss: 1.09626
# Early stopping, best iteration is:
# [278]	valid's multi_logloss: 1.09548
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10029
# [200]	valid's multi_logloss: 1.09645
# [300]	valid's multi_logloss: 1.09616
# [400]	valid's multi_logloss: 1.09635
# Early stopping, best iteration is:
# [254]	valid's multi_logloss: 1.09576
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09997
# [200]	valid's multi_logloss: 1.09891
# [300]	valid's multi_logloss: 1.10106
# Early stopping, best iteration is:
# [168]	valid's multi_logloss: 1.09843
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.097
# [200]	valid's multi_logloss: 1.0963
# Early stopping, best iteration is:
# [171]	valid's multi_logloss: 1.09574
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09752
# [200]	valid's multi_logloss: 1.09729
# Early stopping, best iteration is:
# [137]	valid's multi_logloss: 1.0966
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09798
# [200]	valid's multi_logloss: 1.09754
# Early stopping, best iteration is:
# [143]	valid's multi_logloss: 1.09691
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09961
# [200]	valid's multi_logloss: 1.10026
# Early stopping, best iteration is:
# [135]	valid's multi_logloss: 1.09904
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09881
# [200]	valid's multi_logloss: 1.09806
# Early stopping, best iteration is:
# [154]	valid's multi_logloss: 1.09798
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 5408.074235880375 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686185	test: 1.3686254	best: 1.3686254 (0)	total: 101ms	remaining: 5m 3s
# 100:	learn: 1.1097440	test: 1.1107771	best: 1.1107771 (100)	total: 4.28s	remaining: 2m 2s
# 200:	learn: 1.1009662	test: 1.1037322	best: 1.1037322 (200)	total: 8.42s	remaining: 1m 57s
# 300:	learn: 1.0961917	test: 1.1002595	best: 1.1002595 (300)	total: 12.5s	remaining: 1m 52s
# 400:	learn: 1.0924508	test: 1.0978418	best: 1.0978418 (400)	total: 16.9s	remaining: 1m 49s
# 500:	learn: 1.0890851	test: 1.0960643	best: 1.0960643 (500)	total: 20.8s	remaining: 1m 43s
# 600:	learn: 1.0862814	test: 1.0948824	best: 1.0948824 (600)	total: 24.8s	remaining: 1m 38s
# 700:	learn: 1.0839259	test: 1.0941092	best: 1.0941092 (700)	total: 28.7s	remaining: 1m 34s
# 800:	learn: 1.0817316	test: 1.0935069	best: 1.0935069 (800)	total: 32.8s	remaining: 1m 29s
# 900:	learn: 1.0797332	test: 1.0929637	best: 1.0929634 (899)	total: 36.7s	remaining: 1m 25s
# 1000:	learn: 1.0778385	test: 1.0926665	best: 1.0926665 (1000)	total: 40.6s	remaining: 1m 21s
# 1100:	learn: 1.0760197	test: 1.0923998	best: 1.0923998 (1100)	total: 44.6s	remaining: 1m 16s
# 1200:	learn: 1.0743431	test: 1.0922049	best: 1.0922049 (1200)	total: 48.8s	remaining: 1m 13s
# 1300:	learn: 1.0727221	test: 1.0919935	best: 1.0919905 (1299)	total: 52.7s	remaining: 1m 8s
# 1400:	learn: 1.0711467	test: 1.0919216	best: 1.0919109 (1394)	total: 56.6s	remaining: 1m 4s
# 1500:	learn: 1.0696090	test: 1.0918673	best: 1.0918526 (1498)	total: 1m	remaining: 1m
# 1600:	learn: 1.0680632	test: 1.0918351	best: 1.0918164 (1588)	total: 1m 4s	remaining: 56.2s
# 1700:	learn: 1.0666051	test: 1.0917585	best: 1.0917488 (1689)	total: 1m 8s	remaining: 52.2s
# 1800:	learn: 1.0650669	test: 1.0916819	best: 1.0916751 (1786)	total: 1m 12s	remaining: 48.1s
# 1900:	learn: 1.0635749	test: 1.0917015	best: 1.0916507 (1848)	total: 1m 16s	remaining: 44s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091650741
# bestIteration = 1848
#
# Shrink model to first 1849 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685833	test: 1.3686005	best: 1.3686005 (0)	total: 44.7ms	remaining: 2m 14s
# 100:	learn: 1.1070680	test: 1.1095558	best: 1.1095558 (100)	total: 4.97s	remaining: 2m 22s
# 200:	learn: 1.0966495	test: 1.1024350	best: 1.1024350 (200)	total: 9.54s	remaining: 2m 12s
# 300:	learn: 1.0903263	test: 1.0991761	best: 1.0991761 (300)	total: 13.9s	remaining: 2m 4s
# 400:	learn: 1.0848169	test: 1.0968785	best: 1.0968785 (400)	total: 18.3s	remaining: 1m 58s
# 500:	learn: 1.0793762	test: 1.0951794	best: 1.0951794 (500)	total: 22.6s	remaining: 1m 52s
# 600:	learn: 1.0744583	test: 1.0943369	best: 1.0943369 (600)	total: 26.9s	remaining: 1m 47s
# 700:	learn: 1.0698857	test: 1.0937005	best: 1.0937005 (700)	total: 31.3s	remaining: 1m 42s
# 800:	learn: 1.0656706	test: 1.0932280	best: 1.0932280 (800)	total: 35.7s	remaining: 1m 38s
# 900:	learn: 1.0616575	test: 1.0929971	best: 1.0929942 (899)	total: 40.2s	remaining: 1m 33s
# 1000:	learn: 1.0576373	test: 1.0928756	best: 1.0928509 (994)	total: 44.7s	remaining: 1m 29s
# 1100:	learn: 1.0536424	test: 1.0926860	best: 1.0926764 (1099)	total: 49s	remaining: 1m 24s
# 1200:	learn: 1.0498145	test: 1.0927238	best: 1.0926475 (1112)	total: 53.3s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092647501
# bestIteration = 1112
#
# Shrink model to first 1113 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686017	test: 1.3686079	best: 1.3686079 (0)	total: 38.6ms	remaining: 1m 55s
# 100:	learn: 1.1111727	test: 1.1116353	best: 1.1116353 (100)	total: 3.67s	remaining: 1m 45s
# 200:	learn: 1.1037586	test: 1.1051340	best: 1.1051340 (200)	total: 7.42s	remaining: 1m 43s
# 300:	learn: 1.0995668	test: 1.1017929	best: 1.1017929 (300)	total: 11.1s	remaining: 1m 39s
# 400:	learn: 1.0964098	test: 1.0994431	best: 1.0994431 (400)	total: 15s	remaining: 1m 37s
# 500:	learn: 1.0934961	test: 1.0974760	best: 1.0974760 (500)	total: 18.5s	remaining: 1m 32s
# 600:	learn: 1.0911756	test: 1.0961102	best: 1.0961102 (600)	total: 22s	remaining: 1m 27s
# 700:	learn: 1.0891078	test: 1.0950387	best: 1.0950387 (700)	total: 25.6s	remaining: 1m 23s
# 800:	learn: 1.0873764	test: 1.0942991	best: 1.0942991 (800)	total: 29s	remaining: 1m 19s
# 900:	learn: 1.0857998	test: 1.0937931	best: 1.0937931 (900)	total: 32.5s	remaining: 1m 15s
# 1000:	learn: 1.0843830	test: 1.0933396	best: 1.0933396 (1000)	total: 35.9s	remaining: 1m 11s
# 1100:	learn: 1.0829858	test: 1.0929806	best: 1.0929753 (1099)	total: 39.4s	remaining: 1m 7s
# 1200:	learn: 1.0816731	test: 1.0927241	best: 1.0927241 (1200)	total: 43.6s	remaining: 1m 5s
# 1300:	learn: 1.0804651	test: 1.0925424	best: 1.0925424 (1300)	total: 48.4s	remaining: 1m 3s
# 1400:	learn: 1.0792647	test: 1.0923316	best: 1.0923270 (1396)	total: 52.1s	remaining: 59.5s
# 1500:	learn: 1.0781584	test: 1.0922026	best: 1.0922016 (1493)	total: 55.7s	remaining: 55.6s
# 1600:	learn: 1.0770214	test: 1.0919405	best: 1.0919405 (1600)	total: 59.1s	remaining: 51.6s
# 1700:	learn: 1.0759167	test: 1.0918697	best: 1.0918681 (1673)	total: 1m 2s	remaining: 47.6s
# 1800:	learn: 1.0748631	test: 1.0918523	best: 1.0918426 (1794)	total: 1m 5s	remaining: 43.8s
# 1900:	learn: 1.0738358	test: 1.0917712	best: 1.0917712 (1900)	total: 1m 9s	remaining: 40s
# 2000:	learn: 1.0728058	test: 1.0917115	best: 1.0917055 (1968)	total: 1m 12s	remaining: 36.2s
# 2100:	learn: 1.0718471	test: 1.0916852	best: 1.0916733 (2094)	total: 1m 15s	remaining: 32.5s
# 2200:	learn: 1.0708585	test: 1.0916332	best: 1.0916210 (2195)	total: 1m 19s	remaining: 28.8s
# 2300:	learn: 1.0698820	test: 1.0916189	best: 1.0916145 (2216)	total: 1m 22s	remaining: 25.1s
# 2400:	learn: 1.0689714	test: 1.0915696	best: 1.0915696 (2400)	total: 1m 26s	remaining: 21.5s
# 2500:	learn: 1.0680007	test: 1.0915101	best: 1.0915016 (2478)	total: 1m 29s	remaining: 17.9s
# 2600:	learn: 1.0670608	test: 1.0915625	best: 1.0915001 (2509)	total: 1m 33s	remaining: 14.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091500114
# bestIteration = 2509
#
# Shrink model to first 2510 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685318	test: 1.3685747	best: 1.3685747 (0)	total: 50.8ms	remaining: 2m 32s
# 100:	learn: 1.1039753	test: 1.1083950	best: 1.1083950 (100)	total: 5.13s	remaining: 2m 27s
# 200:	learn: 1.0907065	test: 1.1012167	best: 1.1012167 (200)	total: 10.3s	remaining: 2m 22s
# 300:	learn: 1.0817005	test: 1.0978617	best: 1.0978617 (300)	total: 15.4s	remaining: 2m 18s
# 400:	learn: 1.0739707	test: 1.0960048	best: 1.0960048 (400)	total: 20.4s	remaining: 2m 12s
# 500:	learn: 1.0659143	test: 1.0946350	best: 1.0946350 (500)	total: 25.6s	remaining: 2m 7s
# 600:	learn: 1.0581550	test: 1.0937860	best: 1.0937776 (596)	total: 30.9s	remaining: 2m 3s
# 700:	learn: 1.0510240	test: 1.0933897	best: 1.0933788 (694)	total: 35.9s	remaining: 1m 57s
# 800:	learn: 1.0443876	test: 1.0932782	best: 1.0932372 (744)	total: 40.9s	remaining: 1m 52s
# 900:	learn: 1.0377320	test: 1.0931821	best: 1.0931513 (895)	total: 45.8s	remaining: 1m 46s
# 1000:	learn: 1.0312536	test: 1.0931811	best: 1.0930805 (942)	total: 51s	remaining: 1m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093080538
# bestIteration = 942
#
# Shrink model to first 943 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3684240	test: 1.3684957	best: 1.3684957 (0)	total: 63.6ms	remaining: 3m 10s
# 100:	learn: 1.1001968	test: 1.1078081	best: 1.1078081 (100)	total: 6.39s	remaining: 3m 3s
# 200:	learn: 1.0821764	test: 1.1003825	best: 1.1003825 (200)	total: 12.3s	remaining: 2m 50s
# 300:	learn: 1.0693905	test: 1.0977075	best: 1.0977075 (300)	total: 18.2s	remaining: 2m 43s
# 400:	learn: 1.0577963	test: 1.0961415	best: 1.0961415 (400)	total: 24.1s	remaining: 2m 36s
# 500:	learn: 1.0452843	test: 1.0952073	best: 1.0951622 (494)	total: 30.3s	remaining: 2m 31s
# 600:	learn: 1.0336585	test: 1.0946342	best: 1.0946342 (600)	total: 36.5s	remaining: 2m 25s
# 700:	learn: 1.0223469	test: 1.0946537	best: 1.0944364 (635)	total: 42.8s	remaining: 2m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.094436413
# bestIteration = 635
#
# Shrink model to first 636 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686017	test: 1.3686079	best: 1.3686079 (0)	total: 37.8ms	remaining: 1m 53s
# 100:	learn: 1.1111727	test: 1.1116353	best: 1.1116353 (100)	total: 3.74s	remaining: 1m 47s
# 200:	learn: 1.1037586	test: 1.1051340	best: 1.1051340 (200)	total: 7.39s	remaining: 1m 42s
# 300:	learn: 1.0995668	test: 1.1017929	best: 1.1017929 (300)	total: 11s	remaining: 1m 38s
# 400:	learn: 1.0964098	test: 1.0994431	best: 1.0994431 (400)	total: 14.5s	remaining: 1m 34s
# 500:	learn: 1.0934961	test: 1.0974760	best: 1.0974760 (500)	total: 18s	remaining: 1m 29s
# 600:	learn: 1.0911756	test: 1.0961102	best: 1.0961102 (600)	total: 21.6s	remaining: 1m 26s
# 700:	learn: 1.0891078	test: 1.0950387	best: 1.0950387 (700)	total: 25.4s	remaining: 1m 23s
# 800:	learn: 1.0873764	test: 1.0942991	best: 1.0942991 (800)	total: 28.8s	remaining: 1m 19s
# 900:	learn: 1.0857998	test: 1.0937931	best: 1.0937931 (900)	total: 32.2s	remaining: 1m 15s
# 1000:	learn: 1.0843830	test: 1.0933396	best: 1.0933396 (1000)	total: 35.7s	remaining: 1m 11s
# 1100:	learn: 1.0829858	test: 1.0929806	best: 1.0929753 (1099)	total: 39.2s	remaining: 1m 7s
# 1200:	learn: 1.0816731	test: 1.0927241	best: 1.0927241 (1200)	total: 42.6s	remaining: 1m 3s
# 1300:	learn: 1.0804651	test: 1.0925424	best: 1.0925424 (1300)	total: 46s	remaining: 1m
# 1400:	learn: 1.0792647	test: 1.0923316	best: 1.0923270 (1396)	total: 49.4s	remaining: 56.4s
# 1500:	learn: 1.0781584	test: 1.0922026	best: 1.0922016 (1493)	total: 52.9s	remaining: 52.9s
# 1600:	learn: 1.0770214	test: 1.0919405	best: 1.0919405 (1600)	total: 56.8s	remaining: 49.6s
# 1700:	learn: 1.0759167	test: 1.0918697	best: 1.0918681 (1673)	total: 1m	remaining: 46.1s
# 1800:	learn: 1.0748631	test: 1.0918523	best: 1.0918426 (1794)	total: 1m 3s	remaining: 42.4s
# 1900:	learn: 1.0738358	test: 1.0917712	best: 1.0917712 (1900)	total: 1m 7s	remaining: 38.8s
# 2000:	learn: 1.0728058	test: 1.0917115	best: 1.0917055 (1968)	total: 1m 10s	remaining: 35.3s
# 2100:	learn: 1.0718471	test: 1.0916852	best: 1.0916733 (2094)	total: 1m 14s	remaining: 31.7s
# 2200:	learn: 1.0708585	test: 1.0916332	best: 1.0916210 (2195)	total: 1m 17s	remaining: 28.1s
# 2300:	learn: 1.0698820	test: 1.0916189	best: 1.0916145 (2216)	total: 1m 20s	remaining: 24.6s
# 2400:	learn: 1.0689714	test: 1.0915696	best: 1.0915696 (2400)	total: 1m 24s	remaining: 21s
# 2500:	learn: 1.0680007	test: 1.0915101	best: 1.0915016 (2478)	total: 1m 27s	remaining: 17.5s
# 2600:	learn: 1.0670608	test: 1.0915625	best: 1.0915001 (2509)	total: 1m 31s	remaining: 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091500114
# bestIteration = 2509
#
# Shrink model to first 2510 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686018	test: 1.3686046	best: 1.3686046 (0)	total: 43.1ms	remaining: 2m 9s
# 100:	learn: 1.1110547	test: 1.1120728	best: 1.1120728 (100)	total: 4.04s	remaining: 1m 56s
# 200:	learn: 1.1036953	test: 1.1054793	best: 1.1054793 (200)	total: 7.78s	remaining: 1m 48s
# 300:	learn: 1.0995043	test: 1.1020459	best: 1.1020459 (300)	total: 11.3s	remaining: 1m 41s
# 400:	learn: 1.0962499	test: 1.0994867	best: 1.0994867 (400)	total: 14.9s	remaining: 1m 36s
# 500:	learn: 1.0933798	test: 1.0974345	best: 1.0974345 (500)	total: 18.3s	remaining: 1m 31s
# 600:	learn: 1.0910705	test: 1.0960943	best: 1.0960943 (600)	total: 21.7s	remaining: 1m 26s
# 700:	learn: 1.0890514	test: 1.0951701	best: 1.0951701 (700)	total: 25.2s	remaining: 1m 22s
# 800:	learn: 1.0872724	test: 1.0944699	best: 1.0944699 (800)	total: 28.7s	remaining: 1m 18s
# 900:	learn: 1.0857443	test: 1.0939707	best: 1.0939707 (900)	total: 32.1s	remaining: 1m 14s
# 1000:	learn: 1.0843477	test: 1.0935641	best: 1.0935641 (1000)	total: 35.9s	remaining: 1m 11s
# 1100:	learn: 1.0830394	test: 1.0932488	best: 1.0932470 (1099)	total: 39.3s	remaining: 1m 7s
# 1200:	learn: 1.0817988	test: 1.0930555	best: 1.0930542 (1197)	total: 42.7s	remaining: 1m 4s
# 1300:	learn: 1.0806290	test: 1.0928861	best: 1.0928854 (1299)	total: 46.1s	remaining: 1m
# 1400:	learn: 1.0794430	test: 1.0927033	best: 1.0926987 (1397)	total: 49.5s	remaining: 56.5s
# 1500:	learn: 1.0782911	test: 1.0925738	best: 1.0925738 (1500)	total: 53.1s	remaining: 53s
# 1600:	learn: 1.0771878	test: 1.0924551	best: 1.0924494 (1593)	total: 56.8s	remaining: 49.7s
# 1700:	learn: 1.0761529	test: 1.0924077	best: 1.0924017 (1694)	total: 1m	remaining: 46s
# 1800:	learn: 1.0750914	test: 1.0923375	best: 1.0923229 (1763)	total: 1m 3s	remaining: 42.4s
# 1900:	learn: 1.0740703	test: 1.0923052	best: 1.0922959 (1860)	total: 1m 7s	remaining: 39s
# 2000:	learn: 1.0730645	test: 1.0923025	best: 1.0922768 (1922)	total: 1m 10s	remaining: 35.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092276848
# bestIteration = 1922
#
# Shrink model to first 1923 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685995	test: 1.3686067	best: 1.3686067 (0)	total: 45.2ms	remaining: 2m 15s
# 100:	learn: 1.1111648	test: 1.1119013	best: 1.1119013 (100)	total: 3.72s	remaining: 1m 46s
# 200:	learn: 1.1037754	test: 1.1053723	best: 1.1053723 (200)	total: 7.41s	remaining: 1m 43s
# 300:	learn: 1.0996161	test: 1.1019915	best: 1.1019915 (300)	total: 11s	remaining: 1m 39s
# 400:	learn: 1.0963095	test: 1.0993692	best: 1.0993692 (400)	total: 14.7s	remaining: 1m 35s
# 500:	learn: 1.0933897	test: 1.0974066	best: 1.0974066 (500)	total: 18.1s	remaining: 1m 30s
# 600:	learn: 1.0909716	test: 1.0960889	best: 1.0960889 (600)	total: 21.6s	remaining: 1m 26s
# 700:	learn: 1.0890388	test: 1.0950732	best: 1.0950732 (700)	total: 25.1s	remaining: 1m 22s
# 800:	learn: 1.0872795	test: 1.0944401	best: 1.0944399 (797)	total: 28.8s	remaining: 1m 19s
# 900:	learn: 1.0857539	test: 1.0938307	best: 1.0938224 (899)	total: 32.3s	remaining: 1m 15s
# 1000:	learn: 1.0843127	test: 1.0934531	best: 1.0934531 (1000)	total: 35.8s	remaining: 1m 11s
# 1100:	learn: 1.0829383	test: 1.0931255	best: 1.0931198 (1098)	total: 39.2s	remaining: 1m 7s
# 1200:	learn: 1.0816752	test: 1.0927963	best: 1.0927963 (1200)	total: 42.6s	remaining: 1m 3s
# 1300:	learn: 1.0804554	test: 1.0925176	best: 1.0925176 (1300)	total: 46.1s	remaining: 1m
# 1400:	learn: 1.0792992	test: 1.0923784	best: 1.0923784 (1400)	total: 49.6s	remaining: 56.6s
# 1500:	learn: 1.0781715	test: 1.0922027	best: 1.0922027 (1500)	total: 52.9s	remaining: 52.8s
# 1600:	learn: 1.0770561	test: 1.0920859	best: 1.0920770 (1596)	total: 56.3s	remaining: 49.2s
# 1700:	learn: 1.0759920	test: 1.0920110	best: 1.0919903 (1681)	total: 1m	remaining: 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091990283
# bestIteration = 1681
#
# Shrink model to first 1682 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686125	test: 1.3686137	best: 1.3686137 (0)	total: 38.5ms	remaining: 1m 55s
# 100:	learn: 1.1107743	test: 1.1116693	best: 1.1116693 (100)	total: 3.76s	remaining: 1m 47s
# 200:	learn: 1.1033972	test: 1.1054185	best: 1.1054185 (200)	total: 7.4s	remaining: 1m 43s
# 300:	learn: 1.0990997	test: 1.1021411	best: 1.1021411 (300)	total: 11s	remaining: 1m 38s
# 400:	learn: 1.0957724	test: 1.0998689	best: 1.0998689 (400)	total: 14.6s	remaining: 1m 34s
# 500:	learn: 1.0929505	test: 1.0981777	best: 1.0981755 (499)	total: 18s	remaining: 1m 30s
# 600:	learn: 1.0906166	test: 1.0969250	best: 1.0969250 (600)	total: 21.5s	remaining: 1m 25s
# 700:	learn: 1.0885863	test: 1.0961238	best: 1.0961238 (700)	total: 25.1s	remaining: 1m 22s
# 800:	learn: 1.0868611	test: 1.0955720	best: 1.0955702 (799)	total: 28.9s	remaining: 1m 19s
# 900:	learn: 1.0852845	test: 1.0951148	best: 1.0951148 (900)	total: 32.4s	remaining: 1m 15s
# 1000:	learn: 1.0838643	test: 1.0948387	best: 1.0948387 (1000)	total: 35.9s	remaining: 1m 11s
# 1100:	learn: 1.0824891	test: 1.0945358	best: 1.0945294 (1096)	total: 39.4s	remaining: 1m 7s
# 1200:	learn: 1.0812144	test: 1.0943462	best: 1.0943462 (1200)	total: 42.8s	remaining: 1m 4s
# 1300:	learn: 1.0799173	test: 1.0941409	best: 1.0941409 (1300)	total: 46.3s	remaining: 1m
# 1400:	learn: 1.0787158	test: 1.0940161	best: 1.0940115 (1395)	total: 49.8s	remaining: 56.9s
# 1500:	learn: 1.0775476	test: 1.0939113	best: 1.0939105 (1499)	total: 53.3s	remaining: 53.2s
# 1600:	learn: 1.0763783	test: 1.0938595	best: 1.0938405 (1539)	total: 56.7s	remaining: 49.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093840464
# bestIteration = 1539
#
# Shrink model to first 1540 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3686149	test: 1.3686138	best: 1.3686138 (0)	total: 33.8ms	remaining: 1m 41s
# 100:	learn: 1.1110957	test: 1.1119629	best: 1.1119629 (100)	total: 3.75s	remaining: 1m 47s
# 200:	learn: 1.1034795	test: 1.1053439	best: 1.1053439 (200)	total: 7.36s	remaining: 1m 42s
# 300:	learn: 1.0993127	test: 1.1020174	best: 1.1020174 (300)	total: 11.2s	remaining: 1m 40s
# 400:	learn: 1.0960086	test: 1.0995311	best: 1.0995311 (400)	total: 14.6s	remaining: 1m 34s
# 500:	learn: 1.0931336	test: 1.0977074	best: 1.0977074 (500)	total: 18.1s	remaining: 1m 30s
# 600:	learn: 1.0908295	test: 1.0963434	best: 1.0963434 (600)	total: 21.6s	remaining: 1m 26s
# 700:	learn: 1.0888698	test: 1.0954507	best: 1.0954507 (700)	total: 25.1s	remaining: 1m 22s
# 800:	learn: 1.0871675	test: 1.0948057	best: 1.0948057 (800)	total: 28.5s	remaining: 1m 18s
# 900:	learn: 1.0856323	test: 1.0942876	best: 1.0942876 (900)	total: 32.3s	remaining: 1m 15s
# 1000:	learn: 1.0841548	test: 1.0938979	best: 1.0938952 (998)	total: 35.8s	remaining: 1m 11s
# 1100:	learn: 1.0828214	test: 1.0936206	best: 1.0936129 (1099)	total: 39.2s	remaining: 1m 7s
# 1200:	learn: 1.0815543	test: 1.0934426	best: 1.0934324 (1188)	total: 42.7s	remaining: 1m 3s
# 1300:	learn: 1.0802770	test: 1.0932748	best: 1.0932745 (1292)	total: 46.1s	remaining: 1m
# 1400:	learn: 1.0790744	test: 1.0931847	best: 1.0931847 (1400)	total: 49.6s	remaining: 56.6s
# 1500:	learn: 1.0779731	test: 1.0930058	best: 1.0930058 (1500)	total: 53s	remaining: 52.9s
# 1600:	learn: 1.0768929	test: 1.0929620	best: 1.0929382 (1582)	total: 56.5s	remaining: 49.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092938247
# bestIteration = 1582
#
# Shrink model to first 1583 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Time left 11397.990141868591
# Layer 1 training completed.
#
#
# Layer 2 ...
# Train process start. Time left 11397.880434274673 secs
# Start fitting Lvl_1_Pipe_0_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09312
# [200]	valid's multi_logloss: 1.09426
# [300]	valid's multi_logloss: 1.09531
# Early stopping, best iteration is:
# [121]	valid's multi_logloss: 1.0931
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09324
# [200]	valid's multi_logloss: 1.09392
# [300]	valid's multi_logloss: 1.09482
# Early stopping, best iteration is:
# [102]	valid's multi_logloss: 1.09316
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09275
# [200]	valid's multi_logloss: 1.0937
# [300]	valid's multi_logloss: 1.09495
# Early stopping, best iteration is:
# [101]	valid's multi_logloss: 1.09274
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09561
# [200]	valid's multi_logloss: 1.09672
# Early stopping, best iteration is:
# [93]	valid's multi_logloss: 1.09546
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09342
# [200]	valid's multi_logloss: 1.09393
# [300]	valid's multi_logloss: 1.09522
# Early stopping, best iteration is:
# [108]	valid's multi_logloss: 1.09331
# Lvl_1_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_0_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3673609	test: 1.3673573	best: 1.3673573 (0)	total: 68.2ms	remaining: 3m 24s
# 100:	learn: 1.0922740	test: 1.0939790	best: 1.0939790 (100)	total: 5.42s	remaining: 2m 35s
# 200:	learn: 1.0868968	test: 1.0918284	best: 1.0918111 (191)	total: 10.3s	remaining: 2m 22s
# 300:	learn: 1.0833670	test: 1.0917799	best: 1.0916632 (251)	total: 14.9s	remaining: 2m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09166319
# bestIteration = 251
#
# Shrink model to first 252 iterations.
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3673641	test: 1.3673621	best: 1.3673621 (0)	total: 62.4ms	remaining: 3m 7s
# 100:	learn: 1.0924133	test: 1.0941739	best: 1.0941739 (100)	total: 5.07s	remaining: 2m 25s
# 200:	learn: 1.0869929	test: 1.0920042	best: 1.0919978 (194)	total: 9.87s	remaining: 2m 17s
# 300:	learn: 1.0835785	test: 1.0920480	best: 1.0919029 (252)	total: 14.6s	remaining: 2m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091902883
# bestIteration = 252
#
# Shrink model to first 253 iterations.
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3673537	test: 1.3673649	best: 1.3673649 (0)	total: 93.7ms	remaining: 4m 40s
# 100:	learn: 1.0923889	test: 1.0942917	best: 1.0942917 (100)	total: 5.28s	remaining: 2m 31s
# 200:	learn: 1.0869803	test: 1.0922321	best: 1.0922321 (200)	total: 10.5s	remaining: 2m 26s
# 300:	learn: 1.0836320	test: 1.0922383	best: 1.0922077 (210)	total: 15.1s	remaining: 2m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092207736
# bestIteration = 210
#
# Shrink model to first 211 iterations.
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3674759	test: 1.3675459	best: 1.3675459 (0)	total: 62.4ms	remaining: 3m 6s
# 100:	learn: 1.0919718	test: 1.0955656	best: 1.0955656 (100)	total: 5.12s	remaining: 2m 27s
# 200:	learn: 1.0865366	test: 1.0938027	best: 1.0938027 (200)	total: 9.86s	remaining: 2m 17s
# 300:	learn: 1.0831148	test: 1.0939701	best: 1.0937962 (225)	total: 14.6s	remaining: 2m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093796199
# bestIteration = 225
#
# Shrink model to first 226 iterations.
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3674962	test: 1.3674667	best: 1.3674667 (0)	total: 59.2ms	remaining: 2m 57s
# 100:	learn: 1.0920660	test: 1.0958386	best: 1.0958386 (100)	total: 5.52s	remaining: 2m 38s
# 200:	learn: 1.0868046	test: 1.0936456	best: 1.0936456 (200)	total: 10.5s	remaining: 2m 25s
# 300:	learn: 1.0834750	test: 1.0935150	best: 1.0935015 (299)	total: 15.2s	remaining: 2m 16s
# 400:	learn: 1.0799843	test: 1.0936233	best: 1.0934523 (318)	total: 19.9s	remaining: 2m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093452301
# bestIteration = 318
#
# Shrink model to first 319 iterations.
# Lvl_1_Pipe_0_Mod_1_CatBoost fitting and predicting completed
# Time left 11148.155514240265
# Blending: Optimization starts with equal weights and score -1.0926700774629827
# Blending, iter 0: score = -1.0925325657749947, weights = [0.20960213 0.7903979 ]
# Blending, iter 1: score = -1.0925325657749947, weights = [0.20960213 0.7903979 ]
# No score update. Terminated
#
# Automl preset training completed in 1452.85 seconds.
# Current random state: {'reader_params': {'random_state': 43}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 43}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'cb_tuned', 'lgb_tuned'], ['cb', 'lgb']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 11147.108330249786 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (99918, 101)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 11100.864838123322 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1117167051798038
# Linear model: C = 5e-05 score = -1.1085991058364404
# Linear model: C = 0.0001 score = -1.1082463611560085
# Linear model: C = 0.0005 score = -1.108292694123025
# Linear model: C = 0.001 score = -1.1082955894945525
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.111130851388777
# Linear model: C = 5e-05 score = -1.107176972216098
# Linear model: C = 0.0001 score = -1.1065031489994142
# Linear model: C = 0.0005 score = -1.106189867788799
# Linear model: C = 0.001 score = -1.1062197944736951
# Linear model: C = 0.005 score = -1.1062843893908914
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1106682796735134
# Linear model: C = 5e-05 score = -1.1062008732313915
# Linear model: C = 0.0001 score = -1.1054333197094612
# Linear model: C = 0.0005 score = -1.1049027224298749
# Linear model: C = 0.001 score = -1.1049022913624862
# Linear model: C = 0.005 score = -1.1049360607163883
# Linear model: C = 0.01 score = -1.1049360607163883
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1117118953501195
# Linear model: C = 5e-05 score = -1.108320870534833
# Linear model: C = 0.0001 score = -1.107802952884858
# Linear model: C = 0.0005 score = -1.107553608863554
# Linear model: C = 0.001 score = -1.1075779204641096
# Linear model: C = 0.005 score = -1.1075801917230654
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1111552311375126
# Linear model: C = 5e-05 score = -1.1075655594427103
# Linear model: C = 0.0001 score = -1.1070827603830815
# Linear model: C = 0.0005 score = -1.1070633940754762
# Linear model: C = 0.001 score = -1.1071449938595
# Linear model: C = 0.005 score = -1.1072582359047425
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 11085.090988874435
# Start fitting Selector_LightGBM ...
#
# ===== Start working with fold 0 for Selector_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.1
# [200]	valid's multi_logloss: 1.09647
# [300]	valid's multi_logloss: 1.09609
# [400]	valid's multi_logloss: 1.09652
# Early stopping, best iteration is:
# [297]	valid's multi_logloss: 1.09606
# Selector_LightGBM fitting and predicting completed
# Optuna may run 1739.7889700312362 secs
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.0996
# [200]	valid's multi_logloss: 1.09887
# [300]	valid's multi_logloss: 1.10088
# Early stopping, best iteration is:
# [153]	valid's multi_logloss: 1.09851
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09902
# [200]	valid's multi_logloss: 1.0976
# [300]	valid's multi_logloss: 1.09902
# [400]	valid's multi_logloss: 1.10137
# Early stopping, best iteration is:
# [216]	valid's multi_logloss: 1.09741
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10003
# [200]	valid's multi_logloss: 1.09652
# [300]	valid's multi_logloss: 1.09622
# [400]	valid's multi_logloss: 1.09668
# Early stopping, best iteration is:
# [265]	valid's multi_logloss: 1.096
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09967
# [200]	valid's multi_logloss: 1.09627
# [300]	valid's multi_logloss: 1.09612
# [400]	valid's multi_logloss: 1.09682
# Early stopping, best iteration is:
# [265]	valid's multi_logloss: 1.096
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10004
# [200]	valid's multi_logloss: 1.09882
# [300]	valid's multi_logloss: 1.10047
# Early stopping, best iteration is:
# [175]	valid's multi_logloss: 1.09864
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09813
# [200]	valid's multi_logloss: 1.09782
# Early stopping, best iteration is:
# [125]	valid's multi_logloss: 1.09743
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09715
# [200]	valid's multi_logloss: 1.09685
# Early stopping, best iteration is:
# [155]	valid's multi_logloss: 1.09621
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09796
# [200]	valid's multi_logloss: 1.09803
# Early stopping, best iteration is:
# [156]	valid's multi_logloss: 1.09722
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09899
# [200]	valid's multi_logloss: 1.09904
# Early stopping, best iteration is:
# [129]	valid's multi_logloss: 1.09846
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09812
# [200]	valid's multi_logloss: 1.09879
# Early stopping, best iteration is:
# [118]	valid's multi_logloss: 1.09775
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 4723.910841083526 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685908	test: 1.3685882	best: 1.3685882 (0)	total: 49.8ms	remaining: 2m 29s
# 100:	learn: 1.1095755	test: 1.1107114	best: 1.1107114 (100)	total: 4.19s	remaining: 2m
# 200:	learn: 1.1011278	test: 1.1039008	best: 1.1039008 (200)	total: 8.54s	remaining: 1m 58s
# 300:	learn: 1.0963579	test: 1.1006700	best: 1.1006700 (300)	total: 12.7s	remaining: 1m 53s
# 400:	learn: 1.0925295	test: 1.0983045	best: 1.0983045 (400)	total: 16.7s	remaining: 1m 48s
# 500:	learn: 1.0891041	test: 1.0965799	best: 1.0965789 (499)	total: 21s	remaining: 1m 44s
# 600:	learn: 1.0862040	test: 1.0954795	best: 1.0954795 (600)	total: 25s	remaining: 1m 39s
# 700:	learn: 1.0837625	test: 1.0946932	best: 1.0946932 (700)	total: 29s	remaining: 1m 35s
# 800:	learn: 1.0815210	test: 1.0940539	best: 1.0940539 (800)	total: 33s	remaining: 1m 30s
# 900:	learn: 1.0795526	test: 1.0936959	best: 1.0936882 (898)	total: 37s	remaining: 1m 26s
# 1000:	learn: 1.0776759	test: 1.0935167	best: 1.0935167 (1000)	total: 41.1s	remaining: 1m 22s
# 1100:	learn: 1.0757919	test: 1.0934325	best: 1.0934278 (1099)	total: 45.1s	remaining: 1m 17s
# 1200:	learn: 1.0741156	test: 1.0932859	best: 1.0932753 (1194)	total: 49.1s	remaining: 1m 13s
# 1300:	learn: 1.0724863	test: 1.0931692	best: 1.0931622 (1297)	total: 53.4s	remaining: 1m 9s
# 1400:	learn: 1.0709832	test: 1.0929951	best: 1.0929951 (1400)	total: 57.3s	remaining: 1m 5s
# 1500:	learn: 1.0693397	test: 1.0929224	best: 1.0929214 (1498)	total: 1m 1s	remaining: 1m 1s
# 1600:	learn: 1.0677672	test: 1.0928984	best: 1.0928528 (1541)	total: 1m 5s	remaining: 57s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092852791
# bestIteration = 1541
#
# Shrink model to first 1542 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685499	test: 1.3685656	best: 1.3685656 (0)	total: 47.6ms	remaining: 2m 22s
# 100:	learn: 1.1069064	test: 1.1092357	best: 1.1092357 (100)	total: 4.71s	remaining: 2m 15s
# 200:	learn: 1.0965945	test: 1.1022918	best: 1.1022918 (200)	total: 9.34s	remaining: 2m 10s
# 300:	learn: 1.0901312	test: 1.0990960	best: 1.0990960 (300)	total: 13.9s	remaining: 2m 4s
# 400:	learn: 1.0846386	test: 1.0972416	best: 1.0972416 (400)	total: 18.8s	remaining: 2m 1s
# 500:	learn: 1.0792767	test: 1.0955218	best: 1.0955197 (499)	total: 23.1s	remaining: 1m 55s
# 600:	learn: 1.0743206	test: 1.0946820	best: 1.0946820 (600)	total: 27.6s	remaining: 1m 50s
# 700:	learn: 1.0697402	test: 1.0941557	best: 1.0941557 (700)	total: 32.1s	remaining: 1m 45s
# 800:	learn: 1.0654669	test: 1.0938764	best: 1.0938689 (788)	total: 36.8s	remaining: 1m 41s
# 900:	learn: 1.0612665	test: 1.0936565	best: 1.0936363 (892)	total: 41.7s	remaining: 1m 37s
# 1000:	learn: 1.0572415	test: 1.0935188	best: 1.0935140 (996)	total: 46.2s	remaining: 1m 32s
# 1100:	learn: 1.0535102	test: 1.0934594	best: 1.0934557 (1090)	total: 51s	remaining: 1m 27s
# 1200:	learn: 1.0497816	test: 1.0933201	best: 1.0933169 (1199)	total: 55.4s	remaining: 1m 23s
# 1300:	learn: 1.0460665	test: 1.0933051	best: 1.0932477 (1291)	total: 59.8s	remaining: 1m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093247656
# bestIteration = 1291
#
# Shrink model to first 1292 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685739	test: 1.3685697	best: 1.3685697 (0)	total: 40.7ms	remaining: 2m 2s
# 100:	learn: 1.1111640	test: 1.1117423	best: 1.1117423 (100)	total: 3.65s	remaining: 1m 44s
# 200:	learn: 1.1036357	test: 1.1051012	best: 1.1051012 (200)	total: 7.39s	remaining: 1m 42s
# 300:	learn: 1.0995009	test: 1.1018070	best: 1.1018070 (300)	total: 11.1s	remaining: 1m 39s
# 400:	learn: 1.0962290	test: 1.0994379	best: 1.0994379 (400)	total: 14.8s	remaining: 1m 35s
# 500:	learn: 1.0933506	test: 1.0976076	best: 1.0976076 (500)	total: 18.6s	remaining: 1m 32s
# 600:	learn: 1.0909070	test: 1.0963622	best: 1.0963622 (600)	total: 22.3s	remaining: 1m 28s
# 700:	learn: 1.0888905	test: 1.0954854	best: 1.0954854 (700)	total: 25.9s	remaining: 1m 24s
# 800:	learn: 1.0871222	test: 1.0948916	best: 1.0948916 (800)	total: 29.4s	remaining: 1m 20s
# 900:	learn: 1.0855483	test: 1.0944118	best: 1.0944090 (897)	total: 33s	remaining: 1m 16s
# 1000:	learn: 1.0840806	test: 1.0941212	best: 1.0941188 (990)	total: 36.6s	remaining: 1m 13s
# 1100:	learn: 1.0827133	test: 1.0938107	best: 1.0937940 (1086)	total: 40.2s	remaining: 1m 9s
# 1200:	learn: 1.0814296	test: 1.0936016	best: 1.0935876 (1196)	total: 43.8s	remaining: 1m 5s
# 1300:	learn: 1.0802467	test: 1.0934052	best: 1.0934036 (1297)	total: 47.3s	remaining: 1m 1s
# 1400:	learn: 1.0790979	test: 1.0932916	best: 1.0932858 (1390)	total: 51.1s	remaining: 58.3s
# 1500:	learn: 1.0779742	test: 1.0931960	best: 1.0931960 (1500)	total: 54.8s	remaining: 54.7s
# 1600:	learn: 1.0768285	test: 1.0931371	best: 1.0931150 (1586)	total: 58.3s	remaining: 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09311496
# bestIteration = 1586
#
# Shrink model to first 1587 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3684907	test: 1.3685166	best: 1.3685166 (0)	total: 54.3ms	remaining: 2m 42s
# 100:	learn: 1.1037683	test: 1.1082821	best: 1.1082821 (100)	total: 5.27s	remaining: 2m 31s
# 200:	learn: 1.0906291	test: 1.1013422	best: 1.1013422 (200)	total: 10.7s	remaining: 2m 28s
# 300:	learn: 1.0819819	test: 1.0982757	best: 1.0982757 (300)	total: 15.8s	remaining: 2m 21s
# 400:	learn: 1.0742096	test: 1.0964728	best: 1.0964728 (400)	total: 22.9s	remaining: 2m 28s
# 500:	learn: 1.0663200	test: 1.0950077	best: 1.0950077 (500)	total: 29.6s	remaining: 2m 27s
# 600:	learn: 1.0586579	test: 1.0944387	best: 1.0944387 (600)	total: 34.9s	remaining: 2m 19s
# 700:	learn: 1.0513592	test: 1.0941866	best: 1.0941619 (696)	total: 40.1s	remaining: 2m 11s
# 800:	learn: 1.0445182	test: 1.0940200	best: 1.0939875 (795)	total: 45.3s	remaining: 2m 4s
# 900:	learn: 1.0379313	test: 1.0938838	best: 1.0938325 (882)	total: 50.5s	remaining: 1m 57s
# 1000:	learn: 1.0315089	test: 1.0937941	best: 1.0937635 (988)	total: 56.1s	remaining: 1m 51s
# 1100:	learn: 1.0250760	test: 1.0936563	best: 1.0935740 (1067)	total: 1m 1s	remaining: 1m 45s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093574042
# bestIteration = 1067
#
# Shrink model to first 1068 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3684709	test: 1.3685086	best: 1.3685086 (0)	total: 66.3ms	remaining: 3m 18s
# 100:	learn: 1.0998324	test: 1.1078012	best: 1.1078012 (100)	total: 6.21s	remaining: 2m 58s
# 200:	learn: 1.0818633	test: 1.1006668	best: 1.1006668 (200)	total: 12.5s	remaining: 2m 54s
# 300:	learn: 1.0690148	test: 1.0979993	best: 1.0979993 (300)	total: 18.7s	remaining: 2m 47s
# 400:	learn: 1.0576897	test: 1.0962150	best: 1.0962150 (400)	total: 25s	remaining: 2m 42s
# 500:	learn: 1.0454204	test: 1.0950282	best: 1.0950183 (498)	total: 31.3s	remaining: 2m 35s
# 600:	learn: 1.0337385	test: 1.0945055	best: 1.0945055 (600)	total: 37.4s	remaining: 2m 29s
# 700:	learn: 1.0221204	test: 1.0943351	best: 1.0942702 (659)	total: 43.7s	remaining: 2m 23s
# 800:	learn: 1.0109354	test: 1.0941417	best: 1.0940592 (758)	total: 50s	remaining: 2m 17s
# 900:	learn: 1.0004449	test: 1.0941842	best: 1.0940520 (858)	total: 56.7s	remaining: 2m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.094052038
# bestIteration = 858
#
# Shrink model to first 859 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685908	test: 1.3685882	best: 1.3685882 (0)	total: 43.8ms	remaining: 2m 11s
# 100:	learn: 1.1095755	test: 1.1107114	best: 1.1107114 (100)	total: 4.28s	remaining: 2m 2s
# 200:	learn: 1.1011278	test: 1.1039008	best: 1.1039008 (200)	total: 8.61s	remaining: 1m 59s
# 300:	learn: 1.0963579	test: 1.1006700	best: 1.1006700 (300)	total: 12.8s	remaining: 1m 54s
# 400:	learn: 1.0925295	test: 1.0983045	best: 1.0983045 (400)	total: 16.8s	remaining: 1m 49s
# 500:	learn: 1.0891041	test: 1.0965799	best: 1.0965789 (499)	total: 20.9s	remaining: 1m 44s
# 600:	learn: 1.0862040	test: 1.0954795	best: 1.0954795 (600)	total: 24.9s	remaining: 1m 39s
# 700:	learn: 1.0837625	test: 1.0946932	best: 1.0946932 (700)	total: 29.2s	remaining: 1m 35s
# 800:	learn: 1.0815210	test: 1.0940539	best: 1.0940539 (800)	total: 33.2s	remaining: 1m 31s
# 900:	learn: 1.0795526	test: 1.0936959	best: 1.0936882 (898)	total: 37.3s	remaining: 1m 26s
# 1000:	learn: 1.0776759	test: 1.0935167	best: 1.0935167 (1000)	total: 41.3s	remaining: 1m 22s
# 1100:	learn: 1.0757919	test: 1.0934325	best: 1.0934278 (1099)	total: 45.3s	remaining: 1m 18s
# 1200:	learn: 1.0741156	test: 1.0932859	best: 1.0932753 (1194)	total: 49.2s	remaining: 1m 13s
# 1300:	learn: 1.0724863	test: 1.0931692	best: 1.0931622 (1297)	total: 53.2s	remaining: 1m 9s
# 1400:	learn: 1.0709832	test: 1.0929951	best: 1.0929951 (1400)	total: 57.1s	remaining: 1m 5s
# 1500:	learn: 1.0693397	test: 1.0929224	best: 1.0929214 (1498)	total: 1m 1s	remaining: 1m 1s
# 1600:	learn: 1.0677672	test: 1.0928984	best: 1.0928528 (1541)	total: 1m 5s	remaining: 57.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092852791
# bestIteration = 1541
#
# Shrink model to first 1542 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685855	test: 1.3685945	best: 1.3685945 (0)	total: 44ms	remaining: 2m 11s
# ...
# 500:	learn: 1.0888208	test: 1.0972182	best: 1.0972182 (500)	total: 21.3s	remaining: 1m 46s
# 600:	learn: 1.0860278	test: 1.0959837	best: 1.0959837 (600)	total: 25.3s	remaining: 1m 40s
# 700:	learn: 1.0836404	test: 1.0951770	best: 1.0951770 (700)	total: 29.7s	remaining: 1m 37s
# 800:	learn: 1.0814587	test: 1.0946482	best: 1.0946482 (800)	total: 33.7s	remaining: 1m 32s
# 900:	learn: 1.0793974	test: 1.0942154	best: 1.0942112 (899)	total: 37.7s	remaining: 1m 27s
# 1000:	learn: 1.0775513	test: 1.0938617	best: 1.0938617 (1000)	total: 41.7s	remaining: 1m 23s
# 1100:	learn: 1.0757517	test: 1.0936560	best: 1.0936560 (1100)	total: 45.7s	remaining: 1m 18s
# 1200:	learn: 1.0740385	test: 1.0934272	best: 1.0934272 (1200)	total: 51.3s	remaining: 1m 16s
# 1300:	learn: 1.0723835	test: 1.0932298	best: 1.0932298 (1300)	total: 56.7s	remaining: 1m 14s
# 1400:	learn: 1.0707362	test: 1.0930722	best: 1.0930721 (1398)	total: 1m 1s	remaining: 1m 10s
# 1500:	learn: 1.0691841	test: 1.0929372	best: 1.0929198 (1490)	total: 1m 5s	remaining: 1m 5s
# 1600:	learn: 1.0676631	test: 1.0928685	best: 1.0928455 (1584)	total: 1m 9s	remaining: 1m 1s
# 1700:	learn: 1.0661427	test: 1.0928223	best: 1.0928169 (1696)	total: 1m 13s	remaining: 56.4s
# 1800:	learn: 1.0646622	test: 1.0927819	best: 1.0927819 (1800)	total: 1m 17s	remaining: 51.8s
# 1900:	learn: 1.0631745	test: 1.0927068	best: 1.0927068 (1900)	total: 1m 21s	remaining: 47.3s
# 2000:	learn: 1.0617639	test: 1.0926978	best: 1.0926829 (1954)	total: 1m 25s	remaining: 42.8s
# 2100:	learn: 1.0604092	test: 1.0926389	best: 1.0926389 (2100)	total: 1m 30s	remaining: 38.6s
# 2200:	learn: 1.0590696	test: 1.0927151	best: 1.0926252 (2105)	total: 1m 34s	remaining: 34.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092625237
# bestIteration = 2105
#
# Shrink model to first 2106 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685950	test: 1.3685930	best: 1.3685930 (0)	total: 42.2ms	remaining: 2m 6s
# 100:	learn: 1.1095628	test: 1.1101162	best: 1.1101162 (100)	total: 4.31s	remaining: 2m 3s
# 200:	learn: 1.1010578	test: 1.1028672	best: 1.1028672 (200)	total: 8.81s	remaining: 2m 2s
# 300:	learn: 1.0962625	test: 1.0993902	best: 1.0993902 (300)	total: 13s	remaining: 1m 56s
# 400:	learn: 1.0925253	test: 1.0970631	best: 1.0970631 (400)	total: 17.2s	remaining: 1m 51s
# 500:	learn: 1.0891233	test: 1.0952451	best: 1.0952451 (500)	total: 21.2s	remaining: 1m 45s
# 600:	learn: 1.0863390	test: 1.0940946	best: 1.0940946 (600)	total: 25.1s	remaining: 1m 40s
# 700:	learn: 1.0838391	test: 1.0933575	best: 1.0933575 (700)	total: 29.6s	remaining: 1m 36s
# 800:	learn: 1.0817003	test: 1.0928122	best: 1.0928122 (800)	total: 33.9s	remaining: 1m 32s
# 900:	learn: 1.0797451	test: 1.0924053	best: 1.0924053 (900)	total: 37.9s	remaining: 1m 28s
# 1000:	learn: 1.0778362	test: 1.0920410	best: 1.0920355 (999)	total: 41.9s	remaining: 1m 23s
# 1100:	learn: 1.0761021	test: 1.0917637	best: 1.0917637 (1100)	total: 45.9s	remaining: 1m 19s
# 1200:	learn: 1.0744109	test: 1.0915276	best: 1.0915220 (1197)	total: 49.8s	remaining: 1m 14s
# 1300:	learn: 1.0726776	test: 1.0913489	best: 1.0913421 (1299)	total: 53.8s	remaining: 1m 10s
# 1400:	learn: 1.0710698	test: 1.0912072	best: 1.0912072 (1400)	total: 57.8s	remaining: 1m 5s
# 1500:	learn: 1.0694518	test: 1.0911373	best: 1.0911373 (1500)	total: 1m 2s	remaining: 1m 2s
# 1600:	learn: 1.0678854	test: 1.0910261	best: 1.0910194 (1598)	total: 1m 6s	remaining: 58.1s
# 1700:	learn: 1.0663827	test: 1.0909467	best: 1.0909467 (1700)	total: 1m 10s	remaining: 53.8s
# 1800:	learn: 1.0649405	test: 1.0909466	best: 1.0909206 (1707)	total: 1m 14s	remaining: 49.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.090920578
# bestIteration = 1707
#
# Shrink model to first 1708 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685911	test: 1.3685910	best: 1.3685910 (0)	total: 39.3ms	remaining: 1m 57s
# 100:	learn: 1.1091086	test: 1.1106325	best: 1.1106325 (100)	total: 4.26s	remaining: 2m 2s
# 200:	learn: 1.1006561	test: 1.1038955	best: 1.1038955 (200)	total: 8.59s	remaining: 1m 59s
# 300:	learn: 1.0960902	test: 1.1007602	best: 1.1007602 (300)	total: 12.7s	remaining: 1m 53s
# 400:	learn: 1.0923721	test: 1.0984808	best: 1.0984808 (400)	total: 16.9s	remaining: 1m 49s
# 500:	learn: 1.0889883	test: 1.0966401	best: 1.0966401 (500)	total: 21.6s	remaining: 1m 47s
# 600:	learn: 1.0861532	test: 1.0954911	best: 1.0954911 (600)	total: 25.6s	remaining: 1m 42s
# 700:	learn: 1.0838089	test: 1.0946701	best: 1.0946701 (700)	total: 29.6s	remaining: 1m 37s
# 800:	learn: 1.0815669	test: 1.0941437	best: 1.0941437 (800)	total: 33.6s	remaining: 1m 32s
# 900:	learn: 1.0795030	test: 1.0935416	best: 1.0935416 (900)	total: 37.5s	remaining: 1m 27s
# 1000:	learn: 1.0776013	test: 1.0932311	best: 1.0932202 (985)	total: 41.5s	remaining: 1m 22s
# 1100:	learn: 1.0757733	test: 1.0929880	best: 1.0929827 (1094)	total: 45.5s	remaining: 1m 18s
# 1200:	learn: 1.0740797	test: 1.0927798	best: 1.0927766 (1199)	total: 49.6s	remaining: 1m 14s
# 1300:	learn: 1.0723810	test: 1.0926479	best: 1.0926263 (1291)	total: 54.3s	remaining: 1m 10s
# 1400:	learn: 1.0707327	test: 1.0924581	best: 1.0924581 (1400)	total: 58.3s	remaining: 1m 6s
# 1500:	learn: 1.0691542	test: 1.0923620	best: 1.0923580 (1499)	total: 1m 2s	remaining: 1m 2s
# 1600:	learn: 1.0676221	test: 1.0922990	best: 1.0922856 (1594)	total: 1m 6s	remaining: 58s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092285596
# bestIteration = 1594
#
# Shrink model to first 1595 iterations.
# Lvl_0_Pipe_1_Mod_1_CatBoost fitting and predicting completed
# Time left 866.1479117870331
# Layer 1 training completed.
#
#
# Layer 2 ...
# Train process start. Time left 866.0342309474945 secs
# Start fitting Lvl_1_Pipe_0_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09933
# [200]	valid's multi_logloss: 1.09502
# [300]	valid's multi_logloss: 1.09433
# [400]	valid's multi_logloss: 1.09457
# [500]	valid's multi_logloss: 1.09489
# Early stopping, best iteration is:
# [305]	valid's multi_logloss: 1.09428
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10004
# [200]	valid's multi_logloss: 1.09642
# [300]	valid's multi_logloss: 1.09599
# [400]	valid's multi_logloss: 1.09648
# Early stopping, best iteration is:
# [274]	valid's multi_logloss: 1.09584
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10076
# [200]	valid's multi_logloss: 1.09665
# [300]	valid's multi_logloss: 1.09578
# [400]	valid's multi_logloss: 1.09647
# Early stopping, best iteration is:
# [276]	valid's multi_logloss: 1.09573
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09986
# [200]	valid's multi_logloss: 1.09596
# [300]	valid's multi_logloss: 1.09517
# [400]	valid's multi_logloss: 1.09546
# [500]	valid's multi_logloss: 1.09629
# Early stopping, best iteration is:
# [307]	valid's multi_logloss: 1.09509
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.10063
# [200]	valid's multi_logloss: 1.0971
# [300]	valid's multi_logloss: 1.097
# [400]	valid's multi_logloss: 1.09745
# Early stopping, best iteration is:
# [240]	valid's multi_logloss: 1.09664
# Lvl_1_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_0_Mod_1_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685880	test: 1.3686036	best: 1.3686036 (0)	total: 48.4ms	remaining: 2m 25s
# 100:	learn: 1.1069585	test: 1.1090186	best: 1.1090186 (100)	total: 5.23s	remaining: 2m 30s
# 200:	learn: 1.0966446	test: 1.1017925	best: 1.1017925 (200)	total: 10.1s	remaining: 2m 20s
# 300:	learn: 1.0902981	test: 1.0985064	best: 1.0985064 (300)	total: 14.6s	remaining: 2m 10s
# 400:	learn: 1.0848418	test: 1.0963272	best: 1.0963272 (400)	total: 19.2s	remaining: 2m 4s
# 500:	learn: 1.0794440	test: 1.0946834	best: 1.0946834 (500)	total: 24.5s	remaining: 2m 2s
# 600:	learn: 1.0745004	test: 1.0938588	best: 1.0938588 (600)	total: 29.1s	remaining: 1m 55s
# 700:	learn: 1.0700265	test: 1.0931967	best: 1.0931869 (698)	total: 33.6s	remaining: 1m 50s
# 800:	learn: 1.0657952	test: 1.0928255	best: 1.0928045 (796)	total: 38s	remaining: 1m 44s
# 900:	learn: 1.0615072	test: 1.0926867	best: 1.0926383 (884)	total: 42.5s	remaining: 1m 39s
# 1000:	learn: 1.0575211	test: 1.0924583	best: 1.0924554 (999)	total: 47s	remaining: 1m 33s
# 1100:	learn: 1.0536001	test: 1.0922524	best: 1.0922524 (1100)	total: 51.9s	remaining: 1m 29s
# 1200:	learn: 1.0498455	test: 1.0921531	best: 1.0921382 (1198)	total: 56.9s	remaining: 1m 25s
# 1300:	learn: 1.0460584	test: 1.0921441	best: 1.0920589 (1258)	total: 1m 1s	remaining: 1m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092058892
# bestIteration = 1258
#
# Shrink model to first 1259 iterations.
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685873	test: 1.3686057	best: 1.3686057 (0)	total: 45.7ms	remaining: 2m 16s
# 100:	learn: 1.1068260	test: 1.1098126	best: 1.1098126 (100)	total: 4.72s	remaining: 2m 15s
# 200:	learn: 1.0963372	test: 1.1027649	best: 1.1027649 (200)	total: 9.35s	remaining: 2m 10s
# 300:	learn: 1.0898052	test: 1.0994092	best: 1.0994092 (300)	total: 13.9s	remaining: 2m 4s
# 400:	learn: 1.0843165	test: 1.0974040	best: 1.0974040 (400)	total: 18.6s	remaining: 2m
# 500:	learn: 1.0788670	test: 1.0959535	best: 1.0959336 (499)	total: 23.6s	remaining: 1m 57s
# 600:	learn: 1.0737554	test: 1.0951140	best: 1.0951096 (599)	total: 28s	remaining: 1m 51s
# 700:	learn: 1.0691539	test: 1.0946444	best: 1.0946376 (697)	total: 32.3s	remaining: 1m 46s
# 800:	learn: 1.0648298	test: 1.0943516	best: 1.0943496 (798)	total: 36.7s	remaining: 1m 40s
# 900:	learn: 1.0606549	test: 1.0941966	best: 1.0941926 (899)	total: 41s	remaining: 1m 35s
# 1000:	learn: 1.0566877	test: 1.0942723	best: 1.0941288 (966)	total: 45.5s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.094128821
# bestIteration = 966
#
# Shrink model to first 967 iterations.
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685882	test: 1.3686084	best: 1.3686084 (0)	total: 46.2ms	remaining: 2m 18s
# 100:	learn: 1.1065645	test: 1.1100129	best: 1.1100129 (100)	total: 5.15s	remaining: 2m 27s
# 200:	learn: 1.0961380	test: 1.1032678	best: 1.1032678 (200)	total: 10.3s	remaining: 2m 23s
# 300:	learn: 1.0897656	test: 1.1002299	best: 1.1002299 (300)	total: 14.8s	remaining: 2m 13s
# 400:	learn: 1.0844454	test: 1.0978981	best: 1.0978981 (400)	total: 19.3s	remaining: 2m 4s
# 500:	learn: 1.0790990	test: 1.0963243	best: 1.0963243 (500)	total: 23.8s	remaining: 1m 58s
# 600:	learn: 1.0741207	test: 1.0953536	best: 1.0953536 (600)	total: 28.2s	remaining: 1m 52s
# 700:	learn: 1.0696670	test: 1.0946476	best: 1.0946476 (700)	total: 32.8s	remaining: 1m 47s
# 800:	learn: 1.0654320	test: 1.0942566	best: 1.0942234 (798)	total: 37.3s	remaining: 1m 42s
# 900:	learn: 1.0614352	test: 1.0939557	best: 1.0939521 (894)	total: 42.1s	remaining: 1m 38s
# 1000:	learn: 1.0574720	test: 1.0937420	best: 1.0937354 (998)	total: 46.4s	remaining: 1m 32s
# 1100:	learn: 1.0535263	test: 1.0935438	best: 1.0935346 (1097)	total: 50.8s	remaining: 1m 27s
# 1200:	learn: 1.0496709	test: 1.0935238	best: 1.0934646 (1129)	total: 56.1s	remaining: 1m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093464563
# bestIteration = 1129
#
# Shrink model to first 1130 iterations.
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685241	test: 1.3685579	best: 1.3685579 (0)	total: 55.9ms	remaining: 2m 47s
# 100:	learn: 1.1073084	test: 1.1093896	best: 1.1093896 (100)	total: 5.38s	remaining: 2m 34s
# 200:	learn: 1.0966923	test: 1.1017177	best: 1.1017177 (200)	total: 10.3s	remaining: 2m 23s
# 300:	learn: 1.0901755	test: 1.0980604	best: 1.0980604 (300)	total: 14.8s	remaining: 2m 12s
# 400:	learn: 1.0849208	test: 1.0958514	best: 1.0958514 (400)	total: 19.6s	remaining: 2m 7s
# 500:	learn: 1.0794842	test: 1.0942994	best: 1.0942994 (500)	total: 24s	remaining: 1m 59s
# 600:	learn: 1.0745912	test: 1.0934095	best: 1.0934095 (600)	total: 28.5s	remaining: 1m 53s
# 700:	learn: 1.0700423	test: 1.0928816	best: 1.0928796 (699)	total: 32.9s	remaining: 1m 47s
# 800:	learn: 1.0657384	test: 1.0925195	best: 1.0925171 (796)	total: 37.2s	remaining: 1m 42s
# 900:	learn: 1.0616326	test: 1.0922237	best: 1.0922228 (899)	total: 42s	remaining: 1m 37s
# 1000:	learn: 1.0576021	test: 1.0920129	best: 1.0920113 (998)	total: 46.4s	remaining: 1m 32s
# 1100:	learn: 1.0537575	test: 1.0919059	best: 1.0919059 (1100)	total: 51.5s	remaining: 1m 28s
# 1200:	learn: 1.0499373	test: 1.0918007	best: 1.0917997 (1193)	total: 55.9s	remaining: 1m 23s
# 1300:	learn: 1.0462092	test: 1.0917258	best: 1.0917152 (1297)	total: 1m	remaining: 1m 18s
# 1400:	learn: 1.0426194	test: 1.0916068	best: 1.0916068 (1400)	total: 1m 4s	remaining: 1m 13s
# 1500:	learn: 1.0391275	test: 1.0915513	best: 1.0915321 (1481)	total: 1m 9s	remaining: 1m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091532103
# bestIteration = 1481
#
# Shrink model to first 1482 iterations.
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_1_CatBoost =====
#
# 0:	learn: 1.3685267	test: 1.3685362	best: 1.3685362 (0)	total: 42.7ms	remaining: 2m 7s
# 100:	learn: 1.1073257	test: 1.1101432	best: 1.1101432 (100)	total: 4.6s	remaining: 2m 11s
# 200:	learn: 1.0963205	test: 1.1027607	best: 1.1027607 (200)	total: 9.7s	remaining: 2m 15s
# 300:	learn: 1.0898775	test: 1.0994965	best: 1.0994965 (300)	total: 14.2s	remaining: 2m 7s
# 400:	learn: 1.0843632	test: 1.0974717	best: 1.0974717 (400)	total: 18.9s	remaining: 2m 2s
# 500:	learn: 1.0789550	test: 1.0959369	best: 1.0959369 (500)	total: 23.6s	remaining: 1m 57s
# 600:	learn: 1.0740586	test: 1.0948125	best: 1.0948125 (600)	total: 28s	remaining: 1m 51s
# 700:	learn: 1.0694340	test: 1.0942322	best: 1.0942168 (699)	total: 32.5s	remaining: 1m 46s
# 800:	learn: 1.0652184	test: 1.0938515	best: 1.0938515 (800)	total: 37.2s	remaining: 1m 42s
# 900:	learn: 1.0611045	test: 1.0935788	best: 1.0935788 (900)	total: 42s	remaining: 1m 37s
# 1000:	learn: 1.0570455	test: 1.0934740	best: 1.0934664 (998)	total: 46.3s	remaining: 1m 32s
# 1100:	learn: 1.0531449	test: 1.0932894	best: 1.0932706 (1089)	total: 50.8s	remaining: 1m 27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093270595
# bestIteration = 1089
#
# Shrink model to first 1090 iterations.
# Lvl_1_Pipe_0_Mod_1_CatBoost fitting and predicting completed
# Time left 309.8928852081299
# Blending: Optimization starts with equal weights and score -1.0933444222131532
# Blending, iter 0: score = -1.0928421724415354, weights = [0.11772826 0.88227177]
# Blending, iter 1: score = -1.0928421724415354, weights = [0.11772826 0.88227177]
# No score update. Terminated
#
# Automl preset training completed in 1703.46 seconds.
# Blending: Optimization starts with equal weights and score -1.09167780528278
# Blending, iter 0: score = -1.09153903576755, weights = [0.27835706 0.         0.09886371 0.11161028 0.26704898 0.14006504
#  0.10405494]
# Blending, iter 1: score = -1.0915347574997798, weights = [0.23319413 0.         0.10674538 0.12399632 0.30942786 0.12796707
#  0.09866925]
# Blending, iter 2: score = -1.091534077368954, weights = [0.2253163  0.         0.12088787 0.13641715 0.30791533 0.11953504
#  0.08992831]
# Blending, iter 3: score = -1.0915339788436418, weights = [0.22874475 0.         0.12286264 0.14094578 0.30127507 0.11893399
#  0.08723778]
# Blending, iter 4: score = -1.0915339592727997, weights = [0.23182143 0.         0.12128954 0.14058197 0.2988169  0.12022459
#  0.08726559]
#
#
# y_pred_meta_lama: (99918, 4)

# %%
oof_score = log_loss(Ytrain_oh, y_pred_meta_lama.data)
print("Aggregate OOF Score: {}".format(oof_score))
# Out:
# Aggregate OOF Score: 1.0915339592727997

# %%
y_pred_final_lama = model.predict(test_df)

# %%
np.savez_compressed('./LAMA_Meta_Features.npz',
                    y_pred_meta_lama=y_pred_meta_lama.data, 
                    oof_score=oof_score,
                    y_pred_final_lama=y_pred_final_lama.data)

# %% [markdown]
# ## Create submission file

# %%
test_df = pd.read_csv("../input/tabular-playground-series-may-2021/test.csv")
submit_df = pd.DataFrame()
submit_df['id'] = test_df['id']
submit_df['Class_1'] = y_pred_final_lama.data[:,0]
submit_df['Class_2'] = y_pred_final_lama.data[:,1]
submit_df['Class_3'] = y_pred_final_lama.data[:,2]
submit_df['Class_4'] = y_pred_final_lama.data[:,3]
submit_df.head()
# Out:
#        id   Class_1   Class_2   Class_3   Class_4
# 0  100000  0.093282  0.621752  0.163495  0.121472
# 1  100001  0.089292  0.667576  0.148231  0.094901
# 2  100002  0.085493  0.613204  0.196380  0.104923
# 3  100003  0.085608  0.517825  0.295891  0.100676
# 4  100004  0.077717  0.624484  0.179608  0.118191

# %%
submit_df.to_csv("./LAMA_submission.csv", index=False)
